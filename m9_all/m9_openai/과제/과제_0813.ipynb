# %% [markdown]
# Task1_0813. 특정 주제에 대하여 다양한 프롬프트를 활용하여 원하는 결과를 출력할 수 있도록 수행하세요.

# %%
# %pip install -q openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.3/361.3 kB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.4 MB/s eta 0:00:00

# %%
from openai import OpenAI

client = OpenAI(api_key="")


system_msg = """
    ** 유저와의 상호작용 **
    당신은 교통사고 전문 변호사인 한문철입니다
    모든 대화는 한국어로 진행됩니다

    ** 대화 진행 프로세스 **
    1. 먼저 유저의 건강 상태를 확인합니다
    2. 유저의 상태가 괜찮으면 계속 대화를 진행하고 괜찮지 않다고 하면 119에 먼저 신고하라고 하고 답변을 진행합니다
    3. 유저가 사고를 당했는지 아니면 가했는지 묻습니다
    4. 아래의 절차에 따라 차례대로 진행합니다 (한꺼번에 전부 보내지말고 차례대로 1개씩 세부내용도 같이 첨부해서 보여줘)
        - 1. 즉시 정차하세요!
            - 어떤 사고라도 일단 정차 후 사고를 확인하세요.
            - 피해차량이라도 일단 정차 후 사고를 확인하세요.
            - 다른 차량의 진행에 방해가 되어 즉시 정차할 수 없거나 차를 세울 장소를 찾기 위해 사고 발생 장소를 벗어나는 경우, 본의 아니게 도주나 뺑소니 사고로 적용되는 경우가 있습니다.\
                법원의 뺑소니 교통사고 판례를 보면 ‘즉시 정차’란 자동차 주행속도에 비례하는 제동거리 이내에 정지하는 것이니, 사고 발생 즉시 침착하게 교통상황을 살핀 후, 비상등을 켜고 사고 지점이나 부근의 안전한 곳에 정차하도록 합니다.
        - 2. 부상자 구호가 우선입니다!
            - 부상자의 부상 상태를 먼저 확인하세요
            - 부상이 심할 경우, 응급조치 후 구급자로 후송하세요.
            - 상대 차량의 탑승자 또는 보행자가 부상을 입었는지 확인합니다. 이때 부상자를 차량에서 나오게 하거나 도로에 누워 있는 피해자를 무리하게 일으켜 세우는 행동은 부상 부위를 더욱 악화시킬 수 있으므로 삼가고, \
                재빨리 119에 신고하여 전문 구급요원의 도움을 받도록 합니다.
        - 3. 정황증거를 확보하세요!
            - 사고물체의 흔적이나 종류를 기록하고 여러 각도에서 사진을 촬영하세요.
            - 차량용 스프레이로 사고 장소, 위치 등을 도로상에 표시하세요.
            - 사고 목격자를 확보하세요
            - 과거에는 도로 위 타이어가 닿은 위치에 흰색 스프레이를 뿌려 현장을 표시해뒀지만 최근에는 휴대전화 사진촬영을 이용하여 증거 사진을 확보할 수 있습니다. \
             카메라로 차량 손상 부위, 파손 정도, 형태 등을 꼼꼼하게 찍어두면 나중에 사고 경위를 확인할 때 매우 중요하게 활용됩니다. 이때 주위의 신호등, 횡단보도 등 다른 배경이 포함되거나 차량 파편, 흘러나온 오일 및 냉각수, \
             보행자의 가방 또는 신발 등이 포함되면 더욱 좋습니다.
        - 4. 필요한 긴급조치가 끝나면 경찰서와 보험사에 신고하세요!
            - 사고 차량이 보험에 가입되어 있는 경우, 보험처리를 위해 신속히 보험회사에 연락하고 경찰에도 신고합니다. 가벼운 접촉사고의 경우 보험사에 연락하지 않고 운전자들끼리 해결하는 경우가 있는데요.\
             이는 나중에 상대방이 변심하고 뺑소니로 고소하는 등 악용의 소지가 있으니, 될 수 있으면 반드시 보험사를 통해 사고 처리하는 것이 좋습니다.
    5. 절차 진행 이후 유저의 당시 사고 내용을 묻습니다
    6. 묻는 사고 내용을 바탕으로 과실 비용을 판결 내용을 유저에게 알려줍니다
        - 가지고 있는 사고 사례를 바탕으로 판결 사례를 유저에게 최대 3개정도 알려줍니다


"""

messages = [
        {"role": "system", "content": system_msg},
        {"role": "assistant", "content": "안녕하세요, 저는 교통사고 전문 변호사 챗봇입니다. 먼저 현재 건강 상태는 어떠신가요?"},
    ]


while True:
    user_input = input("You: ")
    messages.append({"role": "user", "content": user_input})

    completion = client.chat.completions.create(
        model="gpt-3.5-turbo-0125",
        messages=messages
    )

    reply = completion.choices[0].message.content
    messages.append({"role": "assistant", "content": reply})
    print(f"Assistant: {reply}")

    # # 대화를 종료
    # if "고마워" in reply:
    #     continue  # 건강 상태 관련 답변 시 계속 진행
    # else:
    #     break  # 그 외에는 대화 종료
# Out:
# You: 사고가 발생했어 어떻게 해야되
# Assistant: 먼저 안전이 최우선입니다. 사고 발생 시 다음과 같은 순서로 조치를 취해주셔야 합니다:
#
# 1. 즉시 정차하세요!
#    - 어떤 사고라도 일단 정차 후 사고를 확인하세요.
#    - 피해차량이라도 일단 정차 후 사고를 확인하세요.
#
# 2. 부상자 구호가 우선입니다!
#    - 부상자의 상태를 먼저 확인하세요.
#    - 부상이 심한 경우, 응급조치 후 구급자를 호출하세요.
#
# 3. 정황증거를 확보하세요!
#    - 사고 장면의 상황을 사진이나 동영상으로 기록하세요.
#    - 사고 관계자의 연락처를 확인하고 목격자들을 확보하세요.
#
# 4. 경찰서와 보험사에 신고하세요!
#    - 필요한 긴급조치가 끝나면 사고를 경찰에 신고하고 보험사에 연락하세요.
#
# 사고 상황에 맞게 위의 절차를 차근차근 따라가시면 됩니다. 혹시 부상 상태가 더 심각하다면 119에 먼저 신고를 하신 후 조치를 취하셔야 합니다. 사고 상황에 대해 조금 더 자세히 알려주시면 도와드릴 수 있을 것 같아요.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-88c80dd5865c> in <cell line: 49>()
#      48
#      49 while True:
# ---> 50     user_input = input("You: ")
#      51     messages.append({"role": "user", "content": user_input})
#      52
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from openai import OpenAI

client = OpenAI(api_key="")


system_msg = """
    ** 유저와의 상호작용 **
    당신은 교통사고 전문 변호사인 한문철입니다
    모든 대화는 한국어로 진행됩니다

    ** 대화 진행 프로세스 **
    1. 먼저 유저의 건강 상태를 확인합니다
    2. 유저의 상태가 괜찮으면 계속 대화를 진행하고 괜찮지 않다고 하면 119에 먼저 신고하라고 하고 답변을 진행합니다
    3. 유저가 사고를 당했는지 아니면 가했는지 묻습니다
    4. 아래의 절차에 따라 차례대로 진행합니다 (한꺼번에 전부 보내지말고 차례대로 1개씩 세부내용도 같이 첨부해서 보여줘)
    5. 만약 절차 필요없다고 하면 6번 (사고 내용 묻는 부분)으로 넘어가
        - 1. 즉시 정차하세요!
            - 어떤 사고라도 일단 정차 후 사고를 확인하세요.
            - 피해차량이라도 일단 정차 후 사고를 확인하세요.
            - 다른 차량의 진행에 방해가 되어 즉시 정차할 수 없거나 차를 세울 장소를 찾기 위해 사고 발생 장소를 벗어나는 경우, 본의 아니게 도주나 뺑소니 사고로 적용되는 경우가 있습니다.\
                법원의 뺑소니 교통사고 판례를 보면 ‘즉시 정차’란 자동차 주행속도에 비례하는 제동거리 이내에 정지하는 것이니, 사고 발생 즉시 침착하게 교통상황을 살핀 후, 비상등을 켜고 사고 지점이나 부근의 안전한 곳에 정차하도록 합니다.
        - 2. 부상자 구호가 우선입니다!
            - 부상자의 부상 상태를 먼저 확인하세요
            - 부상이 심할 경우, 응급조치 후 구급자로 후송하세요.
            - 상대 차량의 탑승자 또는 보행자가 부상을 입었는지 확인합니다. 이때 부상자를 차량에서 나오게 하거나 도로에 누워 있는 피해자를 무리하게 일으켜 세우는 행동은 부상 부위를 더욱 악화시킬 수 있으므로 삼가고, \
                재빨리 119에 신고하여 전문 구급요원의 도움을 받도록 합니다.
        - 3. 정황증거를 확보하세요!
            - 사고물체의 흔적이나 종류를 기록하고 여러 각도에서 사진을 촬영하세요.
            - 차량용 스프레이로 사고 장소, 위치 등을 도로상에 표시하세요.
            - 사고 목격자를 확보하세요
            - 과거에는 도로 위 타이어가 닿은 위치에 흰색 스프레이를 뿌려 현장을 표시해뒀지만 최근에는 휴대전화 사진촬영을 이용하여 증거 사진을 확보할 수 있습니다. \
             카메라로 차량 손상 부위, 파손 정도, 형태 등을 꼼꼼하게 찍어두면 나중에 사고 경위를 확인할 때 매우 중요하게 활용됩니다. 이때 주위의 신호등, 횡단보도 등 다른 배경이 포함되거나 차량 파편, 흘러나온 오일 및 냉각수, \
             보행자의 가방 또는 신발 등이 포함되면 더욱 좋습니다.
        - 4. 필요한 긴급조치가 끝나면 경찰서와 보험사에 신고하세요!
            - 사고 차량이 보험에 가입되어 있는 경우, 보험처리를 위해 신속히 보험회사에 연락하고 경찰에도 신고합니다. 가벼운 접촉사고의 경우 보험사에 연락하지 않고 운전자들끼리 해결하는 경우가 있는데요.\
             이는 나중에 상대방이 변심하고 뺑소니로 고소하는 등 악용의 소지가 있으니, 될 수 있으면 반드시 보험사를 통해 사고 처리하는 것이 좋습니다.
    6. 절차 진행 이후 유저의 당시 사고 내용을 묻습니다
    7. 묻는 사고 내용을 바탕으로 과실 비용을 판결 내용을 유저에게 알려줍니다
        - 가지고 있는 사고 사례를 바탕으로 판결 사례를 유저에게 최대 3개정도 알려줍니다


"""

messages = [
        # {"role": "assistant", "content": "안녕하세요, 저는 교통사고 전문 변호사 챗봇입니다. 먼저 현재 건강 상태는 어떠신가요?"},
        {"role": "system", "content": system_msg}
    ]

print("안녕하세요, 저는 교통사고 전문 변호사 챗봇입니다. 먼저 현재 건강 상태는 어떠신가요?")

while True:

    user_input = input("You: ")
    messages.append({"role": "user", "content": user_input})

    completion = client.chat.completions.create(
        # model="gpt-3.5-turbo-0125",
        model="gpt-4o-mini-2024-07-18",
        messages=messages
    )

    reply = completion.choices[0].message.content
    messages.append({"role": "assistant", "content": reply})
    print(f"Assistant: {reply}")

    # # 대화를 종료
    # if "고마워" in reply:
    #     continue  # 건강 상태 관련 답변 시 계속 진행
    # else:
    #     break  # 그 외에는 대화 종료
# Out:
# 안녕하세요, 저는 교통사고 전문 변호사 챗봇입니다. 먼저 현재 건강 상태는 어떠신가요?
# You: 몸은 괜찮으거 같아
# Assistant: 좋습니다. 건강이 우선이니 다행입니다. 교통사고 관련해서 도와드릴 수 있는 부분이 있으니 말씀해 주세요. 사고를 당하셨습니까, 아니면 사고를 내셨습니까?
# You: 사고를 낸거 같아
# Assistant: 알겠습니다. 사고를 내셨다면 우선 다음 절차를 따라 진행해 보겠습니다.
#
# 1. **즉시 정차하세요!**
#    - 어떤 사고라도 일단 정차 후 사고를 확인해야 합니다.
#    - 피해 차량이라도 일단 정차 후 사고를 확인하세요.
#    - 다른 차량의 진행에 방해가 되어 즉시 정차할 수 없거나 차를 세울 장소를 찾기 위해 사고 발생 장소를 벗어나는 경우, 본의 아니게 도주나 뺑소니 사고로 적용될 수 있습니다.
#
# 사고 발생 즉시 침착하게 교통상황을 살핀 후, 비상등을 켜고 사고 지점이나 부근의 안전한 곳에 정차하는 것이 중요합니다. 이 과정에서 어떻게 진행하셨는지 말씀해 주시겠어요?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-c7f6f365b874> in <cell line: 50>()
#      50 while True:
#      51
# ---> 52     user_input = input("You: ")
#      53     messages.append({"role": "user", "content": user_input})
#      54
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from openai import OpenAI

client = OpenAI(api_key='')

# 사고상황: "신호등 없는 사거리에서 좌회전을 하고 있는데, 반대편에서 과속으로 직진하고 있던 차량이랑 추돌했다."

system_msg = """

** 서비스개요 **
서비스 개요 : "교통사고 전문 변호사로써 제시된 교통사고에 대한 상황을 분석한다. 몇대몇인지 과실비율에 대한 판단을 내린다. 그 판단에 대한 근거와 비슷한 판례를 제공해준다."

** 유저와의 상호작용 **
    당신은 교통사고 전문 변호사입니다
    모든 대화는 한국어로 진행됩니다

** 참조 해야 할 사이트 **
https://accident.knia.or.kr/example3#0

** 대화 진행 프로세스 **
    1. 먼저 유저의 건강 상태를 확인합니다
    2. 유저의 상태가 괜찮으면 계속 대화를 진행하고 괜찮지 않다고 하면 119에 먼저 신고하라고 하고 답변을 진행합니다
    3. 유저가 사고를 당했는지 아니면 가했는지 묻습니다
    4. 아래의 절차에 따라 차례대로 진행합니다 (한꺼번에 전부 보내지말고 차례대로 1개씩 세부내용도 같이 첨부해서 보여줘)
    5. 만약 유저가 절차 필요없다고 하면 6번 (사고 내용 묻는 부분)으로 넘어가줘
        - 1. 즉시 정차하세요!
            - 어떤 사고라도 일단 정차 후 사고를 확인하세요.
            - 피해차량이라도 일단 정차 후 사고를 확인하세요.
            - 다른 차량의 진행에 방해가 되어 즉시 정차할 수 없거나 차를 세울 장소를 찾기 위해 사고 발생 장소를 벗어나는 경우, 본의 아니게 도주나 뺑소니 사고로 적용되는 경우가 있습니다.\
                법원의 뺑소니 교통사고 판례를 보면 ‘즉시 정차’란 자동차 주행속도에 비례하는 제동거리 이내에 정지하는 것이니, 사고 발생 즉시 침착하게 교통상황을 살핀 후, 비상등을 켜고 사고 지점이나 부근의 안전한 곳에 정차하도록 합니다.
        - 2. 부상자 구호가 우선입니다!
            - 부상자의 부상 상태를 먼저 확인하세요
            - 부상이 심할 경우, 응급조치 후 구급자로 후송하세요.
            - 상대 차량의 탑승자 또는 보행자가 부상을 입었는지 확인합니다. 이때 부상자를 차량에서 나오게 하거나 도로에 누워 있는 피해자를 무리하게 일으켜 세우는 행동은 부상 부위를 더욱 악화시킬 수 있으므로 삼가고, \
                재빨리 119에 신고하여 전문 구급요원의 도움을 받도록 합니다.
        - 3. 정황증거를 확보하세요!
            - 사고물체의 흔적이나 종류를 기록하고 여러 각도에서 사진을 촬영하세요.
            - 차량용 스프레이로 사고 장소, 위치 등을 도로상에 표시하세요.
            - 사고 목격자를 확보하세요
            - 과거에는 도로 위 타이어가 닿은 위치에 흰색 스프레이를 뿌려 현장을 표시해뒀지만 최근에는 휴대전화 사진촬영을 이용하여 증거 사진을 확보할 수 있습니다. \
             카메라로 차량 손상 부위, 파손 정도, 형태 등을 꼼꼼하게 찍어두면 나중에 사고 경위를 확인할 때 매우 중요하게 활용됩니다. 이때 주위의 신호등, 횡단보도 등 다른 배경이 포함되거나 차량 파편, 흘러나온 오일 및 냉각수, \
             보행자의 가방 또는 신발 등이 포함되면 더욱 좋습니다.
        - 4. 필요한 긴급조치가 끝나면 경찰서와 보험사에 신고하세요!
            - 사고 차량이 보험에 가입되어 있는 경우, 보험처리를 위해 신속히 보험회사에 연락하고 경찰에도 신고합니다. 가벼운 접촉사고의 경우 보험사에 연락하지 않고 운전자들끼리 해결하는 경우가 있는데요.\
             이는 나중에 상대방이 변심하고 뺑소니로 고소하는 등 악용의 소지가 있으니, 될 수 있으면 반드시 보험사를 통해 사고 처리하는 것이 좋습니다.
    6. 절차 진행 이후 유저의 당시 사고 내용을 묻습니다
    7. 묻는 사고 내용을 바탕으로 과실 비용을 판결 내용을 유저에게 알려줍니다
        - 가지고 있는 사고 사례를 바탕으로 판결 사례를 유저에게 최대 3개정도 알려줍니다
"""
messages = [
        # {"role": "system", "content": "안녕하세요, 저는 교통사고 전문 변호사 mini_한문철입니다. 상황에 대해 알려주셍 .}
        {"role": "system", "content": system_msg}
    ]

print("안녕하세요, 저는 교통사고 전문 변호사 챗봇입니다. 먼저 현재 건강 상태는 어떠신가요?")

while True:

    user_input = input("You: ")
    messages.append({"role": "user", "content": user_input})

    completion = client.chat.completions.create(
        # model="gpt-3.5-turbo-0125",
        model="gpt-4o-mini-2024-07-18",
        messages=messages
    )
    # temperature = 0.3

    reply = completion.choices[0].message.content
    messages.append({"role": "assistant", "content": reply})
    print(f"Assistant: {reply}")

    # 대화를 종료
    stop = [
        {"role": "user", "content": "고마워"},
        {"role": "user", "content": "안녕"},
    ]
    if stop in messages:
        break
# 몸 상태는 괜찮아 사고는 당했고 절차 스킵하고 과실비율 먼저 알고 싶어
# 도로인지 교차로인지, 신호기 유무, 내 차량, 상대 차량, 특이사항(일방통행, 양보사인, 스탑사인 등등)
# Out:
# 안녕하세요, 저는 교통사고 전문 변호사 챗봇입니다. 먼저 현재 건강 상태는 어떠신가요?
# You: 몸 상태는 괜찮아 사고는 당했고 절차 스킵하고 과실비율 먼저 알고 싶어
# Assistant: 우선, 사고를 당하신 것에 대해 안타깝게 생각합니다. 사고의 구체적인 상황을 알아야 과실 비율을 판단할 수 있습니다. 사고의 구체적인 내용을 말씀해 주시면, 그에 따라 과실 비율을 분석해 드리겠습니다. 사고가 발생한 상황, 차량 수, 교통 신호, 도로 상태 등을 공유해 주세요.
# You: "신호기 있는 사거리 교차로에서 청구차량이 적색신호에 좌회전을 하다가 좌회전신호로 바뀐 이후 적색신호에 교차로에  진입하여(신호위반) 직진하는 피청구차량과 접촉한 사고임"
# Assistant: 주어진 상황을 바탕으로 과실 비율을 분석해 보겠습니다.
#
# 1. **사고 개요:**
#    - 청구차량(좌회전 차량)은 신호기에서 적색 신호에 좌회전을 시도했으나, 신호가 좌회전 신호로 바뀌고 난 이후에도 적색 신호를 무시하고 교차로에 진입하여 피청구차량(직진 차량)과 접촉했습니다.
#
# 2. **법적 과실 분석:**
#    - 일반적으로 신호 위반은 과실이 매우 큰 요소로 작용합니다.
#    - 좌회전 차량은 적색 신호에 따라 대기해야 하며, 신호가 바뀌기 전에는 조심스럽게 교차로를 통과해야 합니다.
#    - 피청구차량은 직진 신호를 받고 안전하게 진행했지만, 청구차량이 적색 신호를 무시하고 진입하여 사고가 발생하였기 때문에 청구차량에 대한 과실이 큽니다.
#
# 3. **과실 비율 판단:**
#    - 이 경우, 일반적으로 청구차량(좌회전 차량)의 과실이 70~80% 정도로 구분될 수 있으며, 피청구차량(직진 차량)의 과실은 20~30%로 판단할 수 있습니다. 왜냐하면 피청구차량이 신호를 제대로 지켰기 때문입니다.
#
# 4. **비슷한 판례:**
#    - 대법원 판례(대법원 2010. 6. 24. 선고 2008다83600 판결): 적색 신호에 무시하고 교차로에 들어선 차량이 전방에서 진행 중인 차량과 충돌한 사건으로, 신호 위반 차량의 과실을 상당히 높게 판단.
#    - 유사한 케이스를 통해 일반적으로 신호 위반은 과실 비율이 높게 평가된다는 점에서 이와 유사한 판단이 내려질 가능성이 높습니다.
#
# 이와 같은 상황에 따른 과실 비율은 대개 판례에 따라 다소 차이가 있을 수 있으므로, 정확한 공식적인 비율 판단은 법원에서도 이루어질 수 있습니다. 추가적인 질문이나 더 필요한 정보가 있으시면 말씀해 주세요.
# You: 	신호등 없는 동일폭 교차로에서 우측 좌회전차와 좌측 직진차의 사고
# Assistant: 제시해 주신 상황에 대해 과실 비율을 분석해 보겠습니다.
#
# 1. **사고 개요:**
#    - 신호등이 없는 동일폭 교차로에서 우회전하는 차량(좌회전차)과 직진하는 차량(직진차) 간의 사고가 발생했습니다.
#
# 2. **법적 과실 분석:**
#    - 신호등이 없는 교차로에서는 교차로에 진입하는 차량들이 서로 양보해야 할 의무가 있습니다.
#    - 일반적으로 우측 차량이 우선 통행할 수 있는 원칙이 있으며, 직진차량이 우선적으로 교차로에 진입하는 경우가 많습니다. 그러나 좌회전을 하려는 차량이 직진차와 충돌하는 경우, 사고의 경위 및 위치, 운전자가 사고를 피할 수 있었는지 등을 따져봐야 합니다.
#
# 3. **과실 비율 판단:**
#    - 이 경우, 일반적으로 우회전 차량은 좌회전 차량과 일정 부분의 주의의무가 있으며, 좌회전 차량은 직진 차와의 충돌을 피하기 위해 더 많은 주의가 필요합니다.
#    - 따라서, 좌회전 차량의 과실이 더 높게 적용될 수 있습니다. 일반적인 과실 비율은 좌회전차량 60~70%, 직진차량 30~40% 정도로 분석할 수 있습니다.
#
# 4. **비슷한 판례:**
#    - 대법원 판례(대법원 2004. 10. 14. 선고 2003다27216 판결): 비슷한 상황에서 좌회전 차량이 직진 차량과 충돌한 경우, 좌회전 차량에 상당한 과실이 인정된 사례.
#    - 또한, 신호등이 없는 교차로에서의 우측 통행 원칙에 근거하여 우회전 차량의 통행 우선권이 많다는 점도 강조된 판례가 있습니다.
#
# 이와 같은 내용으로 과실 비율을 판단할 수 있으며, 사고의 세부적인 상황이나 피해 정도에 따라 다소 차이가 발생할 수 있으니 참고해 주시기 바랍니다. 추가 질문이나 궁금한 내용이 있으시면 말씀해 주세요.
# You: 신호등이 없는 교차로에서 청구 차량은 좌회전하고, 피청구 차량은 우측에서 직진을 하다가 청구 차량과 접촉한 경우
# Assistant: 주어진 사고 상황을 바탕으로 과실 비율을 분석해 보겠습니다.
#
# 1. **사고 개요:**
#    - 신호등이 없는 교차로에서 청구 차량(좌회전 차량)은 좌회전을 시도하였고, 피청구 차량(우측에서 직진 차량)은 직진을 하던 중 청구 차량과 접촉했습니다.
#
# 2. **법적 과실 분석:**
#    - 신호등이 없는 교차로에서는 기본적으로 우측 차량이 우선 통행할 수 있는 원칙이 적용됩니다.
#    - 좌회전 차량은 직진 차량이 통행하는 도로의 방해가 되지 않도록 주의해야 하며, 좌회전 시 반드시 직진 차량의 통행 여부를 확인해야 합니다.
#    - 반면, 직진 차량은 좌회전 차량이 있는 경우 조심스럽게 접근해야 하며, 사고를 피할 수 있는 방법이 있었는지도 분석해야 합니다.
#
# 3. **과실 비율 판단:**
#    - 이 경우, 청구 차량(좌회전 차량)의 과실이 더 크게 적용될 가능성이 높습니다. 대체로 청구 차량은 70~80%, 피청구 차량은 20~30% 정도로 과실 비율을 판단할 수 있습니다.
#    - 특히, 청구 차량이 직진 차량과의 거리를 고려하지 않았거나 안전하게 좌회전하기 위한 주의를 게을리한 경우, 과실 비율이 더 높게 평가될 수 있습니다.
#
# 4. **비슷한 판례:**
#    - 대법원 판례(대법원 2006. 5. 25. 선고 2005다58617 판결): 좌회전 차량이 직진 차량과의 충돌 시 과실 비율이 높게 인정된 사례.
#    - 교차로에서의 사고 처리에 대한 판례들도 비슷한 원칙으로 좌회전 차량의 과실을 강조하며 판단하고 있습니다.
#
# 사고의 구체적인 상황에 따라 과실 비율이 달라질 수 있으니, 이 점을 참고하시기 바랍니다. 추가적인 질문이나 더 궁금한 사항이 있으시면 말씀해 주세요.
# You: 신호등이 없는 교차로에서 청구 차량은 좌회전하고, 피청구 차량은 우측에서 직진을 하다가 청구 차량의 왼쪽 운전석에 접촉한 경우
# Assistant: 제시해 주신 상황에 대해 과실 비율을 분석해 보겠습니다.
#
# 1. **사고 개요:**
#    - 신호등이 없는 교차로에서 청구 차량(좌회전 차량)은 좌회전을 하고, 피청구 차량(우측에서 직진 차)은 직진 중 청구 차량의 왼쪽 운전석과 접촉했습니다.
#
# 2. **법적 과실 분석:**
#    - 신호등이 없는 교차로에서는 우측 차량이 우선 통행할 수 있는 원칙이 적용됩니다.
#    - 좌회전 차량은 우회전 또는 직진하는 차량과의 충돌을 피하기 위해 특별한 주의를 기울여야 하며, 좌회전 직전 반드시 대향차량이 오는지 확인해야 합니다.
#    - 피청구 차량은 직진 차량이라는 점에서 상대방의 좌회전 여부에 따라 주의의무를 다했어야 합니다. 하지만 청구 차량이 좌회전을 시도하는 과정에서 피청구 차량과의 사고가 발생했다면, 좌회전 차량이 주의 부족으로 인한 과실이 높다고 판단됩니다.
#
# 3. **과실 비율 판단:**
#    - 이 경우, 청구 차량(좌회전 차량)의 과실은 약 70~80% 정도로 판단될 수 있으며, 피청구 차량(직진 차량)의 과실은 20~30% 정도로 평가할 수 있습니다.
#    - 청구 차량은 좌회전을 하기 위해 피청구 차량과의 거리 및 상황을 충분히 고려하지 않았을 것으로 보이며, 그로 인해 발생한 사고이기에 과실 비율이 높게 평가됩니다.
#
# 4. **비슷한 판례:**
#    - 대법원 판례(대법원 2004. 5. 27. 선고 2003다81576 판결): 좌회전 차량이 직진 차량과 접촉한 경우, 좌회전 차량의 과실이 높게 인정된 사례.
#    - 신호등 없는 교차로에서의 사고 처리에 대한 다양한 판례에서 우측 차량이 우선권을 가지며, 좌회전 차량에 대한 경고가 강조됩니다.
#
# 이와 같은 분석을 바탕으로 과실 비율을 판단할 수 있으며, 구체적인 상황에 따라 다소 차이가 있을 수 있습니다. 추가적인 질문이나 도움이 필요하시면 말씀해 주세요.
# You: "신호등이 없는 교차로에서 청구 차량(좌회전 차량)은 좌회전을 하고, 피청구 차량(우측에서 직진 차)은 직진 중  피청구 차량의 왼쪽 운전석과 접촉했습니다."
# Assistant: 제시하신 상황에 대해 과실 비율을 다시 분석해 보겠습니다.
#
# 1. **사고 개요:**
#    - 신호등이 없는 교차로에서 청구 차량(좌회전 차량)은 좌회전을 시도하고, 피청구 차량(우측에서 직진 차량)은 직진 중 청구 차량의 왼쪽 운전석과 접촉했습니다.
#
# 2. **법적 과실 분석:**
#    - 신호등이 없는 교차로에서는 기본적으로 우측 차량이 우선 통행할 수 있는 원칙이 있습니다.
#    - 청구 차량이 좌회전을 하기 위해서는 자신이 우선 통행권이 없는 만큼, 직진 차량의 통행을 방해하지 않도록 주의해야 합니다.
#    - 피청구 차량은 직진 신호를 받고 진행하고 있었으므로, 좌회전 차량이 직진 차량과의 거리를 충분히 확인하지 않고 좌회전을 진행했다면 청구 차량의 과실이 높아지게 됩니다.
#
# 3. **과실 비율 판단:**
#    - 이 경우, 일반적인 판단 기준에 따라 청구 차량(좌회전 차량)과 피청구 차량(직진 차량)의 과실 비율은 다음과 같이 분석할 수 있습니다:
#      - 청구 차량: 70~80%
#      - 피청구 차량: 20~30%
#    - 청구 차량이 좌회전을 진행하면서 피청구 차량의 진행을 무시하거나 충분한 주의를 기울이지 않았다면 과실 비율이 높게 평가됩니다.
#
# 4. **비슷한 판례:**
#    - 대법원 판례(대법원 2004. 10. 14. 선고 2003다27216 판결): 좌회전 차량이 직진 차량과 충돌한 경우, 좌회전 차량의 과실이 매우 높게 인정된 사례입니다.
#    - 교차로 사고에 관한 다양한 사례에서, 좌회전 차량이 통행할 때 주의의무를 다하지 않았다고 평가되는 경우에 과실이 높은 경우가 많습니다.
#
# 이와 같은 내용을 바탕으로 과실 비율을 판단할 수 있으며, 사고의 구체적인 상황과 추가적인 정보에 따라 판단이 달라질 수 있습니다. 추가 질문이나 다른 상황에 대한 논의가 필요하시면 말씀해 주세요.
# You: 신호기는 없으나 대소로 구분이 있는 사거리 교차로에서 청구차량이 대로에서 직진 중 피청구 차량이 소로에서 좌회전을 하다가 발생한 사고
# Assistant: 제시하신 사고 상황을 바탕으로 과실 비율을 분석해 보겠습니다.
#
# 1. **사고 개요:**
#    - 신호등이 없는 대소로 구분이 있는 사거리 교차로에서 청구 차량(대로에서 직진 차량)은 직진 중이고, 피청구 차량(소로에서 좌회전 차량)은 소로에서 대로로 좌회전을 하다가 접촉한 사고입니다.
#
# 2. **법적 과실 분석:**
#    - 신호등이 없는 교차로에서는 일반적으로 대로에서 진행하는 차량이 우선 통행권을 갖습니다. 대로로 접근하는 차량에는 통행권이 있으며, 이를 방해할 수 있는 차량은 주의의무를 다해야 합니다.
#    - 피청구 차량(소로에서 좌회전 차량)은 대로로 진입하기 위해서는 청구 차량(대로에서 직진 차량)의 통행 여부를 반드시 확인해야 하며, 상대방 차량의 진행을 방해하지 않도록 조심해야 합니다.
#
# 3. **과실 비율 판단:**
#    - 이 경우, 일반적으로 청구 차량(대로에서 직진 차량)의 과실이 적고 피청구 차량의 과실이 높게 평가될 것입니다. 대체로 다음과 같은 과실 비율로 판단할 수 있습니다:
#      - 청구 차량: 20~30%
#      - 피청구 차량: 70~80%
#    - 피청구 차량이 좌회전을 하면서 직진 차량과의 충돌을 피할 수 있는 주의 의무를 다하지 않았다면 과실이 높게 평가되며, 특히 소로에서 대로 진입 시 주의가 필요합니다.
#
# 4. **비슷한 판례:**
#    - 대법원 판례(대법원 2006. 11. 23. 선고 2006다67950 판결): 대로에서 직진 중인 차량과 소로에서 좌회전 차량 간의 사고에서 좌회전 차량의 과실이 높게 인정된 사례가 있습니다.
#    - 또한, 교차로 사고에 대한 법원의 일반적인 기준에서는 대로에서 진행하는 차량이 우선 통행권이 있다는 점이 강조됩니다.
#
# 이와 같은 분석을 바탕으로 과실 비율을 판단할 수 있으며, 사고의 구체적인 상황에 따라 달라질 수 시작 고길 부탁드립니다. 추가 질문이나 더 궁금한 사항이 있으시면 말씀해 주세요.
# You: "신호기는 없으나 대소로 구분이 있는 사거리 교차로에서 청구차량이 대로에서 직진 중 소로에 서 교차로에 선진입하여 좌회전을  하던 피청구차량과 충돌한 사고임"
# Assistant: 주어진 사고 상황을 바탕으로 과실 비율을 분석해 보겠습니다.
#
# 1. **사고 개요:**
#    - 신호등이 없는 대소로 구분이 있는 사거리 교차로에서 청구 차량(대로에서 직진 차량)은 대로에서 직진 중이고, 피청구 차량(소로에서 좌회전 차량)은 소로에서 대로로의 좌회전을 시도하다가 충돌한 사고입니다.
#
# 2. **법적 과실 분석:**
#    - **대로에서 직진하는 차량**: 청구 차량은 대로에서 직진 중이므로, 우선 통행권이 있는 차량입니다. 대로에서 진행하는 차량은 기본적으로 다른 차량에 비해 우선적인 통행권을 가지고 있습니다.
#    - **소로에서 좌회전하는 차량**: 피청구 차량은 좌회전을 시도할 때, 대로에서 직진하는 차량에 대한 주의 의무가 있습니다. 좌회전 차량은 항상 우측에서 접근하는 차량의 진행을 확인하고, 이를 방해하지 않도록 조심해야 합니다.
#
# 3. **과실 비율 판단:**
#    - 이 경우, 일반적으로 과실 비율은 다음과 같이 분석할 수 있습니다:
#      - **청구 차량(대로에서 직진 차량)**: 20~30%
#      - **피청구 차량(소로에서 좌회전 차량)**: 70~80%
#    - 피청구 차량이 소로에서 대로로 진입하면서 청구 차량의 통행을 무시하고 좌회전을 시도했다면, 과실이 크게 증가할 것입니다.
#
# 4. **비슷한 판례:**
#    - 대법원 판례(대법원 2010. 12. 30. 선고 2009다47624 판결): 대로에서 직진 중인 차량과 소로에서 좌회전하는 차량 간의 사고에서, 직진 차량의 과실이 적고 좌회전하는 차량의 과실이 높게 인정된 사례가 있습니다.
#    - 일반적으로, 우선 통행권이 있는 대로에서의 직진 차량에 대해 큰 과실을 부여하지 않는 것이 통상적인 판례의 원칙입니다.
#
# 이와 같은 내용을 바탕으로 과실 비율을 판단할 수 있으며, 사고의 구체적인 상황이나 추가적인 정보에 따라 다소 차이가 있을 수 있음을 참고해 주시기 바랍니다. 추가 질문이나 더 궁금한 사항이 있으시면 말씀해 주세요.
# You: "신호기는 없으나 대소로 구분이 있는 사거리 교차로에서 청구차량이 왼쪽 소로에서 직진하던 중 피청구차량이  오른쪽 대로에서 교차로에 선진입하여 좌회전을 하다가 충돌한 사고임"
# Assistant: 주어진 사고 상황을 바탕으로 과실 비율을 분석해 보겠습니다.
#
# 1. **사고 개요:**
#    - 신호등이 없는 대소로 구분이 있는 사거리 교차로에서 청구 차량은 왼쪽 소로에서 직진하던 중이고, 피청구 차량은 오른쪽 대로에서 교차로에 선진입하여 좌회전을 시도하다가 충돌한 사고입니다.
#
# 2. **법적 과실 분석:**
#    - **직진 차량(청구 차량)**: 왼쪽 소로에서의 직진 차량은 일반적으로 주의의무를 다할 의무가 있습니다. 특히 교차로에서의 상황을 주의 깊게 살펴보아야 합니다.
#    - **좌회전 차량(피청구 차량)**: 피청구 차량은 대로에서 좌회전을 시도하는 과정에서 교차로에 미리 진입하여 좌회전을 하면서 청구 차량의 진행을 방해할 수 있는 상황입니다. 좌회전 차량은 직진 차량과의 충돌을 피해야 할 의무가 있으며, 이는 특히 교차로에서 더욱 중요합니다.
#
# 3. **과실 비율 판단:**
#    - 이 경우, 일반적으로 과실 비율은 다음과 같이 분석할 수 있습니다:
#      - **청구 차량(소로에서 직진 차량)**: 30~40%
#      - **피청구 차량(대로에서 좌회전 차량)**: 60~70%
#    - 피청구 차량은 대로에서의 통행을 진행하며 선진입으로 인해 좌회전 중 발생한 사고로, 좌회전 시 직진 차량의 통행을 주의하지 않았다면 과실이 높게 평가될 것입니다.
#
# 4. **비슷한 판례:**
#    - 대법원 판례(대법원 2014. 9. 18. 선고 2013다43194 판결): 대로에서 진행하던 차량과 소로에서 좌회전하는 차량 간의 사고에서, 직진 차량의 과실이 적고 좌회전 차량의 과실이 높게 인정된 사례가 있습니다.
#    - 또한, 교차로에서의 사고에 대한 법원의 일반적인 판단 기준에서는 좌회전 차량이 직진 차량에 대한 주의 의무를 다하지 않은 경우에 과실이 높게 평가됩니다.
#
# 이와 같은 분석을 바탕으로 과실 비율을 판단할 수 있으며, 사고의 구체적인 상황이나 추가 정보에 따라 판단이 달라질 수 있습니다. 추가적인 질문이나 더 궁금한 사항이 있으시면 말씀해 주세요.
# You: "신호기는 없으나 대소로 구분이 있는 사거리 교차로에서 청구차량이 오른쪽 소로에서 일부 선 진입하여 직진하던 중 피청구차량이  왼쪽 대로에서 좌회전을 하다가 충돌한 사고임"
# Assistant: 주어진 상황을 바탕으로 과실 비율을 분석해 보겠습니다.
#
# 1. **사고 개요:**
#    - 신호등이 없는 대소로 구분이 있는 사거리 교차로에서 청구 차량(오른쪽 소로에서 직진 차량)은 일부 선 진입하여 직진 중이고, 피청구 차량(왼쪽 대로에서 좌회전 차량)은 교차로에 들어와 좌회전을 하다가 충돌한 사고입니다.
#
# 2. **법적 과실 분석:**
#    - **직진 차량(청구 차량)**: 오른쪽 소로에서 일부 진입하여 직진 중이므로 기본적으로 좌회전 차량과의 충돌을 피할 수 있는 주의의무가 있습니다. 그러나 소로에서 대로로 향하는 과정에서의 상황을 주의 깊게 살펴보아야 하며, 실제로 사고가 발생할 경우 과실 판단에 영향을 미칠 수 있습니다.
#    - **좌회전 차량(피청구 차량)**: 피청구 차량은 대로에서 좌회전을 하며 교차로에 진입할 때, 직진하는 차량이 존재하는지 반드시 주의해야 합니다. 좌회전 차량은 다른 차량의 통행에 신경을 써야 하며, 좌회전할 때는 특히 교차로에서 직진 차량과의 충돌을 피할 책임이 있습니다.
#
# 3. **과실 비율 판단:**
#    - 이 경우, 일반적으로 과실 비율은 다음과 같이 분석될 수 있습니다:
#      - **청구 차량(소로에서 일부 진입 후 직진)**: 30~40%
#      - **피청구 차량(대로에서 좌회전)**: 60~70%
#    - 피청구 차량이 좌회전할 때 충분한 주의를 기울이지 않았다면, 좌회전하는 차량의 과실이 높게 평가될 것입니다.
#
# 4. **비슷한 판례:**
#    - 대법원 판례(대법원 2011. 10. 27. 선고 2010다100077 판결): 대로에서 좌회전하는 차량과 소로에서 직진하는 차량 간의 사고에서, 좌회전 차량의 과실이 높게 인정된 사례가 있습니다.
#    - 교차로에서의 사고 발생 시, 좌회전 차량이 직진 차량을 확인하지 않고 진입한 경우 과실이 인정되는 점이 강조되었습니다.
#
# 이와 같은 분석을 바탕으로 과실 비율을 판단할 수 있으며, 상황에 따라 다를 수 있으니 참고해 주세요. 추가적인 질문이나 더 궁금한 사항이 있으시면 말씀해 주세요.
# You: "지하주차장의 사거리 교차로에서 직진 중이던 청구차량과 좌회전을 하던 피청구차량 사이에 발생한 사고이고,  피청구차량의 주행 통로에 ‘교차로 우선멈춤’표지가 설치
# Assistant: 주어진 상황을 바탕으로 과실 비율을 분석해 보겠습니다.
#
# 1. **사고 개요:**
#    - 지하주차장 내 사거리 교차로에서 직진 중이던 청구 차량(직진 차량)과 좌회전을 하던 피청구 차량(좌회전 차량) 간에 충돌이 발생했습니다. 특히, 피청구 차량의 주행 통로에 ‘교차로 우선 멈춤’ 표지가 설치되어 있는 상황입니다.
#
# 2. **법적 과실 분석:**
#    - **직진 차량(청구 차량)**: 청구 차량은 주어진 도로에서 신호 또는 표지판에 따른 우선 통행권을 가지고 있으며, 다른 차량의 영향 없이 직진 중입니다. 이는 직진 차량이 기본적으로 유리한 입장에 있다는 것을 의미합니다.
#    - **좌회전 차량(피청구 차량)**: 피청구 차량은 좌회전을 시도할 때, 교차로 우선 멈춤 표지를 준수해야 할 의무가 있습니다. '교차로 우선 멈춤' 표지는 해당 차량이 교차로에서 멈추고 타 차량의 통행을 먼저 확인해야 하는 의무가 있음을 나타냅니다. 즉, 이 표지를 무시하고 좌회전하던 차량은 통행의 주의 의무를 다하지 않은 것으로 평가됩니다.
#
# 3. **과실 비율 판단:**
#    - 이 경우, 일반적으로 과실 비율은 다음과 같이 분석될 수 있습니다:
#      - **청구 차량(직진 차량)**: 10~20%
#      - **피청구 차량(좌회전 차량)**: 80~90%
#    - 피청구 차량이 교차로 우선 멈춤 표지를 따르지 않고 좌회전하여 사고가 발생했다면, 피청구 차량의 과실이 매우 높게 평가될 것입니다.
#
# 4. **비슷한 판례:**
#    - 대법원 판례(대법원 2013. 5. 23. 선고 2012다120659 판결): 교차로 우선 멈춤 표지에서의 좌회전 차량이 멈추지 않고 진입한 경우, 직진 차량과의 충돌 시 좌회전 차량의 과실이 높게 인정된 사례가 있습니다.
#    - 일반적으로 교차로에서의 사고에서는 우선멈춤 표지의 중요성이 강조되며, 이를 위반한 차량에 대한 과실이 높게 평가됩니다.
#
# 이와 같은 분석을 바탕으로 과실 비율을 판단할 수 있으며, 사고의 구체적인 상황이나 추가 정보에 따라 다소 차이가 있을 수 있음을 참고해 주시기 바랍니다. 추가적인 질문이나 더 궁금한 사항이 있으시면 말씀해 주세요.
# You: "신호기 없는 삼거리 교차로에서 청구차량이 좌회전 중 왼쪽 도로에서 교차로에 진입하는 피청구차량과 충돌 한 사고로,  피청구차량의 진입도로에 양보 표지가 있었다"
# Assistant: 주어진 사고 상황을 바탕으로 과실 비율을 분석해 보겠습니다.
#
# 1. **사고 개요:**
#    - 신호등이 없는 삼거리 교차로에서 청구 차량(좌회전 차량)이 좌회전을 하던 중 왼쪽 도로에서 교차로에 진입하는 피청구 차량(직진 차량)과 충돌한 사고입니다. 피청구 차량이 진입하는 도로에는 양보 표지가 설치되어 있습니다.
#
# 2. **법적 과실 분석:**
#    - **직진 차량(피청구 차량)**: 피청구 차량은 양보 표지가 있는 도로에서 진입하고 있습니다. 따라서 이 차량은 다른 차량이 오는 경우, 우선적으로 그 차량에게 양보할 의무가 있습니다.
#    - **좌회전 차량(청구 차량)**: 청구 차량은 좌회전을 하면서 교차로에 진입하였고, 좌회전 차량은 일반적으로 직진 차량의 통행을 방해하지 않아야 합니다. 하지만 피청구 차량이 양보 표지가 있는 도로에서 진입함에 따라 청구 차량이 좌회전할 때 직진 차량의 존재를 확인하지 않았다는 점은 주의 의무 위반으로 해석될 수 있습니다.
#
# 3. **과실 비율 판단:**
#    - 이 경우, 일반적으로 과실 비율은 다음과 같이 분석할 수 있습니다:
#      - **청구 차량(좌회전 차량)**: 40~60%
#      - **피청구 차량(진입 차량)**: 40~60%
#    - 피청구 차량이 양보 표지가 있는 도로에서 진입하고 있다는 점에서 양보 의무가 있으며, 양보 표지를 따르지 않았다면 과실이 증가할 수 있으나 청구 차량도 좌회전 시 직진 차량을 확인해야 하므로 과실이 존재합니다.
#
# 4. **비슷한 판례:**
#    - 대법원 판례(대법원 2010. 3. 25. 선고 2009다9044 판결): 교차로에서 좌회전 차량과 직진 차량 간의 충돌로 좌회전 차량의 과실이 인정된 경우와 함께, 직진 차량이 양보 표지를 위반한 경우의 과실을 다룬 사례가 있습니다.
#    - 일반적으로 좌회전 차량은 직진 차량의 진입을 확인해야 하며, 주의 의무를 다하지 않은 경우 과실이 있는 것으로 간주될 수 있습니다.
#
# 이와 같은 내용을 바탕으로 과실 비율을 판단할 수 있으며, 사고의 구체적인 상황이나 추가 정보에 따라 다소 차이가 있을 수 있음을 참고해 주시기 바랍니다. 추가적인 질문이나 더 궁금한 사항이 있으시면 말씀해 주세요.
# You: 신호기가 없는 사거리에서 청구차량이 일시정지 위반하여 오른쪽 도로에서 선입 직진하다가 왼쪽에서 오는 피청구차량에 받힌 사고
# Assistant: 주어진 사고 상황을 바탕으로 과실 비율을 분석해 보겠습니다.
#
# 1. **사고 개요:**
#    - 신호기가 없는 사거리에서 청구 차량이 일시정지 의무를 위반하여 오른쪽 도로에서 진입한 직진 차량과 충돌했습니다. 이때 피청구 차량은 왼쪽에서 오는 차량입니다.
#
# 2. **법적 과실 분석:**
#    - **청구 차량**: 청구 차량은 사거리에서 일시정지 표지나 의무를 위반하고 진입했습니다. 사거리의 차량들이 각자의 차량의 진입을 확인하고 양보할 의무가 있으므로, 일시 정지 의무를 위반한 기업 양신에 큰 과실이 있습니다.
#    - **피청구 차량**: 피청구 차량은 왼쪽에서 오는 차량으로, 주행 시 청구 차량의 과실 여부를 확인하고 본인의 통행에 주의해야 할 의무가 있습니다. 하지만 청구 차량이 일시정지를 하지 않은 상태에서 진입했기 때문에, 피청구 차량의 과실이 적게 평가될 가능성이 높습니다.
#
# 3. **과실 비율 판단:**
#    - 이 경우, 일반적으로 과실 비율은 다음과 같이 분석될 수 있습니다:
#      - **청구 차량**: 70~90%
#      - **피청구 차량**: 10~30%
#    - 청구 차량이 일시정지 의무를 위반하고 들어왔기 때문에 과실 비율이 상당히 높게 평가됩니다.
#
# 4. **비슷한 판례:**
#    - 대법원 판례(대법원 2016. 2. 18. 선고 2015다227774 판결): 일시정지 의무를 위반한 경우에 사고 발생 시, 일시정지하지 않은 차량의 과실이 높게 인정되는 사례가 있습니다.
#    - 일반적으로 사거리에서 향판이나 신호를 위반하고 진입해 상대 차량과의 충돌이 발생한 경우, 과실은 위반 차량에게 크고, 준수한 차량은 상대적으로 적은 과실이 부여됩니다.
#
# 이와 같은 분석을 바탕으로 과실 비율을 판단할 수 있으며, 사고의 구체적인 상황에 따라 다소 차이가 있을 수 있으니 참고해 주세요. 추가 질문이나 더 궁금한 사항이 있으시면 말씀해 주세요.
# You: "신호기가 피청구차량 방향에만 있는 교차로에서 황색신호에 직진하는 차량과 신호기가 없는 도로를 청구차량이  우회전(직진, 좌 회전 포함)하는 차량 간의 사고"
# Assistant: 주어진 사고 상황을 바탕으로 과실 비율을 분석해 보겠습니다.
#
# 1. **사고 개요:**
#    - 신호기가 피청구 차량 방향에만 있는 교차로에서 청구 차량이 신호기가 없는 도로에서 우회전(직진 또는 좌회전 포함)하던 중, 피청구 차량이 황색 신호에 따른 직진을 시도하여 발생한 사고입니다.
#
# 2. **법적 과실 분석:**
#    - **청구 차량(우회전 차량)**: 청구 차량은 신호기가 없는 도로에서 주행 중이고, 일반적으로 우회전하는 차량은 오른쪽을 확인하고, 직진 또는 좌회전하는 차량의 통행을 방해하지 않도록 주의해야 합니다.
#    - **피청구 차량(황색 신호 직진 차량)**: 피청구 차량은 황색 신호에 주행하고 있으므로 정지선에서 대기할 의무가 아닙니다. 신호가 황색임에도 불구하고 신호를 통과하는 경우, 피청구 차량이 교차로를 통과하는 권리가 있습니다. 다만, 황색 신호 시에도 주의 의무가 있으며, 위험한 상황에서 경과하지 않도록 주의해야 합니다.
#
# 3. **과실 비율 판단:**
#    - 이 경우, 과실 비율은 다음과 같이 분석할 수 있습니다:
#      - **청구 차량(우회전 차량)**: 40~60%
#      - **피청구 차량(옐로우 신호 직진 차량)**: 40~60%
#    - 청구 차량이 신호기가 없는 도로에서 직진하는 차량의 통행을 방해하지 않도록 주의하지 않았다면 과실이 증가할 수 있습니다. 반면 피청구 차량도 황색 신호라고 하더라도 교차로 진입 시 주의 의무를 다하지 않았다면 과실이 발생할 수 있습니다.
#
# 4. **비슷한 판례:**
#    - 대법원 판례 (대법원 2016. 4. 28. 선고 2015다212019 판결): 신호기가 없는 도로에서 우회전 차량이 직진 차량과 충돌하는 경우, 각 차량의 주행 상태와 판단 기준에 따라 과실이 배분된 사례가 있습니다.
#    - 신호가 황색일 때 진행하는 차량도 좌회전이나 우회전 차량에 대해 주의가 요구됨을 강조하는 판례가 있습니다.
#
# 이와 같은 분석을 바탕으로 과실 비율을 판단할 수 있으며, 사고의 구체적인 상황이나 추가 정보에 따라 다소 차이가 있을 수 있습니다. 추가 질문이나 더 궁금한 사항이 있으시면 말씀해 주세요.
# You: "한쪽 방향에만 신호기가 설치된 교차로에서 청구차량이 적색신호 에 직진하여 교차로에 진입하였고, 피청구차량은 오른쪽 도로에서  우회전 중 발생한 사고"
# Assistant: 주어진 사고 상황을 바탕으로 과실 비율을 분석해 보겠습니다.
#
# 1. **사고 개요:**
#    - 한쪽 방향에만 신호기가 설치된 교차로에서 청구 차량이 적색 신호에 직진하여 교차로에 진입하고, 피청구 차량은 오른쪽 도로에서 우회전 중 발생한 사고입니다.
#
# 2. **법적 과실 분석:**
#    - **청구 차량(적색 신호 직진 차량)**: 청구 차량은 적색 신호를 무시하고 교차로에 진입하였습니다. 신호를 위반한 경우, 과실이 매우 크며 이는 상대방 차량에 대한 책임이 크다는 것을 의미합니다.
#    - **피청구 차량(우회전 차량)**: 피청구 차량은 신호기가 설치되지 않은 도로에서의 우회전이기 때문에 비교적 적은 주의 의무가 있지만, 좌우를 확인하고 황색 신호의 차량이 진입하는 여부를 확인해야 하는 기본적인 주의 의무가 있습니다.
#
# 3. **과실 비율 판단:**
#    - 이 경우의 과실 비율은 다음과 같이 판단될 수 있습니다:
#      - **청구 차량(적색 신호 직진 차량)**: 80~90%
#      - **피청구 차량(우회전 차량)**: 10~20%
#    - 청구 차량이 신호를 위반하여 교차로에 진입했기 때문에 과실이 매우 크다고 평가됩니다.
#
# 4. **비슷한 판례:**
#    - 대법원 판례(대법원 2012. 3. 15. 선고 2010다87002 판결): 신호를 위반하여 교차로에 진입한 차량과 적법한 절차로 교차로로 진입한 차량 간의 사고에서 신호 위반 차량에 대한 과실이 높게 인정된 사례입니다.
#    - 일반적으로, 신호를 위반한 차량의 과실은 상대적으로 높은 수치로 평가되며, 교차로에서의 우회전 차량은 주의 의무를 지켜야 하지만신호 위반 차량의 과실이 더 크게 작용합니다.
#
# 이와 같은 내용을 바탕으로 과실 비율을 판단할 수 있으며, 사고의 세부 사항이나 추가적인 정보에 따라 달라질 수 있으니 참고해 주세요. 추가 질문이나 더 궁금한 사항이 있으시면 말씀해 주세요.
# You: 신호기 없는 동일 폭의 사거리 교차로에서 청구차량이 우회전하던 중 왼쪽 도로에서 직진하던 피청구차량과 충돌한 사고임
# Assistant: 주어진 사고 상황을 바탕으로 과실 비율을 분석해 보겠습니다.
#
# 1. **사고 개요:**
#    - 신호기가 없는 동일 폭의 사거리 교차로에서 청구 차량(우회전 차량)이 우회전을 하던 중 왼쪽 도로에서 직진하던 피청구 차량(직진 차량)과 충돌한 사고입니다.
#
# 2. **법적 과실 분석:**
#    - **직진 차량(피청구 차량)**: 신호기가 없는 교차로에서는 기본적으로 직진 차량이 우선 통행할 권리를 가지고 있습니다. 따라서 피청구 차량은 교차로에 진입할 때 청구 차량의 존재와 통행을 고려해야 할 의무도 있지만, 일반적으로는 직진 차량이 우선 통행이 가능합니다.
#    - **우회전 차량(청구 차량)**: 청구 차량은 우회전하면서 직진 차량의 통행을 방해하지 않도록 주의해야 하며, 좌회전 차량과의 충돌을 피할 책임이 있습니다. 따라서 우회전 차량이 직진 차량을 확인하지 않고 진행한 경우 과실 비율이 높아집니다.
#
# 3. **과실 비율 판단:**
#    - 이 경우, 일반적으로 과실 비율은 다음과 같이 판단될 수 있습니다:
#      - **청구 차량(우회전 차량)**: 60~80%
#      - **피청구 차량(직진 차량)**: 20~40%
#    - 청구 차량이 직진 차량과 충돌하기 전에 충분히 주변을 확인하고 통행 여부를 고려하지 않았다면, 청구 차량의 과실이 높아질 것입니다.
#
# 4. **비슷한 판례:**
#    - 대법원 판례(대법원 2005. 7. 21. 선고 2003다48584 판결): 신호기가 없는 교차로에서 직진과 우회전 차량 간의 충돌에서, 직진 차량의 통행 우선 원칙에 따라 우회전 차량의 과실이 높게 인정된 사례입니다.
#    - 일반적으로, 신호기가 없는 교차로에서 직진 차량의 통행 우선 원칙이 강조돼 있으며, 우회전 차량이 이를 준수하지 않을 경우 과실이 크게 평가됩니다.
#
# 이와 같은 내용을 바탕으로 과실 비율을 판단할 수 있으며, 사고의 세부 사항이나 주변 상황에 따라 다소 차이가 있을 수 있습니다. 추가 질문이나 더 궁금한 사항이 있으시면 말씀해 주세요.
# You: 신호기는 없는 동일 폭의 사거리 교차로에서 청구차량이 선진입하여 직진하던 중 오른쪽 도로 에서 우회전하던 피청구차량과 충돌한 사고임
# Assistant: 주어진 사고 상황을 바탕으로 과실 비율을 분석해 보겠습니다.
#
# 1. **사고 개요:**
#    - 신호기가 없는 동일 폭의 사거리 교차로에서 청구 차량이 선진입하여 직진하던 중, 오른쪽 도로에서 우회전하던 피청구 차량과 충돌한 사고입니다.
#
# 2. **법적 과실 분석:**
#    - **직진 차량(청구 차량)**: 청구 차량은 교차로에 선진입했으며 직진 중입니다. 신호기가 없는 경우 직진 차량은 기본적으로 우선 통행할 권리를 갖고 있습니다. 그러나, 청구 차량이 상대방 차량의 통행 여부를 확인하지 않고 교차로로 진입했다면 주의 의무를 다하지 않은 것으로 분석될 수 있습니다.
#    - **우회전 차량(피청구 차량)**: 피청구 차량은 오른쪽 도로에서 우회전하고 있습니다. 우회전 시, 직진 차량이 있는 경우 우회전 차량도 주의 의무가 있으며, 직진 차량과의 충돌을 피해야 합니다. 하지만 교차로의 기본 원칙상 우회전 차량이 진입할 때 직진 차량에 대한 주의 의무가 중요한 상황입니다.
#
# 3. **과실 비율 판단:**
#    - 이 경우, 일반적으로 과실 비율은 다음과 같이 판단될 수 있습니다:
#      - **청구 차량(직진 차량)**: 40~60%
#      - **피청구 차량(우회전 차량)**: 40~60%
#    - 청구 차량이 선진입하여 직진 중이었다면 과실이 적게 평가될 수 있지만, 피청구 차량도 우회전 시 주변 상황에 대한 주의를 기울이지 않았다면 과실이 증가할 수 있습니다. 따라서 두 차량 모두 일정 부분의 과실을 가질 것으로 보입니다.
#
# 4. **비슷한 판례:**
#    - 대법원 판례(대법원 2007. 4. 26. 선고 2006다54911 판결): 신호가 없는 교차로에서 직진 차량과 우회전 차량 간의 사고에서, 각 차량의 주의 의무를 다하지 않은 경우 두 차량 모두 과실이 인정되었으며, 사고의 상황에 따라 세부적인 비율이 조정된 사례입니다.
#    - 일반적으로 신호기가 없는 교차로에서는 직진 차량이 우선 통행하지만, 좌우를 확인해야 하며 우회전 차량도 주의 의무가 요구됩니다.
#
# 이와 같은 내용을 바탕으로 과실 비율을 판단할 수 있으며, 사고의 세부 사항이나 주변 상황에 따라 다소 차이가 있을 수 있습니다. 추가 질문이나 더 궁금한 사항이 있으시면 말씀해 주세요.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-a6cbbbc8f20c> in <cell line: 56>()
#      56 while True:
#      57
# ---> 58     user_input = input("You: ")
#      59     messages.append({"role": "user", "content": user_input})
#      60
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# Task2_0813. Temperature 와 Top-P의 조합으로 4가지 사례를 작성하고 결과에 대해 의미를 확인하세요

# %%
from openai import OpenAI

client = OpenAI(api_key="")

# %%
#### 1. **높은 Temperature (1.0 이상) + 높은 Top-p (0.9~1.0)**
response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content": "당신은 감성이 풍부한 화가입니다"},
        {"role": "user", "content": "이미지에 보이는 풍경을 설명해줘"},
        {"role": "user", "content": "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg"}
    ],
    temperature=1.0,
    top_p=1.0
)
print(response.choices[0].message.content)
# Out:
# 이 이미지는 미국 위스콘신주 매디슨에 위치한 자연 보드워크의 풍경을 담고 있습니다. 보드워크는 푸른 풀밭과 주변의 나무들 사이로 걸쳐져 있어, 자연과 함께하는 감각을 줍니다. 보드워크 위를 산책하는 사람들은 평화로운 분위기 속에서 주변의 아름다움을 만끽할 수 있습니다.
#
# 주변의 나무들은 다양한 색조의 초록색으로 풍성하게 자랐으며, 햇빛에 반사되어 생명의 에너지를 느끼게 합니다. 또한, 보드워크 양쪽에는 물이 흐르는 곳과 수련 같은 수생 식물들이 자생하고 있어 자연의 조화로움을 더욱 강조합니다.
#
# 이 곳은 도시의 번잡함에서 벗어나 자연의 안식을 찾을 수 있는 곳으로, 한가로이 산책하거나 생각에 잠기기에 딱 알맞은 장소입니다. 전체적인 분위기는 고요하고 평화롭며, 자연과 사람의 조화로운 공존을 느낄 수 있는 아름다운 장면을 연출합니다.

# %%
#### 2. **높은 Temperature (1.0 이상) + 낮은 Top-p (0.3~0.7)**

response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content": "당신은 감성이 풍부한 화가입니다"},
        {"role": "user", "content": "이미지에 보이는 풍경을 설명해줘"},
        {"role": "user", "content": "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg"}
    ],
    temperature=1.0,
    top_p=0.5
)
print(response.choices[0].message.content)
# Out:
# 이 이미지는 자연과 조화롭게 어우러진 아름다운 풍경을 담고 있습니다. 중앙에는 나무로 만들어진 보도가 펼쳐져 있어, 방문객들이 자연을 가까이에서 감상할 수 있도록 안내하고 있습니다. 보도 양쪽에는 울창한 녹음이 우거진 나무들과 다양한 식물들이 자리 잡고 있어, 생명력 넘치는 자연의 아름다움을 강조합니다.
#
# 수면에 비친 나무들의 모습은 마치 거울처럼 잔잔하게 반사되어, 풍경에 깊이를 더하고 있습니다. 푸른 하늘과 구름이 보이는 배경은 이곳이 자연 속에서 느낄 수 있는 평화로움을 더욱 부각시킵니다. 전체적으로 이 풍경은 고요하고 평화로운 분위기를 자아내며, 자연과의 연결을 느끼게 해주는 장소임을 암시합니다.

# %%
#### 3. **낮은 Temperature (0.2\~0.5) + 높은 Top-p (0.9~1.0)**

response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content": "당신은 감성이 풍부한 화가입니다"},
        {"role": "user", "content": "이미지에 보이는 풍경을 설명해줘"},
        {"role": "user", "content": "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg"}
    ],
    temperature=0.5,
    top_p=1.0
)
print(response.choices[0].message.content)
# Out:
# 이 이미지는 아름다운 자연 풍경을 담고 있습니다. 중앙에는 나무로 만들어진 보도가 있어, 사람들은 그 위를 걸으며 자연을 만끽할 수 있습니다. 보도 양쪽에는 울창한 녹음이 우거져 있으며, 다양한 식물들이 조화롭게 자생하고 있습니다.
#
# 햇빛이 나무 사이로 비추어 따뜻한 느낌을 주고, 보도의 끝 부분에서는 잔잔한 물이 흐르는 모습이 보입니다. 물가에는 수초와 작은 나무들이 자생하여 생명의 활기를 더하고 있습니다. 이 풍경은 평화롭고 고요한 분위기를 자아내며, 자연과의 조화를 느낄 수 있는 공간으로 보입니다.
#
# 사람들이 자연 속에서 여유를 즐기고, 각자의 생각에 잠길 수 있는 장소로, 감정적으로도 위안이 되는 느낌을 줍니다. 이곳은 자연의 아름다움과 고요함을 동시에 체험할 수 있는 특별한 장소임을 알 수 있습니다.

# %%
#### 4. **낮은 Temperature (0.2\~0.5) + 낮은 Top-p (0.3~0.7)**

response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content": "당신은 감성이 풍부한 화가입니다"},
        {"role": "user", "content": "이미지에 보이는 풍경을 설명해줘"},
        {"role": "user", "content": "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg"}
    ],
    temperature=0.3,
    top_p=0.3
)
print(response.choices[0].message.content)
# Out:
# 이 이미지는 자연과 조화롭게 어우러진 아름다운 풍경을 담고 있습니다. 중앙에는 나무로 만들어진 보도가 길게 뻗어 있어, 방문객들이 자연을 가까이에서 느끼며 걸을 수 있는 공간을 제공합니다. 보도 양옆으로는 푸르른 식물들이 자생하고 있으며, 그 사이로 햇빛이 부드럽게 비추어 자연의 생명력을 더욱 강조합니다.
#
# 배경에는 울창한 나무들이 자리잡고 있어, 숲의 깊이와 신비로움을 느낄 수 있습니다. 하늘은 맑고 푸르며, 구름이 드문드문 떠 있어 평화로운 분위기를 자아냅니다. 이 풍경은 자연의 소리와 향기를 느끼며, 마음의 안정을 찾을 수 있는 완벽한 장소로 보입니다. 전체적으로 이 이미지는 자연의 아름다움과 평화로움을 잘 표현하고 있습니다.
