# %% [markdown]
# ## OpenAI API
# 정의와 목적
# - OpenAI API는 GPT-4와 같은 대규모 언어 모델을 활용하여 자연어 처리 작업을 자동화하고 향상시키기 위한 도구입니다.
# - API는 개발자가 다양한 응용 프로그램에서 인공지능을 통합하여 텍스트 생성, 대화형 AI, 콘텐츠 생성 등을 구현할 수 있도록 설계되었습니다.
#
# 활용 방법
# - OpenAI API는 클라우드 기반으로 작동하며, 모델에 프롬프트를 보내고 결과를 받습니다. 주로 Chat Completion API를 사용하여 텍스트 완성, 요약, 번역 등을 수행하며, 다양한 언어 모델과 설정을 선택할 수 있습니다.
#
# 적용 절차
# - API 키 생성: OpenAI 계정에서 API 키를 생성합니다.
# - 프롬프트 설계: 수행할 작업에 맞는 프롬프트를 작성합니다.
# - API 호출: HTTP 요청으로 프롬프트를 포함한 API 호출을 수행합니다.
# - 결과 처리: 모델이 생성한 응답을 분석하고 필요시 후속 조치를 취합니다.
# - 활용 사례
#   - 고객 서비스: 자동 응답 챗봇 구축.
#   - 콘텐츠 생성: 블로그, 소셜 미디어 포스트 자동 생성.
#   - 교육: 질문에 대한 자동화된 답변 제공.
#   - 개발자 도구: 코드 자동 완성 및 디버깅 지원.
#   - 이 API는 자연어 처리의 다양한 응용 프로그램에서 핵심적인 역할을 합니다.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mp
from google.colab import drive

drive.mount('/content/drive')

# 이미지 파일의 경로
image_path = '/content/drive/MyDrive/KDT_240424/m9_openai/data/optimization.png'
# 이미지 읽기
img = mp.imread(image_path)

# 이미지 출력
plt.figure(figsize=(15, 10))
plt.imshow(img)
plt.axis('off') # 축 제거
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## OpenAI API를 활용한 모델 최적화
# Context Optimization과 LLM Optimization이라는 두 가지 주요 과정으로 나눌 수 있으며, 이 과정은 프롬프트 엔지니어링, RAG(Retrieval-Augmented Generation), 파인 튜닝(Fine-Tuning) 등 다양한 방법과 밀접하게 연관되어 있습니다.
#
# Context Optimization (맥락 최적화)
# - Context Optimization은 모델이 무엇을 알아야 하는지를 최적화하는 과정입니다. 여기에는 모델이 주어진 프롬프트나 문제를 정확하게 이해하고, 이를 바탕으로 적절한 응답을 생성할 수 있도록 맥락을 제공하는 것이 포함됩니다.
# - 이 과정은 특히 다음과 같은 방법들과 연계됩니다:
#   - 프롬프트 엔지니어링 (Prompt Engineering): 프롬프트 엔지니어링은 맥락을 명확하게 전달하기 위해 프롬프트를 설계하는 과정입니다. 잘 설계된 프롬프트는 모델이 더 정확한 컨텍스트를 이해하도록 도와주며, 결과적으로 더 신뢰할 수 있는 응답을 생성하게 합니다. 예를 들어, 특정한 예시나 추가적인 정보를 포함시켜 모델이 문제를 더 잘 이해하도록 유도할 수 있습니다.
#   - RAG (Retrieval-Augmented Generation): RAG는 모델이 외부 데이터 소스에서 정보를 검색하여 그 정보를 바탕으로 응답을 생성하도록 하는 방법입니다. 이 방법은 특히 최신 정보나 특정 도메인에 대한 지식이 필요한 경우 매우 유용합니다. RAG는 단순히 모델에게 제공되는 컨텍스트를 강화하여 모델이 더 정확한 정보에 기반한 응답을 생성하도록 도와줍니다. 예를 들어, 사용자가 질의한 질문에 대해 모델이 최신 기사를 검색하여 그 내용을 바탕으로 답변하는 경우입니다.
# - RAG와 프롬프트 엔지니어링은 모두 모델이 주어진 문제에 대해 더 깊이 있는 맥락을 이해하도록 돕고, 이로 인해 더 정확한 응답을 생성하도록 합니다. 이 과정에서 Context Optimization이 이루어지며, 이를 통해 모델의 이해도와 성능을 향상시킬 수 있습니다.
#
# LLM Optimization (모델 최적화)
# - LLM Optimization은 모델이 주어진 문제에 대해 어떻게 행동해야 하는지를 최적화하는 과정입니다. 이 과정에서는 주로 모델의 학습 과정과 파인 튜닝이 중요한 역할을 합니다:
#   - 파인 튜닝 (Fine-Tuning): 파인 튜닝은 특정 도메인이나 작업에 맞게 모델을 재학습시키는 과정입니다. 기본적으로 대규모 데이터로 학습된 언어 모델이지만, 특정 도메인이나 작업에 대해 더 정확한 결과를 얻기 위해 추가적인 학습이 필요할 수 있습니다. 파인 튜닝을 통해 모델이 특정 작업에 최적화된 성능을 발휘하도록 조정할 수 있습니다. 예를 들어, 의료 데이터셋으로 파인 튜닝된 모델은 일반적인 GPT 모델보다 의료 관련 질문에 대해 더 정확한 응답을 제공할 수 있습니다.
# - LLM Optimization은 주로 파인 튜닝을 통해 이루어지며, 이를 통해 모델이 주어진 작업에 대해 최적의 성능을 발휘할 수 있도록 만듭니다.
#
# Context Optimization과 LLM Optimization의 연계
# - 이 두 가지 최적화 과정은 서로 보완적입니다. Context Optimization은 모델이 문제를 더 잘 이해하고, 맥락을 명확하게 파악하도록 돕는 반면, LLM Optimization은 모델이 그 문제를 어떻게 해결해야 하는지에 대한 학습을 통해 성능을 최적화합니다.
#   - 프롬프트 엔지니어링과 RAG는 주로 Context Optimization에 집중하여 모델이 정확한 정보를 기반으로 적절한 맥락을 이해하도록 도와줍니다.
#   - 파인 튜닝은 LLM Optimization에 초점을 맞추어, 모델이 주어진 작업에 대해 최적화된 성능을 발휘할 수 있도록 합니다.
# - 이 과정들이 결합되어 OpenAI API를 활용한 모델이 다양한 응용 분야에서 최대의 성능을 발휘할 수 있게 합니다. 최종적으로, 이러한 최적화 방법들은 모델이 더 일관되고 신뢰할 수 있는 결과를 생성할 수 있도록 지원합니다.

# %% [markdown]
# [GPT-4o-mini Model Information](https://openai.com/index/gpt-4o-mini-advancing-cost-efficient-intelligence/)
#
# | MODEL                   | DESCRIPTION                                                                                                      | CONTEXT WINDOW | MAX OUTPUT TOKENS | TRAINING DATA  |
# |-------------------------|------------------------------------------------------------------------------------------------------------------|----------------|-------------------|----------------|
# | gpt-4o-mini             | **New GPT-4o-mini** <br> Our affordable and intelligent small model for fast, lightweight tasks. <br> GPT-4o mini is cheaper and more capable than GPT-3.5 Turbo. <br> Currently points to gpt-4o-mini-2024-07-18. | 128,000 tokens | 16,384 tokens     | Up to Oct 2023 |
# | gpt-4o-mini-2024-07-18  | gpt-4o-mini currently points to this version.                                                                    | 128,000 tokens | 16,384 tokens     | Up to Oct 2023 |

# %%
# %pip install -q openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.3/361.3 kB 19.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.9 MB/s eta 0:00:00

# %%
from openai import OpenAI

client = OpenAI(api_key="")

completion = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {"role": "system", "content": "당신은 AI 모델 개발자입니다"},
    {"role": "user", "content": "LLM에 대해 설명해줘"}
  ]
)

print(completion.choices[0].message.content)
# Out:
# LLM(대규모 언어 모델, Large Language Model)은 자연어 처리(NLP) 분야에서 사용되는 AI 모델로, 방대한 양의 텍스트 데이터를 학습하여 언어의 구조와 의미를 이해하고 생성하는 능력을 갖추고 있습니다. 이러한 모델은 주로 기계 학습 기법인 딥러닝을 사용하여 훈련됩니다.
#
# ### LLM의 주요 특징:
#
# 1. **대규모 데이터 훈련**: LLM은 인터넷에서 수집된 다양한 텍스트 데이터를 기반으로 훈련됩니다. 이를 통해 일반적인 언어 패턴, 문법, 지식 등을 학습하게 됩니다.
#
# 2. **Transformer 아키텍처**: 대부분의 현대 LLM은 Transformer라는 신경망 아키텍처를 기반으로 합니다. 이 아키텍처는 Attention 메커니즘을 활용하여 문맥을 이해하고, 단어 간의 관계를 효과적으로 포착합니다.
#
# 3. **언어 생성**: LLM은 주어진 입력 텍스트에 대해 관련성 높은 텍스트를 생성할 수 있습니다. 이를 통해 질문에 답하거나, 글을 작성하거나, 대화를 할 수 있는 등의 작업이 가능합니다.
#
# 4. **전이 학습**: 한 종류의 작업에 대해 훈련된 모델은 다른 작업에도 적용할 수 있습니다. LLM은 이 전이 학습을 통해 다양한 NLP 태스크(예: 감정 분석, 번역, 요약 등)에 활용될 수 있습니다.
#
# 5. **사전 훈련 및 미세 조정**: LLM은 일반적인 언어 모델링 작업을 위해 대규모로 사전 훈련된 후, 특정 작업이나 도메인에 맞추어 미세 조정(fine-tuning)하여 성능을 향상시킬 수 있습니다.
#
# ### 응용 분야:
#
# - **대화형 AI**: 챗봇, 가상 비서 등
# - **자동 번역**: 다국어 번역 서비스
# - **콘텐츠 생성**: 기사 작성, 스토리 생성 등
# - **정보 검색 및 QA 시스템**: 질문 응답 시스템
# - **감정 분석**: 소셜 미디어 데이터 분석 등
#
# LLM은 그 성능과 가능성 덕분에 다양한 분야에서 혁신을 일으키고 있으며, 앞으로도 더욱 발전할 것으로 기대되고 있습니다.

# %% [markdown]
# # max_tokens 적용
# - 효과 : 응답의 길이를 조절

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content": "당신은 헬스 트레이너입니다"},
        {"role": "user", "content": "운동을 규칙적으로 했을 때의 장점이 뭐가 있을까? 키워드만 줘"}
    ],
    max_tokens=100  # 응답의 길이를 100 토큰으로 제한
)

print(response.choices[0].message.content)
# Out:
# 1. 체력 증진
# 2. 체중 조절
# 3. 근육 증가
# 4. 심장 건강
# 5. 스트레스 감소
# 6. 정신 건강 개선
# 7. 면역력 강화
# 8. 혈당 조절
# 9. 수면 질 향상
# 10. 노화 방지

# %% [markdown]
# # temperature 적용
# - 효과 : 응답의 창의성을 조절

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content": "당신은 매우 논리적이고 정확한 어시스턴트입니다"},
        {"role": "user", "content": "여행을 준비 할 때 필요한 필수 항목은 무엇인가요"}
    ],
    max_tokens=200,  # 응답의 길이를 200 토큰으로 제한
    temperature=1  # 창의성을 0.5로 설정
)

print(response.choices[0].message.content)
# Out:
# 여행을 준비할 때 필요한 필수 항목은 여행의 목적지, 기간, 계절 등에 따라 다를 수 있지만, 일반적으로 다음과 같은 항목들이 있습니다:
#
# 1. **여권 및 비자**: 해외 여행 시 유효한 여권과 필요한 비자.
#
# 2. **항공권**: 예약 확인서 및 전자 티켓.
#
# 3. **숙소 예약 확인서**: 호텔, 에어비앤비 등의 예약 증명서.
#
# 4. **여행 보험**: 여행 중 발생할 수 있는 사고나 의료비를 대비한 보험.
#
# 5. **현금 및 신용카드**: 현지 통화, 신용카드, 체크카드 등.
#
# 6. **의류**: 목적지의 날씨에 맞는 의류 및 신발.
#
# 7. **세면도구**: 개인 위생을 위한 치약, 칫솔, 샴푸, 바디워

# %% [markdown]
# # Top P(또는 nucleus sampling)
# - Top P의 값을 0.9로 설정하면, 모델은 누적 확률이 90%에 도달할 때까지 가장 높은 확률의 토큰들을 선택하고, 나머지 토큰들은 무시하게 됩니다.

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content": "당신은 매우 논리적이고 정확한 어시스턴트입니다"},
        {"role": "user", "content": "여행을 준비 할 때 필요한 필수 항목은 무엇인가요"}
    ],
    max_tokens=200,  # 응답의 길이를 200 토큰으로 제한
    # temperature=1  # 창의성을 0.5로 설정
    top_p=0.9  # 누적 확률이 90%에 도달할 때까지 선택
)

print(response.choices[0].message.content)
# Out:
# 여행을 준비할 때 필요한 필수 항목은 여행의 목적지, 기간, 계절, 개인의 필요에 따라 다를 수 있지만, 일반적으로 고려해야 할 항목들은 다음과 같습니다.
#
# 1. **여권 및 비자**: 국제 여행의 경우 여권과 필요한 비자를 확인합니다.
# 2. **항공권 및 교통편**: 비행기 티켓, 기차표, 자동차 렌트 예약 등.
# 3. **숙소 예약**: 호텔, 게스트하우스, 에어비앤비 등의 숙소 예약 정보.
# 4. **여행 보험**: 사고나 질병에 대비한 보험 가입.
# 5. **의류 및 신발**: 여행지의 날씨에 맞는 적절한 옷과 편안한 신발.
# 6. **세면도구 및 개인 용품**: 칫솔, 치약, 샴푸, 세안제 등.

# %% [markdown]
# #**Temperature와 Top P를 같이 사용**
# - 응답의 다양성과 일관성 사이에서 균형을 맞출 수 있습니다.
#
#
# #### 1. **높은 Temperature (1.0 이상) + 높은 Top-p (0.9~1.0)**
#    - **특징**:
#      - 생성된 텍스트가 매우 창의적이고 다양하며, 예측하기 어려운 결과가 나올 수 있습니다.
#      - 확률이 낮은 단어들도 자주 선택되기 때문에, 결과가 독특하거나 비논리적일 수 있습니다.
#    - **사용 사례**:
#      - 창의적인 글쓰기, 스토리텔링, 아이디어 브레인스토밍 등에서 예상치 못한 결과를 원할 때.
#      - 실험적인 콘텐츠 생성.
#
# #### 2. **높은 Temperature (1.0 이상) + 낮은 Top-p (0.3~0.7)**
#    - **특징**:
#      - 매우 창의적이지만, 텍스트가 때때로 비논리적이거나 일관성이 떨어질 수 있습니다.
#      - 제한된 단어 집합에서 불확실한 선택이 이루어져 결과가 예상치 못한 방향으로 갈 수 있습니다.
#    - **사용 사례**:
#      - 독특하고 실험적인 텍스트 생성.
#      - 예술적인 표현이나 새로운 아이디어를 탐색할 때.
#
# #### 3. **낮은 Temperature (0.2\~0.5) + 높은 Top-p (0.9~1.0)**
#    - **특징**:
#      - 일관되고 예측 가능한 텍스트를 생성하며, 안정적이고 논리적인 결과를 제공합니다.
#      - 다양한 단어를 고려하면서도, 확률이 높은 단어를 중심으로 선택합니다.
#    - **사용 사례**:
#      - 정보 전달, 기술 문서 작성, 공식적인 답변 등에서 일관된 결과가 필요할 때.
#      - 실용적인 응용 프로그램에서의 안정적 출력.
#
# #### 4. **낮은 Temperature (0.2\~0.5) + 낮은 Top-p (0.3~0.7)**
#    - **특징**:
#      - 매우 보수적이고 제한적인 텍스트 생성. 확률이 높은 단어들만 선택되어 결과가 단조롭고 반복적일 수 있습니다.
#      - 텍스트의 창의성이 제한되며, 매우 일관된 결과가 나옵니다.
#    - **사용 사례**:
#      - 매우 안정적이고 보수적인 텍스트 생성이 필요할 때.
#      - 규칙이 명확히 정의된 상황에서의 응답 (예: 특정한 포맷의 문장 생성, 공식 문서 작성).

# %% [markdown]
# # n 적용
# - 효과 : 여러 응답 생성

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content": "당신은 생산관리 전문가입니다"},
        {"role": "user", "content": "생산성을 높이는 팁을 알려주세요"}
    ],
    n = 3  # 3개의 응답 생성
)
for i, choice in enumerate(response.choices):
    print(f"Response {i+1}: {choice.message.content}")
# Out:
# Response 1: 생산성을 높이기 위한 여러 가지 팁이 있습니다. 다음은 그 중 몇 가지입니다:
#
# 1. **목표 설정**: SMART (Specific, Measurable, Achievable, Relevant, Time-bound) 원칙에 따라 구체적이고 측정 가능한 목표를 설정하세요. 명확한 목표는 집중력을 높이고 효과적인 작업을 도와줍니다.
#
# 2. **우선순위 정하기**: 할 일이 많을 때는 긴급성과 중요성을 기준으로 우선순위를 정하세요. 이를 통해 가장 중요한 작업에 집중할 수 있습니다.
#
# 3. **시간 관리**: Pomodoro 기법(25분 작업 후 5분 휴식) 등과 같은 시간 관리 기법을 활용하세요. 짧은 작업 시간과 규칙적인 휴식을 통해 집중력을 유지할 수 있습니다.
#
# 4. **자동화 도구 활용**: 반복적인 작업은 자동화 도구를 사용해 효율성을 높이세요. 예를 들어, 데이터 입력 작업을 자동화하거나, 소프트웨어를 통해 일정 관리 및 업무 분담을 효율적으로 할 수 있습니다.
#
# 5. **작업 환경 정리**: 깨끗하고 정돈된 작업 환경은 집중력을 높이며, 불필요한 스트레스를 줄입니다. 필요한 도구와 자료만 가까이에 두세요.
#
# 6. **팀워크 강화**: 팀원들과의 원활한 커뮤니케이션과 협력은 생산성을 높이는 데 중요합니다. 정기적인 회의를 통해 진행 상황을 공유하고 피드백을 주고받으세요.
#
# 7. **지식과 기술 향상**: 지속적인 교육과 훈련을 통해 개인과 팀의 역량을 강화하세요. 최신 기술과 트렌드에 대한 이해도를 높이는 것이 중요합니다.
#
# 8. **기술 활용**: 프로젝트 관리 소프트웨어, 협업 도구, 클라우드 스토리지 등을 활용하여 정보를 효율적으로 공유하고 작업 진행 상황을 관리하세요.
#
# 9. **정기적인 리뷰**: 정기적으로 작업 진행 상황을 검토하고 피드백을 받으세요. 이를 통해 개선할 점을 발견하고 조정할 수 있습니다.
#
# 10. **건강 관리**: 신체적, 정신적 건강은 생산성에 큰 영향을 미칩니다. 규칙적인 운동, 충분한 수면, 건강한 식사를 통해 에너지를 유지하세요.
#
# 이 팁들을 참고하여 본인의 작업 스타일에 맞게 적용해 보세요. 지속적인 개선을 통해 생산성을 높이는 데 도움이 될 것입니다.
# Response 2: 생산성을 높이는 데 도움이 되는 몇 가지 팁을 제공합니다:
#
# 1. **목표 설정**: 구체적이고 측정 가능한 목표를 설정하세요. SMART (Specific, Measurable, Achievable, Relevant, Time-bound) 원칙을 적용하면 효과적입니다.
#
# 2. **작업 우선순위 정하기**: 중요도와 긴급성에 따라 작업을 분류하여 우선순위를 정하세요. 이를 통해 중요한 작업에 더 많은 시간을 할애할 수 있습니다.
#
# 3. **시간 관리 기술**: Pomodoro 기법(25분 집중, 5분 휴식)을 사용해 집중력을 유지하고, 주기적인 휴식으로 피로를 줄입니다.
#
# 4. **생산 과정 표준화**: 작업 프로세스를 표준화하여 일관성을 높이고, 불필요한 변동을 줄입니다.
#
# 5. **계속적인 개선**: Kaizen(지속적 개선) 접근 방식을 도입하여 작은 개선을 지속적으로 수행하세요. 팀원 모두가 개선 아이디어를 제안할 수 있도록 장려합니다.
#
# 6. **자동화 및 기술 활용**: 생산 공정에서 가능한 부분을 자동화하고 최신 기술을 도입하여 효율성을 높입니다.
#
# 7. **팀워크와 커뮤니케이션**: 팀원 간의 원활한 소통은 오해를 줄이고 협업을 촉진합니다. 정기적인 회의나 체크인 등을 통해 정보를 공유하세요.
#
# 8. **교육 및 훈련**: 직원들이 필요한 기술과 지식을 갖추도록 교육하여 생산성을 높입니다. 이를 통해 오류를 줄이고 작업 효율성을 향상시킬 수 있습니다.
#
# 9. **작업 환경 개선**: 안전하고 쾌적한 작업 환경을 조성하여 직원들의 집중력과 사기를 높입니다.
#
# 10. **피드백 수집**: 직원들과 고객으로부터의 피드백을 적극적으로 수집하고 이를 바탕으로 개선해 나가세요.
#
# 이러한 팁들을 적용하면 생산성을 높이는 데 도움이 될 것입니다. 각 기업의 상황에 맞게 조정하여 효율적으로 활용하세요.
# Response 3: 생산성을 높이는 방법은 여러 가지가 있으며, 기업의 특정 상황이나 산업에 따라 다를 수 있습니다. 하지만 일반적으로 효과적인 몇 가지 팁은 다음과 같습니다:
#
# 1. **효율적인 작업 프로세스 구축**: 프로세스 맵을 작성하여 각 단계에서의 시간과 자원을 분석하고 불필요한 단계를 제거합니다.
#
# 2. **자동화 도입**: 반복적인 수작업 작업을 자동화하여 인력을 더 가치 있는 작업에 배치합니다. 이를 통해 시간을 절약하고 오류를 줄일 수 있습니다.
#
# 3. **적절한 도구 사용**: 최신 기술과 소프트웨어를 활용하여 생산성을 높입니다. 예를 들어, 프로젝트 관리 소프트웨어나 생산 관리 시스템을 도입합니다.
#
# 4. **스마트 재고 관리**: 재고 수준을 최적화하고 과잉 재고를 줄이는 동시에 필요한 자재를 제때 확보할 수 있도록 합니다.
#
# 5. **직원 교육 및 개발**: 직원들이 자신의 업무에 대해 더 잘 이해하고 숙련될 수 있도록 지속적인 교육 프로그램을 제공합니다.
#
# 6. **커뮤니케이션 개선**: 팀 간의 원활한 커뮤니케이션을 통해 문제가 발생할 가능성을 줄이고, 빠른 의사 결정을 할 수 있도록 합니다.
#
# 7. **생산 목표 설정**: SMART(구체적, 측정 가능, 달성 가능, 관련성, 시간 제한) 목표를 설정하여 생산성과 성과를 명확하게 방향성을 갖고 관리합니다.
#
# 8. **유연한 근무 환경**: 직원들이 최적의 환경에서 일할 수 있도록 하여 동기부여를 높이고 작업 효율성을 증가시킵니다.
#
# 9. **지속적인 개선(CI)**: 운영 프로세스의 지속적인 개선을 위한 계획을 세우고, 정기적으로 검토하여 최적의 결과를 도출합니다.
#
# 10. **성과 분석 및 피드백 활용**: 데이터를 분석하여 생산 과정을 모니터링하고, 정기적으로 피드백을 수집해 개선점과 성공 사례를 공유합니다.
#
# 이 방법들을 적용하면 생산성을 증대시키는 데 큰 도움이 될 수 있습니다. 각 조직의 특성과 상황에 맞는 전략을 선택하는 것이 중요합니다.

# %% [markdown]
# # stop 적용
# - 효과 : 특정 단어에서 응답 멈추기

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content": "당신은 커피 전문가입니다"},
        {"role": "user", "content": "커피 한 잔을 만드는 과정을 설명해 주세요"}
    ],
    stop = ["\n"]
)
print(response.choices[0].message.content)
# Out:
# 커피 한 잔을 만드는 과정은 여러 단계로 나눌 수 있습니다. 여기서는 일반적인 드립 커피를 만드는 과정을 설명하겠습니다.

# %% [markdown]
# # image_input

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content": "당신은 감성이 풍부한 화가입니다"},
        {"role": "user", "content": "이미지에 보이는 풍경을 설명해줘"},
        {"role": "user", "content": "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg"}
    ],
    max_tokens=200,
)
print(response.choices[0].message.content)
# Out:
# 이 이미지는 아름다운 자연의 보존 구역을 보여줍니다. 사진의 중심에는 나무로 만들어진 보도가 넓게 펼쳐져 있으며, 그 위를 걷는 사람들의 모습이 보입니다. 보도는 울창한 숲 속으로 이어져 자연과 사람의 조화를 상징하고 있습니다.
#
# 주변에는 푸르른 나무들, 다양한 식물들이 가득하며, 그 사이로 햇빛이 부드럽게 비추고 있어 따뜻한 느낌을 줍니다. 배경에는 수풀과 하늘이 어우러져 있으며, 맑은 하늘이 그림처럼 펼쳐져 있습니다. 이곳은 여유롭고 평화로운 분위기를 제공하며, 자연과 가까이 할 수 있는 안식처로 보입니다. 특히 수생 식물들이 자생하는 모습과 그들이 비추는 반영이 조화를 이루어, 생명의 아름다
