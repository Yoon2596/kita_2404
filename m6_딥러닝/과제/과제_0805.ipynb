# %% [markdown]
# Task1_0805. 주어진 함수 $ g(x,y)=e^{x+y} +sin(x∗y) $에 대해 x에 대한 편미분과 y에 대한 편미분을 구하세요.

# %%
import sympy
# Jupyter 노트북에서 수학식이 LaTeX 표현을 위해 필요함
sympy.init_printing(use_latex='mathjax')

# %%
x, y = sympy.symbols('x y')
g = sympy.exp(x+y) + sympy.sin(x*y)
g
# Out:
#  x + y
# ℯ      + sin(x⋅y)

# %%
# x에 대한 편미분
g.diff(x)
# Out:
#               x + y
# y⋅cos(x⋅y) + ℯ

# %%
# y에 대한 편미분
g.diff(y)
# Out:
#               x + y
# x⋅cos(x⋅y) + ℯ

# %% [markdown]
# # 강사님 버전

# %%
import sympy

# Jupyter 노트북의 수학식의 LaTeX표현을 위해 필요함
sympy.init_printing(use_latex='mathjax')

import sympy as sp
x, y = sp.symbols('x y')
g = sp.exp(x + y) + sp.sin(x * y)

# x에 대한 편미분
partial_gx = sp.diff(g, x)

# y에 대한 편미분
partial_gy = sp.diff(g, y)

partial_gx, partial_gy
# Out:
# ⎛              x + y                x + y⎞
# ⎝y⋅cos(x⋅y) + ℯ     , x⋅cos(x⋅y) + ℯ     ⎠
