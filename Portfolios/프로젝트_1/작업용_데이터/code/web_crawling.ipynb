# %%
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, WebDriverException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
from time import sleep
import pandas as pd
import os
import json
import csv
import requests
import folium
import numpy as np
import platform
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
import re

# %%
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, WebDriverException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
from time import sleep
import pandas as pd
import os


############################################################################################################################################################################

def set_review_order_to_recent():
    max_retries = 5
    retries = 0
    while retries < max_retries:
        try:
            # 새로 고침
            driver.refresh()
            time.sleep(3)
            # 리뷰 정렬 드롭다운 클릭
            driver.execute_script("document.querySelectorAll('#main > section.section.mb-20 > div.section-header._1xvmu764._1xvmu765 > div > div._10fm75h2 > a').forEach(a => a.click())")
            time.sleep(2)
            # '최근 등록순' 클릭
            driver.execute_script("document.querySelectorAll('#main > section.section.mb-20 > div.section-header._1xvmu764._1xvmu765 > div > div._10fm75h2 > div > label:nth-child(2) > span').forEach(a => a.click())")
            time.sleep(4)

            # 정렬이 변경되었는지 확인
            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            sort_indicator = soup.select_one('#main > section.section.mb-20 > div.section-header._1xvmu764._1xvmu765 > div > div._10fm75h2 > div > label._10fm75h1._1xvmu767 > span')
            if sort_indicator and '최근 등록순' in sort_indicator.text:
                print("리뷰가 '최근 등록순'으로 변경되었습니다.")
                break
        except Exception as e:
            print("정렬 변경 중 오류 발생:", e)
        
        retries += 1
        if retries == max_retries:
            print("최대 재시도 횟수 도달. 정렬 변경 실패.")
            break
        else:
            print(f"재시도 {retries}/{max_retries}")
            time.sleep(2)






# 초기 설정 및 URL 열기
url = 'https://app.catchtable.co.kr/'
id = '01076300106'
pw = '=Cherrycow910'

# 브라우저 열기
driver = webdriver.Chrome()
driver.get(url)

# 페이지 로드 대기
time.sleep(5)

wait = WebDriverWait(driver, 10)

# 팝업 정리
driver.execute_script("document.querySelectorAll('#dock > div > nav > a:nth-child(5)').forEach(a => a.click())")           
driver.execute_script("document.querySelectorAll('._1qn1ik44._1ltqxco1e').forEach(a => a.click())")
time.sleep(2)
driver.execute_script("document.querySelectorAll('#main > section > div.__inner > div > div > div._1w07br45 > button:nth-child(3)').forEach(a => a.click())")

# 로그인 절차
wait.until(EC.presence_of_element_located((By.ID, 'login-id'))).send_keys(id)
wait.until(EC.presence_of_element_located((By.ID, 'login-pw'))).send_keys(pw)
wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, '#main > div > button'))).click()

# 로그인 후 팝업 닫기
wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, '#popup > div > div > div > div > div._1qn1ik43 > button._1qn1ik44._1ltqxco1u'))).click()

# 내 주변 들어가기
time.sleep(3)
# wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, '#main > section:nth-child(6) > div > div.section-body > div > div > div > a.icon'))).click()

# 필터 클릭
wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, '#main > div.search-header.__autohide > div:nth-child(2) > div > div.speb4g1 > button'))).click()
time.sleep(2)

# 서울에서 특정 지역 (예: 강남) 필터링
wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, '.fldt7j1 > button:nth-child(2)'))).click()

#overlay > div.BottomSheet_bottomSheetContent__1tetrf80.BottomSheet_bottomSheetContent_hasMaxWidth_true__1tetrf81 > div > main > div:nth-child(1) > section > div.fldt7j0 > div.fldt7j2 > button.FilterChip_container__1mb4yfk0.app_typo_body_body1__jg3o1w1d.FilterChip_container_isFocused_true__1mb4yfk2
# select문 마지막 child(2) 이부분만 수정해주면 원하는 지역을 찍어줌 괄호안 숫자만 바꾸면 됨
wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, '#overlay > div.BottomSheet_bottomSheetContent__1tetrf80.BottomSheet_bottomSheetContent_hasMaxWidth_true__1tetrf81 > div > main > div:nth-child(1) > section > div.fldt7j0 > div.fldt7j2 > button:nth-child(9) > span'))).click()
wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, '#overlay > div.BottomSheet_bottomSheetContent__1tetrf80.BottomSheet_bottomSheetContent_hasMaxWidth_true__1tetrf81 > div > footer > div.j4ixu30 > div > button'))).click()
time.sleep(2)
driver.execute_script("document.querySelectorAll('#search-result-header > div._10fm75h2 > button').forEach(a => a.click())")
time.sleep(2)
driver.execute_script("document.querySelectorAll('#search-result-header > div._10fm75h2 > div > label:nth-child(3)').forEach(a => a.click())")
time.sleep(2)

# 총 매장수 확인 및 기타
m_num = driver.page_source
soup = BeautifulSoup(m_num, 'html.parser')
num = int(soup.select_one('#search-result-header > div._54rkq62 > strong').text.replace(',','').replace('개',''))
print(num)
idx = 5, 15, 17, 29, 33, 43, 51, 59, 62, 70, 73, 78, 78
scroll_increment = 120
data = []
# idx = 16

while True:
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    items = soup.select('.restaurant-info')
    for item in items:
        current_scroll_position = 0
        if idx != 3:    # 스시소라가 계속 안들어가져서 제외하고 크롤링하는 조건문 
            if item is not None:
                time.sleep(3)
                # 가게 리스트 앞부분만 긁어오는 코드
                Category = item.select_one('.detail .restaurant-meta .tags').text.split(' • ')[0] if item.select_one('.detail .restaurant-meta .tags') else "NA"
                Location = item.select_one('.detail .restaurant-meta .tags').text.split(' • ')[1] if item.select_one('.detail .restaurant-meta .tags') else "NA"
                Price_range = item.select_one('.detail .restaurant-meta .price').text if item.select_one('.detail .restaurant-meta .price') else "NA"

                # 가게 클릭
                driver.find_element(By.CSS_SELECTOR, f'#virtual_{idx}').click()
                time.sleep(2)

                idx += 1
                
                # 팝업 광고 닫아주는 스크립트
                driver.execute_script("document.querySelectorAll('._1qn1ik44._1ltqxco1u').forEach(a => a.click())")
                time.sleep(1)

                # 지도 클릭 및 세부주소
                driver.execute_script("document.querySelectorAll('._4qv338d.location').forEach(a => a.click())")
                time.sleep(1)
                driver.execute_script("document.querySelectorAll('.z8ddia').forEach(a => a.click())")
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                shop_name = soup.select_one('.name').text if soup.select_one('.name') else "NA"
                region = soup.select_one('.addr').text.replace('복사', '') if soup.select_one('.addr') else "NA"
                time.sleep(3)
                driver.back()
                time.sleep(3)

                print(shop_name)

                # 리뷰클릭
                script = "document.querySelectorAll('._4qv338e').forEach(a => a.click())"
                driver.execute_script(script)
                time.sleep(2)
                
                #main > section.section.mb-20 > div.section-header._1xvmu764._1xvmu766 > div > div > a

                # # 페이지 줌 레벨 33%로 설정
                # driver.execute_script("document.body.style.zoom='33%'")
                # time.sleep(3)

 

                # html = driver.page_source
                # soup = BeautifulSoup(html, 'html.parser')

                # driver.execute_script("document.querySelectorAll('#main > section.section.mb-20 > div.section-header._1xvmu764._1xvmu765 > div > div._10fm75h2 > a').forEach(a => a.click())")
                # time.sleep(2)
                # driver.execute_script("document.querySelectorAll('#main > section.section.mb-20 > div.section-header._1xvmu764._1xvmu765 > div > div._10fm75h2 > div > label:nth-child(2) > span').forEach(a => a.click())")
                # time.sleep(4)


                # 페이지 줌 레벨 33%로 재설정
                driver.execute_script("document.body.style.zoom='33%'")
                time.sleep(3)

                # 리뷰 정렬을 '최근 등록순'으로 설정
                set_review_order_to_recent()

                # 매장 정보 및 리뷰 가져오기
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')

            
                
                # 매장 정보 및 리뷰 가져오기
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')

                shop_rating = soup.select_one('.score').text if soup.select_one('.score') else "NA"
                review_num = soup.select_one('#main > div.tab-menu.sticky > ul > li.active > a > span:nth-child(2)').text.replace(',','') if soup.select_one('#main > div.tab-menu.sticky > ul > li.active > a > span:nth-child(2)') else 'NA'
                
                # 리뷰수
                r_num = int(review_num)
                time.sleep(5)
                # 리뷰 백개 뽑기
                if r_num > 50:
                    for i in range(50):
                        html = driver.page_source
                        soup = BeautifulSoup(html, 'html.parser')
                        
                        # 찜
                        save = soup.select_one("#dock > div > span").text if soup.select_one("#dock > div > span") else "NA"
                        # 유저 이름
                        nickname = soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__header > div.__user-info > a > h4 > span").text if soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__header > div.__user-info > a > h4 > span") else "NA"
                        # 유저 별점
                        user_rating = soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__header > div.__review-meta.__review-meta--with-rating > div > a > div").text if soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__header > div.__review-meta.__review-meta--with-rating > div > a > div") else "NA"
                        # 점심 저녁
                        lun_di = soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__header > div.__review-meta.__review-meta--with-rating > div > p").text if soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__header > div.__review-meta.__review-meta--with-rating > div > p") else "NA"
                        # 리뷰 등록시간
                        times = soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__header > div.__review-meta.__review-meta--with-rating > span").text if soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__header > div.__review-meta.__review-meta--with-rating > span") else "NA"
                        # 리뷰
                        review = soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__body > div.__review-post > p").text if soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__body > div.__review-post > p") else "NA"

                        data.append([shop_name,shop_rating,r_num,Category,Location,region,Price_range,nickname,user_rating,lun_di,times,review,save])
                        print(nickname)
                        
                        time.sleep(1)
                        last_height = driver.execute_script("return document.body.scrollHeight")
                        current_scroll_position += scroll_increment
                        driver.execute_script(f"window.scrollTo(0, {current_scroll_position});")
                        time.sleep(2)


                else :
                    for i in range(r_num):
                        html = driver.page_source
                        soup = BeautifulSoup(html, 'html.parser')
                        
                        # 찜
                        save = soup.select_one("#dock > div > span").text if soup.select_one("#dock > div > span") else "NA"
                        # 유저 이름
                        nickname = soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__header > div.__user-info > a > h4 > span").text if soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__header > div.__user-info > a > h4 > span") else "NA"
                        # 유저 별점
                        user_rating = soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__header > div.__review-meta.__review-meta--with-rating > div > a > div").text if soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__header > div.__review-meta.__review-meta--with-rating > div > a > div") else "NA"
                        # 점심 저녁
                        lun_di = soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__header > div.__review-meta.__review-meta--with-rating > div > p").text if soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__header > div.__review-meta.__review-meta--with-rating > div > p") else "NA"
                        # 리뷰 등록시간
                        times = soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__header > div.__review-meta.__review-meta--with-rating > span").text if soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__header > div.__review-meta.__review-meta--with-rating > span") else "NA"
                        # 리뷰
                        review = soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__body > div.__review-post > p").text if soup.select_one(f"#shopReviewListScroll_{i} > div > article > div.__body > div.__review-post > p") else "NA"
                        
                        data.append([shop_name,shop_rating,r_num,Category,Location,region,Price_range,nickname,user_rating,lun_di,times,review,save])
                        print(nickname)
                        time.sleep(1)
                        last_height = driver.execute_script("return document.body.scrollHeight")
                        current_scroll_position += scroll_increment
                        driver.execute_script(f"window.scrollTo(0, {current_scroll_position});")
                        time.sleep(2)

                # 페이지 줌 레벨 100%로 설정
                driver.execute_script("document.body.style.zoom='100%'")

                time.sleep(3)  # 페이지가 로드될 시간을 줍니다
                driver.back()
                driver.back()
                time.sleep(3)
                
                # 캐치테이블 가게 리스트 스크롤링
                # 모달 창 내부를 스크롤 arguments[0].scrollTop += 260 상황에 맞게 px 정해주면 됨
                try:
                    modal_scroll_element = driver.find_element(By.CSS_SELECTOR, '#root > div > div > div > div._53lcbm0._53lcbm1 > div')
                    driver.execute_script('arguments[0].scrollTop += 270', modal_scroll_element)
                    time.sleep(2)
                    html = driver.page_source
                    soup = BeautifulSoup(html, 'html.parser')
                    items = soup.select('.restaurant-info')
                except StaleElementReferenceException:
                    print("요소를 다시 찾습니다.")
                    modal_scroll_element = driver.find_element(By.CSS_SELECTOR, '#root > div > div > div > div._53lcbm0._53lcbm1 > div')
                    driver.execute_script('arguments[0].scrollTop += 270', modal_scroll_element)
                    time.sleep(2)
                    html = driver.page_source
                    soup = BeautifulSoup(html, 'html.parser')
                    items = soup.select('.restaurant-info')
        else:
            try:
                modal_scroll_element = driver.find_element(By.CSS_SELECTOR, '#root > div > div > div > div._53lcbm0._53lcbm1 > div')
                driver.execute_script('arguments[0].scrollTop += 270', modal_scroll_element)
                time.sleep(2)
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                items = soup.select('.restaurant-info')
            except StaleElementReferenceException:
                print("요소를 다시 찾습니다.")
                modal_scroll_element = driver.find_element(By.CSS_SELECTOR, '#root > div > div > div > div._53lcbm0._53lcbm1 > div')
                driver.execute_script('arguments[0].scrollTop += 270', modal_scroll_element)
                time.sleep(2)
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                items = soup.select('.restaurant-info')
            idx += 1
            
            
driver.quit()
# Out:
# 582
# 로우앤슬로우
# 건강한 미식가_25269
# lkj12!!!!!!
# 션조시코코아빠
# 예약필수죠
# 외로운 식도락가_34751
# rinikim
# 재능있는 미식가_10191
# 행복한 마스터_29480
# 호기심 많은 식객_59542
# 차이엔
# 발랄한 식객_27120
# 둥이통이
# 위이이이이이잉
# 화려한 식객_36340
# 꼼꼼한 맛사냥꾼_43906
# 촤누
# kenny
# 우수한 맛사냥꾼_98416
# 호신용손난로
# 갱갱이726
# wsdx****
# 애기 치타
# 이노미
# 김인육
# 승빙0706
# 깜찍한 셀럽_41284
# 즐거운 개척가_34337
# 쵠링
# 고독한 개척가_93828
# 은쓸
# 세상천지
# 이나박식
# 가영5
# Stanley
# K맑은샘
# 다잉콩
# 뚜비듀바
# 얄밉지롱
# 윤십오
# 꼬기염
# 손사장
# 기분좋은 식도락가_59517
# 재미있는 맛사냥꾼_10183
# 행복한 셀럽_46711
# 날으는쿠키
# 초이cms
# 놀고먹는인생
# 규스규스
# 우정규
# 포항장인경
# 오스테리아 오르조
# euha
# 강직한 식객_85885
# 캐시퍼00
# 지현이랑말랑이
# 콜드브류소이라떼
# Rok07
# 오레오1004
# 따뜻한 미식가_44451
# 남다른 식도락가_60609
# toru07
# 온화한 식객_77499
# 굥구리9
# 굥구리9
# ooUSHoo
# Dagu
# 새로운 식객_99228
# 옴뇨뇸
# 영서언니
# 하야니
# 아라미♥진&진
# Hyoador
# 오렌지꽃피는
# soljjang
# hippolicity
# dla002
# 음식인생사랑
# cheongdy
# 지혜로운 마스터_67927
# pieldo
# juyoungjuiin
# safflower
# 태종태세문단속잘해라
# 행복한 개척가_44371
# elly0826
# 동금
# kkarcia
# Adam Ballin
# dlckdud
# 지너니입니다
# leahly
# 조용한 마스터_25607
# 부드러운 마스터_94226
# 기분좋은 마스터_12226
# 정소금0217
# 한명신
# 분홍지렁이
# Markkkkkk
# 밝은 식도락가_46990
# 밝은 식도락가_46990
# 랗할
# 이속우화
# yuna9278
# 밍먕묭먕
# 외로운 맛사냥꾼_40498
# 비비빕비.
# 가을 솜
# yjseo****
# 짜증왕왕
# jnqrt
# 나이뽀그치
# Effy0506
# komment
# 원숭이강아지
# 따뜻한 미식가_7432
# 봉이2
# 은동사
# ma mark
# 아름다운 개척가_48011
# 참소라
# 여유로운 마스터_75879
# 인기많은 마스터_23078
# 건강한 식도락가_93307
# 민교민채
# 여유로운 맛사냥꾼_96123
# Soosoo5
# 발랄한 셀럽_76609
# 이곰미
# Attila Park
# tmdwo
# jaehoon
# 붕기님
# 따뜻한 개척가_90964
# 유명한 식객_91529
# Hello8
# 비범한 식도락가_51845
# 성운히
# Estrella✨
# 삼봉햄
# 우수한 마스터_63254
# 두애삼
# 혤반장
# ㄱ.Ｊ
# s2ujin
# 링하4301
# 먹지연
# 뇨ㅇ니뇽니
# 백둉이
# 멋찐슈
# 페라리맨
# 박창균
# 발랄한 맛사냥꾼_94580
# 스시우미 용산
# 슈댕e
# mikaelrv93
# 규혁임
# 꼼꼼한 식객_48309
# 동밈미
# 전병달
# 냑냥
# 혜딩1
# 리케인
# 게섹이스
# 신나는 맛사냥꾼_30304
# 이범미인
# 곰돌이푸푸우
# 발랄한 개척가_73141
# Foodlex
# 호두파이조각
# 호락
# 비범한 맛사냥꾼_61020
# 고독한 셀럽_85932
# 호황
# 줄리아 정
# 2012555248 이진경
# Yumminmy
# 잡식성 동물
# ADOM
# 유지미
# 슈댕e
# 개구진 미식가_6668
# shwankim
# 꿈꾸는 식객_48074
# 새로운 마스터_73935
# 쾌활한 개척가_60380
# 3917542
# Sh5036
# 부드러운 식객_3558
# wine_dinings__
# 졜롱
# 2salt
# 네꼬
# akibl****
# 곰돌잉푸우
# 입생너랑
# JH_JH_JH
# LEEJUNYONG
# 새로운 셀럽_61632
# rlawogus567
# 이 승재
# 풍뎅
# dnfma19
# 제현_
# 쿠촐로 서울
# 유명한 식도락가_82138
# 예리한 맛사냥꾼_33249
# 경쾌한 미식가_32887
# 시소맘
# 짱아맘지니
# 똑똑한 맛사냥꾼_96968
# 김수린니
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# MAISON HANNAM
# zzjsi122
# 따샤라쿵
# 조용한 식객 126
# Jy07
# Gloria000
# 람쥐137
# Saint jean
# 활기찬 식도락가_47989
# 재능있는 미식가_69464
# 슈나나나
# 정직한 맛사냥꾼_73777
# bolcond
# 미징징님
# 여유로운 맛사냥꾼_45495
# Dr.Reena kim
# 깜찍한 마스터_64482
# 호기심 많은 마스터_27264
# 곰돌이72
# 부꿍부꾼
# 포뇨테이블
# 고독한 미식가_No.1
# pinball
# 도도한 맛사냥꾼_90894
# 다빈아씨
# 온화한 미식가_44719
# 안진원1
# 건강한 식도락가_79339
# 웅야이
# 빛나는 식객_71153
# 서현맘
# 아키와놀고먹고행복하고
# 준영대두
# 발랄한 맛사냥꾼_12555
# 문스타프로
# lotus_jin
# 리얼무비
# 민희보존법칙
# 윤뽀
# 도도한 셀럽_61932
# Nanhee Lee
# KHANC
# 정수아93
# ssssjjjj
# 린찌
# JUNY07
# 쇼블은말보로
# 발랄한 마스터_41316
# Baekk
# 다사랑해
# Afixbw
# 레에스티우
# Harago
# 후루진
# 따뜻한 셀럽_44917
# 아스필리쿠에타
# 아름다운 개척가_88147
# lovelyyyy
# 따뜻한 셀럽_1227
# 쾌활한 식객_65931
# 全洙弘
# 서촌러버
# 해피써니
# 강직한 셀럽_18963
# 젤조아하는음식스시
# 온화한 맛사냥꾼_7207
# 크크롱롱
# 코고고고고고고
# Alice.P
# 박명재1
# 위트있는 미식가_86379
# 푸드황
# 맛집폭순이
# 화려한 미식가_5551
# 미식탐허
# 젤리걸
# 별가에요
# 재능있는 미식가_32926
# 특별한 셀럽_11860
# 빛나는 맛사냥꾼_89149
# 팍쿠키
# 장창수
# 의
# 꼼꼼한 식도락가_33254
# noobmaster
# 남다른 미식가_58574
# 음맛있으면됬지
# Chohahm
# youngkownppo
# 파인애쁠
# 목멱곰
# 신나는 셀럽_91910
# ♡김희정♡
# 유명한 마스터_36277
# NYC1
# hannah519
# 강직한 마스터_84864
# 신나는 맛사냥꾼_53381
# 착한 식객_63890
# 유심조911
# 지나가던햄스터
# 참새구경
# 쇼니노
# 아키킼
# 맛집탐방대12345
# 맛없는거먹으면화나고분함
# nicky_kimmo
# 새로운 미식가_73179
# 봉쥬르으니
# 유명한 맛사냥꾼_7537
# 샤론술통
# jru
# 하나123
# 리끌레르
# 맛집많이알려줘
# 콘초0
# 소르서르소스
# 고독한미식가003
# HJaa
# 최고의 식도락가_9813
# 비타빈
# 멍멍아 야옹해봐
# 개구진 맛사냥꾼_54678
# 재미있는 식도락가_26109
# 주리노
# HT.L
# zebralion
# 릿이
# 너그러운 묭꾸
# 프린세스핼
# 신777
# 범내려오온다
# 발랄한 개척가_78381
# 콩룡
# 천신
# 멍멍아 야옹해봐
# 화려한 식도락가_98890
# 빵송이2
# 성공한 식객_6424
# 곤롱
# 피그0
# 떠요닝ㅋ
# 푸푸s2
# 빤마
# 다원97
# 경쾌한 개척가_30618
# Ginny Park
# 프린세스핼
# 개구진 셀럽_35008
# 행복한 셀럽_49702
# 우혀니마루
# 멋진 식객_92966
# 최소피아
# 고청담 용산점
# 비트와석류
# 486우기
# 미니송
# 초코누낭
# 인기많은 마스터_31814
# 도도한 맛사냥꾼_69663
# 신재혁,강동하
# 상호98
# 뇨끼는옥수수뇨끼
# Happy :D
# 도도한 식도락가_5266
# 배추마루
# 민현기입니다
# 강한별이
# 송글로리
# 고독한 식객_18732
# 씩씩한 셀럽_71651
# 조동욱/세상이 경이롭다
# 아름다운 셀럽_49061
# 온화한 개척가_43646
# 멋진 개척가_42606
# 비주언니
# 빛나는 개척가_22232
# 쿠키 블랙
# 뽀보리
# 활기찬 맛사냥꾼_69294
# 토실이
# 사랑풍선
# 우상향1
# 멋진 미식가_55069
# 진짜배고팡팡
# nhtwo2876
# 재능있는 개척가_80068
# 호기심 많은 셀럽_2655
# 밥밥돌이
# 코코볼랑
# 가나다9
# 솔직한 식도락가_19512
# Journey83
# 에밀리얍
# 활기찬 맛사냥꾼_69294
# haeunning
# 멋진 개척가_42606
# 오레오치즈
# ohni_s
# 쿠키 블랙
# 토실이
# 라이언93
# sallychuchu
# 한량 8888
# 타카 스키야키&우나기
# SOOGAB
# sissimop
# 여유로운 맛사냥꾼_73628
# 한량 8888
# 웨이팅힘들어
# 멋진 마스터_93015
# 최채
# 오향석
# 마카미아
# 정직한 식객_3124
# Pink Tree
# NayoungAn
# 정성원타이슨
# Chloekimqwzx
# 따뜻한 셀럽_32441
# 성공한 맛사냥꾼_81642
# 살라미와초리조
# 재능있는 셀럽_63224
# jkrealstar
# 맛캅
# 무난구기
# 씩씩한 마스터_87359
# Foodyyyyy
# 부르릉이
# 이원우 Wonwoo Lee
# 고독한 개척가_53272
# 배은수다
# 솔직한입맛
# 밝은 개척가_51581
# 포르리
# 가지가가지가지
# 개코가석자
# 살라미와초리조
# 미소만세
# 재미있는 개척가_47539
# 혜영 J
# 인기많은 미식가_93766
# Yohwang
# J R
# 깜찍한 개척가_99603
# youngky****
# 멋진 셀럽_21726
# 배은수다
# 재능있는 식객_1285
# 임슐랭
# 고독한미식가9
# 호온호온
# 까니에오
# SANGAH0420
# 고독한미식가9
# 살라댕앰버시
# 해리티지
# 유왕
# 쿠사하라
# 이헌규짱
# 민민동
# 여기요오
# 로잔느83
# Myounghwan Han
# 꿈꾸는 맛사냥꾼_16792
# Kahlenk
# 들꽃승이0704
# 쾌활한 식도락가_37042
# MJ L
# 아악악악악
# 이주원타로스튜디오
# 강직한 미식가_4527
# 유리미0
# 깜찍한 미식가_31812
# 킄킄ㅋ
# 김유리리
# 화려한 개척가_6586
# 해이♡
# 밀리제이
# 성공한 식도락가_8187
# ummumm
# 무키묵이
# 발랄한 식객_35597
# 온화한 셀럽_72479
# hyun.ji
# sky921003
# 고독한대미식가
# 블링수정
# 쭈또
# Nuha263
# 착한 마스터_90785
# 아르데코초이
# 지혜로운 식객_30877
# boxes
# minim
# Treeeeee
# Jessica on
# 인기많은 식도락가_78205
# Sywonhe
# 유자언
# 우수한 마스터_89488
# 깜찍한 미식가_31812
# T&J
# 지니티미
# 린재이
# 스텔라루시
# 쥬에
# 재능있는 식도락가_50538
# 깐부
# 향이얌
# victorina13
# greyhouse
# 보토끼
# 서요밍
# 전블리0920
# hwan5377
# 나는야엄마지
# 김호경@
# mr.henry
# 돌나
# 대박피카
# 활기찬 식도락가_47989
# 꼼꼼한 식객_44981
# 파란.사과
# Gladiator
# 미냉안
# yangyeo1021
# @mlnhah
# 꼬마재우기
# 새로운 식객_79584
# 혈미녀
# 동키재키♥
# 아름다운 셀럽_47622
# Gladiator
# leejiyeon
# 냉정한만두
# 꿈꾸는 식도락가_6435
# 나날이새로운날들
# 빈승이의 냠냠기록
# 발랄한 식도락가_31620
# no.1stomach
# 에이프라이오리
# 개구리구리
# F&B INSPECTOR
# 하아푸움
# 우수한 식객_29939
# 냥냥 냥냥냥
# renehwang
# 100hwajeom
# 키키쿄쿄쿄쿄
# 아리예지
# 하프ㆍ
# 우수한 셀럽_45432
# 미슐미술
# Anese
# 외로운 식도락가_11226
# 맛죠아이
# 한우물
# 슝슝슝슝슝슝
# 우애임
# 런치맨
# ㄸㅇ
# the_victory
# 눙앙
# 여유로운 셀럽_31177
# 맛스터킴
# 밝은 식도락가_35316
# 퓨히히
# 아드리엔
# 서래마미
# 쾌활한 셀럽_84405
# 핫스윗닭강정
# 특별한 개척가_79730
# 조용한 쩝쩝이
# 그레이스오마미
# 상록수노
# 여유로운 식객_66945
# 시리톡톡
# 남다른 식객_11229
# 오르카
# 464
# 승한
# hasmoir
# 착한뜻
# 이미사용중이지않은닉네임
# 대만짱
# 쉐이2
# 씩씩한 식도락가_50063
# 부드러운 미식가_67631
# 숯덩
# 림해인
# 부드러운 식객_8024
# 다호맘
# 고마리곰
# ㅂㅣ니
# 도롯또
# 맛스터킴
# ritenour
# 착한 식도락가_48953
# jbr0081
# MarkOh
# 쁜린이
# 현욱a
# LEEJ00911
# 밍뭄미
# K.권경희
# jjin95
# 발랄한 미식가_1434
# 스시츠바사
# doob22
# 외로운 맛사냥꾼_1173
# 정직한 개척가_21487
# 신나는 식객_54884
# 라벨
# ohayi
# 스시더쿠후
# emporos
# 호뚠
# 햄쯔터
# 카일싱
# casrush
# 투민슐랭
# 솔직한 미식가_33331
# onoprince
# 배은관
# 김테이블
# 재능있는 맛사냥꾼_72152
# 호_시탐탐
# 김김김태태태태
# 깜찍한 맛사냥꾼_7551
# 발랄한 셀럽_43233
# 뽀꾸만두
# Angela Jung
# 권륜
# 조미조리
# 솔이소리ㅎ
# ssobo
# 스시더쿠후
# 외로운 개척가_66107
# 유명한 미식가_20087
# 상남매
# 건강한 미식가_70211
# 네냥이집사
# 서브랜든
# 화창한기운
# 남다른 맛사냥꾼_82270
# 바바밥밥밥
# 세계일주고고
# 고도카미시카
# 흥미로운 식객_34164
# 라떼벨
# 용~큐~룡
# Rubee
# 염미
# 코지코지
# 혜쫑이누나얌
# 밍구낑그
# 착한 맛사냥꾼_14472
# Dhhur
# 드포레 와인다이닝 용산
# 고독한 미식갸
# Mijuuu
# 먹Guru
# 르미릉
# 대쥰
# 302
# 다인이인데요
# 거거녕녕
# 이상엽상
# 외로운 식객_80284
# 주원종
# 젼젼져니
# 쯰뿡
# 윤루이
# 꼼꼼한 식도락가_25236
# 남다른 마스터_36453
# 께밸라
# 보으은
# 외로운 식도락가_76227
# 창우11
# 아아애애오오
# 하늘94
# 아름다운 식도락가_93139
# 욘둥
# 경쾌한 개척가_63227
# 촌놈테이블잡기
# 식사중이에요
# heewoneeee
# 스누피92
# 솔직한 개척가_36358
# Elise1002
# hyemmmm
# 해피쀼
# 관평대장
# 이상비나
# 수니재이
# wnls****
# 이엘바라기
# 지추쏭
# 스몰테이스트
# 쾌활한 식도락가_38883
# 다빈2ya
# Astrid
# 발랄한 마스터_52041
# 피타랑
# 똑똑한 셀럽_59398
# 콴치
# 성현132
# 조만세
# 기분좋은 식객_28660
# 생면 파스타 전문점 에그앤플라워_해방촌 본점
# 로맨틱루트
# 특별한 셀럽_64500
# 뚱뚱돼지
# 리파르도
# 조용한 맛사냥꾼_33391
# Pweetpeanut
# 깜찍한 개척가_6941
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 아치서울(arch__seoul) 용산점
# 슈퍼밀크
# 재미있는 맛사냥꾼_81844
# 착한 셀럽_76378
# 그루얌
# 융계융계
# 남다른 맛사냥꾼_58486
# 고독한 식도락가_63016
# 샹지
# 이 용섭
# imYeriel
# apfhd7
# 즐거운 셀럽_44682
# 라떼뛰뛰
# Michellel
# 로지맘
# zzuu_
# parkka0
# 달고달고
# 르네킴
# 딤예
# 위이이이이이잉
# 똑똑한 마스터_79579
# 호기심 많은 마스터_27264
# 모순덩어리a
# 고스락
# 벨수
# 재미있는 개척가_63963
# 정인돈
# NA
# 꺄뀨뀨뀨
# NA
# 소낙J
# 릴리도경
# 소욤이짱
# 슐슐깅
# 윤준석석
# 하얀꽃씨
# 아름다운 미식가_64231
# 씸바아
# 엔젤라님
# 땀콩
# 강직한 개척가_90432
# 최채
# 신나는 식도락가_67944
# 여름안녕
# 꿈꾸는 식도락가_38131
# 카모마
# NA
# junnkim
# NA
# 초승달
# lovely_b
# 똑똑한 개척가_13395
# 정굠민
# 야옹이픽
# 꼼꼼한 마스터_30467
# Aromabeach
# 개구진 셀럽_50180
# 비범한 식객_74810
# 욘두니
# 빛나는 식도락가_16826
# Alleck
# 루똥이맘
# jear****
# 무너1
# paping
# ParkKiHwan
# Q Shim
# 따뜻한 미식가_3240
# 따뜻한 미식가_32253
# Mbti cute
# Charlesjhcho
# 더블링
# 써넹이예욧
# 깜찍한 맛사냥꾼_52051
# Lee yujin
# 유명한 식도락가_98581
# 민짱구만두
# 광수니
# 조아진짜
# 크림맘맘
# 망고언니❣
# 외로운 개척가_23152
# 꽁꽁찡
# Danniel.SoJiro
# 지홍식
# nap****
# 진이6883
# 성공한 식객_70170
# 박민흠
# 경쾌한 식객_96085
# 현현999
# 기분좋은 셀럽_9170
# 샤미에
# 찌니님님
# 예리한 개척가_84457
# 레오스스스
# Nar.
# 위트있는 개척가_96664
# 데드풀
# joanna0726
# 뇨끼바
# 메뉴러버
# stu2445
# Soyoung Jun
# umchiki_um
# EsameE
# 선영
# log.
# yomisikga
# 똑똑한 미식가_99115
# 푸리니잉
# 귤Ol
# 쓰틴
# 임성민2
# 문소미ㅣ
# 투찌둥
# 외로운 맛사냥꾼_83010
# 지니ㅇㅇ
# Charlotteyun
# Ddo.u
# 무언의 식사가
# 쿄쿄쿄야옹이러버
# 히히힛 a
# luckkimm
# 정일훈
# 내가모찌언니
# 정동진정동진
# 련수
# 태롱
# 유명한 셀럽_83061
# 방청객
# 곽재섭
# 미오뽀오
# 송메롱
# 맛캅
# 건강한뚱
# 깜찍한 미식가_7160
# 박인선
# 화려한 식객_80415
# Skycoco
# ozz9k
# seleesong
# 애ㅡ옹
# 갔던데또가는게취미
# Seoultheown
# 포포둥
# Park2
# ekmom
# Sooooooobin
# 정연후
# 최고의 개척가_31428
# Cement
# 정직한 셀럽_76239
# 이햅
# 비트차
# 김민강
# Soyoung Jun
# 김하찌
# 새로운 마스터_1343
# Jgpl3107
# 별이맘이다
# Wdudmom
# 아름다운 셀럽_54185
# 건강한 마스터_62268
# ㅊㅗㅂㅏㅂ
# 지그시
# 도모
# Seungha You
# 조용한 마스터_85097
# Morning dew
# 고술진
# 호기심 많은 미식가_96897
# 멍이 7
# 흥미로운 마스터_15146
# 김스테이블
# 매기언니
# AlldayChristmas
# 주차왕파킹
# 도도한 셀럽_5466
# 아름다운 마스터_26973
# 뚀미니
# 로라빡
# gemstone1995
# hooneybi
# 함예인
# 김민둥2
# piggygirl
# 세빙구링
# 위트있는 식객_59799
# Migmigmig
# eunbbe
# ree660re
# 특별한 맛사냥꾼_9095
# 강직한 셀럽_18963
# 포도0418
# 새로운 마스터_69954
# 양승찬
# Sbkim323
# 멋진 맛사냥꾼_4263
# 발랄한 식객_46134
# 우오아앙아
# 옥이랑
# 내추럴하이
# 해니해니핸핸
# Sage Chung
# Jkuk
# 하리뽀젤리
# Oliviashs
# daisytree2
# 신운선
# heoda
# 쏭언니
# clairechichi
# jyj8308
# 맛돌탐험대
# ㄱ 김종경 임 ㄴ
# kayleeshim
# only82
# B__K
# 허윤우
# 김진양히
# 헬레나 킴
# 조늅
# 프랭크크
# 민든
# Sage Chung
# 건강한 셀럽_9482
# 민둉이
# 맛도e
# 박설민
# 성공한 맛사냥꾼_65963
# 믕치치
# 올라프8
# 위에는윌
# 맛있으면 우는 원숭이
# 세비비빅
# 베리제리
# chanti
# 미미피알
# 예리한 맛사냥꾼_13539
# 미국산김칭
# 따뜻한 개척가_60531
# 서문
# 경쾌한 마스터_91786
# okbbi
# 트리니이
# Hazel sj
# mimi._.chuu
# 똑똑한 개척가_84509
# Irene0210
# 아름다운 식도락가_22272
# 예지다람킴
# 기분좋은 미식가_4229
# 심퍼티쿠시 용산점
# 예리한 미식가_19017
# 철판요리
# Kate 이경아
# hyellll
# 꿈꾸는 개척가_97513
# 잭그레인키
# 호기심 많은 마스터_27264
# 빵이조아
# 행복한 마스터_62836
# Dahye Kim
# 씩씩한 식객_39895
# 서철민
# Jusef
# 외로운 미식가_8332
# 치즈돈까스
# 댕집사
# 현영2
# 호기심 많은 개척가_91891
# 좋아요좋아요좋아요
# 착한 개척가_92328
# 키키꼬
# 행복한 셀럽_32422
# 네냥이집사
# 기분좋은 마스터_78617
# 쩝쩝박사출동
# hheyii
# 소낙J
# 제니깽
# 조주원2222
# LMH85
# 멜로즈2
# 솔직한 맛사냥꾼_20523
# 채원잉
# joselynjypark
# 그루트ㄴㅋ
# jhn7939
# aidtisl
# 루시뿌
# 옴뇸뇸냠냠
# 고독한 맛사냥꾼_31660
# 우블리블리
# sowon456
# 쪼미쪼미
# 김병준27
# 가나다라미
# 따뜻한 식객_41040
# 제이슨혹은조엘
# 꿈꾸는 개척가_67563
# tyche0628
# 루캐치
# 쌤쌤쌤
# 화려한 셀럽_33004
# 호기심 많은 식객_68012
# 뇨끼먹고싶다
# 박예영TINA
# 깜찍한 셀럽_21601
# 빵미
# 신예준2
# 성공한 식객_4185
# 아도아돈
# 아름다운 개척가_5789
# 우수한 맛사냥꾼_97337
# 맹서현
# 인기많은 식객_47456
# 망고손
# 화니뿌
# solviture ambulando
# 화려한 맛사냥꾼_37111
# 화수78
# 81박은하
# 즐거운 미식가_30988
# 소밍이이
# 화려한 식도락가_95666
# 지뽕4289
# underCSR
# 경쾌한 개척가_13202
# 망나뇽이닷
# 성효성
# 신나는 개척가_91435
# 화수78
# 스텔라한
# 즐거운 맛사냥꾼_43832
# 페브리z
# 오성은은
# 찐맛집을찾아~
# 라기921
# 비범한 식객_46884
# 모순덩어리a
# 멋진 미식가_96968
# 도도한 식객_23071
# 착한 식도락가_68693
# 진수수수수깡
# 도도한 식객_16214
# 재미있는 개척가_43531
# 인아의하루
# 맛도리찾는다이어터
# 빛나는 셀럽_56754
# 오렌지콜드브루
# 멋진 식도락가_92060
# 발랄한 미식가_57203
# 최고의 셀럽_62658
# 와 서울 (wwah)
# 아름다운 맛사냥꾼_68434
# 썬더형
# WJee
# 신모차르트
# 룰룰알라랑
# 이채니
# 곤고오니
# 솔직한 개척가_90364
# gmlfid25
# 기준손
# 롯 데 리아 사장님
# 꼼햐
# 츄베릅_
# 맛집뿌시기
# 허니문
# 짜니22
# simipolo
# 사자추천
# 수연인데
# Bomishot
# 이소리는배에서나는소리가아니야
# 씩씩한 식객_66719
# 꿈꾸는 식객_12012
# _쩡222222_
# 송알2
# 다존
# 혜옹옹이
# 인기많은 식객_15406
# 혜성khs
# 브랜든_
# 노용석
# 20:39
# 조용한 식객_80859
# 특별한 개척가_76194
# 오마쥬
# 탈토시
# 토토리이이
# 깜찍한 식도락가_2220
# 탱탱봉봉
# seolhwalee
# 디사시
# ㄱ윰니ㄴ
# 요치치야
# 감규링
# 꿈꾸는 식도락가_58870
# 비범한 식도락가_96035
# sssg0309
# 만소리
# 김뉴야
# Syhahaha87
# 심야식당 기억
# 김모네김
# 변정혁
# 지누쓰봉
# AIRP
# 따뜻한 식객_90525
# 부드러운 마스터_70850
# 건국현
# 밝은 미식가_88910
# seung3un
# 홍북진
# zero.k
# 꿈꾸는 마스터_1273
# 라연178
# 슙이두
# lee_ji
# 조조조1019
# sojae
# 지현제니
# 내가맛있다하면믿어줘
# Yw2222
# 꿈꾸는 식객_24654
# 씩씩한 식객_16718
# 멋진 개척가_98138
# 수퍼덩크왕
# 홍챔케
# 망고스틴바나나
# David kwik
# Mars Kwon
# 갱스터쥐
# 김모네김
# 비범한 식도락가_92148
# 동구리코로코로
# 우수한 셀럽_50905
# 솔1219
# 흥나흥나
# 니냥냐
# 재미있는 셀럽_28741
# 태백
# 눈이녹으면봄이온다
# 파리의가을
# 흥미로운 맛사냥꾼_14232
# 멋진 미식가_44027
# 앵뽈맘
# 오피지지
# 강직한 미식가_20395
# 건강한 식도락가_32982
# 찬,준
# 최사월
# ...,
# 동지니동
# 샤브인서울 신용산 본점
# 알베로귤
# 도덕구
# 똑똑한 마스터_37540
# M M
# hello5146
# 루버스
# powerpnt
# 애옹띄
# 이정환12345678
# 꼼꼼한 식도락가_54859
# 앙꼬미
# 루밍_
# 화려한 마스터_95292
# 개구진 개척가_78789
# sukuan
# RL
# 미모밍
# 맛있는거같이먹쟈
# 곰됴르옆에
# Joshua Ahn
# 빛나는 개척가_24852
# 행복한 셀럽_83610
# ♡  花樣年華  ♡
# Kanv
# 인기많은 식객_67310
# 갤린
# shn891115
# ㅣㅓㅑㅐ
# 우아한색시
# 따뜻한 마스터_71226
# 쥬니츄
# 착한 식도락가_97628
# 기분좋은 마스터_19426
# 가자새로미
# 다람쥐웅이
# 띠용띠요옹
# 히죠이
# 와니87
# Jay N Jamie
# 특별한 미식가_42085
# 호세호세
# 쭌쉐
# sarasara
# 마아안두
# 쟈스유
# 서히츄
# Hye luv
# 인기많은 미식가_3404
# 씩씩한 미식가_95174
# 미식가99
# 디해방 D HAEBANG
# 와쟈테디
# IAN JIN
# 반포마우스
# 다미담미
# 제임스박군
# 상아제약 주식회사
# 미띵쓰
# Uptou
# Ellashella
# 불가링
# 특별한 개척가_90394
# 지혜로운 식도락가_54754
# 아지유222
# Ohsj
# 국빈_727
# JUU__
# 제파니
# jollyjoy
# 온화한 맛사냥꾼_7207
# 디디오오오
# ʏᴜᴊɪɴ
# mingle0315
# 경쾌한 개척가_69837
# niyu
# 경쾌한 식객_28465
# charlottena
# 클로텔
# 수꾸니
# 핑키피치
# ʚ 최예문ɞ
# 대성인테리어조명
# 고기샌드백
# 휘바마미
# nonono
# 빛나리처녀
# 화려한 개척가_37479
# 조용한 식도락가_43799
# 포동포동 치즈
# 즐거운 미식가_23857
# mingle0315
# Bethuel
# Jamescho
# 휘종박
# 채닝이
# 감쟈합니댜
# 김가봉
# 지징징징
# 좌콩우디
# 바토랑
# 지혜로운 개척가_25711
# 스시 노 아야
# 새로운 개척가_44487
# 엱ㅜ
# xnxn
# YT님
# 맛살
# Checkitout
# 외로운 개척가_92628
# 서요밍
# 꿈꾸는 맛사냥꾼_52671
# 잰잰니
# 박태성
# 따르르릉11
# Gladiator
# Sweetdoo
# 김peter
# 재능있는 미식가_69464
# 김민영0407
# 힘빼윤프로
# 영자고고
# cochon
# ekmom
# BHMJ
# 꿈꾸는 식객_77537
# YISJ1218
# 나또쿠로산도
# 자머주
# 자머주
# 냉동돼지2
# 쾌활한 맛사냥꾼_52533
# 송송송솔송
# 김곰석
# npng0948
# 미시쿠헌터
# 자머주
# Hancom78
# 자머주
# 도동이야요
# 도도한 미식가_732133
# 펭귄jw
# 사내아이
# 원숭이강아지
# joli52
# Gros mangeur
# 도도도도도희
# 발랄한 맛사냥꾼_22766
# Checkitout
# 아맛나군요
# WillSonn
# 하잇ㅅ
# WillSonn
# 미미옥 신용산점
# simUri
# Sun Youn
# bbaekbb****
# 난끝까지
# Lisa DH Kim
# 빛나는 마스터_79137
# mimi찌
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 몽크스부처 이태원
# 씩씩한 셀럽_34558
# jung moonhee
# C.no
# 냥냥이러버
# OG1
# Jyurs
# Jaeyong Lee
# 씩씩한 맛사냥꾼_65349
# MRG Korea
# 쾌활한 세미_36732
# 개구진 식객_11845
# 허필
# 콜드브류소이라떼
# 미미캣
# 테이바
# 연랑이
# matdara_jane
# 짱요이
# 한남동까치
# 끌로이쥬
# 계획적먹부림
# 쾌활한 식객_18367
# 꿈꾸는 식객_38093
# inuage
# Anna aus
# 착한 개척가_48532
# 노숭디
# 안박소상연일
# 스깔
# 우수한 셀럽_58393
# 부드러운 식도락가_61708
# 인기많은 식도락가_62614
# 프 장
# 정자동 미식가
# 개구진 맛사냥꾼_45134
# 고독한 식도락가_28557
# 깜찍한 식도락가_62441
# 루이24세
# 생선에진심
# 광이이잉
# 지혜로운 미식가_92545
# 다미25
# 까메하메하
# ohi5
# Helen Gi
# ynggch
# 오공오공오공오공
# 고양이 구스
# 송승현 Song Seung-hyun
# Heeja9
# 카밀로 한남
# 포수
# 꿈꾸는 마스터_86077
# 조용한 개척가_29488
# 여유로운 맛사냥꾼_96468
# dasffe
# 쭌홍
# 젠ㄴ
# 쾌활한 미식가_9075
# 피피는먹는게조하
# 양무너
# 먹고말탱야
# youngholee05
# 정직한 마스터_86277
# 식욕을줄이자
# 온화한 셀럽_38672
# 착한 미식가_75253
# bon1324
# 류병영
# 유명한 셀럽_77489
# Hyeok sang Kwon
# 새로운 식객_20932
# 빛나는 미식가_29034
# agnesyun
# 킴콩지
# 도도한 셀럽_38023
# 카페인중독토끼
# 강유림
# 예리한 셀럽_73595
# agnesyun
# Mason Moon
# 성공한 식도락가_10871
# 온화한 셀럽_60017
# 도도한 셀럽_38023
# 노느니
# Warren Hong
# 레넌니
# ppayoo
# 남다른 식도락가_96741
# dozero91
# 쭌홍
# 수학이좋다
# 요리군
# jeybee
# 활기찬 미식가_75502
# Damin Yang
# 제이에치치
# SSMamba
# 지지지니
# Csem
# 깜찍한 마스터_45254
# 휴135
# Cloudio Serafino
# minnnnm
# sunny007
# 성원보
# Universe96
# 따뜻한 맛사냥꾼_20739
# 맛집계의박평식
# Kokoa
# BSC2450
# skh01099
# shyun_k
# 밝은 미식가_5751
# 먀먀먀먀뱌
# zoyeoni
# 기몽준
# 사비마르
# 하스피1
# BSC2450
# My life
# 두부김치.
# 유나리다33
# 김620
# 서촌러버
# 소개팅
# 기분좋은 맛사냥꾼_74790
# 건강한 마스터_67272
# Hannam Pink
# 새로운 식객_94716
# 레코딧
# quidam
# 유기농맘
# 나너ㅓ나ㅏ
# 기분좋은 식객_28741
# 내가쟤니
# 핑구쨩
# Yoah
# 소루히히
# 고기공룡
# Universe96
# 슬군
# 만도 딘자렌
# ConnorLee
# 킬러웨일
# 빛나는 마스터_59345
# 이엘바라기
# 성공한 미식가_43511
# 로뤼혁길로이
# Lydiachaewon
# 감람나무열매
# 동동쥬스
# 오만지아
# 지혜로운 개척가_34717
# 옴샨티
# JUNGWON
# 고독한 마스터_47285
# 머언지
# 전서해
# 멋진 식객_39363
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ATTA
# jmtjmt
# 히인
# 똥허이
# 정직한 개척가_19981
# 짱배우
# 세라미스트
# racheljlee
# Heyjugang
# 씬디림
# ATRE
# 온화한 개척가_63822
# zombi****
# 어니부밍밍
# 일상의조각들
# 유명한 식도락가_75456
# 서초동박선생
# 듀니
# 흥미로운 식도락가_19439
# alfmir
# 레이스15
# 부드러운 식도락가_75136
# 재능있는 미식가_79425
# 재능있는 식객_72394
# 보니맘
# hannam01
# nicaa
# 위트있는 마스터_10557
# 레이1960
# 아니마니
# ihaterainydays
# 가든맨
# 선도링
# 한입더할수있잖아
# vish
# 유딩파워
# 쩨니이이이이이이이
# 우루룰루루
# Sydney 2020
# 화려한 식객_57447
# 쁘띠프로
# 남다른 식객_90714
# 지은그레이스
# 냠냠ㅎ
# 매앵스
# 입짧은멸치
# 구긍정
# 거북이사요
# artlog
# 푸딩이여
# 주시원
# De tempore 디템포레
# Katlin
# Swony_park
# 활기찬 미식가_12355
# sky79
# 미슐랭 4스타를 찾아
# 오소리선생
# 예리한 마스터_97527
# Mikalias
# K호호
# 공돌2222
# 곤사마님
# Flsnsnfn
# 쾌활한 미식가_51974
# 인기많은 맛사냥꾼_41332
# shbb!
# 위트있는 미식가_44230
# 보 성
# 김명자굴국밥
# 알통
# Blinging
# 활기찬 식객_89174
# 와앙한입에
# 응디꿍디
# 김쥐인
# 따뜻한 맛사냥꾼_93331
# Lucy22
# 베리시
# 외로운 식도락가_79554
# Whatssub
# sweethearts
# 씩씩한 식도락가_54085
# Davidyu87
# 아름다운 미식가_6799
# 니냥냐
# benji
# 빛나는 식도락가_28530
# 먹깨비수미
# 불멸의 떡볶이
# 흥미로운 맛사냥꾼_66874
# 맛있다냠냠냐암
# 씩씩한 식도락가_16882
# 기분좋은 마스터_64214
# 씩씩한 개척가_2618
# 천수민
# sayng8383
# yeoniiw
# Wishkim
# Anonymouss
# 흥미로운 식객_11673
# itsveryme
# 오스테리아 이아드
# freshfruit
# 탐구인
# 자윤
# 정직한 개척가_69880
# 강직한 미식가_99612
# 따뜻한 식도락가_56372
# __noo
# 캐슈너엇
# Silverybird
# 탐구인
# Leenahyun
# 재미있는 셀럽_16618
# 찰리28
# 깅수달
# 쥬씨픽
# 사미쿰
# 지은이89
# Park-G
# Nuevosol
# 경쾌한 마스터_85765
# 똑똑한 식도락가_56070
# 맛있는거만취급
# 활기찬 미식가_57945
# rainason
# ib****
# 지나가는 몽구
# 외로운 맛사냥꾼_75316
# dolphin82
# 도도한 셀럽_70895
# 한나나나나나나나
# 숯덩
# daybye_
# 활기찬 미식가_57945
# daybye_
# 소여뜨이
# ggnoescheoioiiy
# 경쾌한 셀럽_79464
# 정도리님
# 더키J
# BEBEBEBE
# 예리한 맛사냥꾼_71360
# Camila
# 재미있는 맛사냥꾼_57215
# tjduddl120
# 반전할까요
# 경쾌한 셀럽_79464
# 빛나는 식객_92233
# 히요니
# 꼼꼼한 셀럽_89898
# JA00
# NOCT
# 공일2
# 또옹글
# 너굴밍
# chloe s lee
# 용준튼튼
# 즐거운 마스터_78340
# 김뎡훈
# 서니몽05
# 권정언94
# 계살버거
# 동그랑땡90
# 지혜로운 마스터_53627
# 착한 식도락가_22021
# 뚜주르
# 남다른 식객_89688
# 유명한 셀럽_33214
# 개구진 마스터_94302
# 100hwajeom
# 쌍이
# 울울울
# paipai52
# 해지정
# 우수한 식객_50919
# 초팡이
# Jenie.Rin
# jangaess87
# 맛집투어용
# 나나피
# 부드러운 식도락가_58347
# cnzk****
# 돌개빙
# 바라
# 우스맘대디
# 초코비
# 예림공주님
# 김동준천재
# 기분좋은 개척가_52379
# 맛집탐방대
# 임경민
# 배캐성
# 더니짱
# 심일호
# Sorksk
# 박율룡
# 뚱치뚱크
# 생선장수아저씨
# 아름다운 식객_66073
# hwic
# 옹스짱
# young1510
# 사이카쿠
# 소이_
# 꾸꾸미
# 박윰
# 활기찬 개척가_68246
# 건강한 식도락가_33110
# hani24
# 한나팡팡
# 타로다빠빠빠야
# 류류류류임
# 재능있는 개척가_77030
# 깜찍한 미식가_53265
# 흰종이
# Sanghoon P
# 쭈곰
# 박사호소인
# 퍄퍄퍄
# 빛나는 식도락가_11537
# 발랄한 개척가_75497
# Amyyjy
# Paulis
# 빛나는 개척가_84638
# You jung
# 안째손째
# SasimiLuv
# SasimiLuv
# 최고의 맛사냥꾼_67197
# 웅예진진
# 마세미친자
# 구름오빠
# eahe
# 솔짱짱
# 비범한 개척가_52878
# 행갱이2
# 쥬주주주주쥬쥬쥬
# 외로운 셀럽_71776
# 무빙진
# 영세쿠
# sephirot****
# 도영설희
# 쾌활한 셀럽_89330
# 은밀한 미식가143
# 클라민
# 외로운 개척가_6251
# JaydenJ
# 미식가코난
# 이 석관
# 됴됴블리
# 맛없는거먹으면빡침
# 기묘기묘기묘해
# J.S.Kim
# Pimfy 이태원
# 하와이안허스키
# Hpick
# 미네르
# 똔니11
# 활기찬 식도락가_54647
# 예리한 맛사냥꾼_40707
# asey
# 짐
# 야지스
# ㄱ.김우재
# 강직한 마스터_14558
# 헤잉리초
# 동한고슴도치
# 씩씩한 식도락가_80601
# Vbc
# 다솔마미
# Easy24
# 따뜻한 미식가_59249
# 소댕
# 밥나와라뚝딱
# 김실장한국폰
# 오진택
# 그네타는아이
# 외가댁소녀
# 신제후
# qwerqwer90
# 02902
# 따뜻한 맛사냥꾼_23886
# 헬로멜롱
# 스티븐잡셔
# 온습도
# 융엉언
# Charlesjhcho
# ㅎㅎㅎ맹
# 피카츄러스
# 저스틴차
# sesewoong
# 배찌다오
# rk0630
# 오세성
# Why00000234
# jayyyyyy
# 여유로운 개척가_73157
# 미야오오
# 특별한 개척가_95602
# 랑방이
# Jelloclub
# 마롱안니
# 즐거운 맛사냥꾼_33318
# 새로운 맛사냥꾼_52029
# 차경
# 애ㅡ옹
# 함바왕0717
# 베네딕트리
# 채채채채니
# 똑똑한 셀럽_43472
# 예리한 맛사냥꾼_65406
# 참치참치정참치
# dl982
# 채챎
# 우수한 맛사냥꾼_97337
# 노랑콩나물
# 쾌활한 미식가_45003
# 롱가든
# 3년차서당개
# 안경잽이
# 현지짱1
# 똑똑한 개척가_7630
# 지우지우지우준
# Hanskimkorea
# won130
# 기분좋은 식객_17070
# 토류크막토
# 검단흥마니
# EverydayCorrr
# 멍멍냥냥
# 행복한 식도락가_96958
# Rimnmnm
# gammi
# 이든85
# 맛집뿌시는햄찌
# 멜론머스크입니다
# 키키1
# 장구요정옌이
# 발랄한 개척가_286
# 맛집을캐치욧
# 르몽0919
# 알미론
# 솔직한 셀럽_17479
# 즐거운 맛사냥꾼_20853
# 잘먹는아공
# 댕스
# 먹잠이수
# 헤일리12
# YJ Cha92
# rhflffk96
# qhwany
# Petit Cong
# 피야삐야
# 대성kim
# 오하랑
# 5412
# whdnjsdk****
# 행복한 마스터_52285
# 식도락꿈나무
# 지으니지니
# Johnxina
# 우수한 식객_61222
# mineviolet
# 영영영000
# 개구진 마스터_84131
# 서울낚시꾼
# 이수근 강호동
# Misvandero
# gayoon oh
# Mumu94
# 닝냥뇽1230
# 하면하는호랭이
# 특별한 셀럽_81520
# BiBi__G
# 김재국
# Migmigmig
# jiyooraju
# prxirn
# 활기찬 미식가_4425
# 뇽쓰리35
# 피디킴
# 방콕녀
# 빛나는 개척가_9963
# 상오삼오
# 초코코코볼
# 뽀송오빠
# 릭네임1
# 엄익재
# 도도한 식도락
# bbyul
# 솔솔짱이다촤고다
# 양석인
# 강직한 식도락가_50785
# 호기심 많은 셀럽_67098
# 설미니
# 최망띠
# HwanS2
# 럭기카이777
# Gangssss
# mytrueself
# 지혜로운 개척가_181
# a19375****
# 보라색요시
# 인기많은 개척가_58224
# 리리지리
# 호머초
# 먼치 Munch
# 활기찬 마스터_42240
# 버터쿠키
# dk1532kd
# 지순
# 참치참치정참치
# 조용한 셀럽_68889
# 애푸공
# gnihww
# 아잉조아
# Salton
# 도도한 셀럽_52696
# 도돌
# 터히
# 고독한 식객_45594
# Elly*
# dla002
# 주주준준
# 끼풀
# 베어곰
# double-0-7
# 룰루랄라링링
# 난지니임
# 와플사줘
# 기린9
# 얼리먹답터
# 잉뇨
# 클로이민
# 희재리리리리
# 지니퐁
# 돼지뿡뿡
# 맛있으면또먹지옴뇸뇸
# Salton
# iampobby
# 세레나데9
# 기엄둥이미식가
# 경이로운나
# 착한 식객_98942
# 장은제
# 초롱언니는 잠만자 ㅋ
# 도넛츠꼬깜
# tealeaf147
# 만나면현피
# 경쾌한 식도락가_31044
# JW SD
# 빛나는 개척가_27048
# 냐냠누렁
# 지혜로운 식도락가_27145
# 비범한 미식가_87900
# 김지현김지현김지현
# Lnnn
# 노이 이탈리안 하우스
# 행복한 식객_42003
# 푸드라거
# 왕요미
# 남현준짱
# onedaysixmeals
# 지혜로운 식객_94963
# 남다른 식도락가_64429
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 셰프테이너
# eedee
# 고독한 맛사냥꾼_50313
# crys****
# 재욜
# 쿠우소다
# 태리샐리
# 필승지윤
# 기분좋은 마스터_55218
# 쾌활한 마스터_37674
# 루똥이맘
# tkk06
# eedee
# 특별한 개척가_54564
# 미적지근
# 어의k
# 새로운 셀럽_94521
# eedee
# 빅맨1
# alaksana
# 한듯안한듯
# 건강한 개척가_35452
# 강직한 식객_40749
# 선주쌤
# 준수기
# 캐치악어
# smin2529
# 즐거운 식객_25352
# 조윤서02
# 한나97
# beauty978
# 김주0
# 홍자경
# 페잇
# Shy Blue Sky
# 쿨타임
# liliiliilil
# 서울아씨~~♡♡
# 착한 맛사냥꾼_51783
# 슬기12345
# 3187654321
# My life
# 뿡빵뿡빵뿡빵뿡
# penguin
# 특별한 미식가_15033
# 승승77
# Motivator.Ronic
# 밀접한주방
# 레몬민트바질
# 성공한 마스터_2810
# 누구라고
# 소수
# 신생
# Zachariah M
# 쇼와지
# 김기현000
# 망고누잉
# 선우현숙
# 주지로
# 지혜로운 식객_4566
# 둥둥임둥둥
# 밀리온벨
# 빅토르쿠
# 여유로운 개척가_87242
# Jaywin
# 무난한 입맛
# 재능있는 개척가_93779
# 경현짱
# 외로운 개척가_66107
# nhj0747
# 맛집킬러25
# 별이
# Hye luv
# 언제나 사이좋게!
# 흥미로운 셀럽_74851
# 호기심 많은 식객_24986
# ssoo198400
# 깜찍한 식객_82065
# lovelyyyy
# 킥유미
# Camilla
# 인기많은 식도락가_75973
# 위트있는 미식가_38646
# Jinnnaaaa
# Joy.L
# 특별한 마스터_43322
# 이지민아빠
# 윗와인
# 97.KANG
# 인기많은 식객_42705
# 솔이13
# 홍쫄
# 재미있는 개척가_70483
# 호희여
# 젤리지야
# 개구진 식도락가_62479
# 따솜0804
# 황금메기
# 새로미밍
# 위트있는 셀럽_62783
# 샤롱공듀
# 바나나비비
# 알레즈 AL'AISE
# 맛집킬러!!!
# 특별한 식도락가_31208
# Hiiiii_ji
# zoal****
# 빡지0410
# 밝은 셀럽_9261
#  윤재
# 220424270424
# Starlit Night
# 히다다
# 나투르
# 마쵸미미
# 똑똑한 식객_70335
# 쑥떡밤떡
# 도도한 마스터_84168
# 경쾌한 미식가_12907
# 새로운 맛사냥꾼_53081
# 멋진 개척가_36025
# 비밀은없어
# Sophie Seo
# 예리한 식객_50376
# 우인하
# duk618
# 원아
# 최발암
# Edwardo
# 임규민123
# 찐징
# 건강한 셀럽_61992
# isun****
# Kimjinny
# 소월로모찌
# Terry08
# 따뜻한 식객_77448
# 건강한 셀럽_61992
# 남다른 셀럽_28168
# 멋진 미식가_66405
# 멋진 맛사냥꾼_11303
# 고추장맛우유
# Lambert
# 초코딸기빵
# 박애공이
# dotz
# 남다른 셀럽_67440
# 현서아빠0206
# 뮈뮈0319
# gratus907
# Painkillar
# KIMSOOYOUNG
# 주웅재
# 뮤땅
# 특별한 식객_99573
# 발랄한 개척가_58989
# yjsuh4
# Nada
# 호나우
# 강태평
# 상현@
# yjsuh4
# yjsuh4
# yjsuh4
# yjsuh4
# Zenith~
# 우니ㅎ_ㅎ
# hiverete
# 쾌활한 맛사냥꾼_15796
# mufflie
# feedseoul
# 은밀한 소식좌_10281
# 특별한 식객_99573
# 끄니
# 쭈짱8
# loopie00
# ㅈㅈㅈㅈ
# 쾌활한 대식가
# 집시의미식생활
# 기분좋은 셀럽_27785
# 화려한 미식가_8228
# Ski.tada
# smchung1021
# sofly
# 즐거운 식도락가_57137
# 온화한 마스터_71413
# 번마인드
# 홈하우스
# Bornwild
# zizi21
# 목멱곰
# Nada
# 부드러운 셀럽_74731
# dalza
# 테네시
# 비니로미
# 치킨꿈나무
# 핫돌과윤돌
# shanghaigirleat
# KW7N
# lubeena
# 외로운 셀럽_24271
# 빛나는 맛사냥꾼_79815
# 아름다운 셀럽_34130
# 스시이젠
# 굽찐만두
# 뭉치아범
# Dandy7
# 킹킹재
# Zi노
# 미니애니
# 무너지는 계절
# 남언니
# Jks
# 성공담
# 따이몬
# 하학수
# 베푸는베프
# Zi노
# 신나는 맛사냥꾼_72049
# 배추94
# 인기많은 식도락가_18818
# Nicklee
# 미식은사랑입니다.
# 회장님123
# 여유로운 마스터_34213
# 미식은사랑입니다.
# caty
# 맛없는거먹으면빡침
# 후우밍
# 아이스블루
# Zi노
# 요요요요요
# 피노누아27
# 찐빵쓰
# 미니애니
# 게르마늄팔찌
# 평화라떼
# 방구석스린이
# 오천사
# 베푸는베프
# ㄱ강한
# 아임졸리
# 대호멋쟁이
# jyjyjyyhjjjj
# 하학수
# Zi노
# 찬군만마
# 집에가고싶드
# 거니o
# 현강신
# 레츠고 깁스
# 호기심 많은 식도락가_6619
# 성공담
# menmalog
# TBD 한남
# 먹짱군
# 미뿅
# didldka
# 띠뜌
# 부드러운 미식가_54175
# 하태하테
# 건강한 식객_67594
# So-i
# Kokoeun
# 외로운 개척가_73968
# 원더원더원더
# 맛있게도 냠냠이
# s에스제이
# 눈만뜨면 먹는거야
# 호루루루
# 지지월드
# Miella
# Moonsoo83
# 성공한 마스터_28509
# 짜요
# Ud
# 기분좋은 식객_14218
# 꼼꼼한 맛사냥꾼_83011
# 민병국
# 워니
# bluluvsu
# 저니두
# 핫누리
# 위다다
# 아름다운 식객_69740
# 비범한 식도락가_50193
# 고독한 셀럽_83679
# Eun Young
# henry08
# 김법민
# 따뜻한 마스터_96393
# Hitchhiker
# 운조운
# 고양이랑와인
# 쾌활한 식객_22901
# 사막개구리
# 퐁당치즈
# 발랄한 마스터_1366
# 옥힝
# GA먹
# 나야나너야너
# 이흰둥
# Lovebachforever
# jacquelinee
# Miranda318
# 소울 SOUL
# 해수27
# 따뜻한 셀럽_1227
# 해더스
# 제이엠파크
# 피츠커피
# 선릉pt문의
# Zeze13
# 착한 셀럽_11886
# 활기찬 마스터_35449
# hao1203
# _only_one
# Edge72
# foodiejelly
# 지슈슈
# 안양지호맘
# JW HEO
# ㅎ2222
# 착한 식객_9156
# 모카공주
# 라이트유저
# 재미있는 식객_30366
# 으닝11
# 신당동부부
# 전복타코
# Shinyy
# 나는야 돼지구마
# 개처럼벌어정승처럼먹자
# 씩씩한 식객_16517
# 새로운 개척가_34166
# 똑똑한 식도락가_15240
# 강직한 맛사냥꾼_61786
# 인기많은 미식가_93762
# 최준철VIP
# Sunrise_vege
# iiiihoo
# 씩씩한 식도락가_80891
# Sia Kim
# 파파스 남성의원 대구
# Seoa_k____
# 쯍이
# brona0420
# 홀룰룰룰
# 사과하나
# 지금뭐해
# 라인벡
# Mypace
# 빛나는 미식가_75027
# 안녕발렌타인
# Edge72
# 지웁
# 신류 용산점
# 남다른 맛사냥꾼_21045
# 우선화
# 방구람
# 고독한 셀럽_13741
# Nacococo
# 콰아아아아앙6
# twkim1981
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 한쿡 N서울 타워점
# 기분좋은 맛사냥꾼_19550
# 즐거운 개척가_48069
# 빵양2
# 새로운 마스터_16388
# ㄱAshley lee
# 위트있는 마스터_4505
# 김맬
# pnk0813
# 슬래시2
# 예리한 셀럽_
# 밝은 셀럽_58911
# 화려한 미식가_38324
# 땡두땡땡
# Jina _ Sarang
# 솔직한 맛사냥꾼_64421
# 조경은
# 주으니찡
# Brian1404
# 느블느블
# 남다른 식도락가_6979
# episod****
# 삼삼성래미안
# 착한 식도락가_6681
# 나나sksksk
# 꿈꾸는 마스터_38831
# 호기심 많은 마스터_59723
# 지혜로운 식도락가_39702
# 꿀통단지
# 1산돌
# skyu2
# 기분좋은 개척가_40310
# 리카대디
# 꼼꼼한 식도락가_94668
# 루루루루루루루루루
# 토모딕
# 따뜻한 식도락가_77410
# 씩씩한 개척가_26147
# ggab****1
# 온화한 셀럽_30696
# 넥슽레블
# 길위에서
# 조용한 식도락가_46421
# 960202****
# 다은대디
# 상섭1
# 부드러운 미식가_71386
# 착한 식객_80350
# 기분좋은 맛사냥꾼_89039
# 인기많은 맛사냥꾼_27045
# 새로운 셀럽_46518
# 신용산 당스
# 새로운 셀럽_54487
# 55500
# 착한 개척가_99225
# 부드러운 식도락가_55673
# 92 김은지
# 우우붐따
# 츄0_0
# 우수한 식객_85437
# 겸댕이소스도둑
# 두께바
# 우기에디
# polluxis
# Dalryu
# 샛딤
# JI___.
# 장유진1220
# o2
# likesummer
# 똑똑한 마스터_72381
# hamni2
# 김셔닝
# dongoh
# 변잉또오
# 강한프로
# 착한 개척가_8633
# yulmming
# vivigo
# 엉요
# 닉닉과쥬디
# 여유로운 맛사냥꾼_38793
# hwani2
# hwani2
# 정10
# 먹고사는재미죠
# 앎107
# ㄱ 서경
# 마슐랭
# Freeziiia
# 새로운 미식가_81085
# 스시라멘와인
# 가자미이
# Zuzuuu
# 꿀꿀혀니
# 여유로운 식도락가_86448
# 수비수비수비숩
# 갓교
# 혀누이
# 12234
# 밥샤
# 주세희
# Truffle di Alba (트러플 디 알바)
# 흥미로운 식도락가_80103
# 화려한 마스터_76503
# Myseob
# 희근
# 이브와라디
# 신나는 셀럽_33652
# 최배달7
# 현수 LUNA
# 내추럴 매니아
# Elain chung
# 아흥잉용
# 건강한 셀럽_60984
# 똑똑한 미식가_62821
# yoontakhan
# 쾌활한 식객_39119
# 줜쥐현
# 건강한 마스터_58586
# 라덴
# 기욤파크
# Joy_me_myself
# TK1908
# 백프로디테
# 쵸파몬
# 지은정입니다^^
# Sora417
# 발랄한 개척가_23733
# 씩씩한 식객_76888
# 서영주서울
# 예리한 마스터_47843
# B82763
# 씩씩한 마스터_14823
# 즐거운 미식가_58380
# 세콤 달콤
# 고래밮
# 피곤한 술쟁이
# 특별한 셀럽_19574
# 먹는맛에살아요
# Joyfulism
# 전미현 리디아
# HJ15
# 꿈꾸는 개척가_44485
# Beauty N Beast
# 리사강
# evelynchoi
# 담마
# 지혜로운 맛사냥꾼_76104
# 뷰티풀미식가
# 김셍연
# 성공한 미식가_4836
# 냠냠남냠미
# 제이엘 디저트바
# Christine0
# 이성규미
# bongnana
# 씩씩한 마스터_40455
# Lee joomi
# 딸솜팡
# 도넛
# 승진, 이
# 뉴고은
# Jae127
# Julian22
# 새로운 개척가_31112
# 코뚜닝
# Lali
# Kennetj
# 솔직한 맛사냥꾼_46822
# Sallyoung
# jacquelinee
# 밝은 맛사냥꾼_21902
# Sia Kim
# 케븐
# 호기심 많은 식도락가_78760
# 유건명
# 지민닝
# logosde
# park sungbae
# dldpxks
# 손영남
# 라롱이
# 한준홍
# 밍토리밍
# 숟가락123
# 손영남
# 세리미이이
# Ryankimmy
# 씩씩한 식객_36739
# mingggkyys
# ggnoescheoioiiy
# 입짧은 sun
# Time_Min
# 최고의 식도락가_79501
# sinsohoa
# 솔직한 미식가_51326
# Jhanny
# j00
# 버카리
# kimjeon
# 먹보 차블리
# 꼼꼼한 미식가_59191
# juho.ohuj
# 춈 (chome)
# 꼼꼼한 식도락가_38790
# 부드러운 마스터_70850
# 로슬안
# 베가니스
# 식도락 여행
# 태태몽
# 화려한 맛사냥꾼_28199
# 아승
# VEUXSAVOIR
# 슈슐리
# y19****
# 한젤리ㅇㅁㅇ
# 인기많은 미식가_27288
# 최고의 개척가_7753
# 쿄쿄쿄야옹이러버
# 종카1211
# 특별한 식도락가_90814
# 예리한 맛사냥꾼_11343
# 고씨단추
# 이주류
# 서울알라코
# 성탄탄
# 키옹
# 동동주동동
# Angelique
# personadodo
# 케빈정423
# 밍키21
# 남다른 미식가_40662
# sumin511
# 맛있게잘먹음
# 행복한 미식가_81462
# nnjj
# 상상하는 예지니
# 건강한 마스터_28737
# 뜨띠
# 주형한주형
# 생선에진심
# 아지테
# Mocherry
# 빵순이엘라
# 따뜻한 셀럽_57405
# 부드러운 마스터_40936
# J.da
# 쩡쏭
# 주라주
# Yyyy123
# 쬬기쓰
# 즐거운 식객_63447
# ㅁ뮴
# 알아차림 한남점
# HARUJH
# Lisa DH Kim
# ENFJ
# 킴눌이
# ENFJ
# 뉴욕김밥집소년
# Legend.Timmy
# ENFJ
# 무야이거
# 여유로운 식객_82452
# 여유로운 개척가_67480
# JSA랭파리
# 커ㅂl
# 쥬여니
# 꼼꼼한 개척가_50816
# 꼼꼼한 식객_20021
# 맘먹은대로
# lavishchildish
# 고독한 미식가_70300
# 남다른 식도락가_77288
# 애스힐드
# 한소륑
# Petit Cong
# 에스더0909
# Petit Cong
# 정회진
# 킴눌이
# 먹남균
# Not yet!
# Jin A Park
# 엘리사벳@
# ENFJ
# ENFJ
# Sunny6rl
# 댕댕하루
# 서영이언니
# 꿈꾸는 맛사냥꾼_83829
# 세워니와
# 꾱이
# 별뭉언니
# 여유로운 개척가_66247
# ENFJ
# AAA등급한돈
# 동요르
# 또동또동
# 그라시아윤
# 꿀토끼77
# 김종섭 JongSub Kim
# 킴찹
# KK3456
# 버터라이스클럽
# 대오긔
# 조재읔
# 박썰
# 위트있는 맛사냥꾼_18573
# 부드러운 마스터_77116
# 성공한 개척가_56874
# 성공한 미식가_35642
# 이용복필
# 예야악사
# 리구따리
# 특별한 미식가_98624
# 롤롤레롤
# 우수한 셀럽_71221
# 글쿠니
# 곤드리곤곤
# Clkim85
# 손죤
# 레모니1
# 고독한 셀럽_5999
# munchcrunch
# 밝은 식객_81854
# 지혜로운 개척가_57780
# CAP.
# 손멍구
# 어디로든문
# 민굠
# 쿄쿄쿄야옹이러버
# 따뜻한 개척가_6460
# 끈끄
# guknam
# 고독한 셀럽_30905
# 타샤
# Yeaahjin
# 최고의 맛사냥꾼_40866
# 조용한 앵무새
# 씩씩한 식도락가_37418
# 1g_
# 린쿡
# Pattern
# 희냐
# 52521
# 온화한 개척가_82233
# 빛나는 셀럽_53095
# 여유로운 셀럽_14153
# 신나는 미식가_85606
# 흥미로운 식도락가_1771
# Yummy_JH
# 쭝꿍
# dlghw****
# 부드러운 미식가_75690
# 라쿠치나
# 지욱♪
# AIMEE81
# Soo Jin Chung
# 여니니8
# Master JS
# 밝은 셀럽_9261
# Sony83
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 한국술집 안씨막걸리
# 인기많은 미식가_56775
# yonisayshi
# V지환V
# 릴리A
# Day빛
# DD_L
# 고메수링
# 똑똑한 개척가_7630
# 맛있는거맨날먹고싶다
# 민준대디
# smallport
# hyunho26
# 담마
# 호기심 많은 마스터_88599
# 호기심 많은 식객_7104
# 이태원나옹이
# 장우진입니다
# 똑똑한 식도락가_36933
# 강직한 개척가_78236
# 외로운 마스터_57674
# jy4922
# 아기장수우투리?
# 이은로
# Jay Jung
# 머리핀 꽂은 여우
# 먹기위해일한다
# 베케
# 페린토마
# 아름다운 식도락가_87797
# ByeongJae
# 새로운 마스터_55385
# Food lover!
# 샤랄라언니
# 유명한 맛사냥꾼_70128
# 슈도밍
# somnip
# 카섬
# Jimena
# 와빠
# 고은비Eunbi koh
# 지우라쥬
# 아루굴라
# Namaste
# 멋진 개척가_25552
# 꿀홍삼33
# Storyofus
# 행복한 맛사냥꾼_99955
# Soocynn
# 조용한 셀럽_90939
# 이철호.
# 양식문화
# 착한 맛사냥꾼_18475
# 즐거운 맛사냥꾼_52586
# 민원처리담당
# 헤이친구
# 남다른 미식가_65711
# Kiminu_it
# 횸반
# 새로운 식도락가_40343
# agrypnia
# 밍핑밍
# 여유로운 식도락가_48715
# 여유로운 식도락가_48715
# 성공한 식도락가_69306
# jjoonggi
# jjoonggi
# 루달2
# 꾸구뚜
# YYJ-
# Kiminu_it
# 구구성
# 위트있는 식도락가_66981
# 김캐띠
# ㅂㅈㅇ
# 둔케
# 마논트로포
# iliiililillil
# 끽구
# 김용재0909
# 예리한 식객_62245
# 오규버
# 나캉캉
# hwangji_h
# 김 건일
# 호애엥
# 안쥬르
# 쾌활한 마스터_3522
# 닼사
# 누룽지좋아
# andrewshs
# 나야컬리
# 셸쏭
# 밍키밍키매직
# 수구우붕
# imwpq
# 시네공주
# Kiminu_it
# 지효현C
# 자리가없어
# 마은잉
# Kiminu_it
# 마제 스키야키
# 비범한 셀럽_6845
# 서로상 준할준
# 김은경6645
# 현달2
# 도라도하
# 낙산공
# 은솔한별맘
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 쎄오
# 옴뇸미
# 최고의 식객_85554
# 재슐랭
# 쇼비더머니
# 셜리킴
# 힘빼윤프로
# 핑크짱구
# freemina
# Elly*
# 온화한 개척가_2901
# 큐라웃
# 아이린정
# 꿈꾸는 셀럽_38402
# 로빈s
# 깍쟁이
# 강직한 개척가_79856
# 재미있는 미식가_29596
# 찬슐랭가이드_Original
# bsj213
# Manbangzzz
# 여유로운 미식가_87247
# 솔직한 미식가_72143
# 워렌피셔
# Nj shin
# June2498
# 뚱이딸
# 인기많은 미식가_23278
# Roliv
# Dennisryee
# 아니마니
# 풍모란
# chloejna
# 아름다운 셀럽_90639
# 재능있는 개척가_90159
# hsk310
# 혈당스파이크
# LSoo
# 지혜로운 미식가_98529
# 기분좋은 식객_3006
# dennykim77
# 솔직한 맛사냥꾼_13126
# 스뭇치
# 육셰프
# 노니리
# 크레파스용
# Kelly  Lee
# 솔직한 미식가_31433
# 구글무스탕
# 온화한 미식가_93891
# 최고의 식도락가_98848
# ZERO COMPLEX
# 채이원
# ljjungee
# nyjm
# hhbbaa
# 란동야야
# 프로맛잘러_6193
# 강직한 미식가_94053
# janebc
# andadasee
# WhyNot?
# Dmish19
# 1llism
# 남다른 식객_30175
# 해피피오니
# 나롱다롱
# MJZZZZZZZZZZANG
# 쎄쎘쎼
# 정직한 미식가_426
# 두초이
# 덴티스트
# Francesco
# 코레지에그
# 호호호2
# dubu19
# 맵찔이 비비
# 꼼햐
# 강블리ㅋㅋ
# 승훈공주
# 차뇽
# 으정
# 예진핸드
# 똑똑한 맛사냥꾼_70454
# PHILHUTCHY
# 쎈
# visa
# zzinny
# hjwj1004
# 우아상소
# painter
# 노다선
# Kenneth.Ju
# 으정
# 냉정한만두
# 또디ㄴ
# 너와 나의 맛테고리
# 냉정한만두
# 깜슈제이
# 로즈kim
# 최웅웅
# jkseoulla
# 부다스벨리
# yyoujungg
# tokiappa
# 피터변
# 송뚜와
# 혁이맘2
# 행복한 식객_27785
# 윤영인  늦바람
# 예리한 미식가_1861
# 꾸리니
# 상상빌더
# 서현파
# 매운똑보끼
# 경쾌한 개척가_44620
# 탄니눈나
# Sang-Hun Lee
# 인기많은 셀럽_94833
# 이젼젼젼젼
# 뀨꾸우우
# 애용._.
# 초이이이이이이이이
# 활기찬 셀럽_69226
# 인기많은 식도락가_9859
# 에끌라드
# 멋진 식도락가_95361
# 코코앤슈슈
# 안쑝
# 남다른 마스터_96727
# 호정호정
# 제임스박군
# 솔직한 마스터_59273
# 새로운 맛사냥꾼_34281
# 석미혜
# 쾌활한 식객_22901
# 미리 @rahon_tt
# 미식파이터
# 성공한 셀럽_95205
# Whykiki
# 탱저린.
# 현화_thehh
# gaaaemii
# 꼼꼼한 개척가_22527
# 수원감자
# 강직한 식객_3227
# 김세민 12기
# soheebang
# 개구진 마스터_83361
# 류류상상
# stefankim
# 미로리탁
# jawsoo
# 판코네(Pancone)
# 55500
# 하늘날고싶다
# wqidks
# Ronron
# 대추나무사랑걸려버려
# 르메이트
# elena1
# 미뇽구
# 맛있으면홍홍웃는식객
# 즐거운 마스터_98638
# 현듀
# 호손이
# 6.19
# 돈까스41
# 유웅지이
# 우욤
# Harley_35
# 셰링ㅇ
# 헤니헨222
# An유나
# yoonkayoung
# 뽀또콘치
# 둠빠움빠
# 솔직한 식객_23259
# 권두형
# 0050
# 묘댕스
# 나쁘지않지
# 화영.
# 물량공급
# Pierre C
# 이시랭
# sunheebien
# 혜다람
# DJTHEDJ
# 웨일즈 코기
# 깜찍한 맛사냥꾼_54940
# 신나는 미식가_46934
# 재능있는 식객_6622
# 송강호떡사주기
# LJRre
# 아이마르
# 혜죽이
# Jinouk Kim
# 효또술
# 나연✨
# 푸링푸링푸딩
# Connoisseur0000
# 참새방앗간이다
# 여유로운 맛사냥꾼_92960
# 라인드 한남
# moneyspirit
# 아게하찡
# 온화한 셀럽_72479
# vovovovo
# 우수한 미식가_80201
# 리차드29
# Celia17
# 강덤프
# Nickyhyunjin
# 먀먀먀먀뱌
# 경쾌한 개척가_26643
# happyprincesss1
# 딴따따따
# ekjkrl
# 인범허
# CHS!!!
# jehwijin
# Ganeee
# 토토루70
# 유명한 미식가_52633
# 착한 셀럽_15055
# 온화한 식도락가_95106
# 깜찍한 식객_2019
# MRG Korea
# Dkkssioem
# happy****
# 핫태하탱
# happy****
# 엘리이이이
# 덩뎐
# 여희여희
# 깜찍한 미식가_66863
# 신나는 셀럽_46098
# 유니윤2
# 도도한 미식가_732133
# jwko
# 르로아넬
# 봄봄120
# 맛집 투어는 핑계고 먹방투어
# 재미있는 미식가_75311
# 재능있는 미식가_78277
# BC LEE
# 라라앤캣
# aboutbread50
# 발목대장
# casey♡roy
# Fhwof
# 재능있는 미식가_33644
# 저뉸스
# 손작가
# CESTA 세스타
# 솔직한 미식가_826
# Adam Ballin
# 큭큭큭
# 원숭이강아지
# 도도한 마스터_28078
# 강지영^.^♥
# 따뜻한 셀럽_1227
# 욜롤로
# 욜롤로
# Ahyoooonnnie
# 이충훈91
# 지썬이
# 노예1
# bangster
# 재능있는 셀럽_29821
# 착한 식도락가_97628
# 재능있는 식객_46633
# 재능있는 식객_46633
# Adam Ballin
# 예리한 셰프_2020
# Danha
# 현서아빠0206
# NickyDustin
# Karine yoon
# 최영
# 진지한작은배
# 흰색기린
# 차진영
# 호손이
# seungyl
# 후니스ㅡ
# 최영
# 강남백수
# 쇼군리
# 현서아빠0206
# 특별한 식객_52358
# 재미있는 식도락가_52718
# 수와니이
# Francesco
# 재능있는 식객_72394
# 권소빵
# 정직한 개척가_77453
# 최주나
# Tony k
# 발랄한 식객_21156
# 포쉬드레스
# 호미패트릭
# coco44
# 레나바호
# 슈슈슈니
# 파스티피쵸
# 김졍입니다~
# 먹보몬
# 잭영!
# 호기심 많은 미식가_31227
# 슈나이더
# 꿈꾸는 셀럽_45358
# 발랄한 맛사냥꾼_36051
# 예리한 미식가_99700
# 성공한 식객
# 지지지진
# 화려한 미식가_69941
# holichyo
# 졔에
# dreamyjy17
# wsc0605
# 우수한 미식가_81989
# agnes4****
# 트윙클빈이
# 호루루루
# 러브민 콩콩콩
# 추_재연
# aki4****
# 하나바나바나하나
# 밍밍이의 먹부림
# 조용한 개척가_58421
# ZEZE SARA NANA
# 여유로운 개척가_1514
# 쿠로미식가
# Ruby Rucy
# 지영_Ji
# 산드라
# 살아남는 자가 강한 것이다
# 이데소바
# 효니우스
# 우정주
# Gigikeem
# 솔츄리
# 유지니얌
# CindyP
# jangsta
# June Oh
# 보라도리
# 카테리
# J&Cream
# Whykiki
# 성공한 식객
# 최고의 식객_3015
# Christopherkim
# 5성지니
# Jeffmom11
# 치즈플로
# toma24
# 경쾌한 미식가_98937
# 예리한 맛사냥꾼_46648
# 둘리맘시
# 오슬로
# 줄리엣님
# J,H
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 피에세(PIECE)
# 정직한 맛사냥꾼_97765
# 깜찍한 개척가_95179
# 아폐르
# 윤이79
# HeY ' 혁호 '
# 차진영
# jonjihi
# 위트있는 마스터_78255
# 밝은 개척가_63716
# 19.07.13
# 이웃집도토로
# Katherine916
# 찹쌀떡한개반
# s_park
# 권영창
# vnJHL
# 예리한 식객_42701
# 궤에엑
# 화려한 식도락가_34660
# 깜찍한 개척가_11477
# HeY ' 혁호 '
# vnJHL
# 빛나는 맛사냥꾼_50295
# aquapanna
# 활기찬 맛사냥꾼_84936
# 프린세스핼
# 발랄한 마스터_37543
# 신나는 셀럽_315
# 새로운 개척가_38010
# zzzskkck
# 배밀
# 지혜로운 개척가_57751
# The Enzo
# 재미있는 셀럽_22862
# maengjee
# 우또반
# thek0708
# ddo_haa
# 인간1
# 날둥이이
# 준철강
# Lee Margaret J
# 강묘묘
# 탈퇴 회원
# 위트있는 미식가_73941
# 겨울22
# 조세무리뉴
# 백설탕탕탕
# 멋진 맛사냥꾼_92909
# 최고의 맛사냥꾼_84939
# 방방
# 신나는 개척가_90996
# whdnjsdk****
# s.sum
# 기분좋은 마스터_65211
# 흥미로운 미식가_20782
# 기분좋은 셀럽_40130
# 도도한 미식가_48905
# 뚜미뚜두
# 녹차라떼는 말이야
# 호기심 많은 마스터_24963
# 즐거운 식객_33991
# Zozojung
# 개구진 개척가_68855
# thfnqldlqslek
# Heyjude_88
# 9봄
# 집가는중
# 배고픕니도
# 선도링
# 예리한 식객_95527
# 건강한 마스터_89524
# 베짱유
# 수갱스터님
# 두앵
# 꾸꾸124
# 유명한 맛사냥꾼_6859
# 밍밍공듀님야
# coombe
# 비엘
# tpwl****
# 건강한 식도락가_19213
# Isabellerohel
# 네워닝
# babyssoi
# 개코가석자
# 일마레
# 정현선k
# Nakitah . 수인
# 온화한 식도락가_59160
# 쭤퍼쭤퍼
# 댱뮹징
# ba0****
# 박하순
# 쀼리뿌
# 은 빈
# 탕통탕후루
# 건강한 맛사냥꾼_62850
# 남다른 마스터_47715
# chosw0922
# dlrlfdyd11
# 어물전 청 한남점
# 권구89
# 먹짱망곰
# 재미있는 셀럽_22667
# 한남유현
# 착한 식객_49724
# Yessirchitsir
# 조용한 식객_23097
# 맛제비
# 고르드상
# 엘리사벳
# 0621
# 미진지니
# didi48
# 씩씩한 마스터_26101
# 빠숀
# 쩝뿌
# 큐티여니
# Nayeon27
# Hwanhee_lol
# 박경식
# 리기패밀리
# PSY
# 정직한 식객_29229
# Kelly1013
# 슬이숭이
# 꿈꾸는 맛사냥꾼_64584
# 한일수일수
# gggg87
# Eidetic_Ash
# 이 슬   SEUL
# 마법같은한끼식사
# hyon_l
# 착한 마스터_21123
# Narlarda
# 콩만해요
# 추차차추추차
# Jeon96
# tekyb****
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 이속우화 덴푸라 혼
# 쁘쁘링
# 유노암세인
# 지우찌우
# 전션
# 아름다운 셀럽_74702
# 토비범
# 끌로딘
# toms****
# 에르메슈슈
# 인기많은 식도락가_65312
# 피흐
# 헤일림
# 척척석사
# rheeji
# MiMiNiM777
# mininii
# 이화음악원
# 하지메노잇포
# 타이레놀 a
# BBHwang
# LEE JI EON
# 마카오 in
# 미키콩
# 꼼꼼한 미식가_38546
# 까칠은자
# 웅잔디
# 윤덕권
# 재미있는 셀럽_37105
# 하지메노잇포
# Kang G
# 용용자자님님
# 유명한 개척가_72024
# Konadeep
# Ellestchae
# 승주22
# 듀프레인07
# 타임모나코01
# ChanYoung
# 아름다운 맛사냥꾼_23504
# 푸른눈의팽도리
# 지용파
# HEEZINIYUMM
# 인기많은 식도락가_27640
# Andy YANG
# 서니니니
# YAC
# Saechi
# 재능있는 개척가_18447
# 맛잘알 이선생
# euneeune
# 목계화원
# 비범한 셀럽_16511
# 랴랴.
# 브라운아이
# 어떡하징
# 코만도야
# 고독한 식객_23182
# 이름멀루하딩
# 손마음2
# 누워서떡먹기
# 아름다운 식도락가_7623
# 귕심윰
# 연이1004
# Boxerbama
# 숀또는션킴
# 똑똑한 맛사냥꾼_23780
# Thebrights
# lsjs****
# Meggy
# Judex
# 착한 식도락가_31583
# 호기심 많은 맛사냥꾼_1919
# 착한 셀럽_19155
# 박☆숙
# 시예누
# 부드러운 미식가_94275
# 신관수
# 빛나는 마스터_59345
# 착한 식도락가_54995
# Cclapp
# 경쾌한 셀럽_12947
# 고독한 마스터_93119
# KKDM
# 쏠.쏠
# 줄라이2
# 낙원상가김용철
# 특별한 개척가_84245
# 줄탱탱
# 예리한 맛사냥꾼_91194
# 지응둥쓰
# 지혜로운 개척가_57751
# 밸류랩
# 스마일a
# 주혀니들
# 꼬덕
# 김초록1
# 스도웅
# 부드러운 식도락가_89046
# 한지안_
# 버마고양이
# NADA1977
# uphill namsan
# 비비아나나
# elooiselee
# 미나리김
# 김냔늬
# 터치
# 유명한 식도락가_34234
# 날둥이이
# Lovebachforever
# hyoj
# HS84
# 새로운 미식가_90247
# Steve Chung
# 봄브민
# 화려한 식객_85166
# 여름토깽
# 고독한 셀럽_50010
# 솔직한 맛사냥꾼_39402
# 씅11
# 요조져니
# solpower
# 우수한 식도락가_38691
# 홠혎
# 킴콩지
# 동이굿
# 새로운 미식가_90247
# 내가맛있다하면믿어줘
# 추차차추추차
# 아잉슈페너
# 오이가지굴빼고주세효
# 온화한 마스터_3255
# Miru1213
# 강직한 식도락가_45639
# kfi****
# Damon kim
# 하이바이12
# 쥴리412
# 재능있는 식도락가_87552
# Grayknit
# 한끼의즐거움
# 스마일a
# …344
# 특별한 식객_77037
# twinklelia
# Jisooui
# Dr. B
# hjco
# 혜식스
# YDDANI
# 중앙변속기
# 예리한 식객_14369
# 살팀보카
# 행복한 개척가_8819
# 주현쌤
# 소나신
# 신성아**
# 도이루리
# Kao15
# 진흰둥
# 카탈라누
# 착한 미식가_87159
# 이이주연
# 유니문유니
# thfnqldlqslek
# 무스리가
# marc719
# 남다른 식도락가_49018
# 조용한 미식가_81635
# 달고달고
# 윤다솜916
# 예리한 미식가_13080
# 홍석중
# alti
# Blue햇살
# 기혜란
# eh2307
# 모쪼깅
# 하늘이20
# ringring
# 창이끼
# 슈거블루스
# 떰2
# 호기심 많은 미식가_28634
# 흥미로운 식도락가_71094
# 고기샌드백
# 율무32
# 500K
# 에언
# 남다른 식도락가_17682
# 가드너
# 브리타정수기
# 조조의 조조
# 큐센
# Junennbob
# Ynoo
# Kao15
# 페퍼맘79
# 피피조아
# shltlsrnjs
# Limzt9
# 똑똑한 맛사냥꾼_97412
# 부드러운 미식가_21589
# 로기
# 쥬씨픽
# 난 천재다 이멍충아
# 안외로운 미식가
# 난 천재다 이멍충아
# 난 천재다 이멍충아
# 유니대디
# 러스지
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 야스노야 본점
# underCSR
# 이한규예요
# 토마스유
# 꼼꼼한 마스터_31714
# 구태은이
# Madi
# 호두호두해
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 화양연화
# azhar
# 보라마
# Jaywon
# 피크닉바
# milgaru**
# 리뷰왕 뿡요
# 김로즈
# 튀각
# 성민걸
# 샤미에
# 최고의 개척가_81776
# 달달♡♡
# 특별한 개척가_87620
# 유하연2
# 꿈꾸는 마스터_25839
# 재능있는 맛사냥꾼_60374
# meokjjang
# arte1110
# 비온뒤언제나맑음
# 네잎7
# 봄둥 이
# Grooveflow
# 쵸코파
# 0815131
# 고여사1909
# 착한 개척가_57598
# 라링
# 해쏭쏭이
# 168CM
# 빛나는 식도락가_26272
# milgaru**
# yjyjyjyjyjyjyj
# 계란호랑이
# 외로운 식도락가_86077
# Julyrain
# 냠냠호빵맨냠
# Zoonie
# 김태봉이
# 특별한 식도락가_34202
# 밝은 미식가_18814
# 정다긍
# 쁘눙
# JOEY_STYLE
# 와이너프리
# 여유로운 셀럽_89155
# 꾸니형님
# NH2DM
# kyungsun****
# CarpeDiem2020
# mmoi
# 소와나 한남 본점
# 최고의 식객_96004
# 강철몽탁
# 이태원공주님
# Billyansoni
# 3467솜솜
# kaudi
# 유니롱유니
# 히포스
# ranns2
# 나는야 먹깨비
# 여유로운 식객_19351
# 대대디
# 재능있는 식도락가_20500
# pep
# Maggie
# 멋진 식객_63291
# 최고의 개척가_81065
# tjrrn****
# 자칭 현슐랭
# DrG1
# ptrex
# 2Bthere
# 이동윤12
# kelly052
# 싸아아아아악
# 커피뚜껑
# 디팩김승희DFK
# 멋진 식도락가_8183
# 빠유0812
# 슈크림빵
# 프로듀서 이계우
# 재미있는 맛사냥꾼_5222
# 고구마 먹는 춘식이
# 경쾌한 식도락가_90598
# 123qw78o
# K.Top
# 데이지피그
# Migmigmig
# 씩씩한 마스터_40455
# 차차생각
# Jxdn_park
# 최고의 맛사냥꾼_51611
# willy90kr
# 슈가마미룽
# 화려한 개척가_52067
# 붕붕오
# 김수컷
# Liaryu
# 윤대일
# 이도춘
# 한남타츠
# dongzhu
# 신나는 마스터_57352
# 달달한 바닐라
# xminx
# 종로토토로
# 김보랭
# 재미있는 개척가_31432
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 레이지파머스
# 개구진 셀럽_29388
# 피피러브
# 부드러운 식객_2956
# 코코뭉뭉
# 쑤뚜
# 착한 마스터_25264
# 씩씩한 맛사냥꾼_37781
# 아맙스타
# 맛따라구만리
# 유명한 식객_45842
# deliceparty
# suesong
# Anne0806
# Im해피
# HyeAn혜안
# 찌예졔
# For EJ
# 우사기님
# Jaythey
# 20206
# 화려한 미식가_95421
# 호기심 많은 미식가_46203
# 순그린
# 고독한 마스터_69230
# 지현05
# 착한 마스터_90785
# 아맙스타
# 커피밀크아빠
# 아구아구찜
# 미미캣
# 조용한 미식가_68989
# 지니림2
# 유민철
# 밤이마미깡
# 쥴리아코코팝
# 발랄한 식도락가_96184
# 로에베아이레수틸레사
# 남다른 마스터_50967
# 행복한 미식가_79753
# 북웜
# ce
# 윤아뀨
# YDDANI
# 장서희
# 졸리드림
# Jeffmom11
# 대추와자몽과차
# 화려한 식객_11852
# 한놈만팸
# 여르미온
# 스시사이
# 코보리
# 백도야지 0515
# Sasha Lee
# 멋진 식도락가_7837
# 솔직한 식도락가_33500
# 아름다운 셀럽_24510
# 찌스다
# OSS
# 위트있는 식도락가_96155
# 백도야지 0515
# ELcho
# Uberpseudo
# 재능있는 마스터_49524
# dolkon****
# 임호세
# 스시장
# Dolly Agnes
# you mea
# eui****
# 매력있는 셀럽
# Sangkevin
# Jaya87
# 뽀식2다
# Uberpseudo
# 지훈나
# 연이빵
# 아현동박재우
# 모닝와인
# elro****
# 루구리방구리
# 밝은 미식가_43882
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# Barboo (바부)
# 베리베이413
# 행복한 마스터_52285
# dayever
# hyunev
# Jeong51
# 건두디닝
# 91조성혁
# 삐오삐오
# 미나리김
# 수덕스덕
# 뿌셔뿌셔ㅓ
# belle0118
# Milk.
# 리틀토리
# alice028
# 빵타지
# 몽돌구
# 위트있는 미식가_56713
# Godblessmymouth
# 진구링딩동
# 맛있으면홍홍웃는식객
# 쾌활한 셀럽_36288
# 디빵빵
# 히아신스99
# 예리한 식객_14369
# 새로운 식객_48693
# 박재범 love
# 개구진 개척가_70108
# 꿈꾸는 마스터_88150
# MIRAGESHOP 미라지샵
# daisy03
# 쿄쿄쿄야옹이러버
# 검단흥마니
# 닝냥늉뇽
# LEA KIM
# Foodyyyyy
# 쾌활한 셀럽_43588
# 카레구이
# 가0씨
# Ramaa
# 신규주
# 즐거운 미식가_66040
# 청귤라임
# 쩡어릿
# 도도링링마벨
# 발랄한 미식가_62473
# 김여름리미
# 에이미전
# hyunsu9
# yoonjimin1219@@
# 미래회관 한남
# BlackJane
# alextomchoi
# 고독한 셀럽_44051
# 마을사람A
# jenniejen2
# Jy 71
# 큐피마요네즈
# AlexPark
# 투덜핑
# BlackJane
# hyepark89
# 꼬마elf
# 인기많은 식객_75093
# 기분좋은 식객_76221
# 조쭈하
# 외로운 셀럽_83335
# 즐거운 마스터_75749
# 깜찍한 식객_24827
# 여누또영
# Dennis Nam
# Dennis Nam
# hsh1213
# Lui_o
# Beadjhlee
# 모아이닮은사람
# 신나는 마스터_65250
# 뽀돌뽀돌뽀돌이
# 식객횬이
# 즐거운 식객_3205
# goatchu
# Changwan
# 실패한 식객
# 수르메스
# 지엔빙개고수
# 규귝규귝
# 최고의 맛사냥꾼_43468
# 뭉초라뭉초
# graceful_12415
# graceful_12415
# 외로운 셀럽_26333
# Hyunuuuu
# 꼼꼼한 셀럽_60920
# 쾌활한 식객_22901
# 즐거운 식객_3205
# NA
# 온화한 개척가_8228
# NA
# NA
# NA
# NA
# 스시고코로
# 베스트
# 최고의 셀럽_14532
# 이기욱ㅅ
# 경쾌한 식객_61884
# Fooafighter
# 따뜻한 식도락가_75243
# 에페23
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 사테
# Eun_D
# 뮤즐렛
# oldaugust
# 홍차누나
# 줄기
# 한곳만 조지는 사람
# 외로운 식도락 뭐시깽이
# 참치참치정참치
# 한곳만 조지는 사람
# koo2522
# SHEA LEE
# 한곳만 조지는 사람
# JEON SEUNGHO
# 진수수수수깡
# 윤철
# 쾌활한 대식가
# 새로운 셀럽
# 지혜로운 식객_95335
# 한곳만 조지는 사람
# 유뮤류뮤유미
# 콩국시
# 한곳만 조지는 사람
# 꿈꾸는 식객_83181
# 트레인블루
# 즐거운 미식가_66040
# Mikewineny
# 성수엄마
# KIM BASIL
# KIM BASIL
# DrCoffee
# 한곳만 조지는 사람
# 한곳만 조지는 사람
# 온화한 개척가_88514
# 안희진
# 비범한.티코.
# Citizen Kane
# 진니
# Yong Jin
# 재능있는 식도락가_96996
# 위트있는 마스터_84687
# hippolicity
# 윤아톰
# 와근
# 한곳만 조지는 사람
# 한곳만 조지는 사람
# the9****
# 꼬질
# 와근
# 한곳만 조지는 사람
# iichi
# 스시쵸우
# 미식하는 술쟁이
# 콩가지
# yyyyyyyyyyyyyyd
# 조용한 식도락가_3058
# 이민탱
# 리틀토리
# 루다누리
# 아지들아빠
# 먹보몬
# 예섭s
# wsc0605
# yyyyyyyyyyyyyyd
# 마카오 in
# yoj
# 먹보몬
# 착한 셀럽_93115
# sssoeun
# 미래경영
# 솔직한 개척가_82104
# 한량 8888
# cathy chung
# 먹보몬
# 최고의 개척가_34221
# 타종균
# 먹보몬
# cytoxan
# 무롱롱
# 똑똑한 식객_62676
# hglim19
# zixa
# 미스터서울
# drmi****
# mingdiviolin
# Jvseph
# 김몽기0503
# 진현찡
# Jesusischrist
# 마카오 in
# 송골매u
# cytoxan
# 미엘마미
# 산두맘
# 건ㅡ
# 호랑일
# 활기찬 맛사냥꾼_88200
# 먹보몬
# 비범한 미식가_44401
# 마카오 in
# 먹보몬
# 잭영!
# 제이든by한남
# 매한불매향
# CyberYang
# Phillip C
# Emilie0101
# 꼬맹이구름이맘
# 베로니키
# 이이민주
# 예리한 식객_32434
# 똑똑한 식객_97270
# 위쥰
# seno****
# 솔직한 셀럽_47154
# Han Cho
# illan
# 위트있는 맛사냥꾼_78367
# 성공한 식객_2318
# 최고의 식객 1
# 신나는 개척가_69708
# 박정화1
# alextomchoi
# ㄱ슈어니츄니
# 투덜핑
# kazu0313
# 한위1991
# 일일요일
# 개구진 미식가_46392
# 씁후
# 냐미냐미야
# 가멜맘
# hjsh1115
# 따뜻한 식도락가_39758
# 발전하는나
# 별보석민재맘
# 정코리
# 씩씩한 개척가_70936
# 김치공주
# 솔직한 식객_79409
# 갱스2
# 맛집에진심인
# 아쿠홀릭
# LEEKOR
# 우재짱
# KH♡
# 재능있는 미식가_85713
# kijunghoon
# 쏘쏘쏘22
# 핑크스트로베리
# 밥먹는 포도
# 행복한 셀럽_5463
# Hyunch
# 스이세한남
# 강_상훈
# Marie
# 다니엘 강
# 못먹을만큼시키고다먹자
# 초과로시키는남자남겨야미덕
# 미뚱
# Joy41
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# DOTZ
# hummingbird
# 유명한 셀럽_73871
# 여유로운 미식가_16300
# 강놔
# 째미어트
# 지야니
# 서렝
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 에프더블유브이 용산점
# Nnyule
# 강민철님
# 꿈꾸는 식객_5278
# 나는야돼지팡
# 활기찬 셀럽_93462
# yvonne jung
# 노
# 코로코로
# 고래이야기
# 따뜻한 개인주의자
# 신용진111
# 재롱123
# 착한 식도락가_36249
# 한롱
# 예리한 맛사냥꾼_38846
# 탕탕후루루루루룩
# 즐거운 셀럽_38516
# 설이누나야
# 특별한 맛사냥꾼_67146
# 흥미로운 개척가_96153
# 유옐
# 위이이이이이잉
# 안녕하세용용죽겠지
# 외로운 미식가_6768
# 진코비
# 귀여운토마토
# junyi12
# 빠른나무늘보
# 초코누낭
# mjh0411
# 이맛저맛
# 루씨루씨
# KFC Guy
# JJ_.
# 예리한 맛사냥꾼_6631
# 강고집
# 경쾌한 개척가_69837
# jinamiam
# Kimgongzuu
# Hhhh_
# RARIRO
# 왕코토끼
# 에그재히
# 킴탬탬
# 개구진 미식가_61268
# JJJJAAAA
# sysuiul
# y.dami
# NA
# NA
# 비아톨레도 파스타바
# 데이브레이커
# 맛없으면리뷰안씀
# Dhud
# 맛집좋아욧
# Mason Moon
# 씩씩한 식도락가_24415
# 새로운 맛사냥꾼_50935
# 귤맛
# 루까 LUCA
# 쓰단쓰단
# 피노
# 고독한 식도락가_95717
# 골프친후삼겹살
# ahah1414
# Saaaannm
# 무나두러오보
# 우수한 식도락가_67999
# KateS
# 하눌맘
# INTJ ฅ^•ﻌ•^ฅ
# 똑똑한 마스터_60793
# 맛집좋아욧
# waterpillow
# 봄여름
# Raffaello
# 별명없다
# sewonyoon
# 우또반
# 쓰단쓰단
# 라따뚱이
# 서쿠쿠
# 재능있는 마스터_65022
# 혼을담아서
# logi
# 맛없으면리뷰안씀
# 맛집좋아욧
# 미맹
# chchee
# 쓰단쓰단
# 건강한 셀럽_92611
# 아름다운 마스터_49995
# 똑똑한 셀럽_66657
# 윤금자
# 새로운 식도락가_94803
# rockher
# 런더너
# 청주먹깨비
# 던이에요
# 피노
# 쓰단쓰단
# 스시상남
# JJ80
# cause9
# 꽁뚜
# 맛좋은한끼식사
# 꿈꾸는 마스터_95987
# kassaln
# tomjerrymom
# tomjerrymom
# g4
# tomjerrymom
# 최채
# BAROS
# 쏭쏭-송은서^^
# 특별한 식도락가_2260
# Johnny E&S
# 나경나굥
# 흥미로운 식객_67094
# tomjerrymom
# 배고파밥밥
# 아름다운 마스터_5679
# 세브니1
# 쏭쏭-송은서^^
# 딸기뽀
# 미식가2425
# Gina3
# foodieeee
# tomjerrymom
# 도도한 맛사냥꾼_10357
# tomjerrymom
# 고기마에스트로
# Sandra89
# 따뜻한 식도락가_94665
# 아름다운 미식가_90303
# 아나38876532
# 박모모
# 정아름이찬민이광우
# 조용한 셀럽_39363
# 미식가2425
# 쏭쏭-송은서^^
# 딸기뽀
# 세브니1
# 찰나의그순간
# 개구진 개척가_2221063
# 서연!
# 찌엄마
# 라리
# 빛나는 맛사냥꾼_6229
# 깜찍한 셀럽_41818
# 아름다운 마스터_5679
# yjhw1105
# Trattoria & Bar VILLA DE LA VINO
# 지훈나
# 솔직한 식도락가_16580
# 또치2
# 무니23
# TIC DESIGN
# 새로운 셀럽_38432
# 연필공장
# 성수세연
# 후비주비
# 정직한 개척가_16966
# hej hej
# foodbalance
# 꿀벌벌
# 꿈꾸는 개척가_95602
# auussie
# 현지서
# 라우드스
# 가든맨
# 영섭2
# 현지서
# 클라라즘
# 따뜻한 미식가_66672
# eh2307
# 1월20일
# blondjenny
# 앤디킴영균
# dani77
# 개구진 마스터_31022
# 백종원2
# Sophie Huh
# 우수한 식객_8659
# 정튜피
# 정원아빠
# 구이
# Sophie Huh
# 써울시스터
# 밤창이
# 한남라이더
# 현지서
# 최고의 맛사냥꾼_33766
# greensunlit
# 미스터맨슨
# Sollllll
# 영섭2
# 파파이이
# 안토니오리
# 도도한 마스터_29527
# 입두접시
# 괴도라치
# superpower
# WUI 웨이 티하우스 & 레스토랑
# 해피조이스
# Yunikim
# limejuicy
# 엠졔
# Yangsookyun
# hjlee77
# 냥스
# hjlee77
# 최홍은
# AlldayChristmas
# 해피조이스
# 햄짱짱
# 서교야
# 인간1
# EBO
# 나루식객
# Kokakolalah
# Minarinim
# 부드러운 셀럽_67760
# 라모트리진
# dana44
# Pprs5700
# beomjoon
# 서장주
# 해피조이스
# 스톸커
# 율맘빠
# sunxe
# 헤니누나
# 새로운 식도락가_43272
# 단지냥
# 이음새
# 쾌활한 셀럽_64418
# 재능있는 식도락가_50538
# 공부차
# Jenlee
# 브레이니
# 무적소녀
# 성공한 식객_56019
# 경쾌한 식객_49471
# 경쾌한 식객_49471
# O!boy
# YK_________
# 해피조이스
# MikeAhn1
# pauly5688
# Doug
# rafael0522
# 루이17
# 화려한 셀럽_98923
# 개나리식당
# 알빠야빠빠
# 경쾌한 마스터_78461
# 전인순
# 쥰키_89
# 참치다
# 재미있는 셀럽_10934
# 신나는 셀럽_48853
# chloe63
# ssong29
# 착한 개척가_85435
# 여유로운 셀럽_47144
# 글로리glory
# 온화한 미식가_9407
# 성공한 개척가_75028
# 활기찬 식도락가_11045
# 행복한 개척가_27760
# 이연숙 떳다
# 지혜로운 미식가_83286
# 호기심 많은 개척가_71812
# 밥먹는 포도
# 김뮤뮤뮤
# 이불둘둘
# 깡믜
# 득득득독득
# 신나는 맛사냥꾼_12708
# 호기심 많은 식도락가_91250
# 노랑퍼플
# 네모지게
# 꿈꾸는 맛사냥꾼_41692
# 하쭈공주맘
# 아름다운 개척가_43226
# 지니지니만두
# 김*건
# 이문금
# 우재짱
# 고독한 셀럽_59742
# アリ
# hjsh1115
# 솜사탕수육
# 플로라1110
# 바함
# 부드러운 셀럽_2744
# 발랄한 미식가_33930
# 람쥐대왕
# 발전하는나
# 김은*
# 으뜸인어
# NA
# NA
# NA
# 기러기둥지 용산 'The Train'
# 타래애애
# TALF
# 바다 보고싶다
# 5평싸나이
# 라랄ㄴ
# 개구진 식객_43235
# 지하123
# 1995 김근모
# UZZIi
# 나는민준
# joohyw
# judy0010
# 황천의잃어버린성룡
# 도도한 셀럽_49975
# KLUE
# 포로리리리리리리리리리리리리
# 레캥
# 레캥
# Toss20
# 온화한 마스터_52527
# 조솨
# 포동포동 치즈
# 써니0204
# 재미있는 마스터_83310
# oryeonge
# 레인보우디핀다트
# 외로운 개척가_1022
# 식사중이에요
# 뉙눼임
# 야부엉이
# 온화한 식도락가_26195
# 여우다아아아
# pagi
# nic.shn
# 디이비이
# hhhanii
# 키요옹
# 행복한 식도락가_54026
# 빌리요
# Ju1010
# ssoooooo
# 예리한 미식가_45764
# 기르임
# Steady_kim
# eden1915
# 즐거운 맛사냥꾼_72983
# 부러진나쵸
# 김김하이
# 최유지니
# 냥냐륑
# 엔그릴 (n GRILL)
# 밝은 식도락가_47763
# 여유로운 개척가_22711
# 스티븐 J
# Vipjm
# 오들킴
# 버수니
# 박현호12
# 쏠메잇
# 멈멈띠
# 켄장 Ken Chang
# 20062****
# joy1212
# 즤니건듀
# 손병수
# 수꾸니
# 양헨리
# 임승혁12
# 리치4
# 토끼와케삼이
# 정운이니
# Curo0321
# 혜뚜뚜
# 인기많은 미식가_95697
# 테일러_
# 심옥령
# 착한 미식가_74510
# 꼼꼼한 맛사냥꾼_34636
# 강직한 마스터_50097
# sukyuLim
# 경쾌한 미식가_94713
# 지혜로운 식도락가_43398
# 비범한 마스터_11056
# 위트있는 셀럽_73715
# 배송송이
# 2포대장
# HZHZ..
# 갑작이소낙이
# s**
# minjunkevinkim
# 특별한 미식가_52935
# 강기택
# 뻠혁
# 찬하늘
# 헐랭방구뿡뿡
# piro
# 러블리별이
# 조타이거
# Mera
# 위트있는 개척가_18841
# 방윤제
# pakin
# 갱갱이726
# Sennakim
# 앙돌
# 강직한 식도락가_47249
# Monica
# 제니자니조니
# 선도링
# Youngjun0519
# 갱갱이726
# 잉영이
# 헤일리_
# 야무진sj
# 까슬이
# 달콤누나
# 최토끼ㅇ
# commahan
# AMD
# samsamu
# 유쮸유
# 강맹두
# 뚱냥이:
# 구가
# 집시의미식생활
# 마로누나
# 제리제리효이
# applelee
# 한남동감자탕
# 미쟈*
# 리아lim
# 냠뇸냠냥뇸
# 졍졍jjj
# flowby
# 즐거운 개척가_72011
# 건강한 식도락가_65020
# 라브리
# 피글뢧
# 인기많은 식도락가_27231
# 권따오
# supermanksy
# 신나는먹방
# younsss
# 29Jun
# 감자2023
# 라오니오니
# 유명한 셀럽_32617
# yyul11
# 윤쓰푸디
# Seanday
# Blue whale
# 구깅
# Restaurant I.O.U
# Jhko123
# hjloa
# mywilbe****
# 원더류먼
# 흥덕아자르
# khj2991
# 민정 ღ
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 꼼모아
# 히히소모
# Checkitout
# 호기심 많은 마스터_88599
# 도토리토리
# 빛나는 식객_87515
# 강직한 미식가_87064
# meview
# 도영킴3
# 유명한 맛사냥꾼_81406
# 흥미로운 개척가_4262
# 상봉동야생마
# kayeoning
# 부드러운 미식가_15975
# 주레술주레
# 공주물고기
# 아리지요
# 즐거운 개척가_10557
#  almond
# 진흰둥
# 김재영킹왕짱
# 새로운 식도락가_94803
# 예리한 셀럽_74582
# 김씨123
# 유명한 식객_80723
# 카레쓰
# 히추리99
# 재미있는 미식가_26559
# 이핸주
# 1월
# Heewon Joo
# jkjo
# 정직한 미식가_82776
# 락데드
# h2ice
# 맛도리발굴단
# 인기많은 식객_78847
# 최고피시방존앤존
# 쏠루션
# 행복한 미식가_60404
# 뿌빠삐뽀
# 강키위
# Youne
# tegi88
# 발랄한 개척가_97952
# 닥강
# 꼼꼼한 마스터_65210
# Lagav
# h90h10j29
# RUNET
# 거울소리
# 사랑이 뭐길래
# 꿈꾸는 셀럽_7567
# 바나나사과차
# 무적코털보보
# 흠  :-0
# 크림단팥빵
# 따뜻한 식객_446
# 이재훈92
# 미쑹랭
# 총블리
# lsm
# 강직한 개척가_61641
# ehdgks****
# 배영훈938383883
# 위기의선장님
# 라즈베리잼
# 이수뭄뭄뭄
# 인기많은 마스터_89397
# 외로운 식객_88526
# 베이커베이커
# 서초동 활기찬 맛사냥꾼
# lillyKiimm
# 고독한 마스터_122
# O_Oa.
# 신나는 개척가_42366
# 츄니ㅎㅅㅎ
# Vinie
# 친절한 미자씨
# 여이수
# 혜안97
# 이키
# 미식은즐거워
# 이백림
# coco0
# 허히히
# mooiym
# 아몰구
# 쩝쩝박사노니
# 양승영
# 버터친구
# 밍미리밍
# 변혜린
# yoon0123
# 바질씨
# Jdadah
# 뿡츄츄
# 고대홍
# 하아미이
# 뷰zl
# 하품하는심바
# 혜안97
# KEEM
# Mr 조
# Jason Fat Diary
# Jhjl
# cause9
# mminnng
# 정직한 개척가_13600
# 깜찍한 식객_18728
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 더즌 오이스터 한남
# 꼼꼼한 식도락가_54859
# Good speciman
# 김J
# 청포도아가씨
# moonabell
# O!boy
# 도도한 식도락가_32883
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 보르고한남
# 외로운 식객_88526
# SsOB
# kilyeon
# 짜장이언니
# 프쉬케1001
# 최리버림
# csong0417
# 최고의 식도락가_9813
# WIN:D
# kkim1980
# Jakeonme
# 지혜로운 식객_19587
# 비범한 셀럽_710
# 캐치캐치캐췻
# solution
# 루카아
# hyunbinee
# SK1122
# ema
# 쿠로미식가
# honjaso
# 아름다운 미식가_46654
# 차진영
# 쨈파파
# 훈훈훈쓰
# 현지다람쥐
# 그린싱크
# 쿄쿄27
# 외로운 식객_88526
# 압구정성수미식가
# Victoria Vic
# Julesdada
# secretvabes
# kimbangfoods
# 레나바호
# 경쾌한 식객_24708
# 유미54
# 아름다운 셀럽_28074
# arinmaria
# 안재범   JB.jaebeom.Ahn
# 솔직한 맛사냥꾼_14989
# 정직한 개척가_55843
# ChachaCharlotte
# Ashley61
# 외로운 식객_88526
# elooiselee
# 미소만세
# 채리초리초
# 둘이맘
# 외로운 식객_88526
# 마음집
# 여유로운 개척가_36002
# 볼드모트씨
# 엥겔지수폭팔
# Lee.지현
# 보까
# 폭주 알파카
# 호지파파
# 동혁John
# Elle Kim
# aaakiii
# 짱유하
# 복슬
# 호기심 많은 마스터_54606
# ~예찬
# ammeg
# 숑숑푸
# Elina83
# goni75
# 조용한 미식가_66851
# 씩씩한 식도락가_80891
# 인기많은 식객_49094
# rnehd****
# mmnngg
# 볼드모트씨
# 예리한 식도락가_58559
# 최소여
# 김종지
# 꿈꾸는 식객_21844
# 똘또리몽
# 경쾌한 맛사냥꾼_74155
# 양요섭_
# 조승형
# 약포카토
# 톨레빵
# 혜원뿌이
# 위트있는 식도락가_43623
# Samantha Kim
# rhflffk96
# donguranmj
# 권영혜127
# Olivia jung
# 하안동칼날여왕
# 빅터님
# 백소사
# 착한 맛사냥꾼_89964
# 리아솜
# Elina83
# 씩씩한 식도락가_59807
# 새로운 미식가_45738
# 르씨엘
# 몬드리안 클레오(CLEO)
# 써니아빵
# 기분좋은 미식가_12220
# Mystylekmk
# ☆Huey Kim☆
# JY.Ku
# jiyyoon
# 희망인
# 위트있는 미식가_32376
# 착한 미식가_15960
# 위트있는 맛사냥꾼_92747
# 밀크맨
# 예리한 맛사냥꾼_79216
# Chris won
# 퓨어라임
# 도도한 셀럽_58205
# 세이굿바이
# 인기많은 미식가_64724
# Junny
# Twiggy
# 활기찬 미식가_4425
# everpeace
# 조익구
# Jes0414
# 쾌활한 마스터_21632
# 밍밍이17
# 강직한 미식가_28431
# Odi
# 옥시코기
# dryun
# 휴휴몽
# 착한 마스터_57762
# hhh11wl
# 앨리스84
# 스마티73
# swon****
# Thomas Aquinas
# 아라미뇨
# jinpa****
# 우겅겅
# yhk8262
# 활기찬 미식가_4425
# ma ma ma j
# 제임스박군
# Shin4018
# angelok
# YH. Chin
# 강직한 미식가_28431
# 케이케이_KK
# NA
# NA
# MAISON HANNAM V
# bbbo****0000
# Jhleetax
# 솔직한 마스터_18217
# progdesigner
# 인지♡
# 쾌활한 식객_8209
# 라그랑지안
# cosmcjgmrncn
# 남슈탱
# ysoll
# 예리한 식도락가_84704
# haelnny
# Leah's
# 비버남
# Joyongsu
# 정직한 마스터_69602
# Bethuel
# leedre
# 고래씨
# 착한 개척가_64672
# 최고의 셀럽_9047
# 젠이ㅣ
# 즐거운 개척가_84282
# 강직한 셀럽_9881
# crstmt
# 추연빈
# 날둥이이
# hjjhhj
# 영미바보
# 맛제비
# michaleHan
# 연쨘
# 역삼동총잽이
# adore_yeon
# 셈로랑
# 개구진 식도락가_17143
# 뀹뀹
# 우수한 식도락가_78732
# 추상
# ʚ혜주ɞ
# Webstyle
# 나이아스
# 쾌활한 식객_60392
# xc****
# 유명한 식객_56928
# 일촉즉발
# 푸드환
# 깜찍한 식도락가_65441
# 김김딤
# Armchair Traveler
# 르다 (Le Da)
# 밍유링
# 예리한 식객_61980
# 그니지아
# 체리마루ㅋ
# 토깽이들
# 아름다운 마스터_94554
# umchiki_um
# jojongt****
# 호있짜있
# 징글맞게예쁨
# 떵뀨
# 춘춘시기
# CrimsonB
# 최고다석
# 강직한 맛사냥꾼
# 밝은 식도락가_27275
# WANG LU
# 낭키러버
# 식탁엔안창살
# 박창한슬기
# 엔시맘
# 고선비
# 쭈이이이이이
# 미실냥이
# passion.ha
# 잼니쓰
# 도롱밍
# 꼼꼼한 마스터_648
# 효니닷
# 재능있는 마스터_50786
# 난 천재다 이멍충아
# 아갓갓
# 인기많은 미식가_77405
# 쫜크리스탈
# LKLKLKLKZ
# 뚱땡보빵야빵야
# 장팡
# 김환철A
# 망고아버디
# 뷔뷔엔
# tailleur
# 고독한미식가3333
# 김댄댄
# 최혜연2
# 치행
# 송이1231
# 우수한 맛사냥꾼_52722
# 365외식하는귀객
# 우수한 마스터_19389
# 세일러윤
# 라페름
# 김녕0
# 스마티73
# 여유로운 미식가_8589
# 씨와이패키지
# inuage
# 빛나는 미식가_29034
# claire14
# 신문경
# Leilajo
# artcera
# 박서지니
# 미드나잇켈리
# 아르스노바
# tren
# Lovely Judie
# 오레오뜨
# 남다른 미식가_7543
# 코코장군
# Green Court
# HwaYoung Lee
# yulie
# sv375
# Chou&cream
# Jipp
# 발랄한 미식가_84293
# 류리_
# sminoh
# 밝은 식객_34630
# hjsarah
# 젠장소녀
# MichaelS
# Js10065
# 고독한 식도락가_99317
# 임라미
# 화려한 셀럽_64776
# ksenia515
# 고독한 셀럽_30905
# 바둑이돼지
# 개구진 마스터_55410
# 케이0831
# unwhoq
# eva77
# hww
# findfirst
# owooin
# 쥬ㅣ
# 강수맘
# 성공한 마스터_41318
# Yum yum good
# 화려한 셀럽_64776
# 푸에고
# kseoj
# keithkh
# woodansub
# 남산아씨
# 타칭 허슐랭
# 쿵따리샤바바
# pandoro
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# Harbour
# 최고의 식도락가_43072
# 수퍼두퍼맑음
# 배숭숭
# 굿럭찰리
# 휘식가
# 유기주
# Daniel0727
# @스누피@
# 행복천사12
# 프린세스핼
# 구탱김
# 기모노
# 잉앵양
# 새로운 미식가_26541
# 대단한너구리
# 해나류
# 닉네임랑기
# preet****
# imidnj
# 주난99
# Redvelvet_Cake
# 행복한 식객_64597
# 위이이이이이잉
# 한라프
# Ejoh272
# 솔직한 맛사냥꾼_46217
# 도넛킹
# 리니파
# 양양양양잉
# Hazeleey
# 은서은서
# 아로미1219
# u.hee
# 강직한 맛사냥꾼_46745
# 유명한 식도락가_92931
# Celiaa
# 경쾌한 맛사냥꾼_77644
# 스루루기기
# 밝은 식도락가_42485
# irene.at
# Sudin
# 탱구리
# jushin
# 초이오농이
# 갱이234
# 로토랜드
# 예리한 식도락가_53533
# 민트.
# JH_DK
# 이동자님
# KIMI
# 멋진 식객_473
# 예리한 개척가_28262
# 민초파파파
# 위트있는 마스터_75846
# 잔비
# 눈누누눈
# 예롱쓰
# 달콤신
# 특별한 미식가_17481
# 해피제이드
# 쑝쑝쑝구리구리구
# 현캉
# 기마비
# 스탈2680
# 지혜로운 셀럽_12741
# 밝은 개척가_85730
# 힐조야밥조
# 마포아가씨
# 냉정한만두
# BOOTS CIAO
# fkfh
# 비범한 미식가_87900
# 빙빙구
# 조용한 마스터_27943
# Minggyul
# 전졔님
# 아름다운 식도락가_7623
# 본투비미식가
# 체리9
# 빛빈
# 하이은비
# songhaenjoi
# Ojeone
# 경쾌한 셀럽_13083
# 특별한 개척가_34073
# 후씨야
# 윤서현서맘
# Grace lover
# Redvelvet_Cake
# 대구쏘쏘
# 올라봉봉!
# 기모키
# 미니콩
# 뚜링희
# 띳띳
# 본투비미식가
# 라리빠
# songhaenjoi
# 떼구링
# 챠오벨라
# 구찌 오스테리아 다 마시모 보투라 서울
# Aparis
# 여인의초상
# 유걍민
# 건강한 마스터_61255
# 먹방요정이야
# 꼼꼼한 마스터_70631
# 맛있는취미
# 빛나는 마스터_85936
# 따뜻한 셀럽_57944
# 온화한 미식가_55157
# 제리팍
# 미징징님
# M0z12
# 똑똑한 셀럽_10083
# 곤히야
# 쌈장밥
# 홍지홍태
# wonnie12
# 남궁경미
# ~정원
# sofly
# 싱긋
# 신난 재클린
# i2st****
# Amybymi
# 정직한 맛사냥꾼_71910
# vivi-vivi
# 호호호둘둘둘
# 착한 식객_15917
# Ella Fitz
# 씩씩한 셀럽_37543
# 인이 예여
# 남다른 맛사냥꾼_58892
# 지혜로운 개척가_57751
# 밍부인
# 구오리
# anthemlove
# 캐치유캐치유캐치미캐치미S2
# dino2545
# 10183773
# 물이되어
# 태탱니
# 시연써니
# 개구리마왕
# 다국
# 100H
# 이쁜신랑
# MookYeon
# YeonMook
# 디마킴
# 쎄니에
# 꿈꾸는 맛사냥꾼_92873
# 큐로롱
# 영쉐이
# 성규특별시명수구
# 스탠포드쩝쩝박사
# 착한 마스터_85694
# 마프자 타노스
# 그럴수있지맞아
# 조용한 셀럽_56205
# 도도한 맛사냥꾼_22099
# 보리오빠야
# aru
# 지혜로운 셀럽_20705
# 희복
# 3인분
# 우수한 마스터_866
# justin655
# 한신
# 여나링
# GOYAGOYA
# 기분좋은 개척가_15938
# 용산구 푸드파이터 남편
# Soooooj
# 관심법의발견
# Bhkim5
# 바리공주님
# 캥거루7
# 므네모니스
# 온새미로
# 달리삐
# 아기꽃대지
# 스시좋아좋아좋아
# yjleeee
# 포오74
# 함냐함냠냠
# 비트러버
# 휴르
# 김희희
# Bonita2011
# 동도르
# 꿈꾸는 개척가_47999
# 기분좋은 개척가_15938
# 맨인더
# ggnoescheoioiiy
# 식도락꿈나무
# 위트있는 맛사냥꾼_50976
# Heritage Woods
# 도도한 맛사냥꾼_22099
# 오눌
# 싱코미
# 더플레이스다이닝
# ㅂㅎ라
# pds20****
# ㅇㅇㅇㅇ12345ㅐ먿ㅎ경
# Calphad
# 쩌린이
# 김진태
# 활기찬 개척가_51152
# 그냥 유나
# 킹강수
# stj90****
# leehwaj****
# 조용한 식객_46516
# 찹쌀동수육
# mdy****
# 북산청솔모
# 마부위침_맛집탐방
# 지혜로운 개척가_957
# 구름발견
# chajh5128
# 고우만
# 잠충이77
# 부르지마
# 재능있는 개척가_97281
# 불피에르
# 꿈꾸는 식도락가_21973
# 리바비언니
# 호기심 많은 맛사냥꾼_64291
# 곽면성
# jinjulove77
# 국가대포
# 초룍향기
# kwonminsu
# 새로운 식도락가_11050
# 미저리이
# 인기많은 개척가_54154
# 토끼굴
# 김보람내꺼
# 달려라펭수야
# 건강한 마스터_81569
# sunny80910
# 강직한 미식가_11766
# 꼬갱
# 아침에오렌지
# 기타쟁이
# 마이콩
# Jaemin2023
# 예리한 맛사냥꾼_75064
# 예리한 셀럽_
# 활기찬 맛사냥꾼_15715
# 맛난거내꼬
# 인손 서울
# Lauren sj
# 이강일83
# 흥미로운 마스터_15145
# 인자요산
# 버디빠빠
# Natyang
# 우수한 식객_30244
# 이주완성
# 오현중
# 미미미츄
# 혜화경찰서문지기
# kba80
# 현됴리
# 특별한 미식가_58332
# rinvelyy
# 쩡116
# 기능재부
# 일루와임뫄
# 킹토닉
# singapura
# 뿌공이
# 구류기
# 랑009
# 찌부언니
# 일루와임뫄
# 김도하는나야둘이될수없어
# 호기심 많은 셀럽_53862
# 만두탕
# 밝은 셀럽_23411
# 기김지진여영
# 아나벨라
# Grlel
# 쾌활한 마스터_72605
# 뚱인데요2
# 딩구르
# 써니_링
# 조용한 식도락가_38580
# hhhhhh_
# 상상22
# 김도하는나야둘이될수없어
# 살찌자
# 따뜻한 식객_41040
# 꿈꾸는 미식가_61772
# monster
# kyh13574
# 안경잽이
# Raina1
# 형진920325
# 리치00
# 이우성123
# 마나오
# 빛나는 셀럽_84500
# 벤지대디
# 조용한 식객_89539
# 유왕
# 외로운 식객_88526
# kia****
# 최고의 미식가_24307
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 군몽
# Ethan JD
# 수진:D
# 뿌빼
# 뿌밥
# Phil Kim.
# 온화한 미식가_95064
# 예리한 미식가_1861
# 똑똑한 식객_42592
# 정직한 셀럽_22503
# 브람준
# 우수한 식도락가_86473
# Amy J White
# Scott Jung
# Pdapda1223
# ssongjina
# 안녕하세요 4444
# 김연777
# 고독한 미식가_69105
# Parrot
# 흥미로운 식도락가_33180
# 정직한 미식가_92901
# 솔직한 셀럽_81279
# 심바타
# dragon1
# 도도한 셀럽_97282
# 취미는스시먹기
# 푸드색서
# 챙e510
# 새로운 식도락가_94803
# 김선생니임
# 김아메리카노
# 50316
# 외로운 식객_88526
# Yiebin
# 신나는 식객_39466
# nocnoc
# 찌나리
# 멋진 개척가_66275
# 창현송
# 더블샷닐라
# 캠핑재덕
# 최고의 미식가_85555
# Jay00009
# Hanama
# 위대한먹부림
# 멋미15
# 빛나는 미식가_58434
# 햄햄듀
# 밝은 셀럽_53749
# 이동준
# 시칠리
# 손순남 yuridda
# 성공한 셀럽_34921
# 가비바비
# 무코
# 훈크
# 르블로숑
# fatima
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 나무솥밥 경리단점
# 강직한 개척가_15119
# 따뜻한 마스터_83365
# 숀더미식가
# 시간이 약
# 입맛이까다로운사람
# 입맛이까다로운사람
# 쾌활한 식객_8711
# 아름다운편지
# KAKI29
# 화려한 식도락가_87463
# 강직한 식도락가_26737
# Ariel1
# becau****
# 똑똑한 식도락가_34648
# Jong Ho Park
# 호기심 많은 맛사냥꾼_51862
# 공감능력 탑재한 인티제
# 예리한 셀럽_43169
# 카타리나고경희
# 푸른솔모
# 경쾌한 셀럽_62529
# 발랄한 마스터_85846
# 맛있는것만먹는
# 정화정
# 나눙귀요밍
# 마루맘77
# uniqbong
# 동공
# reed****
# 공자81대손
# 개구진 마스터_86719
# 어후졸려죽게똥
# 기분좋은 마스터_43552
# 주차왕파킹
# 아드리엔
# 동물왕
# 화려한 맛사냥꾼_36703
# 여유로운 식객_34696
# 미소KING
# 말콤65
# nuasarang
# 깜찍한 개척가_60257
# gekka****
# Mina089u
# JJAE21
# 건강한 식객_3265
# moosin
# 소울맛잘러
# 훈이가연맘
# 꼼꼼한 개척가_50538
# 레드문
# si****
# 꼼꼼한 마스터_50446
# Genius
# 나헝
# 손종윤2
# 고독한미식가랍니다
# 축구거시기
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 멜팅팟
# 이인홍
# 달고달고
# phjpjh12
# AM:
# 태인박
# 캔디2222
# 찐정현
# 미모란
# 태인박
# 디앤디
# 띠리띠리리이
# 수정2
# BBOOO
# Ejin1212
# 달고달고
# Pinkgirl
# 크크미니미
# 아름다운 식도락가_7623
# 커비이이
# 밝은 개척가_49021
# 요한이에요
# 지호토닉
# 여유로운 개척가_20058
# 달고달고
# 강직한 식객_96652
# 팔랑방구
# 이뿐개미
# 뜌520
# 태인박
# 예리한 맛사냥꾼_51762
# 베이컨샌드위치
# 태권뷔
# 태인박
# 영14
# 특별한 식도락가_80129
# 예리한 마스터_29546
# 달고달고
# 하마 노마드 맛집 찾기
# 선명한풀잎
# 밝은 셀럽_10364
# 정신차리니 새벽4시
# 냐니냐냐
# 기분좋은 식도락가_28923
# Haru001
# 김갤럭시
# 달고달고
# 요한이에요
# leap_m****
# 맛도도리
# 초코볼828
# 로바타 화목
# 우리 복덩이
# orolnrzr1
# k.명훈
# claire11111
# 유재영63
# Ac
# gluevibesonly
# Ovining
# BbBbBbBbBbi
# 착한 식객_57538
# 솔직한 미식가_93510
# ...
# 입맛 까다로움
# 체리형님
# âme libre
# 쾌활한 개척가_34402
# 유리지르코프
# ❤❤이쁜이들 ❤❤
# 엘리트서울 (Elite Seoul)
# 장수연42
# 곰탱진
# ros2y
# 음식과위스키
# ㅁㄴㅁㅁㄴ
# 이예진6666
# 흥미로운 미식가_97500
# 착한 식객_59346
# 주원070500
# 씩씩한 마스터_28738
# 남다른 셀럽_93046
# 온화한 식객_5243
# 기분좋은 식도락가_15474
# 비범한 셀럽_8499
# 지혜로운 식객_63159
# 배거파여
# 쫑쫑s
# 임정석
# 라니!!!
# 쥬넴
# 백지민 Jimin
# 외로운 개척가_70891
# 나영영영영
# Dreamy
# 고독한 맛사냥꾼_30663
# 김구다
# Yoonline
# 불나방82
# 재능있는 미식가_50157
# 밝은 식도락가_20793
# Creescent
# 금자씨닉네임
# 태웅__
# 해삐ㅎㅅ
# 똑똑한 셀럽_67589
# 한굴
# 서형민!
# 새로운 개척가_52295
# 성공한 식객_97702
# 데이나95
# 박아담
# 윰자아
# 신민개미
# 신나는 식객_97755
# SuB1nn
# 성공한 미식가_13837
# dlaeotjr****
# 101094
# 지나천
# 앙르
# 배반낭자
# 유씨디
# Johnxina
# 린지러브
# 고독한 맛사냥꾼_6299
# 개구진 셀럽_79361
# 따뜻한 셀럽_81478
# modern42
# 기몽준
# Hh2266
# 응디쀼리
# 배숮
# logi
# dji409
# 린지러브
# CamilaCho
# jjjjjjjiiiiiiin
# 프랭크신났드라
# 서교동깐돌이
# 리즈♡
# sssssssul
# EsameE
# 브라우닝닝
# 쑈퍄
# 희희12
# 쿠스리
# HYUNJU012
# Beeeem
# 김동비짱
# 윈드수
# s.sum
# 고독한폭식가
# 존슨이야
# 이형쥰
# jjjjjjjiiiiiiin
# 날씬한맛집탐방객
# 신나는먹방
# sssssssul
# Clarita
# 구깅
# 기몽준
# sonuim
# 기분좋은 맛사냥꾼_80362
# Summer Bae
# RaulAhn
# 밝은 식객_85453
# 고독한폭식가
# 푸합후
# 눈뉴난나와인은맛있어
# 남다른 셀럽_63476
# 오루
# 세렌디피크닉
# 이쁜진희
# 지효희
# 부드러운 맛사냥꾼_92199
# limithee
# 즐거운 식도락가_9547
# yumi4808
# 감쟈만두
# 양개래래래래개개갱
# 맛집 좀 알려주세요
# 끄리리링
# 도움되는나나
# 꿈꾸는 음식 평론가
# 활기찬 맛사냥꾼_30904
# 최사월
# 다나베아미
# Jws2jw
# 재미있는 식도락가_62526
# 화려한 마스터_7160
# 히히히삐에요
# 조경은
# Kimjyeong
# 갱밍스
# 실버리버
# 유ding
# 혜다람
# 제제lee
# 건강한 개척가_59566
# 오둥쓰
# 바이베
# 흥미로운 미식가_64891
# 밝은 개척가_30165
# 코코계절
# 노꿈이
# 프리지아999
# 꿀꼬구마
# 포도숑oOo
# 기분좋은 식객_95875
# 쫑맴
# 반짝장미
# one000
# 이종123
# Juns_11
# 양스리
# 여유로운 맛사냥꾼_68922
# 마성가이드
# 예리한 미식가_65346
# 흥미로운 식객_89152
# 보자고
# 특별한 맛사냥꾼_31436
# 재능있는 마스터_50037
# 바보섬 용산
# Yang Jung Ah
# 린다김
# 솔직한ENTP
# 외로운 셀럽_17772
# 솔직한 마스터_10504
# 미뇽미뇽2
# 라밍___s2
# JiNu81
# 이은경님
# 양효진
# 인기많은 식객_57382
# 지롤트
# yu na na
# 모찌볼
# 우수한 개척가_16316
# 윪ㅁㅁ
# Gina3
# 비범한 식도락가_62623
# 지혜로운 마스터_79716
# 토끼1234
# 밝은 식도락가_32168
# 양양몬
# 몽키P루피
# 엘른이
# 안흥팥찐빵
# ye0nniiiii
# 유파카
# 밀가루체공
# 이윤딩
# 정직한 마스터_6423
# 윪ㅁㅁ
# 심술딱지
# durud****
# 특별한 식도락가_587
# 김존민
# cambium
# 따뜻한 맛사냥꾼 0129
# 엠웨일
# 즐거운 식객_94985
# 따뜻한 식객_12987
# 부드러운 개척가_86215
# 파이어주하
# 범숭이
# 지당
# d-daisy
# 솔직한ENTP
# 쭈깨미
# 먹팔
# 오방이
# cheb
# 라따뚜이 인 서울
# 체호프갈매기
# 착한 식도락가_11245
# 예리한 미식가_34675
# Jinto102
# 뮤무_9849
# 미식하는 술쟁이
# 정말중요한고객님
# Illiliiiliiiil
# 에드린
# 미식하는 술쟁이
# 한소오리
# 에드린
# 비범한 맛사냥꾼_33562
# chaek****
# 미식초초이
# 밝은 맛사냥꾼_7182
# 꼼꼼한 식객_24543
# 미식하는 술쟁이
# bchoi
# 최청희
# Demain44
# 핍박받는 수도꼭지_36592
# 여나여나요나
# 꽃다운나이
# Surh
# 채짜리
# hellochaeeun
# wonjayoon
# 좀비당
# 루우우미이이
# 왕십리가 마음으로 낳은 낑깡
# dragonash
# 꼼꼼한 개척가_31354
# 봄의 눈사람
# 김묘우
# 흥미로운 식객_55648
# Wormsekrms
# Mintia85
# 키힘
# kensi****
# 미식하는 술쟁이
# 화려한 식도락가_6164
# 따뜻한 마스터_13457
# yesmeme
# 호종미
# 신나는 셀럽_81745
# wonjayoon
# Nayoung0603
# 토끼라떼
# Latulipe1
# 나노히
# 홍동우
# tacot25
# 나가다라사바아
# 담윤부
# eeehan
# 꾸덕한미식가
# 한남동스지히끼
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 오오미미
# Magico
# Happppy
# 조개맨
# 몰라두댐
# 지연2
# Mooring
# 맛대맛장
# Moonclan
# 용산구 푸드파이터 남편
# Thorthor
# 건강한 셀럽_15903
# Dwhy
# Norahi
# 알라래
# 화려한 개척가_57693
# Karine yoon
# 기분좋은 맛사냥꾼!
# eunzizang
# rimmo
# 파카파카.
# 앨리밤
# 중복중이라고?그럴리업흔데
# minazzzzang
# 성공한 개척가_25054
# 제젲
# 배고픈칙피
# 행복한 개척가_29688
# 아놔이거참!
# 신나는 맛사냥꾼_4227
# 쓱배송
# 우리민지훈ㅋㅋ
# 예리한 맛사냥꾼_9883
# 캐슈너엇
# 인더선낫문
# 미식맛잘러
# 발랄한 개척가_37784
# 미슐랭덴티스트
# jb존
# 파파파파이리님
# 김재영...
# Hyunu
# Agnes han
# Agnes han
# hellohwang
# 지연쓰 배고픈디
# ghspy
# 작시니
# jjhhh
# hannam01
# 민엘클럽
# 앤더슨씨 나인원점
# yudoll
# Bibi_1
# 이영쓰
# 재능있는 셀럽_67345
# 즐거운 셀럽_44682
# juns2121
# Mo3366
# stranger824
# yoonbbo_
# 쾌활한 맛사냥꾼_44644
# 아름다운 미식가_50043
# Caterina72
# boknawara
# starmuk
# Joowon05
# 새로운 맛사냥꾼_54597
# MookYeon
# bythewind
# 종화15
# 쏨인0000
# 애슐대니
# 쁘띠버디
# Jihyu
# 블루베리진
# jwm0617
# 소소ㅡ*
# 똑똑한 식도락가_86936
# 씨씨씨
# 유지리현
# Samisi
# 타박타박
# 기분좋은 맛사냥꾼_55301
# 정범엄마
# 멋진 식도락가_90720
# 미소만세
# 오카 oka
# 삼이2233
# yns11
# 밥 주세요!
# Kim74
# 김은숙글라라
# 켄민
# iiimoon
# 서라벌신사
# KimZiZi
# Roniviki
# 비지비비
# Lee2450
# 스위밍22
# U_니
# 익선관
# 김은영♡Silver
# 3호선맵옹역
# 조떠
# 슈딤쓰
# 역곡운동킹
# 외로운 식객_94839
# 맛잘알 러바오
# JSA랭파리
# 로이맨
# 기분좋은 식객_96677
# 용산 오팀장
# Casey@79
# 나혀니
# 밝은 개척가_75701
# creep1472
# HJ Kim 21
# 바비0204
# 부드러운 식도락가_69983
# 태산박
# cairun
# 져닝e
# Caterina72
# 씩씩한 마스터_1757
# heespoon
# 승아지똥
# 여유로운 마스터_32028
# Ramsey Kim
# 짜장이언닝
# 따뜻한 개인주의자
# 에드린
# 밝은 개척가_58961
# nlch****
# 비범한 미식가_22353
# Dalgoooo
# 맛집팩폭
# Maaaaannn
# bubobubo
# 비범한 개척가_89612
# gureeson
# 또또먹을거야
# 꿈꾸는8323
# 싼드로
# Ejoh272
# 최고의 식도락가_6411
# 용산무리뉴
# 부드러운 개척가_28204
# 모오라
# 냠냠쏘
# 김진균2
# 달면 삼키고 쓰면 마신다
# 마틸다
# 밝은 셀럽_38074
# 화려한 식도락가_90951
# 한나97
# 이쁜척
# 한우폭격기
# 매요니
# 조Jo
# ssooong
# 운좋은호랑
# 소엥
# 다이닝피그
# 흥미로운 맛사냥꾼_9041
# 고민갱
# 예ㅇ린
# Foodie80
# 티먐미
# applemint31
# Soonki85
# 마산댁
# 솔솔솔솔
# 강다솜
# 꾸쭈꾸
# 밍기1
# 붕붕오
# 총장
# 성현우.
# 인기많은 개척가_15502
# 특별한 식도락가_56658
# 활기찬 마스터_46838
# 윤영이에요
# 토깽이히진
# 닥터묭
# 남다른 개척가_68297
# angibingo
# 김희원ㅇㅇㅇ
# jay_y
# 름뱅
# 깜찍한 식도락가_52887
# 999구민
# 호롯찌
# MPHN
# 소피치
# 클래식우기
# rubin***
# 2cow
# 정민11
# nam moa
# 댄버스뷘
# 곽쌍
# MUSH27
# 한남소관 漢南小館
# 게으른이슈
# Latteeeeee
# 밥주라주
# 기분좋은 식도락가_74665
# 즐거운 식객_19541
# 성공한 마스터_78287
# 정최
# 태탱니
# 밤비83
# 미식은사랑입니다.
# ssong2
# 임짓우
# 솔직한 식객_7249
# better now
# 인우드
# 흥미로운 개척가_24407
# 네링링
# 메아리_26777
# 비타민흡수중입니다
# coko
# 리프레도
# 우댕댕
# chltjf
# 빛나는 맛사냥꾼_87194
# gogeum
# 로몬댇
# aniz88
# 이안11
# HaleyC
# 온화한 개척가_44617
# 형준@.@
# 새로운 마스터_73189
# Delicuouson
# WY24
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 어반클리프 & 글래스룸
# 성공한 맛사냥꾼_13892
# pastry52
# 오아이오우
# Gottime
# ranggoo
# 뽀뇨니
# 유림02
# 김두필이라고
# 신나는 마스터_40600
# raymond24
# 따뜻한 셀럽_31031
# 망둥띠
# 밀키맘마
# Yun_now
# 고독한효식가99
# 호기심 많은 미식가_84846
# 왕커커
# 솔직한 개척가_78196
# 착한 미식가_3638
# sik0117
# 멜롱ㅇ
# 교미닝
# 재미있는 셀럽_56971
# Moonyfarida
# 남다른 식도락가_79067
# 유니크코리아잇츠
# Lisa DH Kim
# 린또또
# 짱맛덕
# 쾌활한 셀럽_24758
# 경쾌한 미식가_12981
# 최고의 맛사냥꾼_6058
# 지혜로운 미식가_36698
# CC쩡
# Cle Chloe
# 인천불나방2
# 건강한 맛사냥꾼_50558
# 싱디헤
# 애ㅡ옹
# 채소마스터
# Annachef
# 예리한 셀럽_86024
# 됴옹
# 최고의 셀럽_61840
# Mkimm
# 황서현2
# 쓰응
# 홍_찬
# 손씨네7
# 뉴뉴09
# 코코모모
# 쿨한지니
# 김태연손
# 햄흠햄
# bogleeee
# 자유로운 새
# 술쟁이 맛쟁이
# 크크미니미
# 멋진 셀럽_98411
# 먹레이더
# 구름규름
# 소맥보이
# 먹공쥬 / 전국구 맛집 소개
# 빛나는 셀럽_30608
# mukplan
# 똑똑한 마스터_79579
# 새로운 개척가_35101
# 건강한 마스터_56882
# 푸디은또먹
# 토깽이랜드
# 경쾌한 셀럽_87758
# 와이푸디
# missbinna
# 외로운 맛사냥꾼_66377
# 호롤로꾸룩
# 치즈퐁듀로
# 꿈꾸는 마스터_95025
# 조아나아나조
# 현냠
# 먼지탱
# 밍밍밍222
# yuxmix
# dlcodus****
# 똑똑한 식객_20740
# 푸드보따리
# whiterin
# 진진딘딘진
# 깜찍한 셀럽_37574
# 신혜선
# 연니부기
# 소소so
# 아름다운 개척가_70245
# MJ ఇ
# eqeq0728
# 인기많은 개척가_37715
# 재미있는 맛사냥꾼_37036
# 예리한 식도락가_53533
# 황해도
# 마미여행꾼
# 짱써치
# 쥬드정
# 알랭들롱
# 정직한 마스터_11594
# 솔직한우럭이
# 농사짓는밍밍
# 소낙J
# Kyla Song
# 만네르헤임
# 왕인철
# 강직한 식도락가_56589
# 아름다운 식객_81652
# dayever
# AGNESS_
# Y 얌
# pswooju
# 재능있는 개척가_61382
# 쥬니아이린
# hyundo38
# 프로틴마피아
# Choiseohyun
# im1004girl
# eeune10
# 즐거운 식객_94985
# 동마이동
# yummiii
# 비범한 마스터_46099
# 서연ㅇ하라랄
# 효택순이
# 브라운라떼
# 다영굿
# 띠기띠니
# 망고걸
# Miracle park
# 갈릴레오
# 응딘요
# 발랄한 셀럽_84836
# 레드블루1117
# ie0ie0
# 아내바보
# bossAhn
# 그래그래도
# 파주한지수
# 깜찍한 미식가_29153
# 토끼와다람쥐
# 얼얼나얼얼
# 착한 마스터_95562
# 쏘오오오
# 푸드먼치킨
# dms****
# laview
# 맛있어서 눈물나
# 소뎡
# 교촌필방 오마카세
# 레드로즈
# 해달별79
# kaylee01
# Alshed
# Solitudeismyhom
# mamapua
# 레드로즈
# ひじぇせき
# 부드러운 개척가_87275
# 부드러운 개척가_87275
# 새로운 맛사냥꾼_70530
# 랑랑앤
# 뷔뷔엔
# 백우형
# 와봉거사
# 씩씩한 식도락가_51055
# 정호호야
# 희또
# 도도한 미식가_9004
# 보리잉잉
# clemenstreter
# 지넷
# 솔직한 식도락가_68940
# 뭉뭉오빠멍멍
# 새로운 마스터_5629
# 장진우팀장
# 룰루의루룰
# sjbshin
# teddy123
# 발상의 전환
# 밥만축내는사람
# passionist
# 정직한 식객_69090
# 인기많은 미식가_95909
# 9700****
# 지극한 정성
# sjbshin
# sjbshin
# 행복한7048
# 새로운 맛사냥꾼_42176
# 지극한 정성
# 주믈리에_21011
# JJ.T
# OQ
# ea0723
# 솔직한 식도락가_54601
# since950206
# 호기심 많은 셀럽_59625
# 다솜미미미
# 포터
# 란포
# 9s
# 성공한 맛사냥꾼_7623
# 여유로운 미식가_30800
# Anyonebutnoone
# 맑은하늘123
# 밥장사술장사
# 온화한 셀럽_28701
# 먹기에 진심
# 맑은하늘123
# 배앙아
# 루돌프마마
# rwacky
# 9s
# 똑똑한 마스터_37058
# 카키라이노
# 성경몬
# 마리아보사노
# 안부를 묻는 밤
# eyenet
# rlawngml
# 착한 마스터_7986
# sw001****
# 9s
# 씩씩한 식객_74715
# 맑은하늘123
# 지미라임
# 재능있는 식객_40119
# 성공한 개척가_37297
# eunzizang
# favelave
# 내추럴 규뱅
# 호브이
# 활기찬 셀럽_83637
# 온화한 미식가_73002
# 성장소
# 예리한 셀럽_18324
# 명미선
# uush07
# 께꼬
# 9s
# Ramsoong
# 제니원
# 완스민
# zxc789vbnm
# 누누콩
# 빛나는 마스터_80374
# 맑은하늘123
# 한남동부루쓰
# 붱붱22
# 영진
# 소소막창 한남본점
# HEEWON YANG
# 똥나웅
# 미르랑설이랑
# 슬라이스단
# 경쾌한 개척가_65554
# 뽀로로힝
# 정태현1
# Yukimaron
# 빅소현이
# zenaaaa
# 슬라이스단
# 예리한 식객_66300
# 부산밍블루
# 쫑쫑몬
# 준돌쿤
# 부드러운 맛사냥꾼_86742
# 주희정정
# dahyun77
# 여비메리
# 희냥낭
# eungttori
# 안전왕
# JKkky
# 재능있는 셀럽_66215
# 유명한 맛사냥꾼_42053
# 슬라이스단
# 탄저씨맘
# 포테토띠
# 뽀로로힝
# 얄다
# Wooooooon
# TeddyPk
# 쇼랴
# 먹으러 여행감
# 곽민경
# jjjj54
# 해이♡
# 리남쉔
# 술상무의 맛집기행
# HEEWON YANG
# 따뜻한 식도락가_418
# 오지선공주
# 짱구는못말ㄹ
# Simon116
# 멋진 셀럽_28429
# Joo0y
# 민지민
# 김용완
# 쾌활한 셀럽_42323
# 특별한 마스터_80807
# 우우
# 뿌뿌린린
# 네진혜진
# 정인돈
# 오아도라
# 경쾌한 맛사냥꾼_71831
# 앨리앨리앨리
# 위트있는 식객_43568
# 순슨
# 릉환이
# Kenshin
# 기분좋은 맛사냥꾼_80362
# 윤하욘
# 핫태하탱
# 모모얌
# zzineeey
# Yooooonga
# 훕스토레스
# 김집옹
# 쓸라이쓰
# 상보보
# 동븨
# Light eater
# 북이찌
# 소공동벼농사
# 흰동쓰
# Irene_89
# jd915
# 지니찌니
# 쩝쩝박사지망생0
# 기분좋은 마스터_11677
# Dina안
# 송알맹
# 웅찌블리
# 메타쨩
# 건강한 마스터_5500
# 수우우아
# 내가맛있다하면믿어줘
# 메리메리짱
# 서나02
# 주 이
# 착한 미식가_17333
# 68102
# Virgil Ahnbloh
# 영지버섯
# zadoo
# parkda
# Estelle
# AllenLee
# 뚱땅꼬
# RAMY
# 히가시 (東)
# 홍동우
# 악귀66
# 밝은 식도락가_89146
# 소울리즈
# 홍동우
# 여유로운 식도락가_45662
# 홍동우
# 로지로지ㅣ
# 소중한서우
# 홍동우
# 보니니_
# 여유로운 식도락가_45662
# 여유로운 식도락가_45662
# 외로운 미식가_40458
# 홍동우
# 홍동우
# 청룡78
# 여유로운 식도락가_45662
# CaliforniaSun
# Kevin_Hwang
# 유니앤죠이
# July0731
# 기분좋은 식도락가_79323
# 샨티데바
# 여유로운 식도락가_45662
# 우주나비맘
# 홍록기김영욱
# 최고의 맛사냥꾼_58612
# 여유로운 식도락가_45662
# 여유로운 식도락가_45662
# 똑똑한 개척가_4143
# 빛나는 미식가_2151
# 재미있는 미식가_82266
# 보니니_
# 미식에진심
# 홍동우
# 정직한 마스터_83936
# 새로운 미식가_41229
# 여유로운 식도락가_45662
# ChrisPark91
# Don Lim
# 중큐93
# 중큐93
# 여유로운 식도락가_45662
# 죠리퐁
# 카시아스
# Hanju Kim
# weedkim
# Hanju Kim
# 중큐93
# 어텀(autumn)
# 공이림주
# WONnn
# 지미윤
# 밝은 식도락가_75941
# 먹짱망곰
# acidrock
# JUNII
# 서지누션
# 노루꼬꼬
# YJJYJ
# 크로비오
# 뚜디두
# LDN
# 왕마늘
# 운디디
# dsgtsy
# 지니쓰2
# acidrock
# 1예슬
# hahaha22
# 하요아빠
# 602ღ
# 오두부
# 지리산광어
# 춘장언니
# 지혜로운 식객_11679
# 문웅주
# 숨수리숨
# 밥정은
# 뭐하쥐
# Juul
# 갱갱이다
# 으아앙이
# 띵쟈몽
# 성은님
# 똑똑한 셀럽_57202
# 맥코이
# 신나는 식객_39793
# Diana kim
# Aideninseoul
# 앙듄스
# Peachya
# 황도양
# 재미있는 미식가_78616
# 밥가온나
# 맛집만리뷰합니다
# 리키리26
# 착한 개척가_76929
# lmgb
# pmg9
# 오스테리아 안나
# Phgphg11
# nick63
# 도루루빵빵
# 예리한 식도락가_87155
# Doremipasol
# 전윤발
# 데판
# ioioioioio
# MookYeon
# 도도한 식객_19521
# YeonMook
# Isaac88
# 김좌진
# 건강한 식도락가_72550
# 캐치캐치캐췻
# zampino123
# 모찌작은형
# 메타미식
# ruin2003
# Phgphg11
# Phgphg11
# 해피노마드
# min kyu
# Jeanparky
# 호기심 많은 셀럽_60232
# 메이블리
# Cecile
# 아이엔지중
# 따뜻한 식객_46928
# 말리구지아
# 란재김
# 레이솔
# 아만다김
# 자몽허브차
# 기분좋은 미식가_47203
# Phgphg11
# GVF88
# 하하산타
# 최고의 개척가_6928
# 아이엔지중
# 자머주
# Capuccino
# 세요르
# 뚱데렐라
# 따뜻한 식객_46928
# SKY Gold
# 코기지우
# 구럼이
# 새로운 미식가_935
# 챱쑤이
# NFNG
# 맛사냥꾼ㅋㅋ
# 남다른 식도락가_3757
# 데이쏨
# 조용한 셀럽_81646
# 외로운 미식가_24114
# 지현9
# Suriingo
# 특별한 식도락가_71877
# 유명한 개척가_65103
# 예그리
# 새로운 마스터_82166
# 성공한 미식가_5927
# 건강한 식객_86381
# 김경일 maro
# 둥둥이 뮤
# 홍행힝
# kwanghopark
# 토춘
# Hyeoh
# 새로운 마스터_82166
# 데이쏨
# 나만
# 개구진 맛사냥꾼_37168
# Suriingo
# 솔직한 식도락가_9378
# 양자역학
# 나만
# 사빠딸처돌이
# 이귀
# 빙빙구
# 개구진 맛사냥꾼_37168
# 단테리
# 하와이피자
# Mini Pig
# 빛나는 셀럽_67760
# 부드러운 마스터_49253
# 단테리
# 우수한 맛사냥꾼_15014
# 바경쓰
# Mini Pig
# 홍행힝
# 인기많은 미식가_96604
# 데이쏨
# 꿈꾸는 셀럽_84027
# 좋은음식만고집
# 특별한 맛사냥꾼_31436
# 유리아야
# 나만
# 두더지고로케_
# 밈두루
# 삼각지 주식
# 맛있는게 딱 좋아
# 문주동생병주
# 문주동생병주
# 냥냥뇽뇽ㅇㅇ
# 류상현1004
# 냥냥뇽뇽ㅇㅇ
# 여유로운 개척가_74497
# 씩씩한 맛사냥꾼_95657
# 행복한 식객_42003
# 외로운 맛사냥꾼_47471
# nazzang73
# 시몽k
# 문주동생병주
# 건돼o3o
# ㅎㅎ넹
# 꿈꾸는 셀럽_27882
# kim !
# 쑤ㄱI
# 문주동생병주
# 뭐하쥐
# 떰2
# 핼이이
# 문주동생병주
# 팡윤하
# 밍밍뷰잉
# 골목대장봉달
# 특별한 마스터_49144
# Myungsun Kim
# 지옥에서온맛
# 박예린97
# 김로디
# 스트로베리리
# 기분좋은 셀럽_80148
# 뜽이22
# 마토지
# 경이로운나
# 영월려인
# 발랄한 식도락가_51839
# 아아..그건 제 짬입니다만?
# 탄저씨맘
# ddjk
# 문주동생병주
# 뽀류류
# dodddoo
# 고독한 셀럽_11273
# sseooyy
# 기분좋은 식객_9121
# Symom
# 맛보깅
# 벙스스
# 브라이리퍼블릭 이태원점🇿🇦
# 특별한 식객_50394
# 룰루_
# 쉬닝닝잉
# 냠!!
# ca7971
# 깜찍한 식도락가_17311
# 어난데
# 외로운 맛사냥꾼_85881
# M A G P I E
# 행복한 맛사냥꾼_6923
# Vera79
# 안드레시또
# 지혜로운 식도락가_18848
# ______1_____
# 비범한 마스터_82553
# VRNH
# 발랄한 식객_27120
# 령 ㅇ
# glitterrr
# s_support
# 밝은 개척가_52342
# 쀼리뽕
# 라티노
# 수학은미적미적
# 좋아요좋아요좋아요
# bsunity
# 답이없는닉
# Ah-012
# 배재a
# 키키폴리오
# 화려한 식도락가_23656
# 미어미어캣캣
# 쀼리뽕
# 쀼리뽕
# 신나는 식도락가_83849
# 임희석
# 겨울012
# Ryanguro
# 비범한 맛사냥꾼_1478
# 경쾌한 식도락가_41383
# 서초소미
# 가봉
# 새우꼬다리안머거
# 이달리
# 루제미
# 위현anna
# 닭터봉
# 고기파 미식가
# 김옐옐
# 데레사229
# 아망뜨 한남 (Amante Hannam)
# 부드러운 식객_70475
# 럭키헤븐
# 개구진 마스터_45478
# 보라냐
# 쿄쿄쿄야옹이러버
# Kyoungho
# Celia17
# 바티붱
# Newedward
# 냐♡
# 행복한 개척가_61634
# 바비맘
# 베베쿤
# 남다른 셀럽_17748
# 엘렌9797
# 길시코기
# 샬롬 김현숙
# hisol
# 지혜로운 식도락가_61405
# 행복한 미식가_36688
# 윰하
# 쁨~이
# 이니미니마이니모우
# 킬러웨일
# 케이덥
# 우리이
# 허창훈님
# 막동이뉴나이자엄마이자친구일걸
# 당나라당근
# Leejoa
# 착한 셀럽_97147
# 허니뀨
# 꾸꾸8484
# 온화한 셀럽_34364
# 빵순이는빵빵혀
# 굥리
# 밍밍베베
# 루루루루루루루루루루루루루루루
# 푸디워너비
# 안녕녀
# ㅅㅅㅎㅈ
# sis01290
# Lindamonkey
# 재트리버
# flatn
# Harry♡Mom
# 정가성원
# 개구진 마스터_55077
# superrhdms9
# 이전홍
# 유가소점
# 고니달
# 깜찍한 개척가_97091
# 아놔이놔
# nonego
# 다나44
# Lino
# 특별한 셀럽_40240
# Madamlee02
# 9327
# 미식하는 술쟁이
# 파리의가을
# 경쾌한 셀럽_58016
# 아름다운 마스터_94654
# celebrater
# 성순박
# anna1785
# 흐규
# justin655
# 슈크림빵
# MiniiiK
# 주카푸카
# 주현ㄷ
# 지연경
# 씩씩한 마스터_55599
# ㅋㄹㅅㅌㅇ
# 착한 개척가_75141
# 박성은192922929
# 도도한 개척가_18933
# 최고의 개척가_93386
# 밝은 맛사냥꾼_35183
# @bigkingss
# 오두부
# 재능있는 식도락가_97148
# kenny
# 주병건
# 쪼꼼봄
# 쎄이
# 맛있는거만취급
# 혜선선선
# 성공한 셀럽_91147
# 밀밀구
# jihyoun87
# ppyyjj
# 혠니공쥬
# 씩씩한 식도락가_96609
# 깜찍한 셀럽_33718
# 쿄쿄쿄야옹이러버
# 경쾌한 식객_52557
# 특별한 개척가_7628930
# ide
# 녹다
# breadnbutter
# breadnbutter
# 비케
# 주영아범
# 호기심 많은 개척가_12084
# Jin Ha
# 또미오빠
# moonhee0128
# 꿈★은 이루어진다
# 꼼꼼한 미식가_75662
# 후루루룹ㅎ
# 입짤은 _미식가 1
# tyudung
# limmy126
# 꼬니yu
# 비타민흡수중입니다
# 먹깨비7777777
# 챠르
# 종혁이용
# Rin66
# 린저이이잉
# rkd96
# taeanpic****
# 민아야S2
# .김연휘
# 멋진 미식가_83329
# Kay2kay
# 프로회식가
# jjin95
# 미니언지87
# 우우맛있어
# 레알몰리두커
# 슈~웅 ^^
# 민굥이잉
# 하요찌
# 개구진 개척가_50457
# 착한 맛사냥꾼_20621
# bonitachica
# 모모맘
# 김학진이
# 멍키스패너
# 틀메
# 초잉규
# Scottlee
# 고간니
# Gourmevel
# 온화한 식객_99498
# 특별한 개척가_84167
# 이잉공주
# 여유로운 개척가_49126
# 어항로
# 썬vvv
# 맛있는게 딱 좋아
# 개구진 미식가_53024
# 재미있는 식도락가_20012
# 재미있는 셀럽_26679
# komment
# mitoro
# 밝은 식도락가_65885
# 남다른 식객_49172
# 혭니이
# 딤서밍
# 베어스웅
# 맛잘날 만규
# olive001
# Minggggggggggggggg
# minowen
# 조용한 미식가_46541
# bdodl
# 발랄한 개척가_3277
# 토피넛 라떼
# dk951222
# Bzin
# 달사월
# 피카츄아이츄
# 빈피오니
# 홍칼
# 블루스으으
# 쾌활한 식도락가_8554
# 수르빈
# 온화한 마스터_39635
# 임재형2
# 아영999
# 지혜로운 마스터_50489
# 00안녕하세영00
# 개구진 식객_6059
# 박세르게이
# 건강한 식도락가_53869
# Rainworld
# 흥미로운 식도락가_77073
# 재미있는 맛사냥꾼_72715
# 날것오ㅏㅇ
# Jimmy King
# 다잡아여어
# 고슴도치고양이
# Strongkyu
# 곰75
# 밥맛나
# 씨두니
# 나룽통
# 심준호호호호
# 이자카야 오
# 새로운 맛사냥꾼_12475
# Jiyeon Moon
# Young Il Park
# nujabath
# 함태원
# Doo-Hee Lee
# 잉구리
# 건강한 마스터_48941
# 꿈꾸는 식객_48456
# WonderingSoul
# 이통쿠
# hookgl
# GanziK
# Tedigator
# 위트있는 개척가_25720
# 비램
# 프을레엑
# 맹주희
# 홍테오
# 식도락자
# 미쿄히
# Sunny6rl
# 남민정
# Art_Life
# TerryKim0
# tt239
# open mind
# 특별한 개척가_93229
# 똑똑한 맛스터
# 르아르아
# kwanwoo96
# tubys
# eskh****
# Grayafternoon
# Insung k
# eta_expert
# Bin91
# 내이름한국민
# 조으닝
# 쾌활한 맛사냥꾼_9534
# 라니라니고롸니
# 해파리이프
# 몰라 몰라 맛도리
# 조근범
# 대정주류
# 역삼동마케터
# 헤일리613
# 유링용
# 욤뇸냠냠
# 낌태87
# 테이블뷰
# gogogyu
# J1y0
# jchan21
# 유명한 식객_22658
# 재미있는 미식가_89098
# 신도림체어샷
# 옥동
# 육식육식열매
# 비범한 셀럽_24110
# 재능있는 마스터_64730
# 루똥
# 온화한 식객_80980
# 기분좋은 맛사냥꾼_96446
# 인기많은 미식가_83187
# 물바다
# 여유로운 맛사냥꾼_74963
# 별코코솜솜
# Salicylic acid
# 김우디22
# WONIMARU
# jinsooee
# Joeychoi
# 로빈손
# 조용한 마스터_99905
# 꼼꼼한 개척가_629
# 태
# 젤리여니
# JinaS
# 건강한 개척가_78596
# godblessu94
# ORIII
# 아니마니
# 정직한 미식가_90068
# 000012
# 크리스클라스
# 인궁
# 한승한
# 쾌활한 식객_22990
# 롱은ㄴ
# 강직한 미식가_44533
# 물어라백구
# 김민서ㅎㅎ
# null 311
# 인기많은 미식가_83187
# 인기많은 개척가_20003
# 밝은 식도락가_22421
# jujucoki227
# 똑똑한 맛사냥꾼_75059
# 에밀리 쉬
# 무과과파이
# 돌판장
# 소시키
# 하비에르 사네티
# 산책러버!
# 도마뱀스
# 키키코지
# 고등어가족
# 안드레시또
# 여유로운 개척가_4235
# 맛있는 탐험가
# 카이다짱
# 건츠비
# 온화한 개척가_95373
# 새로운 셀럽_44523
# 쿨쿠리
# nnta99
# 굿띵커
# 난난나
# 신성직
# K 민주
# 두당당스
# 별보석민재맘
# 고독한 개척가_88248
# 빨간벽돌단독주택
# 오징어징
# 카이다짱
# 활기찬 마스터_34085
# singaa
# 호이❤
# 고독한 셀럽_59742
# 착한 식도락가_78528
# KH♡
# 수연13
# Tedigator
# 왓어위원트
# Painkillar
# 신나는 개척가_91435
# Letsgetitititit
# 위트있는 셀럽_73371
# h__wonyy
# 람갱77
# 김승화아아안
# 화려한셀러1998
# Painkillar
# 착한 식도락가_78528
# 경쾌한 셀럽_73137
# 링컨사랑
# 깜찍한 미식가_14166
# 송알맹
# 건강한 식도락가_73281
# 기맹82
# 베라 한남점
# 웨일즈 코기
# 빛의린린맘
# 니퍼니퍼
# 초코서울우유
# 김석모 Art Historian
# 밤빵식빵
# 인그리드
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 비스트로 조조
# Sixseasons
# 급한 마음 버리기
# 도도한 맛사냥꾼_55484
# 피그먼트
# 워니워니-
# j_sung_0o0
# heebeehee
# 재미있는 미식가_90124
# 나냐냔냐나나니냐
# Okok22
# 건강한 식도락가_80896
# 심유밍
# 김삼두
# 발랄한 식객_95053
# 키임소오더엉
# 빛나는 개척가_20629
# 현지053
# 따뜻한 셀럽_31031
# 외로운 식객_71306
# 부드러운 식도락가_12455
# 아름다운 맛사냥꾼_39459
# leanse0y
# 신정우 Steven
# 분당살쾡이
# 밝은 식객_95938
# jooooooooon
# 유우우웆
# Janieee_
# 김삼두
# 듸해
# 하이진
# 크리스탈202457
# 온화한 맛사냥꾼_23297
# zelia28
# 띰뚱횬
# 응온람
# 아만징냐
# 금랑이다
# 유명한 마스터_92262
# 신홍교
# 활기찬 맛사냥꾼_77936
# 깜찍한 미식가_99852
# 예지뿡뿡
# 토끼라떼
# 채뽀송
# 지혜로운 개척가_51991
# blue garden
# 네에리
# 화려한 맛사냥꾼_77701
# Onilife
# 소설옥 본점
# 좋아요좋아요좋아요
# Pierre C
# 좋아요좋아요좋아요
# 류남주
# 꿀푸리
# ㅁ뮴
# 마포짱
# 날랑구
# 주멘즈
# 서용수
# 인호파
# 루카롸카
# 알로하이
# 좋아요좋아요좋아요
# 치치무치
# 희님님
# 권오철.
# 동녘스
# 맛탐러 마징
# 보리83
# 콘바이콘
# 너굴탱탱이
# 유케사케통케
# 온화한 맛사냥꾼_49065
# jinichoo
# 복덩어리
# ImFinee
# 신나는 미식가_99460
# nim****
# Ray*kim
# 히블리히히
# c1park
# 빔바야
# 훌렁룰
# 또치1984
# Jay113
# 화려한 식도락가_95366
# 행복한오니네
# 성현4971
# 착한 미식가_7432
# 웅쓰꿍쓰
# woodunsal87
# 당케쉔
# 특별한 식도락가_67321
# CLAIRE g
# 마마마
# SLSL
# 흥미로운 미식가_46294
# 예리한 마스터_69915
# 외로운 셀럽_65960
# 봉피양 용산점
# 성북동강철주먹
# 인기많은 마스터_21940
# 예리한 맛사냥꾼_33249
# Sean76
# 흥미로운 셀럽_1763
# 심규홍
# 특별한 셀럽_56156
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 블루메쯔 노들섬
# swbs19
# 재미있는 셀럽_5000
# 나당1009
# 몽몽이와밍끼
# 방장
# lollypop
# 구파파
# 활기찬 맛사냥꾼_37253
# ㄹ영
# 빈대떡신사
# Jane_Jiyoung
# 펀
# 착한 개척가_94784
# leeseol10.1
# 구종대
# 볼네
# 주니족장
# O2H2
# 앙고라진주
# 웅냥냥
# 잼잼윤
# 신나는 맛사냥꾼_85489
# 석환김
# 행복한 개척가_11136
# bbbpp
# 삶주인
# LASTHALL
# LASTHALL
# 쭈꾸미낙지
# 아기범고래
# 와칸다포에벌
# 붕둥비버
# 코뿔소흥흥
# 여유로운 식객_82825
# steel1212
# lilyfe
# 괜찮아너구리야
# 정머
# 은밀한강아지
# 마루맘님
# Rhao
# 나이스가목표
# 행복한 미식가_40649
# 서건일
# 고독한 개척가_99908
# 박스페로우
# qhghk83
# 뮥뮥뮥뮥뮥뮥뮥뭉
# 돼지형님123
# LASTHALL
# 야키토리경청
# 맛있는것만 먹어욤
# 솔트비
# k.J.T
# 재미있는 셀럽_17453
# 상아0822
# 건강한 개척가_43313
# 멋진 개척가_44822
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 라뜰리에 한남점
# 솔직한 셀럽_41900
# 특별한 셀럽_76967
# 마이리뷰
# NY K
# 유밍글
# Jihyuna79
# 특별한 셀럽_76967
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 부르고뉴 한남
# 뗀니꾸잇ㄴ
# 제임스설클링
# 은기에요
# 둥이 아빠 67
# 멋진 개척가_5232
# 때깔좋은 고메이
# 개구진 셀럽_11743
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# 제이앤로즈비비큐
# limestone
# ohmim
# 인기많은 미식가_53246
# 치타여사
# 멀 미
# mstone
# 이기현!
# 아름다운 식도락가_85660
# 고고기규
# tae_wooos
# 부드러운 개척가_86215
# 지니언냐
# 노비츸키
# 조용한 셀럽_79899
# 조로맘
# superh****
# 햄로냥불
# 늙은2
# 요사요이
# MW Park
# 니키블루
# 잴리ㅔ
# hyezini
# 이우성2
# 장준후
# roross
# 석댓
# 버핏
# 버핏
# 바디아트
# 고르고
# 베로니키
# 위트있는 식도락가_3432
# 올리브7880
# 즐거운 개척가_54731
# 개구진 셀럽_46040
# 먹기위해살고있는중
# 알리고싶은맛집
# 별아a
# 기몽준
# SJPartners
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 89
#      87 # 가게 리스트 앞부분만 긁어오는 코드
#      88 Category = item.select_one('.detail .restaurant-meta .tags').text.split(' • ')[0] if item.select_one('.detail .restaurant-meta .tags') else "NA"
# ---> 89 Location = item.select_one('.detail .restaurant-meta .tags').text.split(' • ')[1] if item.select_one('.detail .restaurant-meta .tags') else "NA"
#      90 Price_range = item.select_one('.detail .restaurant-meta .price').text if item.select_one('.detail .restaurant-meta .price') else "NA"
#      92 # 가게 클릭
#
# IndexError: list index out of range

# %%
df = data.copy()

# %%
df1 = pd.DataFrame(df)

# %%
df1.tail(50)
# Out:
#              0    1   2   3   4                          5   \
# 16200  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16201  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16202  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16203  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16204  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16205  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16206  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16207  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16208  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16209  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16210  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16211  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16212  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16213  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16214  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16215  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16216  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16217  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16218  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16219  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16220  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16221  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16222  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16223  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16224  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16225  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16226  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16227  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16228  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16229  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16230  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16231  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16232  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16233  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16234  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16235  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16236  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16237  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16238  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16239  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16240  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16241  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16242  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16243  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16244  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16245  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16246  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16247  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16248  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
# 16249  제이앤로즈비비큐  4.8  57  한식  용산  서울특별시 용산구 대사관로30길 6-11 1층
#
#                              6                7     8   9           10  \
# 16200  점심 1 - 5만원 · 저녁 3 - 20만원        limestone  5.0   저녁  2024.05.21
# 16201  점심 1 - 5만원 · 저녁 3 - 20만원            ohmim  4.7   저녁  2024.03.06
# 16202  점심 1 - 5만원 · 저녁 3 - 20만원   인기많은 미식가_53246  5.0   저녁  2024.01.30
# 16203  점심 1 - 5만원 · 저녁 3 - 20만원             치타여사  4.0   저녁  2024.01.08
# 16204  점심 1 - 5만원 · 저녁 3 - 20만원              멀 미  5.0   저녁  2024.01.04
# 16205  점심 1 - 5만원 · 저녁 3 - 20만원           mstone  5.0   저녁  2023.12.30
# 16206  점심 1 - 5만원 · 저녁 3 - 20만원             이기현!  3.8   저녁  2023.12.26
# 16207  점심 1 - 5만원 · 저녁 3 - 20만원  아름다운 식도락가_85660  5.0   저녁  2023.12.25
# 16208  점심 1 - 5만원 · 저녁 3 - 20만원             고고기규  5.0   저녁  2023.12.24
# 16209  점심 1 - 5만원 · 저녁 3 - 20만원        tae_wooos  5.0   저녁  2023.12.17
# 16210  점심 1 - 5만원 · 저녁 3 - 20만원   부드러운 개척가_86215  5.0   저녁  2023.12.06
# 16211  점심 1 - 5만원 · 저녁 3 - 20만원             지니언냐  5.0   저녁  2023.12.01
# 16212  점심 1 - 5만원 · 저녁 3 - 20만원             노비츸키  5.0   저녁  2023.11.19
# 16213  점심 1 - 5만원 · 저녁 3 - 20만원     조용한 셀럽_79899  5.0   저녁  2023.11.11
# 16214  점심 1 - 5만원 · 저녁 3 - 20만원              조로맘  5.0   저녁  2023.11.09
# 16215  점심 1 - 5만원 · 저녁 3 - 20만원       superh****  5.0   저녁  2023.10.24
# 16216  점심 1 - 5만원 · 저녁 3 - 20만원             햄로냥불  5.0   저녁  2023.10.15
# 16217  점심 1 - 5만원 · 저녁 3 - 20만원              늙은2  5.0   저녁  2023.10.09
# 16218  점심 1 - 5만원 · 저녁 3 - 20만원             요사요이  4.7   저녁  2023.10.02
# 16219  점심 1 - 5만원 · 저녁 3 - 20만원          MW Park  4.3   저녁  2023.10.02
# 16220  점심 1 - 5만원 · 저녁 3 - 20만원             니키블루  5.0   저녁  2023.10.01
# 16221  점심 1 - 5만원 · 저녁 3 - 20만원              잴리ㅔ  5.0   저녁  2023.09.29
# 16222  점심 1 - 5만원 · 저녁 3 - 20만원          hyezini  5.0   저녁  2023.09.16
# 16223  점심 1 - 5만원 · 저녁 3 - 20만원             이우성2  5.0   저녁  2023.09.02
# 16224  점심 1 - 5만원 · 저녁 3 - 20만원              장준후  4.5   저녁  2023.08.27
# 16225  점심 1 - 5만원 · 저녁 3 - 20만원           roross  5.0   저녁  2023.08.26
# 16226  점심 1 - 5만원 · 저녁 3 - 20만원               석댓  5.0   저녁  2023.08.22
# 16227  점심 1 - 5만원 · 저녁 3 - 20만원               버핏  5.0   저녁  2023.08.21
# 16228  점심 1 - 5만원 · 저녁 3 - 20만원               버핏  5.0   점심  2023.07.23
# 16229  점심 1 - 5만원 · 저녁 3 - 20만원             바디아트  4.7   저녁  2023.07.07
# 16230  점심 1 - 5만원 · 저녁 3 - 20만원              고르고  5.0   저녁  2023.06.22
# 16231  점심 1 - 5만원 · 저녁 3 - 20만원             베로니키  5.0   점심  2023.06.20
# 16232  점심 1 - 5만원 · 저녁 3 - 20만원   위트있는 식도락가_3432  5.0   점심  2023.05.13
# 16233  점심 1 - 5만원 · 저녁 3 - 20만원          올리브7880  4.0   저녁  2023.05.13
# 16234  점심 1 - 5만원 · 저녁 3 - 20만원    즐거운 개척가_54731  5.0   저녁  2023.05.07
# 16235  점심 1 - 5만원 · 저녁 3 - 20만원     개구진 셀럽_46040  5.0   저녁  2023.04.09
# 16236  점심 1 - 5만원 · 저녁 3 - 20만원        먹기위해살고있는중  5.0   저녁  2023.03.13
# 16237  점심 1 - 5만원 · 저녁 3 - 20만원          알리고싶은맛집  5.0   저녁  2023.03.12
# 16238  점심 1 - 5만원 · 저녁 3 - 20만원              별아a  5.0   저녁  2023.03.02
# 16239  점심 1 - 5만원 · 저녁 3 - 20만원              기몽준  3.7   저녁  2023.03.01
# 16240  점심 1 - 5만원 · 저녁 3 - 20만원       SJPartners  4.2   저녁  2023.02.24
# 16241  점심 1 - 5만원 · 저녁 3 - 20만원               NA    NA  NA          NA
# 16242  점심 1 - 5만원 · 저녁 3 - 20만원               NA    NA  NA          NA
# 16243  점심 1 - 5만원 · 저녁 3 - 20만원               NA    NA  NA          NA
# 16244  점심 1 - 5만원 · 저녁 3 - 20만원               NA    NA  NA          NA
# 16245  점심 1 - 5만원 · 저녁 3 - 20만원               NA    NA  NA          NA
# 16246  점심 1 - 5만원 · 저녁 3 - 20만원               NA    NA  NA          NA
# 16247  점심 1 - 5만원 · 저녁 3 - 20만원               NA    NA  NA          NA
# 16248  점심 1 - 5만원 · 저녁 3 - 20만원               NA    NA  NA          NA
# 16249  점심 1 - 5만원 · 저녁 3 - 20만원               NA    NA  NA          NA
#
#                                                       11     12
# 16200                   바베큐/맥주 너무 맛있고 강아지(조던)는 너무 궈여워요    1,061
# 16201                                           맛있었어요!    1,061
# 16202  강아지와 함께 편안하고 따뜻한 분위기에서 친절하신 사장님 덕분에 든든하고 좋은 식사...  1,061
# 16203  바베큐가 먹고싶어서 급하게 예약해서 갔어요~! 구성은 군더더기 없고, 곁들여 먹는 ...  1,061
# 16204                       맛있게 잘 먹었습니다! 특히 브리스킷 넘 맛도리    1,061
# 16205  너무 맛있고 친절하십니다. 재방문 의사 당연히 있습니다. 찾아가기 힘든 것 빼곤 1...  1,061
# 16206  솔직히 한남에서 가격만 쎄지 별로인 가게 많이 가봐서 그렇게 크게 기대는 안했습니다...  1,061
# 16207  사정때문에 예약시간에 조금 늦었음에도 불구하고 사장님이 너무 친절하게 배려해주셔서 ...  1,061
# 16208                  너무 친절하시고 고기도 너무 맛났습니다 강아지도 귀여워요    1,061
# 16209                            여러명이 함께 먹기좋았고 맛있었습니다.    1,061
# 16210  연말 팀 송년회로 찾은 곳인데 팀원들이 모두 매우 만족스러워했습니다. 음식과 분위기...  1,061
# 16211  6명 모임이라 플래터를 4인,2인 나눴어요. 사진은 4인 플래터. 양 매우 많고, ...  1,061
# 16212                         감사합니다. 넓은 공간 음식도 좋았습니다..    1,061
# 16213  음식 넘 맛났어요 완전 맥주각인데 됫일정땜에 아쉬웠어요 예약보다 30분 일찍 도착했...  1,061
# 16214  한남동1등맛집 회사모임하기 너무 좋았습니다 음식도 하나같이 너무너무 맛있고 술도 다...  1,061
# 16215                  맛있읍니다. 양 많읍니다. 친절합니다. 강아지 귀엽읍니다    1,061
# 16216               음식이 너무 맛있고 분위기가 좋아서 다시 가고 싶은 곳이었어요    1,061
# 16217  맛있습니다.. 평소에 괜찮은 바베큐 집 찾기가 힘들었는데 여기 참 괜찮은 것 같습니...  1,061
# 16218  고기 너무 부드럽고 맛있습니다. 요즘같은 가을에는 테라스 이용하시면 분위기도 있어서...  1,061
# 16219                                    플래터 맛있게 먹었어요!    1,061
# 16220                     고기 촉촉한거 보이시나요? 완벽한 바베큐였습니다!!    1,061
# 16221     너무 맛있고 예쁘고 분위기도 좋은집 !! 다음에 꼭 또 올게요 너무 좋았어요 😊    1,061
# 16222   차분한 분위기가 좋았습니다. 음식 맛 좋고  맥주와 함께 즐기기 너무 좋았습니다.     1,061
# 16223                         너무 맛있고 친절한 식당입니다 양도 많아요~    1,061
# 16224                       사장님도 그렇고 가게 분위기며 맛이며 다 좋네여    1,061
# 16225  처음으로 바베큐플레터를 먹어봤는데 평소에 엄청 자극적인걸 별로 안 좋아하는데 제가 ...  1,061
# 16226  정말 배부르고 맛있게 먹었어요!  그리고 사이드 메뉴도 정말 맛있으니 꼭 같이 시켜...  1,061
# 16227             한국최고비비큐에 친절하신사장님 귀여운 강아지 재방문의사 1000퍼    1,061
# 16228                                       바베큐한국1위입니다    1,061
# 16229  생각보다 길찾기가 쉽지않았지만 어려운 길찾기만큼 보람도 컸던 맛집 쥔장님의 친절햔....  1,061
# 16230                                항상 친절하고 너무 맛있습니다.    1,061
# 16231  여기 브리스킷 미쳤어요..  대충 립 올려주는 바베큐집하고 차원이 다르구여, 당근라...  1,061
# 16232                                    진짜 맛있어요 최고입니다    1,061
# 16233  5시 예약해서 가서 아무도 없고 한가하니 너무 좋았어요.   고기들도 다 맛있고  ...  1,061
# 16234                음식도 좋았고 강아지도 너무 귀여웠습니다. 다음에 또 갈게요    1,061
# 16235  우선 음식이 너무 맛있어서 즐거웠는데, 순둥한 조단이 있어서 가족들 모두 더 행복한...  1,061
# 16236  BBq  가성비 좋게 먹기 좋은곳 입니다. 반려동물도 입장가능해서 애견인분들에게도 ...  1,061
# 16237  사장님도 너무 친절하셧고 웨이터 조단도 귀엽네요. 기대이상의 비비큐 10시간 훈연연...  1,061
# 16238  외식을 싫어하시는 엄마를 모시고 오랜만에 외식 장소를 알아보다 울집 강아지도 같이 ...  1,061
# 16239                            잘먹었습니다:) ^^^^^^^^^^^^    1,061
# 16240                       처음 가보니 예상밖  다시 꼭 재방문 하겠습니다    1,061
# 16241                                                 NA  1,061
# 16242                                                 NA  1,061
# 16243                                                 NA  1,061
# 16244                                                 NA  1,061
# 16245                                                 NA  1,061
# 16246                                                 NA  1,061
# 16247                                                 NA  1,061
# 16248                                                 NA  1,061
# 16249                                                 NA  1,061

# %%
df1.to_csv('1.csv')
df1.to_excel('1.xlsx')

# %%
df
# Out:
# [['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '션조시코코아빠',
#   '4.7 ',
#   '저녁',
#   '2024.07.07',
#   '성인 4명이 패밀리세트와 크라우드 생맥4잔 무한리필 주문했습니다. 고기는 입속에 들어가자마자 녹아 버렸고 입가심으로 마신 생맥주는 시원하고 다음 고기를 부르네요.  매운뭇국으로 마무리하고 성인 4명이 배두둘기며 나왔습니다.  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '예약필수죠',
#   '5.0 ',
#   '저녁',
#   '2024.07.06',
#   '친구들이랑 저녁으로 호불호 없이 맛있게 먹었습니다! 많이 먹는 남자 4명 기준 패밀리세트 하나에 빵 추가 하고 풀드포크 리뷰 하고 소고기무국에 밥까지 먹으면 배터집니다:)  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '외로운 식도락가_34751',
#   '4.0 ',
#   '점심',
#   '2024.07.04',
#   '음료 첫 잔만 가져다주고 셀프로 바뀜 사람 얼마 없음  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   'rinikim',
#   '3.8 ',
#   '저녁',
#   '2024.06.30',
#   '맛도 맛이지만 서비스가 미쳤어요! 기분 좋게 만드는 직원분들 덕분에 너무 행복한 시간이었어요ㅎㅎ 피클, 백김치 같은 곁들임 반찬이 있으면 더 좋을 것 같아요!  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '재능있는 미식가_10191',
#   '3.8 ',
#   '저녁',
#   '2024.06.30',
#   '저에게 먹은 고기중 순위중 10위 안에는 됩니다.  고기 매뉴가 다양햇으면 좋겠어요.  비행기 타고왓는데 또 그렇게 완전 맛있다 정도는 아닙니다. 그냥 맛잇어요.   재방문은 이번까지만 고기양이 적어요. 많이드신근들은 커플2인세트를 혼자 드시기 바랍니다.  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '행복한 마스터_29480',
#   '5.0 ',
#   '저녁',
#   '2024.06.21',
#   '재방문이었는데 역시 맛있습니다!!  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '호기심 많은 식객_59542',
#   '5.0 ',
#   '저녁',
#   '2024.06.18',
#   '창가에서 이태원을 바라보며 먹는 분위기가 좋았어요. 고기도 맛있었구요. 가격대는 조금 높지만 기념일에 한번씩 가긴 괜찮을거 같아요~  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '차이엔',
#   '5.0 ',
#   '저녁',
#   '2024.06.16',
#   '축하할일이 있어 분위기좋은 이태원맛집 찾다가 예약하고 방문했어요. 일찍예약해서 밖이 잘보이는 2층 창가자리에 앉았고 스프랑 샐러드먼저 나와서 코스요리처럼 즐겼네요.고기먹고나서는 소고기뭇국까지.  바베큐 미친맛이에요. 불향육향육즙 모든걸 즐길수있는 바베큐입니다. 한우보다도 부드러움 ㅋㅋ 나만 대식가고 3명이 소식가라 조금 남긴 고기는 포장 부탁드렸는데 빵도 더해서 같이 포장해주셔서 감동먹었어요. 여기 직원분들 엉첨 친절하셔. 진짜 맛있는 바베큐 먹으러 가보셔요   ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '발랄한 식객_27120',
#   '5.0 ',
#   '저녁',
#   '2024.06.16',
#   '맛있게 잘 먹었습니다   ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '둥이통이',
#   '5.0 ',
#   '저녁',
#   '2024.06.16',
#   '로우 앤 슬로우 8시간에서 10시간 동안 익힌  호주산 와규 바베큐라 맛이 없을 수가 없는 곳이죠.  바베큐라 편한게 잘라만 먹어도 되서 일단 너무 좋구요.  힙한 분위기에 음악도 좋고 로우앤슬로우는 2층인데 창문이 활짝 열려 있어서 개방감이 훌륭해요.  2층이라 그런지 바람도 솔솔 잘 들어와요.  낮에 그렇게 더웠는데 로우앤슬로우는 엄청 시원해서  나중에는 추울 정도였어요.  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '위이이이이이잉',
#   '5.0 ',
#   '저녁',
#   '2024.06.14',
#   '비주얼 미쳤고 돌았구! 진짜 양 많아서 배터지게 먹구 왓심당🤗 일단 넘 친절하셔서 더 만족스럽더라구여!! 특별한날 바베큐 먹으러 가기도 넘 좋을거같구 인테리어도 넘 좋아서 모임장소로도 딱이엇어용✨ 또 방문할게요!  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '화려한 식객_36340',
#   '5.0 ',
#   '점심',
#   '2024.06.08',
#   '마치 미국에 와있는듯한 느낌이었고 맛도 더불어서 좋았습니다 고기가 부들부들하니 연해서 좋았고 전반적으로 다 맛있었습니다 남자친구가 중간에 주신 소고기국이 넘 맛있었다고 합니다☺️  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '꼼꼼한 맛사냥꾼_43906',
#   '5.0 ',
#   '점심',
#   '2024.06.08',
#   '먹을수록 고기가 줄어들어서 슬펐다  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '촤누',
#   '4.0 ',
#   '점심',
#   '2024.06.07',
#   '1인당 1메뉴주문이라서 비싸긴하네요. 1인당5만원은 기본 디폴트값이예요^-^;  그래도 고기외에 리필도 가능하고, 괜찮아요. 고기는 정말부드럽고 맛있습니다.  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   'kenny',
#   '5.0 ',
#   '저녁',
#   '2024.06.07',
#   '커플 먹었습니다. 구성도 알차고 서비스도 좋았습니다.  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '우수한 맛사냥꾼_98416',
#   '4.2 ',
#   '저녁',
#   '2024.06.07',
#   '진짜오랜만에갔는데 예전만큼은 아니고 생각보다 사람이 너무 없엇따  재방문의사는x  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '호신용손난로',
#   '4.0 ',
#   '점심',
#   '2024.06.04',
#   '좋은 식당. 다만, 제가 브리스킷을 그닥 안 좋아한다는 걸 깨달았어요.  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '갱갱이726',
#   '4.2 ',
#   '저녁',
#   '2024.05.30',
#   '6명이서 패밀리 플레터, 치킨 플레터 2개 시켜서 배부르게 먹었습니다. 인당 4만원 정도 나오는 식당인것 같아요. 확실히 소고기류가 더 맛있습니다!!  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   'wsdx****',
#   '5.0 ',
#   '저녁',
#   '2024.05.27',
#   '맛집 그잡채  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '애기 치타',
#   '4.7 ',
#   '저녁',
#   '2024.05.27',
#   '토요일 낮 톡파원 텍사스 브리스킷 바베큐를 보다 급하게 예약한 후 4시 40분에 방문했는데 대만족입니다!  지금은 없어졌지만 리솜 포레스트에서 처음 먹은 후 꼭 다시가야지 했는데 이렇게 갑자기 가게되었네요! 정말 모든 부위가 살살 녹고요, 소스도 다양하고 무국도 시원해서 매우 만족스러운 식사였습니다! 고기 외 모든건 리필이란 것도 큰 장점입니다! 빵에 코울슬로와 샐러드 할라피뇨 넣고 버가 만들어 드셔야합니다! 꼭!!  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '이노미',
#   '4.2 ',
#   '저녁',
#   '2024.05.22',
#   '버섯치즈스프랑 소고기뭇국은 진짜 맛있었는데  고기는 누린내 비스무리한 .. 급식에 나오는 소고기인데 부드러운 .? 아 오뚜기 카레에 들어있는 결이 다 느껴지는 소고기 ? 인데 부드러운 ? 같은 느낌입니다  서브웨이를 폴드포크 10만원주고 먹는 느낌입니다 시장에서 산 같은 가격 한우 투뿔 나인 이 풍미 와 맛이 깊습니다  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '김인육',
#   '5.0 ',
#   '저녁',
#   '2024.05.21',
#   '마쉿서용  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '승빙0706',
#   '5.0 ',
#   '저녁',
#   '2024.05.21',
#   '맛있게 잘 먹었습니다:) 다음에 또 방문하겠습니다 ㅎㅎ  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '깜찍한 셀럽_41284',
#   '4.7 ',
#   '점심',
#   '2024.05.20',
#   '훈연된 바베큐 접해보기 좋은 기회인거 같아요. 다양한 소스에 먹어보는 것고 맛있고, 모닝빵?에 싸먹는 것도 엄청 맛있습니다!  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '즐거운 개척가_34337',
#   '3.2 ',
#   '점심',
#   '2024.05.19',
#   '고기는 갠잔지만 그냥 다시 가진 않을것 같아요 잘먹었습니다  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '쵠링',
#   '5.0 ',
#   '저녁',
#   '2024.05.18',
#   '둘이서 커플세트로 배부르게 먹었습니다 맛있고 분위기도 좋은데 아쉬운 점이 있다면 매장에 노래소리가 큰데 벨이 따로 없어서 추가 주문이나 요청 드리기가 어려웠어요 별개로 직원 분들은 매우 친절하셨습니다. ㅔ  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '고독한 개척가_93828',
#   '3.3 ',
#   '점심',
#   '2024.05.13',
#   '고기가 질감도 여러 종류가 있어 좋았어요 다만  중학교2학년, 초등학교6학년 딸 둘을 데리고 갔는데 1인 1메뉴라고 초등학생한테까지 1가지 메뉴를 선택하라고 강요하는 점은 아쉬웠습니다. 어린이가 먹어봐야 얼마나 먹는다고..   어린애들이라고 해도 1인 1메뉴를 안 시키면 못 먹는다고 해서 비도 오고 어디 다시 식당 예약해서 가기도 힘들어서 페밀리 셋트 시켰는데 끝내 배불러서 반이나 남겨서 포장해 갓으나 집에서 식은 고기 다시 먹어본 결과 기름이 다 굳어서 형편이 없엇어요.  예전처럼 줄을 서서 먹어 테이블당 단가를 마춰야 되는게 아니라면 서비스적으로 고객에게 맞춰주는 센스가 있었으면 더 좋앗을꺼 같습니다  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '은쓸',
#   '4.3 ',
#   '점심',
#   '2024.05.12',
#   '맛있게 잘먹었습니다 ㅎㅎ  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '세상천지',
#   '5.0 ',
#   '저녁',
#   '2024.05.11',
#   '저번에 둘이 갔을때 부모님 모시고 와야겠다는 생각이 절로 들어 어버이날 되어 모시고 왔습니다 ㅎㅎ  고기 좋아하시는 아버지 고기 생각 안드실때 까지 드셔서 좋았습니다 ㅎㅎ 마지막 뭇국은 뭇국 싫어한다 말하는 형도 괜찮다고 생각할 정도니까 더 말 안할게요!  다음번에는 친구들 데려와야겠습니다 잘먹었습니다~  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '이나박식',
#   '3.0 ',
#   '저녁',
#   '2024.05.09',
#   '고기에서 냄새가 너무 나요….  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '가영5',
#   '5.0 ',
#   '저녁',
#   '2024.05.07',
#   '가격대는 좀 있는 편이지만 고기 종류도 많고 양도 많았어요! 맛있게 먹고 갑니당😋  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   'Stanley',
#   '5.0 ',
#   '점심',
#   '2024.05.06',
#   '언제나 최고의 바베큐  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   'K맑은샘',
#   '5.0 ',
#   '저녁',
#   '2024.05.06',
#   '3년전에 가고 싶었지만 사정으로 못 가고 잊고 살고 있었습니다. 이태원에서 데이트할 일이 있어서 맛집을 찾다보니 생각나서 바로 예약했습니다. 역시 기대한만큼 맛있었고 오랜만에 고기고기스러운 식사를 해서 좋았습니다. 맥주도 맛있더군요.  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '다잉콩',
#   '4.3 ',
#   '저녁',
#   '2024.05.02',
#   '고기를 소스에 찍어 먹는 것보다 빵 사이에 넣고 먹는게 훨씬 맛있었어요. 갈때 가스활명수 챙겨주셨어요. 센스만점입니다 ㅎㅎㅎㅎ  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '뚜비듀바',
#   '4.3 ',
#   '저녁',
#   '2024.04.29',
#   '스프가 조금 짰고 고기랑 소스는 정말 맛있었는데 먹다보니 조금 물려서 아쉬웠어요ㅠㅠ 남자친구가 매쉬드포테이토 엄청 맛있다고 극찬해서 같이 긁어먹었어요 !!  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '얄밉지롱',
#   '1.0 ',
#   '저녁',
#   '2024.04.28',
#   '메뉴를 어떤 조합으로 주문을 하던 그건 고객 마음 아닌가요 손님 앞에두고 주방에서 자기들 끼리 주문한 메뉴가지고 왜 난리이죠..  다 들리는데 기본적인 예의는 아닌것 같네요 예전에는 괜찮다고 하던데 사장님 사건 이후로 변한듯 하네요 다시는 안갈듯하네요  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '윤십오',
#   '5.0 ',
#   '저녁',
#   '2024.04.27',
#   '예약 시간 착오로 일찍 갔는데도 배려해주셔서 감사했습니다. 메인은 물론이고 후식 뭇국이 물건입니다 :)  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '꼬기염',
#   '3.7 ',
#   '저녁',
#   '2024.04.27',
#   '고기가 맛있어요!!! ㅎㅎ  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '손사장',
#   '3.0 ',
#   '점심',
#   '2024.04.14',
#   '음식이 뜨겁지가 않고 미지근 하게 나오더군요.원래 차가운걸 뎁혀 먹는건가요?  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '기분좋은 식도락가_59517',
#   '5.0 ',
#   '점심',
#   '2024.04.13',
#   '사람이 앖아요  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '재미있는 맛사냥꾼_10183',
#   '3.7 ',
#   '저녁',
#   '2024.04.11',
#   '궁금해서 가봤는데 먹을만 해요  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '행복한 셀럽_46711',
#   '5.0 ',
#   '저녁',
#   '2024.04.10',
#   '일단 가장 중요한 맛이 엄청 훌륭했구요, 서버 남자분이 친절하지 않은 듯 되게 일이 빠르시고 센스 좋게 친절하셔서 그게 되게 좋았어요. 과하지 않은 친절함과 센스! 또 가고싶습니다!  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '날으는쿠키',
#   '3.3 ',
#   '저녁',
#   '2024.04.09',
#   '맛은 있으나 서빙해주시는 직원들이 친절하시진 않았던 것 같네요.  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '초이cms',
#   '4.3 ',
#   '저녁',
#   '2024.04.08',
#   '위치가좋고 고기 잘굽고 다양하게 즐기고 서비스가 좋아요  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '놀고먹는인생',
#   '5.0 ',
#   '점심',
#   '2024.04.08',
#   '가격이 완전 착하다곤 할 수 없었긴 하지만 상당히 만족스러웠습니다. 고기 좋아하신다면 꼭 한번 맛보시길👍  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '규스규스',
#   '4.7 ',
#   '저녁',
#   '2024.04.06',
#   '한동안 인기가 너무 많아서 갈 생각도 못하다 이제서야 맛봤습니다. 브리스킷은 처음이라 마니 기대했는데 역시 맛은 소문만큼 맛있었습니다. 그런데 오직 고기만을 위한 메뉴들만 주를 이루다보니 느끼한 걸 잘 못드시면 금방 물릴수도 있습니다만, 마지막에 소고기무국이 제공되므로 어느정도 중화가 가능하므로 고민되신다면 꼭 시도해보시길 추천합니다^^  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '우정규',
#   '5.0 ',
#   '저녁',
#   '2024.04.06',
#   '리얼 짱짱  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '포항장인경',
#   '4.3 ',
#   '저녁',
#   '2024.03.31',
#   '맛있어용! 한번 먹어보면 딱 알맞을 맛  ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   '주현97',
#   '4.8 ',
#   '저녁',
#   '2024.03.30',
#   '4명이서 패밀리 세트 배부르게 잘 먹었습니다. 생일인 사람이 있다고 미리 말씀드렸더니, 서비스로 와인도 한 잔씩 주셔서 감사하게 잘 마셨어요ㅎ.ㅎ 고기 땡길 때 오기 좋은 곳   ',
#   '9,999+'],
#  ['로우앤슬로우',
#   '4.2',
#   4427,
#   '브런치',
#   '용산',
#   '서울특별시 용산구 보광로 126 2층',
#   '점심 저녁 동일가 1 - 4만원',
#   'audwls',
#   '4.0 ',
#   '저녁',
#   '2024.03.25',
#   '오랜만에 왔는데 맛있어요. 고기도 부드럽고 다먹으면 엄청 배불러요 :)  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'euha',
#   '4.8 ',
#   '저녁',
#   '2024.07.07',
#   '맛있다. 메뉴설명및 서비스 알차다  트러플 안좋아해도 추가주문 고려할만하다.   카르파초, 화이트라구  돈이 아깝지않다  마감이 좀 빠른기분  또가야겠다.  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '강직한 식객_85885',
#   '2.3 ',
#   '저녁',
#   '2024.07.07',
#   '메뉴 마다 양이 적고 대부분 너무  짜고 자극적 입니다. 그리고 여성알바하시분 카운터 나이있으신 남자분 손님을 대하는 매너가 무례한 느낌 을 받았습니다.  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '캐시퍼00',
#   '4.3 ',
#   '점심',
#   '2024.07.07',
#   '음식 맛도 맛있고  분위기도 좋은 곳이에요. 기념일에  데이트하며 가기  좋은곳입니다^^  저희는 바에 앉았는데음식 만드는 것도 볼수 있어서 좋았어요.  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '지현이랑말랑이',
#   '5.0 ',
#   '점심',
#   '2024.07.07',
#   '예약한 시간보다 더 일찍 도착했는데 운 좋게 남는 자리가 있어서 바로 입장 할수 있어서 좋았어요 ㅎㅎ 낮에 왔는데도 분위기도 좋고 기념일이나 데이트 장소로 적합한것 같아요 :)  음식도 빨리 나오고 맛있었습니다 ㅎㅎㅎ 💓 다음에 또 방문 할 예정이에요 !   ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '콜드브류소이라떼',
#   '5.0 ',
#   '저녁',
#   '2024.07.06',
#   '너무너무 맛있어요 💓 오래 전에 방문하고 오랜만에 갔는데 여전히 넘넘 맛있네요-☺️ 고맙습니다!  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'Rok07',
#   '4.0 ',
#   '점심',
#   '2024.07.06',
#   '친철한 서비스와 퀄러티높은 식사, 분위기까지!! 너무 너무 만족입니다!!  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '오레오1004',
#   '5.0 ',
#   '점심',
#   '2024.07.06',
#   '너무너무너무 진짜 다 맛있었어요!!!둘이서 메뉴 5개 뿌수고 왔습니다 남기지않고 진짜 싹 먹었구요 또 생각나요!! 진짜 죤마탱입니당💕 한남오면 또 먹으러 갈게용!! 발렛되서 주차도 편해용 굿굿!!  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '따뜻한 미식가_44451',
#   '5.0 ',
#   '저녁',
#   '2024.07.06',
#   '분위기가 너무 좋은 식당에서, 친절하신 직원분들의 요리와 서빙해 주신 맛있는 음식을 함께 온 친구, 연인, 가족들과 함께 할 수 있는 따뜻한 곳이네요!!  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '남다른 식도락가_60609',
#   '5.0 ',
#   '저녁',
#   '2024.07.05',
#   '모든 것이 완벽한 멋진 곳입니다!  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'toru07',
#   '4.7 ',
#   '점심',
#   '2024.07.05',
#   '음식이 하나같이 다 너무 맛있어요 직원분들도 너무 친절함  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '온화한 식객_77499',
#   '5.0 ',
#   '점심',
#   '2024.07.05',
#   '첫 방문인데 모든 메뉴가 다 맛있었어요 화이트라구가 진짜...👍\U0001f979 시킨 메뉴들이 다 맛있기도 힘든데 정말 마음에 드는 첫끼였어요  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '굥구리9',
#   '4.7 ',
#   '저녁',
#   '2024.07.04',
#   '너무너무 맛있어요 .. 분기마다 생각나는 생면파스타  자리가 좀 협소해서 약간 시끄럽다는 점은 잇지만 맛잇어서 행복한 하루   ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'ooUSHoo',
#   '5.0 ',
#   '저녁',
#   '2024.07.04',
#   '직원분들이 다 친절하시고 기본적인 서비스가 굉장히 좋아요. 추천이나 설명도 잘 해주시고 불편함 없이 신경써주셔서 전반적으로 잘 먹고 좋은 시간 보내고 왔다고 생각들더라구요. 화이트라구, 항정살, 토마토 딸리아딸레 먹고 왔는데 진짜 화이트라구 엄청 추전해요. 녹진하고 짭짤하고 면이 진짜 소스가 잘 베어있어서 맛있엇어요. 딸리아딸레는 고수가 들어있으니 참고하시면 좋을 것 같아요.   ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'Dagu',
#   '4.3 ',
#   '저녁',
#   '2024.07.04',
#   '.  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '새로운 식객_99228',
#   '5.0 ',
#   '저녁',
#   '2024.07.04',
#   '식당 분위기도 좋고, 음식도 주문한 음식 하나하나 다 맛있고, 특히 홀 서빙하시는 여자분이 되게 친절했어요! 덕분에 즐거운 마음으로 즐기고 간 것 같습니다.  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '옴뇨뇸',
#   '4.3 ',
#   '저녁',
#   '2024.07.03',
#   '여긴 미쳤어요. 진짜 다 너무 맛있고 생면 파스타 너무 충격적으로 맛있었어요. 그리고 수비드 항정 진짜 도른자. 이거 레시피 너무너무너무 궁금해요.  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '영서언니',
#   '5.0 ',
#   '저녁',
#   '2024.07.03',
#   '하나같이 다 맛있게 먹었습니다. 생면 파스타는 다른 곳에서도 종종 먹어보았는데 개인적으로 이곳에서 먹은 화이트라구 생면파스타의 식감이 가장 좋았어요. 약을 먹고 있어서 술을 못 먹은 게 아쉽네요. 다음 방문 때에는 꼭 와인 페어링도 함께 하려고요.  친절히 응대해주셔서 감사합니다.  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '하야니',
#   '1.8 ',
#   '저녁',
#   '2024.07.03',
#   '오랜시간 한남동에 자리잡고 있는 오스테리아 오르조.  10명의 직원 중 단 한 명도 주문 누락을 알아차리지 못한채 25분여간 수다 떨고 본인들 간식 먹기 바빴던 직원들. 본인들의 실수 후 에도 아무런 조치가 없었던 오스테리아 오르조.  \u2003 예전에는 생면파스타를 하는 업장이 많지 않았지만, 요새는 잘하는 업장들이 많기 때문에 이런 식으로 운영 하다 조만간 사라질 오스테리아 오르조.   키친이 보이는 바테이블에 앉아 둘이서 총 5개의 메뉴를 주문했는데, 2개의 에피타이저와 3개의 파스타를 주문했다.  2개의 에피타이저가 나오는 텀이 13분정도로 길었고 캐주얼 다이닝이기 때문에 어느정도 감안하고 식사를 진행했다. 세번째 디쉬가 나온 후, 15분이 지났는데 키친에서 아무도 조리하고 있지 않았고 키친 & 서빙 직원 모두 우르르 모여 간식을 나눠 먹고 있었다.  컴플레인을 하려고 했는데, 뒤늦게 메뉴 누락을 알아 차리곤 두개의 메뉴를 급하게 준비하는 모습이 보였다. 본인들이 주문 누락을 뒤늦게 알고 준비했으면 사과와 함께 서빙 해야 하는게 맞다고 생각했다. 하지만 서빙 직원은 아무런 사과 없이, 태연하게 네번째 디쉬 서빙 후 5번째 디쉬를 가져왔다.  7시까지 식사를 마쳤어야 하는데, 6시33분에 마지막 디쉬를 내어주고는 6시48분쯤와서 7시 예약테이블이 있다고 결제를 부탁하러 오셨다. 굉장히 불쾌했고 결제하고 나갈 때까지 사과 한마디 없었다.   [5시 45분] 첫번째 메뉴. 튀긴가지와 토마토 살사 [5시 58분] 두번째 메뉴. 문어와 감자메쉬 [6시 8분] 세번째 메뉴. 페퍼로니 파스타 [6시 31분] 네번째메뉴. 화이트라구 [6시 33분] 다섯번째 메뉴. 스파이시크랩리조또  대처라고 할 것 조차 없이 무대응이였던 오스테리아 오르조. 맛은 메뉴마다 간 조절이 안되어있으며 시그니처 메뉴 또한 시그니처라고 보기 어려웠음.  화이트 라구는 맛은 좋았으나 짰고, 페퍼로니 파스타는 매웠고 고수 향이 났는데 주문전에 맵기정도나 고수향에 대해 언급이 없었음. 페퍼로니와 고수향이 따로 놀아 별로였던 메뉴. 시그니처인 게살 리조또 또한 매웠고 주문전에 맵기 정도에 대한 언급 역시 없었음. 화이트라구와 함께 먹으니 라구는 짜고 게살은 매운데 간은 또 약하게 느껴졌음.   맛도 개선이 필요하지만 서비스 대응 개선이 크게 필요할 것으로 보임.   ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '아라미♥진&진',
#   '3.3 ',
#   '점심',
#   '2024.07.03',
#   '우니파스타 맛있어요.  처음에 음~ 맛있군 했는데  끝맛이 부드럽고 고소하개, 트러플 오일향이 살짝 느껴지며 기분좋게 하는 맛이에요.   ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'Hyoador',
#   '3.8 ',
#   '점심',
#   '2024.07.03',
#   '우니파스타가 제일 맛있고 비프 카르파치오도 맛있어용 ㅎㅎ 분위기는 런치라 시끌벅적한 느낌이 있었어요!  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '오렌지꽃피는',
#   '4.5 ',
#   '저녁',
#   '2024.07.03',
#   '6.29 맛있게 잘 먹었어요!   ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'soljjang',
#   '4.0 ',
#   '점심',
#   '2024.07.02',
#   '넘기대를 많이했나봐용! 그래도 맛있었어용ㅎㅎ  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'hippolicity',
#   '5.0 ',
#   '저녁',
#   '2024.07.02',
#   '이래저래 묻기 전에 먼저 센스 있는 배려를 해 주시는 홀 직원분들께 감사했던 곳! 공연 보듯 오픈키친 감상(?)하는 재미에, 맛은 뭐.. 말이 필요 없음 👏   ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'dla002',
#   '4.3 ',
#   '저녁',
#   '2024.07.01',
#   '분위기 좋지만 음식은 기대를 많이해서 그런지 살짝 아쉬워요  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '음식인생사랑',
#   '2.0 ',
#   '저녁',
#   '2024.07.01',
#   '미쉐린가이드 추천에 걸맞는 정도의 음식 맛은 아니었습니다.  특히 한우안심카르파치오는 대단히 실망이었습니다. 무슨 살라미나 햄을 내놓은 줄 알았습니다. 1시간 30분 식사시간 제한도 손님에 대한 예의는 아닙니다. 패스트푸드점도 아니고.  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'cheongdy',
#   '4.2 ',
#   '점심',
#   '2024.07.01',
#   '비프 카르파치오가 정말 맛있다  파스타는 사실 기대를 너무 많이했는지 무난했다 (재료는 푸짐하고 간도 맛있었다)  다음에 생면 파스타를 먹어봐야 될 것 같다  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '지혜로운 마스터_67927',
#   '5.0 ',
#   '저녁',
#   '2024.06.30',
#   '맛은 너무 인정💝유럽 10번 이상 돌아다닌 친구를 긴장하며 내 최애 맛집이라고 데리고 왔는데~ 너무 맛있다고 약간 못 먹어본 느낌도 나고, 카르파치오는 두번 시켜 먹음 😍 라구도 맛있는데 유럽에서 썰어주는 트러플 향의 1/10도 안나는거 같다해서 트러플 오일 더 받아서 뿌려 먹음~ 수비드 항정도 부드럽게 딱 좋고 소스도 잘 어울림!!  서버 분들도 넘 친절하고 많이 시켜 먹으니 1시간 반 리밋보다 더 즐길 수 있게 센스있게 해 주심😎  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'pieldo',
#   '4.0 ',
#   '저녁',
#   '2024.06.30',
#   '음식이 아주 맛있고 훌륭함. 그런데 한국 식당들은 정말 식당 입구부터 화장실까지… 너무 신경 안씀 ㅠㅠ 계단, 화장실 개선이 필요할듯  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'juyoungjuiin',
#   '5.0 ',
#   '점심',
#   '2024.06.30',
#   '너무 만족스럽게 맛있게 먹었습니다   ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'safflower',
#   '4.8 ',
#   '점심',
#   '2024.06.30',
#   '투뿔한우안심카르파치오,  트러플감자튀김,  화이트라구, 수비드한항정살 친구와 2인이 나눠 먹었는데 맛있었어요. 특히 카르파치오와 화이트라구가 좋았습니다. 양이 적당했는데 경우에 따라서는 적다고 느껴질 수도 있을 것 같아요. 직원분들도 친절하고 바에서 먹어서 조리과정을 살짝 엿볼 수도 있었습니다.   ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '태종태세문단속잘해라',
#   '5.0 ',
#   '점심',
#   '2024.06.30',
#   '맛과 서비스 모두 훌륭했습니다! 바 자리밖에 예약이 안돼서 불편하겠다라규 생각하고 갔는데 생각보다 너무 편했고 바에서 주방을 구경하는게 재밌더라구요! 오픈 키친이라 너무 청결하고 요리하는것도  바로 앞에서 볼 수 있어서 홀테이블보다 바자리가 더 좋았어요! 가격도 비싸지않아서 여러 메뉴 먹기 좋았습니다! 다음에 또 방문할게요~~  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '행복한 개척가_44371',
#   '4.3 ',
#   '저녁',
#   '2024.06.29',
#   '음식이 정말 맛있었어요. 매장이 살짝 협소해서  분위기는 아쉬웠어요.  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'elly0826',
#   '5.0 ',
#   '점심',
#   '2024.06.29',
#   '맛있어요!!  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '동금',
#   '5.0 ',
#   '점심',
#   '2024.06.29',
#   '여자친구와 7주년 기념으로 방문하였는데 친절하고 분위기도 좋고 음식도 너무 맛있었습니다!  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'kkarcia',
#   '4.8 ',
#   '점심',
#   '2024.06.27',
#   '호텔 놀러왔다가 근처 맛집을 찾아보고 오게 되었는데 정말 탁월한 선택이었습니다  분위기하며 맛도 정말 처음 먹어보는 맛에 눈이 띠용 하는 맛이었어요 음식도 하나하나 차례대로 나와서 좋았고 서버분들도 정말 멋지고 친절하셨어요  또 가고 싶네요 😋  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '최소피아',
#   '5.0 ',
#   '점심',
#   '2024.06.27',
#   '우니파스타 퍼포먼스 좋았는데 우니가 너무 적어서 향만납니다 ㅎ아쉬워요. 하지만 탑파스타. 건면 어디브랜드인지 궁굼하네요.  꼬독꼬독 너무 맛있엉  헤어라인파스타인지 면이 엄청 가늘었던 샤프란파스타~양이적었지만 소스가 와...우 향좋았고 발란스 좋아요.  파스타맛집 오르조!!   ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'Adam Ballin',
#   '2.3 ',
#   '저녁',
#   '2024.06.26',
#   'Some dishes were good for example the ragu pasta, rest were just a bit “ok”, wine list was short and not up to date, some bottles sold out. Get rushed out the door after ordering a decent bottle of wine and sitting for just 60 minutes.   I get it’s meant to be a casual experience, but I just expected a bit more. It could have been a 4-5 star with a bit more patience and focus.   ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'dlckdud',
#   '5.0 ',
#   '점심',
#   '2024.06.26',
#   '와이프 출산 후 첫 외식자리였는데 분위기도 맛도 모든것이 만족스러웠던 식사입니다.  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '지너니입니다',
#   '5.0 ',
#   '저녁',
#   '2024.06.26',
#   '방문때마다 늘 맛있게 먹고 있습니다.   ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'leahly',
#   '3.7 ',
#   '저녁',
#   '2024.06.25',
#   '항정살이 엄청나게 부드럽고 맛있었습니다 파스타는 짠맛이 강했지만 이탈리안 특유의 개성으로 이해할 수 있는 정도였어요 음식이 다 특색 있어요 다만 왜 가격 대비 양이 적다고 하는지도 알겠어요 본격적인 식사보다는 맥주나 와인에 가볍게 음식을 곁들이는 자리를 가지면 아주 기분 좋은 시간이 될 것 같습니다  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '조용한 마스터_25607',
#   '5.0 ',
#   '저녁',
#   '2024.06.24',
#   '진짜 기념일 때 여기 가세요..분위기도 너무 좋고 음식도 맛있고 너무 좋습니다 증말 핱시 환연에서 나올법한 데이트 장소입니데  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '부드러운 마스터_94226',
#   '5.0 ',
#   '점심',
#   '2024.06.24',
#   '정말 맛있습니다. 특히 라구파스타가 정말정말 맛있어요.  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '기분좋은 마스터_12226',
#   '5.0 ',
#   '저녁',
#   '2024.06.24',
#   '분위기 좋고 음식이 맛있어요.  너무 시끄러운 분위기가  아니라서 데이트 하기 좋은  곳!  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '정소금0217',
#   '5.0 ',
#   '저녁',
#   '2024.06.23',
#   '진심 올해먹은 양식중에 제일맛있어요. 뵈프부르기뇽 강추입니다  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '한명신',
#   '4.5 ',
#   '저녁',
#   '2024.06.23',
#   '카르파쵸는 정말 맛있었는데 파스타는 전보다 간이 조금 셌네요  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '분홍지렁이',
#   '5.0 ',
#   '저녁',
#   '2024.06.23',
#   '프라이빗하고 좋아요. 카르파치오 추천합니다  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   'Markkkkkk',
#   '5.0 ',
#   '점심',
#   '2024.06.23',
#   '최고의 서비스와 음식~ 엄마랑 누나 생일때 왔는데 너무 좋았어요!  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '밝은 식도락가_46990',
#   '4.8 ',
#   '점심',
#   '2024.06.23',
#   '맛있고, 음식도 빨리 나옵니다.   ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '랗할',
#   '4.0 ',
#   '점심',
#   '2024.06.23',
#   '테이블 사이 간격이 너무 좁아 아쉬워요ㅜㅜ 옆에서 무슨 얘기하는지 그냥 바로 옆테이블이랑 일행인 것 같은 느낌이라.. 그 외엔 다 좋네요 :) 참고로 인당 메뉴 2가지는 먹어야 배불러요 식사만 생각했을때는 인당 최소 5만원 생각해야하고 와인까지 하면 1인당 최소 8-10만원선 이상이라고 보면 돼요  ',
#   '9,999+'],
#  ['오스테리아 오르조',
#   '4.6',
#   4106,
#   '한식',
#   '용산',
#   '서울특별시 용산구 한남대로20길 47 2층',
#   '점심 영업안함 · 저녁 1 - 5만원',
#   '루나예나8',
#   '4.0 ',
#   '저녁',
#   '2024.06.22',
#   '화이트라구가 맛있다고 하던데 저는 입맛이 초딩이라 그런지 녹진하고 강렬한 스파이시 크랩 리조토가 더 맛있었어요 !! 비프 카르파치오는 맛있는데 막 리조토처럼 대박은 아니구 그랬어요 티라미수 귀엽고 보통 티라미수 같지 않게 변주를 둔게 깔끔하니 맛있었어요  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '밍먕묭먕',
#   '5.0 ',
#   '저녁',
#   '2024.07.08',
#   '맛있었어용  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '외로운 맛사냥꾼_40498',
#   '5.0 ',
#   '저녁',
#   '2024.07.08',
#   '꺄하 남자친구가 너무 잘 먹어줘서 더 좋았어요  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '비비빕비.',
#   '3.0 ',
#   '저녁',
#   '2024.07.07',
#   '두번째 방문인데 음식종류는 동일한데 맛은 첫번째 방문했을 때보다 별로에요  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '가을 솜',
#   '4.5 ',
#   '저녁',
#   '2024.07.05',
#   '분위기좋고 맛있어요 친절합니다  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   'yjseo****',
#   '5.0 ',
#   '저녁',
#   '2024.07.02',
#   '고기 품질이나 맛은 당연하게 훌륭하고, 바에서 먹었지만 프라이빗하고 좋았어요!   ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '짜증왕왕',
#   '3.2 ',
#   '저녁',
#   '2024.07.02',
#   '퍼포먼스 적인게 있어서 보는 즐거움은 있었지만 고기템퍼를 맞추는데 서투른감이 보였고 미디엄으로 추천해주셨지만 미디엄레어로 고기가 계속 쿠킹되었고 대신 레스팅은 잘해주셔서 핏물이 많이 흐르진않았음 그리고 룸에서 먹었는데 방에서 연기가 잘 안빠져서 조금 곤란했었습니다.   직원들 친절도도 좋았고 가격대비 괜찮은구성 같았습니다. 콜키지 한병이 무료인점 마음에 들었습니다.  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   'jnqrt',
#   '5.0 ',
#   '저녁',
#   '2024.07.02',
#   'ㅤㅤ ㅤㅤ ㅤㅤ ㅤㅤ ㅤㅤ ㅤㅤ ㅤㅤ ㅤㅤ ㅤㅤ ㅤㅤ   ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '나이뽀그치',
#   '3.3 ',
#   '저녁',
#   '2024.07.01',
#   '가성비로는 진짜 좋습니다 ☺️ 육회도 맛있었구요  처음 구워주신 업진살은 기름기가 너무 많았어요  채끝은 mr로 주신다고 하셨는데 m정도였던 것 같아요 ㅎ,, 장아찌는 맛있어서 계속 먹게 되는,, ㅎㅎ 솥밥도 맛있었어오  원래 진짜 많이 먹는데 집와서도 계속 배뷰르더라구요 !!  가성비 맛집입니다!! 한 번쯤 와봐도 괜찮을 것 같아요 😆  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   'Effy0506',
#   '3.7 ',
#   '저녁',
#   '2024.07.01',
#   '음식도 너무 맛있고 친절하신데 역시나 속도가 빠르다보니 놓쳐서 말 못해주셨던 것들은 뒤늦게 알려주시는 경우가 3번정도 있었어요ㅜㅜㅜㅜ 서버분에 따라 많이 다른 듯 합니다. 저희보다 빨리온 팀이 조금 더 속도에 알맞게 진행 되었고 저희는 고기도 4인분 추가 했음에도 불구하고 다른 팀보다 빠르게  한 번에 싹 다 구워 주셔서 먹는데 뭔가 급한 느낌이였어요!  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   'komment',
#   '4.3 ',
#   '저녁',
#   '2024.07.01',
#   '여자친구와 기념일에 방문했습니다. 분위기도 캐주얼해서 좋고, 짧지만 탄탄한 코스였기에 배부르게 먹을 수 있었습니다. 가격이 다른 우마카세에 비해 부담스럽지 않아 많이 방문 할 수 있겠어요!  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '원숭이강아지',
#   '3.7 ',
#   '저녁',
#   '2024.06.30',
#   '음식 맛은 괜찮은 편이지만 분위기는 별로에요  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '따뜻한 미식가_7432',
#   '5.0 ',
#   '저녁',
#   '2024.06.30',
#   '음식도 너무 맛있고 서비스도 좋고 이 가격에 이렇게 먹을수 있다는게 너무 좋네요 최고예요!!  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '봉이2',
#   '3.0 ',
#   '저녁',
#   '2024.06.30',
#   '이속우화 천공을 4번정도 방문후 이속우화 한남동을 방문했는데 너무 아쉬운점이 많았어요. 메뉴구성 천공에 비해 너무 부실했고 서버가 너무 미숙한티가 나서 놀랬어요..  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '은동사',
#   '5.0 ',
#   '저녁',
#   '2024.06.29',
#   '이속우화 예약 성공해서 다녀왔습니다~~ 루이비통 가방 안 소고기 사진 찍었습니다 ㅎㅎ 고기는 너무 부드럽고 맛있었고요 특히 저 햄버거도 넘 맛있었습니다... 동행인이 야채를 별로 좋아하지 않는 사람이라 걱정했는데 곤드레밥과 된장국도 맛있게 먹었습니다 예약시에 동행인 생일이라고 적었는데 마지막 소르베 주실때에 너무 예쁘게 주셔서 감동받았습니다 ... 덕분에 함께 생일을 맛있고 행복하게 보낼 수 있었어요 이속우화 감사합니다!  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   'ma mark',
#   '4.7 ',
#   '저녁',
#   '2024.06.28',
#   '기본 적으로 맛있어요  성인 남성 기준으로 고기양은 다소 적지만 다양한 코스로 배가 엄청 불렀습니다  기본 코스에 고기를 추가 주문해주면 최고일것 같습니다  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '아름다운 개척가_48011',
#   '5.0 ',
#   '저녁',
#   '2024.06.28',
#   '좋아하는 사람과 맛있고 분위기 좋은 먹으러 가기 너무 좋았고 음식 하나하나 너무 친절히 자세히 설명해 주셔서 이 가격이 말이 되나?ˀ 이런 생각이 들었습니다 잘 먹고 갑니다~  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '참소라',
#   '5.0 ',
#   '저녁',
#   '2024.06.27',
#   '예얃 좌석 생기면 바로 가야하는 곳 …  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '여유로운 마스터_75879',
#   '4.7 ',
#   '저녁',
#   '2024.06.27',
#   '고기 오마카세라기엔 고기가 쪼끔쪼끔 나오는 느낌..? 그래도 성심성의껏 음식을 다루고 제공한단 느낌은 강하게 받아서 만족스럽다  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '인기많은 마스터_23078',
#   '5.0 ',
#   '저녁',
#   '2024.06.26',
#   '직원분들의 항상 웃는 얼굴로 서비스해 주시는 게 너무 기분 좋았어요. 고기는 살살 녹게 구워서 서브해 주시고 식사에 후식까지 기분 좋은 자리였습니다. 거기에 콜키지프리까지! 완벽!!  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '건강한 식도락가_93307',
#   '5.0 ',
#   '저녁',
#   '2024.06.26',
#   '재방문 하고싶은곳~ 양이 많은건 아니지만 충분히 알찬 구성으로 만족합니다. 항상 최상급 고기를 먹는분 아니시라면 고기 맛은 보장!! 특히 조금씩 맛보기 좋아하는 여성분들에겐 딱이지 않을까 생각이 드네요~  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '민교민채',
#   '4.0 ',
#   '저녁',
#   '2024.06.26',
#   '고기 맛 좋아요. 남자분들은 고기추가 필요합니다. 두번째인데 첫방문보다 감동은 덜하네요~  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '여유로운 맛사냥꾼_96123',
#   '5.0 ',
#   '저녁',
#   '2024.06.26',
#   '고기가 맛있어서 추가해서 먹었어요🍷  제 실수가 있었는데 친절하게 안내해주셨어요. 덕분에 즐거운 시간 보내고 갑니당!!!  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   'Soosoo5',
#   '4.8 ',
#   '저녁',
#   '2024.06.26',
#   '맛나요?!   ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '발랄한 셀럽_76609',
#   '4.3 ',
#   '저녁',
#   '2024.06.25',
#   '분위기는 좋았습니다  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '이곰미',
#   '4.2 ',
#   '저녁',
#   '2024.06.25',
#   '친구들과 가족들과 가면 좋을 것 같아요^^ 음식맛은 더할나위 없이 만족 스러웠습다^^  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   'Attila Park',
#   '5.0 ',
#   '저녁',
#   '2024.06.24',
#   '굿굿  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   'tmdwo',
#   '4.3 ',
#   '저녁',
#   '2024.06.23',
#   '높은 경쟁률을 뚫고 기대한 만큼 만족스러운 맛은 아니었지만 그래도 가격 측면에서 이정도 퀄리티의 음식을 먹을 수 있음에 놀라웠습니다.  만족스러운 식사를 제공해주셔서 감사합니다  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   'jaehoon',
#   '5.0 ',
#   '저녁',
#   '2024.06.23',
#   '맛있고 서비스도 너무 좋은데 구운고기의 양이 좀 더 많으면 좋을 것 같아요👍우니 프러플 추가는 필수✋  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '붕기님',
#   '4.8 ',
#   '저녁',
#   '2024.06.20',
#   '친절한 서빙.  알아서 부족한거 물어보고 채워주심.  다음에 또 예약해서 오고싶음. 육회+우니 조합이 너무 좋음. 무조건 한입에 넣어서 같이 먹어야 합니다.  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '따뜻한 개척가_90964',
#   '5.0 ',
#   '저녁',
#   '2024.06.19',
#   '디너 한우 오마카세가 6만원이라니 너무 가성비 좋고 맛있게 잘 먹었습니다 :)  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '유명한 식객_91529',
#   '4.0 ',
#   '저녁',
#   '2024.06.19',
#   '고기 지방이 너무 많았어요 ㅠ 직원분은 너무 친절하고 분위기도 좋았습니다  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   'Hello8',
#   '1.0 ',
#   '저녁',
#   '2024.06.19',
#   '콜키지 되는거 좋은데요... 재방문 절대 안할 거 같아요. 메뉴 구성이 왜 바뀌었는지는 모르겠지만 다른 지점과 다릅니다. 육회에 감태 대신 김이었지만 버거니 밥이니 후식 요거트 아이스크림까진 괜찮은데요... 메인인 고기가 이정도면 굳이 여기서 먹어야 할 이유가 없는 것 같아요.  다른 날은 모르겠지만 제가 간 날은 고기 질이 너무 별로였어요. 드셔보시고 파시는 건지 모르겠지만, 너무 질겨서 안넘어갈 정도였고 결국 삼키지 못했습니다. 고기 외에 피클이나 소스는 맛있었어요.  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '비범한 식도락가_51845',
#   '5.0 ',
#   '저녁',
#   '2024.06.17',
#   '스타터로 나온 육회에 성게 추가 강추합니다 :) 채끝은 사르르 녹아내리고 부채살은 적당한 육질이 느껴지며 부드러웠습니다 추가로 부채살 더 먹었구요  담당 셰프님이 고기 정말 잘 구워주신거 같아용~ 미니버거에 패티도 불고기처럼 달달하니 맛있었구요 같이 주신 감자튀김 쏘스도 취저 였습니당😁😁😁 된장찌개로 마아무으리 하공  디저트로나온 요거트아이스크림도 맛나게 먹었습니당 참고로 생일자 라면 레터링 서비스도 함께~~~ 받아보세용😍  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '성운히',
#   '4.5 ',
#   '저녁',
#   '2024.06.14',
#   '여자친구 생일 기념으로 방문했습니다! 예약하기 어려운 곳답게 가성비가 너무 좋았고, 가성비를 넘어서 음식이 전체적으로 맛있었습니다! 사실 양은 기대하지 않고 갔는데 성인남자 기준으로 충분히 배부르게 먹을 수 있는 양이었습니다! (여자친구도 상당히 잘먹는 편인데 배부르다고 조금 남기더라구요) 다음에도 또 올 의향 있습니다! 오마카세 경험하고 싶은데 해산물 못드시는 분들은 우마카세 너무 괜찮은 것 같습니다! 추천합니다!  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   'Estrella✨',
#   '5.0 ',
#   '저녁',
#   '2024.06.14',
#   '좋아~  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '삼봉햄',
#   '5.0 ',
#   '저녁',
#   '2024.06.14',
#   '너무나 맛있었습니다..  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '우수한 마스터_63254',
#   '4.7 ',
#   '저녁',
#   '2024.06.14',
#   '충분히 맛있었음.  고기 퀄리티도 좋고 가격도 괜찮고  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '두애삼',
#   '5.0 ',
#   '저녁',
#   '2024.06.13',
#   '친절하고 섬세하게 챙겨 주심  맛은 너무 좋았음.  다만 분실물이 생겼는데  식당에  놓고 갔는지 확인 하려는데 전화연결도 어렵고 어디로 연락해야 할지 모르겠어서  직접 가야 하나 싶음 . 다른 연락 루트가 있는건지... 아직 확인 못함   ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '혤반장',
#   '5.0 ',
#   '저녁',
#   '2024.06.13',
#   '드디어 방문한 이속우화!!! 친구랑 같이 맛있게 먹었습니다 설명도 잘 해주시고 다음에 또 예약해서 올게요 :)  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   'ㄱ.Ｊ',
#   '2.7 ',
#   '저녁',
#   '2024.06.12',
#   '예전보다 식사 퀄리티가 매우 떨어짐  식사 메뉴가 간소화 된건지 돈 좀 더 주더라도  개선 되었으면 합니다   ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   's2ujin',
#   '5.0 ',
#   '저녁',
#   '2024.06.12',
#   '주말 저녁타임으로 만족스럽게 다녀왔습니다☺️ 팀별로 담당 서버분께서 구워주시고, 서비스 및 콜키지 칠링등  센스있게 코스 진행해주셔서 좋더라구요.  음식 코스도 괜찮았고, 속도가 빠르다는 후기도 있었지만  저희는 먹는 속도가 맞아서 위스키랑 같이 코스 진행하니  좋았습니다! 고기 퀄리티는 당연히 좋았고, 퍼포먼스가 중간중간  많아서 좋은 시간 보내고 왔습니다. 추천해주신 특수부위까시 추가해서 먹으니 양도 딱 좋았고, 생일 플레이트까지 너무 좋았네요👍🏻 예약은 치열했지만 다음에 또 성공해서 방문하려구요‼️  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '링하4301',
#   '3.7 ',
#   '저녁',
#   '2024.06.12',
#   '우마카세를 경험해보기 좋은곳입니다. 가격은 딱 적당한것같아요.  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '먹지연',
#   '5.0 ',
#   '저녁',
#   '2024.06.11',
#   '서버분이 고기를 잘 구워주셔서 맛있게 먹고왔어요 ㅎㅎ  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '뇨ㅇ니뇽니',
#   '5.0 ',
#   '저녁',
#   '2024.06.11',
#   '행복한 하루와 행복한 맛을 느끼게해주심에 감사하네요 다음에 또 방문할게요 최고에요  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '백둉이',
#   '5.0 ',
#   '저녁',
#   '2024.06.11',
#   '작년부터 너무 가보고 싶었던 곳인데 운좋게 예약에 성공해서 다녀왔어요 코스도 너무 정갈하고 맛도 정말 훌륭해요ㅠㅠㅠ  양이 많지 않을 거라 생각했는데 먹다보니 배가 불러서 마지막에 솥밥과 된장찌개는 많이 남겼어요ㅠㅠ 된장찌개도 자극적이지 않고 정말 맛있어요  콜키지 1병 무료라 근처 와인샵에서 와인 사가서 곁들여 먹으니 정말 더더더더 훌륭했어요  다음에 기회가 되면 또 가보고 싶은 곳이에요!!  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '멋찐슈',
#   '4.5 ',
#   '저녁',
#   '2024.06.10',
#   '가격대비 구성과 코스는 좋았습니다 딱 가격만큼 하는 양이라 조금은 부족하지만  가성비 오마카세이니 감수해야할거같구요 다만 처음에 미디움레어 부탁드렸는데 생각보다 질기고 덜익어서 미디움으로 변경 부탁드렸지만 결과적으로 큰 차이없는 굽기정도여서 계속해서 약간 질긴상태로 먹었습니다. 서버분 캐바캐이겠지만 이러한 운이 작용한다는것도 약간은 아쉬운 부분입니다. 그러나 가격이 저렴하니 조금은 이해 할 수 있어요  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '페라리맨',
#   '5.0 ',
#   '저녁',
#   '2024.06.10',
#   '아이들과 함께 가족 모임 했습니다. 콜키지 프리라서 샴페인도 같이했구요. 양이 적은 거 아닐까 했지만 먹고나니 너무 배부른 ㅎㅎ 음식도 서비스도 분위기도 가성비도 너무 만족합니다. 예약만 된다면 또 가고 싶어요😍  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '박창균',
#   '3.7 ',
#   '저녁',
#   '2024.06.10',
#   '1. 뭔가 프라이빗하다기 보다는 손님끼리 마주보고 앉아서 먹는 느낌이 강함 2. 연기가 가게 안을 다 메워요.. 3. 고기의 퀄리티는 굉장히 좋고 서비스도 좋아요 4. 식사류에서 곤드레 나물밥이랑 된장찌게 주는데 밥량에 비해 반찬이 하나도 없는게 아쉽습니다 ㅠㅠ  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '발랄한 맛사냥꾼_94580',
#   '4.0 ',
#   '저녁',
#   '2024.06.10',
#   '다 맛있었는데 마직막에 나온 우대갈비살 너무질겨서 먹기힘들었어요 음식이  나오는 간격이 너무길어요.  ',
#   '9,999+'],
#  ['이속우화',
#   '4.5',
#   2898,
#   '이탈리아음식',
#   '신용산',
#   '서울특별시 용산구 한남대로20길 61 지1층(한남동)',
#   '점심 1 - 4만원 · 저녁 2 - 4만원',
#   '개포동불주먹b',
#   '5.0 ',
#   '저녁',
#   '2024.06.09',
#   '예약이 어려운데에는 이유가 있는거 같습니다 ! 부모님 모시고 룸 예약했는데 정말 프라이빗 하고 좋은것 같아요 ㅎㅎ 맛도 물론 좋구요 서비스가 정말 좋아여 우대갈비살은 살짝 질기지만 전반적으로 고기가 부드럽고 맛있었습니다. 다음에 또 오고싶어요 !   ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '슈댕e',
#   '4.7 ',
#   '저녁',
#   '2024.05.02',
#   '친구 생일이라 재방문 했는데 맛있았어욤~~  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   'mikaelrv93',
#   '5.0 ',
#   '저녁',
#   '2024.04.30',
#   '스시도 넘 맛있었고, 메뉴 구성도 알차고 서비스도 넘넘 좋았어요!  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '규혁임',
#   '1.0 ',
#   '저녁',
#   '2024.04.30',
#   '남자라서 정말 리뷰 안쓰는 사람인데요. 정말 너무 맛이 이상해서 일행과 저 모두 그렇게 느껴서 옆에 사람들 괜찮냐고 물어보고 싶었습니다. 초밥먹고 맛 없다고 생각한적은 처음입니다. 밥이 상한줄 알았네요. 오마카세 첫 방문도 아닙니다.  돈이 너무 아까워요. 좋은날 망쳤네요  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '꼼꼼한 식객_48309',
#   '5.0 ',
#   '저녁',
#   '2024.04.29',
#   '구성도 좋고 양도 생각보다 많아요  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '동밈미',
#   '5.0 ',
#   '저녁',
#   '2024.04.24',
#   '너무 맛잇고 셰프님두 친절하셔서 좋았어요~~ 앵콜을 계속 해주셔서 죄송.. ㅎㅎ 회들이랑 한입요리들도 감탄 하면소 먹었어요 막 엄청 달거나 하지 않아서 담백하니 슐 안주로도 잘 먹었습니다 ^__^* 또 재방문 할겡요 번창하세욘!!!!  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '전병달',
#   '5.0 ',
#   '저녁',
#   '2024.04.23',
#   '친절하고 맛있어요  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '냑냥',
#   '1.3 ',
#   '저녁',
#   '2024.04.22',
#   '캐치테이블은 예전부터 행사때마다 자주 이용해왔지만 리뷰는 처음으로 작성해봅니다   어머니 생신으로 방문 하였으나 착석 하자마자 바 테이블 위로 바퀴벌레가 지나가는 바람에 특별한 저녁을 준비했던 저로써는 정말 민망했습니다 (직원분이 휴지로 바로 잡아주셨지만 바닥도 아니고 테이블 위로 기어다니는 바퀴벌레는 매우 충격적) 부모님은 식사가 끝날때까지도 바퀴벌레 이슈에 괜찮다고 하셨지만 생각할수록 아니다 싶어 글을 남깁니다 10만원이라는 금액을 인당씩 지불하고 어머니 생신이라는 중요한 이벤트를 망친 기분이 들었습니다 음식에 관한건 식당의 개인적인 스타일이라고 생각해서 긴 말은 하지 않겠으나 다른 오마카세 식당과 비교했을때  맛, 서비스 모두 가격대비 별로였습니다  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '혜딩1',
#   '5.0 ',
#   '점심',
#   '2024.04.20',
#   '앵콜스시도 챙겨주시고, 음식 전부 맛있게 잘 먹었습니다:)  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '리케인',
#   '5.0 ',
#   '점심',
#   '2024.04.16',
#   '너무 분위기도 좋고 맛고 좋았습니다. 그리고 친절한대응도 너무 좋았습니다  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '게섹이스',
#   '5.0 ',
#   '점심',
#   '2024.04.10',
#   '점심에 여자친구랑 방문했습니다. 4월까지 콜키지가 무료라서 유즈사케도 가져갔는데 조용한 분위기에서 맛있는 요리를 먹을 수 있어서 너무 좋았어요. 저는 줄무늬 전갱이와 장어가 개인적으로 제일 맛있었네요ㅎㅎ  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '신나는 맛사냥꾼_30304',
#   '5.0 ',
#   '저녁',
#   '2024.04.07',
#   '일행이 살짝 늦었음에도 너무너무 친절하게 서비스 해 주시고, 음식도 너무너무 맛있게 잘 먹어서 덕분에 행복한 시간 보냈습니다~!!^^ 감사합니다👍👍👍  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '이범미인',
#   '5.0 ',
#   '저녁',
#   '2024.04.07',
#   '맛이 좋았어요!!  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '곰돌이푸푸우',
#   '4.3 ',
#   '저녁',
#   '2024.04.06',
#   '사장님 친절하시고 음식 맛도 좋았습니다. 이정도 가격에 퀄리티가 너무 좋은걸? 싶습니다. 가격대가 합리적이라 여러명한테 대접하기에도 좋습니다. 충분히 재방문 의사 있는 곳입니다. 카카오맵에서 왜 3.8인지 이해가 안가네요.  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '발랄한 개척가_73141',
#   '5.0 ',
#   '점심',
#   '2024.04.02',
#   '입문하기 좋은 정말 맛있었던 오마카세였습니다 푸짐하게 잘 먹었습니다!  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   'Foodlex',
#   '3.0 ',
#   '저녁',
#   '2024.03.31',
#   '양은 많지만 맛은 상당히 실망 했습니다. 보통 스시우미 광화문점을 자주 애용하는데 맛 차이가 많이 나는 것 같습니다.  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '호두파이조각',
#   '4.7 ',
#   '저녁',
#   '2024.03.30',
#   '메뉴들이 색다르고 적초를 사용한 샤리가 매우 만족 스러웠습니다. 식사 중에 기호에 맞게 조리해주시는 것을 보고 다음에 기회가 되면 재방문 하고 싶네요!!  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '호락',
#   '5.0 ',
#   '점심',
#   '2024.03.30',
#   '메뉴 구성 다양하고 맛있었습니다! 덕분에 기념일 잘 보냈습니다  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '비범한 맛사냥꾼_61020',
#   '1.0 ',
#   '저녁',
#   '2024.03.29',
#   '전체적으로 짜고 달고.. 상당히 자극적임. 스시를 주면서 무슨 생선인지 설명을 해줘야하는데 그런 설명 해주지않고 물어봐야만 해줌. 맛있는 음식을 드리겠다는 느낌보다는 체인점 느낌이 강함 세상에 아무리 각박하다고 하지만 이건 아닌거같아요^^ 서비스 더 배우셔야할듯ㅋ  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '고독한 셀럽_85932',
#   '5.0 ',
#   '저녁',
#   '2024.03.26',
#   '간결하고 깔끔한 설명과 가격대비 정말 많은 구성으로 채워주셔서 양도 충분하고 퀄리티는 말할것도 없었습니다 특히 저렴한 주류라인에 놀래서 사케 추가해서 마셨네요  재방문의사 너무있고 감사했습니다!  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '호황',
#   '4.7 ',
#   '점심',
#   '2024.03.25',
#   '좋았어요!  용산마포여의도 일대 스시야 다니고 있어요!  고즈넉하고 음식도 좋았는데 조금 더 편안한 무드가 있으면 좋을것 같아요. 들어갈때 향이 좋았던 기억이 납니다.  잘 먹었어요!   ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '줄리아 정',
#   '3.8 ',
#   '저녁',
#   '2024.03.24',
#   '맛있게 잘 먹었습니다.  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '2012555248 이진경',
#   '5.0 ',
#   '저녁',
#   '2024.03.19',
#   '너무 맛있게 잘 먹었습니다ㅕㅕ  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   'Yumminmy',
#   '5.0 ',
#   '저녁',
#   '2024.03.17',
#   '샤리부터 질감이랑 간이 너무 좋았어요. 전반적으로 네타 퀄리티가 다 좋고 맛있었는데 특히 아귀간에서 비린 맛 하나도 안나고 고소한 거 보면서 새삼 또 느꼈습니다! 양도 많아서 덕분에 배부르게 만족스러운 식사 하고 갑니다 번창하세요 ~!  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '잡식성 동물',
#   '5.0 ',
#   '점심',
#   '2024.03.16',
#   '분위기 좋고 프라이빗하고 셰프님이 잘 챙겨주시고 서비스도 좋아서 또 가고 싶습니다.  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   'ADOM',
#   '3.0 ',
#   '점심',
#   '2024.03.10',
#   '밥이 짜고 구성이 다양하지 않아서 아쉬웠습니다.  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '유지미',
#   '5.0 ',
#   '저녁',
#   '2024.03.06',
#   '개성있어요 !  기념일에 배부르게 잘먹구왓습니다_<   ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '슈댕e',
#   '5.0 ',
#   '저녁',
#   '2024.03.05',
#   '처음 방문했는데 너무 맛있었고 위치도 좋아서 다음엔 부모님 모ㅛㅣ고 또 가야겠어요 감사합니당~!  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '개구진 미식가_6668',
#   '5.0 ',
#   '저녁',
#   '2024.03.05',
#   '맛있어요 친절해요  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   'shwankim',
#   '5.0 ',
#   '저녁',
#   '2024.03.04',
#   '첫 방문이었는데 다들 맛있게 만족스러운 시간이 됐어요.   ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '꿈꾸는 식객_48074',
#   '5.0 ',
#   '저녁',
#   '2024.02.28',
#   '아주아주 맛있고 셰프님이 친절해요!! 추천합니다  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '새로운 마스터_73935',
#   '4.8 ',
#   '점심',
#   '2024.02.26',
#   '아내와. 도란도란. 좋은 시간이었습니다  아내는. 많이. 배불러하고. 저는 딱. 좋았습니다  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '쾌활한 개척가_60380',
#   '4.7 ',
#   '점심',
#   '2024.02.26',
#   '평일 점심에  둘이 조용히 대화하면서 식사하고 싶어서 찾아간 곳입니다.   가격대비 맛이 훌륭했고 주차가 편해서 좋았어요 👍🏻🤍  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '3917542',
#   '4.0 ',
#   '저녁',
#   '2024.02.25',
#   '진쨔 배불렀어요 당연히 맛도 좋구요! 못먹어본 것들도 나와서 새로움도 있었습니다 ㅎㅎ 셰프님이 추천해준 사케도 존맛탱   ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   'Sh5036',
#   '5.0 ',
#   '저녁',
#   '2024.02.23',
#   '셰프님이 너무 친절하시고 음식도 맛있었어요!  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '부드러운 식객_3558',
#   '4.3 ',
#   '저녁',
#   '2024.02.23',
#   '하나하나 설명을 곁들여  먹는  초밥은 더욱 맛있다.  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   'wine_dinings__',
#   '4.5 ',
#   '저녁',
#   '2024.02.21',
#   '항상 만족하는 곳이에요 오마카세 먹으러 주기적으로 들리는 곳! 스시 간이 딱 좋아요  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '졜롱',
#   '5.0 ',
#   '점심',
#   '2024.02.20',
#   '맛있고 좋았어요.   ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '2salt',
#   '4.0 ',
#   '저녁',
#   '2024.02.20',
#   '남자친구 생일 기념으로 방문했는데 일단 주차가 편해서 좋았어요~~!! 음식들도 다 깔끔하고 좋았습니당  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '네꼬',
#   '5.0 ',
#   '점심',
#   '2024.02.19',
#   '스시도 좋았고  서비스도 과한게 아닌 적당하면서도 섬세하게 챙겨주셔서 덕분에 좋은 식사 했습니다 :)   ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   'akibl****',
#   '3.3 ',
#   '점심',
#   '2024.02.19',
#   '용산역 근처에  스시 오마카세를 찾으신다면 한번쯤 방문해 보셔도 좋을거 같습니다.  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '곰돌잉푸우',
#   '5.0 ',
#   '저녁',
#   '2024.02.19',
#   '4번째 방문 항상 맛있고 친절합니다 감사합니다.  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '입생너랑',
#   '4.0 ',
#   '점심',
#   '2024.02.17',
#   '용산역에 가깝고 편하고 친절했어요^^  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   'JH_JH_JH',
#   '4.7 ',
#   '점심',
#   '2024.02.17',
#   '어머니랑 같이 방문했는데 스시가 다양하고 맛있었어요 ! 서비스도 너무 친절했어요!  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   'LEEJUNYONG',
#   '5.0 ',
#   '저녁',
#   '2024.02.10',
#   '귿  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '새로운 셀럽_61632',
#   '5.0 ',
#   '저녁',
#   '2024.02.09',
#   '여러번 방문했지만 방문할때마다 만족하고오는 스시우미!!! 저희는 기념일이나 정말 힘든 시즌 보낸 뒤에 가는 곳인데 진짜 인생 스시오마카세입니다. 메인 셰프님이 정말 친절하게 대해주시고 개개인의 입맛에 맛게 밥양이나 간장 양 등 세심하게 조절해주시고 전반적인 코스 메뉴도 새로운 맛 알던 맛임에도 놀라운 맛 등 입이 즐거운 음식들과 스시로 알차게 배부른 한끼를 먹을 수 있습니다. 전보다 직원분들이 줄어드셨던데 메인 셰프님 오래 뵙고싶습니다. 기회가 닿을때마다 방문하겠습니다.  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   'rlawogus567',
#   '5.0 ',
#   '저녁',
#   '2024.02.08',
#   '가성비도 좋고 친절하시고 설명도 잘 해주세오!!  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '이 승재',
#   '5.0 ',
#   '저녁',
#   '2024.02.08',
#   '가성비가 좋습니다  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '풍뎅',
#   '4.0 ',
#   '저녁',
#   '2024.02.07',
#   'ㅜㅠㅠㅠ 한 두달에 한 번 씩 꼭 가는데 이번에 너무 급하게 주셨어요.... 마감 시간인건 알겠는데 조금만 속도 줄여주셨으면.....  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   'dnfma19',
#   '4.0 ',
#   '점심',
#   '2024.02.04',
#   '갈만함. 괜찮음!!  ',
#   '9,999+'],
#  ['스시우미 용산',
#   '4.5',
#   1850,
#   '다이닝바',
#   '이태원',
#   '서울특별시 용산구 한강대로 69 용산푸르지오써밋 지하 1층',
#   '점심 영업안함 · 저녁 1 - 4만원',
#   '제현_',
#   '5.0 ',
#   '저녁',
#   '2024.02.02',
#   '자리가 넓고 분위기도 편안하고 좋았습니다. 음식들도 맛있어서 데이트하기 좋아요 :)  ',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   '시소맘',
#   '2.7 ',
#   '점심',
#   '2024.07.08',
#   '저녁에 비해 점심 메뉴는 먹을 것이 별로 없고 그마저 음식들이 너무 짰음. 음식 나오는 속도도 매우 느림. 자주 방문하는데 이번에 유난히 그랬던 듯.   ',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   '짱아맘지니 ',
#   '5.0 ',
#   '점심',
#   '2024.07.08',
#   '분위기도 좋고 맛도 좋아요  ',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   '똑똑한 맛사냥꾼_96968',
#   '4.3 ',
#   '점심',
#   '2024.07.08',
#   '맛이 좋고 분위기도 좋아요 1시간 반 시간 제한 있어요  ',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   '김수린니',
#   '5.0 ',
#   '점심',
#   '2024.07.07',
#   '친구들 모임으로 예약후 방문했어요 넘 맛있어서 재방문하고 싶어요 특히 버터치킨 레몬파스타가 맛나요  ',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   '따뜻한 맛사냥꾼_33568',
#   '5.0 ',
#   '점심',
#   '2024.07.07',
#   '7명이라 룸 이용했는데, 저희 주문 받아주신 남자분 친절하시고 기억력도 좋으시고 다 좋았습니다. 특히 밥 다먹고 차 마실 때 티백디쉬 따로 주시는 센스에서 쿠촐로 인정했어여~ ㅎㅎㅎ  ',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   '경쾌한 맛사냥꾼_49572',
#   '4.0 ',
#   '점심',
#   '2024.07.07',
#   '쿠촐로 파스타 맛나기로는 유명하지만 , 오랜만에 방문했는데 여전히 맛나네요!!! 파스타 너무 좋아해서 전 메뉴 다 먹어보고 싶네요~~~   ',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   '서경김',
#   '5.0 ',
#   '저녁',
#   '2024.07.06',
#   '요리들이 다 맛있고 좋아요 가성비이거나 배부르게 먹는 느낌은 아니지만 분위기, 맛, 기분을 즐기러 가기에는 최적화된 곳  ',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+'],
#  ['쿠촐로 서울',
#   '4.5',
#   1806,
#   '다이닝바',
#   '남영',
#   '서울특별시 용산구 한강대로 100 아모레퍼시픽 2층',
#   '점심 영업안함 · 저녁 1 - 3만원',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   '9,999+']]
