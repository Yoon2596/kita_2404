# %% [markdown]
# urllib + bs
# - 정적인 데이터는 urllib 이랑 request 로 가져온다
# - 동적인 데이터는 selenium을 사용한다

# %%
url = 'https://n.news.naver.com/article/296/0000079041?cds=news_media_pc&type=editn'
html = requests.get(url)
bs = BeautifulSoup(html.text, 'html.parser')
print(bs)
# Out:
# <!DOCTYPE html>
#
# <html data-useragent="python-requests/2.32.3" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport">
# <meta content='"몸이 갑자기 거인처럼 커진다" 감각이 왜곡된다는 女, 무슨 증후군?' property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://n.news.naver.com/article/296/0000079041" property="og:url"/>
# <meta content="https://imgnews.pstatic.net/image/296/2024/06/20/0000079041_001_20240620070414202.jpg?type=w800" property="og:image"/>
# <meta content="갑자기 시간이 멈추며 주변 세상은 작아지고 내 몸은 커지는 느낌이 든다면 기분이 어떨까. 현실에서 수시로 이런 느낌을 경험하는 여성이 있다. 그는 영국 작가 루이스 캐럴(Lewis Carroll)의 유명 소설 '이상" property="og:description"/>
# <meta content="코메디닷컴 | 네이버" property="og:article:author"/>
# <meta content="summary_large_image" name="twitter:card"/>
# ...

# %%
import urllib.request as rq

url = 'https://news.naver.com/section/105'

html = rq.urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
print(bs)
# Out:
# <!DOCTYPE html>
#
# <html data-useragent="Python-urllib/3.10" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport">
# <meta content="IT/과학 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/section/105" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="모바일, 인터넷, SNS, 통신 등 IT/과학 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="IT/과학 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# ...

# %%
text1 = bs.find('p')
print(text1)
# Out:
# <p class="sa_head_layer_p">각 헤드라인의 기사와 배열 순서는 개인화를 반영해 자동 추천되어 제공됩니다. 기사 수량이 표기된 기사 우측 하단의 파란색 아이콘을 클릭하면 기사묶음을 확인할 수 있고 기사묶음과 기사묶음 타이틀도 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.</p>

# %%
text2 = bs.find_all('p')
# print(text2)
for i in text2:
    print(i.text)
# Out:
# 각 헤드라인의 기사와 배열 순서는 개인화를 반영해 자동 추천되어 제공됩니다. 기사 수량이 표기된 기사 우측 하단의 파란색 아이콘을 클릭하면 기사묶음을 확인할 수 있고 기사묶음과 기사묶음 타이틀도 기사 내용을 기반으로 자동 추출됩니다.
# AiRS 추천으로 구성된 뉴스를 제공합니다.
# 각 언론사의 가장 많이 본 기사 1건을 제공합니다.
# "외계인이 만든 듯"…돌연 사막에 솟아난 '거울기둥' 미스터리
# “자식 돈에 어디 숟가락”…박세리 논란에 소환된 손웅정
# 또 터진 불량 공모주 사태…이노그리드, 사상 첫 상장승인 취소
# [속보] 북러 조약문 "전쟁상태 처하면 지체없이 군사 원조 제공"
# "짝까지 바꿔가며"..고급중학교 학생 6명, 목욕탕 빌려 집단 성관계, 북한 사회 '발칵'
# 박세리 부친 입 열었다…“내가 아빠니까 나설 수 있지”
# 조국 "이재명, 대통령 되면 재판정지? 한동훈 헌법해석 엉터리"
# 박세리 부친 입 열었다…"내가 아버지니까 나설 수 있지"
# "1억 주면 조용히 있고, 5천 주면 소문내고" 연돈볼카츠 점주들 녹취록 공개
# 北 남녀 고교생 6명, 목욕탕 빌려 집단 성관계에 마약까지
# "특이한 안경" 끼고 대화하는 경찰관 바라본 여성…알고 보니
# “목욕탕서 집단 성관계·마약을”…北청소년들 ‘남녀칠세부동석’ 발칵
# 가슴 큰 여성 vs 작은 여성… 누가 땀 더 많이 흘릴까?
# [단독] 에코프로비엠, 3조원대 투자 유치 추진… FI 물밑 접촉
# 에코+페미, 우리 지금 만나
# '김건희 논문 검증' 학생들 몰표‥'숙대'의 선택은
# 슬기로운 에어컨 사용법? "구형 2시간마다 OFF·신형 연속운전"
# "유명 식당서 훠궈 먹자 혀 까매져"..中, 끝없는 식품위생 논란
# 황우여 "노인 1천만명 시대…80∼90대 비례대표 고려돼야"
# "100조 초대형 에너지 기업 출현"…장중 15% 급등
# “시청률 0%, 터질게 터졌다” 넷플릭스발 초유의 사태 ‘발칵’
# “비상 깜빡이 켰는데”…고속도로서 후진한 여성의 최후 [잇슈 키워드]
# ...

# %%
bs.find('p', class_='sa_head_layer_p')
# Out:
# <p class="sa_head_layer_p">각 헤드라인의 기사와 배열 순서는 개인화를 반영해 자동 추천되어 제공됩니다. 기사 수량이 표기된 기사 우측 하단의 파란색 아이콘을 클릭하면 기사묶음을 확인할 수 있고 기사묶음과 기사묶음 타이틀도 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.</p>

# %%
print(bs.find('title'))
# Out:
# <title>IT/과학 : 네이버 뉴스</title>

# %%
print(bs.find('title').string)
# Out:
# IT/과학 : 네이버 뉴스

# %%
text3 = bs.find('p').get_text()
print(text3)
# Out:
# 각 헤드라인의 기사와 배열 순서는 개인화를 반영해 자동 추천되어 제공됩니다. 기사 수량이 표기된 기사 우측 하단의 파란색 아이콘을 클릭하면 기사묶음을 확인할 수 있고 기사묶음과 기사묶음 타이틀도 기사 내용을 기반으로 자동 추출됩니다.

# %% [markdown]
# requests + bs

# %% [markdown]
# 인코딩 에러를 해결
# - chardet는 "Universal Character Encoding Detector"로, 다양한 인코딩을 감지할 수 있는 파이썬 패키지
# - chardet.detect(response.content)['encoding']은 response.content의 인코딩 방식을 자동으로 감지하여 반환하며
#  이 값을 encoding 변수에 저장한 후, response.content를 이 encoding 방식으로 디코딩하여 html 변수에 저장하고 출력

# %% [markdown]
# pip install chardet

# %%
import requests
import chardet

# HTTP 요청에서 사용될 헤더 정보를 설정합니다
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}

# 웹사이트에서 스크래핑 할 URL을 지정합니다
url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'

# 지정된 URL에서 HTTP GET 요청을 전달
response = requests.get(url, headers=headers)

# HTTP 요청이 성공적으로 전달되었다면, 웹사이트의 HTTP 코드를 출력합니다
print(response, '\n')
if response.status_code == 200:
    encoding = chardet.detect(response.content)['encoding']
    print(response.text)    # 웹사이트의 HTTP 코드를 문자열 형태로 전환
else:
    print('HTTP request failed')
# Out:
# <Response [200]>
#
# <!doctype html>
# <html lang="ko" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36">
# 	<head>
# 		<meta charset="utf-8">
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 		<meta name="referrer" contents="always">
# 		<meta http-equiv="refresh" content="600">
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />
# 		<meta property="og:title" content="정치 : 네이버 뉴스">
# 		<meta property="og:type" content="website">
# 		<meta property="og:url" content="https://news.naver.com/section/100">
# 		<meta property="og:image" content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">
# 		<meta property="og:description" content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공">
# 		<meta property="og:article:author" content="네이버">
# 		<meta name="twitter:card" content="summary">
# ...

# %%
# 한글만 출력
import re
texts = response.text
result = re.findall('[가-힣]+', texts)
print(' '.join(result))
# Out:
# 정치 네이버 뉴스 국회 행정 국방 외교 등 정치 분야 뉴스 제공 네이버 정치 네이버 뉴스 네이버 뉴스 네이버 뉴스 국회 행정 국방 외교 등 정치 분야 뉴스 제공 정치 네이버 뉴스 로그 전송 최대치 도달 본문 바로가기 뉴스 연예 스포츠 날씨 프리미엄 검색 언론사별 정치 경제 사회 생활 문화 과학 세계 랭킹 신문보기 오피니언 팩트체크 알고리즘 안내 정정보도 모음 목 전체 언론사 뉴스스탠드 라이브러리 정치 대통령실 국회 정당 북한 행정 국방 외교 정치일반 뉴스 알고리즘 프리미엄콘텐츠 헤드라인 뉴스 안내 각 헤드라인의 기사와 배열 순서는 개인화를 반영해 자동 추천되어 제공됩니다 기사 수량이 표기된 기사 우측 하단의 파란색 아이콘을 클릭하면 기사묶음을 확인할 수 있고 기사묶음과 기사묶음 타이틀도 기사 내용을 기반으로 자동 추출 됩니다 알고리즘 자세히 보기 닫기 성일종 이재명에 돌직구 내 편이면 공정언론 네 편이면 편파언론 인가 성일종 이재명에 돌직구 내 편이면 공정언론 네 편이면 편파언론 인가 성일종 국민의힘 사무총장이 최근 언론 애완견 발언으로 논란에 휩싸인 이재명 더불어민주당 대표를 겨냥해 내 편이면 공정언론 네 편이면 편파언론 세상 참으로 쉽게 사시는 분 이라며 언론을 검찰의 애완견으로 디지털타임스 개의 관련뉴스 더보기 러 위험한 밀착 침략 당하면 상호 지원 러 위험한 밀착 침략 당하면 상호 지원 북한과 러시아가 옛 소련 시절에 있던 자동군사개입 조항을 사실상 복원시켰다 양국이 침략당할 경우 서로 군사적 지원을 해주는 내용이다 우리 정부가 러시아를 상대로 설정한 레드라인 을 넘어선 것으로 평가된다 한국경제 개의 관련뉴스 더보기 자주포 루마니아 수출 나토국 모두 도입 양낙규의 자주포 루마니아 수출 나토국 모두 도입 양낙규의 한국산 자주포가 루마니아에 수출된다 루마니아가 국내 무기체계를 수입한 첫 사례가 됐다 일 국방부에 따르면 안젤 틀버르 루마니아 국방부 장관은 일 오전 이하 현지시간 루마니아를 방문 중인 신원식 국 아시아경제 개의 관련뉴스 더보기 속보 원희룡 
# ...

# %%
# 영화에서 제목 가져오기
from bs4 import BeautifulSoup
import requests
import re

# HTTP 요청에서 사용될 헤더 정보를 설정합니다
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}

url = "https://serieson.naver.com/v3/movie/ranking/realtime"

response = requests.get(url, headers=headers)

if response.status_code == 200:

    soup = BeautifulSoup(response.content, 'html.parser')
else:
    print('response failed')

find_1st = soup.find('span', class_='Title_title__s9o0D')
# print(find_1st)

text = find_1st.text
print(text)

# all_tag = re.findall(r'>([^<]+)<', html)

# result = re.findall(r'[^<]+(', text)
# print(result)
# Out:
# 인사이드 아웃(패키지상품 : 더빙판 + 부가영상 추가증정)

# %%
# 영화 탑텐을 뽑기
top_ten = soup.find_all('span', class_='Title_title__s9o0D')
# print(top_ten)

# for idx, t in enumerate(top_ten):
#     print(f'{idx+1}위: {t.text}')
#     if idx == 9:
#         break

# for idx, t in enumerate(top_ten[:10]):
#     print(f'{idx+1}위: {t.text}')

    # 정규표현식 패턴 설정
pattern = re.compile(r'^[^\(]+')

# 영화 제목 추출 및 정규표현식 적용
for idx, t in enumerate(top_ten[:10]):
#     raw_text = t.text
    match = pattern.match(t.text)
    if match:
        title = match.group().strip()
        print(f'{idx+1}위: {title}')
# Out:
# 1위: 인사이드 아웃
# 2위: 소울메이트
# 3위: 원더
# 4위: 설계자
# 5위: 외계+인 2부
# 6위: 너의 이름은.
# 7위: 매드맥스: 분노의 도로
# 8위: 빌리 엘리어트
# 9위: 콩나물
# 10위: 악마와의 토크쇼

# %% [markdown]
# ### CSS 선택자
# - 원하는 정보만 선별하여 수집하고 싶을 때 css선택자를 활용할 수 있음
# - (CSS 선택자 설명 추가)
# - F12 >> 수집하고 싶은 부분 클릭 >> 태그 선택 >> copy Selector
# - BeautifulSoup의 select_one, select 활용
#
# 개발자 도구장에서 .class로 확인한 정치기사 개수는 58개인 반면에 select('.class')로 크롤링한 기사 개수는 38개인 이유
# - 많은 사이트는 JavaScript를 사용하여 콘텐츠를 동적으로 로딩하는 반면, requests + BeautifulSoup은 기본적으로 JavaScript를 실행하지 않기 때문에 일부 js로 로딩되는 콘텐츠는 크롤링 되지 않는다
# - 페이지가 완전히 로드되기 전에 크롤링이 시도 될 경우 일부 콘텐츠가 누락 될 수 있다
# - 웹페이지가 비동기 요청(Ajax)를 사용하여 데이터를 가져오는 경우 이 요청을 수동으로 처리하지 않는 한 해당 데이터를 가져오지 못할 수 있다

# %%
from bs4 import BeautifulSoup
import requests as rq
import re
import pandas as pd

# HTTP 요청에서 사용될 헤더 정보를 설정합니다
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}

url = 'https://news.daum.net/politics#1'
r = rq.get(url, headers=headers)
html = r.text
soup = BeautifulSoup(html, 'html.parser')

lines = soup.select('a.link_txt')

# 데이터 프래임으로 변환하여 출력
articles = [line.text.strip() for line in lines]
df = pd.DataFrame({'Articles': articles})
df

# 뉴머레이터로 출력
# body = '\n'.join(f'{i+1}, {line.text}' for i, line in enumerate(lines))
# print(body)
# Out:
#                                              Articles
# 0           민주당 “팔수록 석유 대신 ‘카르텔’ 의혹···동해 바다가 동문회 장소냐”
# 1                      행복청, 삼성이노베이션뮤지엄 등 찾아 1박2일 벤치마킹
# 2       “회의 전날 김건희 안건 긴급 추가 제보”···야3당, ‘건희권익위’ 대응 간담회
# 3                   이준석, '반값 선거법' 발의…"5%만 득표해도 절반 보전"
# 4                       원희룡, 당 대표 출마선언…'한·나·원' 3파전 예고
# 5                    육군 학사·간부사관 438명 임관…독립후손가 후손 등 눈길
# 6              정부 고위 관계자, 북러 조약에 "세상에 없을 시나리오에 대한 약속"
# 7                            광양시의회 후반기 의장 선거 '복당파' 변수
# 8                       [프로필] 김완기 특허청장…무역·통상 전문 정통 관료
# 9            [단독] 이스라엘, 레바논 공격 승인 후폭풍...동명부대 외부활동 금지령
# 10   [단독] 입 연 권익위 “여사께 300만원 엿 선물? 직무 연관성 없으면 줘도 됩니다”
# 11                            구리고 '자율형 공립고 2.0' 전환 추진
# 12           이준석, ‘밥값선거법’ 1호 법안 발의 예고…“공정한 선거환경 만들어야”
# 13                 유시민, 패소 확정 후 한동훈 언급… "그래, 네 팔뚝 굵다"
# 14                    이준석 "원희룡 당대표 출마… 대통령과 상의 있었을 것"
# 15     강민구 "민주당의 아버지는 이재명"···국민의힘 "북한 조선중앙통신에서나 들을 말"
# ...

# %%
from bs4 import BeautifulSoup
import requests as rq
import re
import pandas as pd

# HTTP 요청에서 사용될 헤더 정보를 설정합니다
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}

url = 'https://news.daum.net/politics#1'
r = rq.get(url, headers=headers)
html = r.text
soup = BeautifulSoup(html, 'html.parser')

# body > div.container-doc.cont-category > main > section > div.main-sub > div:nth-child(1) > ul > li:nth-child(1) > div > div > strong > a
# lines = soup.select('body > div > main > section > div > div > ul > li > div > div > strong > a')
titles = soup.select('body > div > main > section > div > div > ul > li > div > div > strong > a')

# articles = [line.text.strip() for line in lines]
# df = pd.DataFrame({'Articles': articles})
# df
# body = '\n'.join(f'{i+1}, {line.text}' for i, line in enumerate(lines))
# print(body)
for i, title in enumerate(titles, start=1):
    print(f'{i}. {title.get_text().strip()}')
# Out:
# 1. 환경부·병무청·농촌진흥청, 2023년 성과관리·자체평가 우수기관 선정
# 2. 이태원 참사 특조위원 시한 내 임명 결국 무산‥여당 몫 추천 아직
# 3. 윤상현, 與대표 경선 출마선언…"대통령에게 할 말 하는 사람"
# 4. 해병 특검법 법안소위 통과…여, 하루에 3명 전대 출사표
# 5. 윤상현 "수도권 승리 견인차…총선 패배한 사람 자숙의 시간 가져야"
# 6. 대구시, 환경단체 'SMR 사업 중단' 요구에 "무책임한 선동"
# 7. 野, 채상병특검 청문회 불출석 증인 ‘무더기 고발’ 예고…“신원식·김계환만 사유서 제출”
# 8. 나경원 "근본 깨는 이재명, 대한민국 비명횡사..무조건 막아야, 곧 결심"
# 9. 박원석 "원희룡 출마? 용산 참전신호"...김근식 "결선투표 노린 듯"
# 10. 나경원 “당 대표는 대통령과의 갈등이 겉으로 드러나면 안 돼…차별화해 대권 가겠다는 건 미래 없어”
# 11. 최진녕 변호사 / 서용주 전 더불어민주당 상근부대변인 - 원 구성 놓고 여야 입장 차…대치 정국 심화
# 12. ③중산층까지 악영향? 금투세 쟁점과 필요한 결정은?
# 13. 위계충 권폭귀
# 14. 1년 전 나경원 막은 친윤, 이번엔 한동훈 대항마로 키운다?
# 15. “김경율 누가 데려왔나”… 與, 한동훈 둘러싸고 뜬금없는 공방

# %%
from bs4 import BeautifulSoup
import requests as rq
import re
import pandas as pd

# HTTP 요청에서 사용될 헤더 정보를 설정합니다
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}

url = 'https://news.daum.net/politics#1'
r = rq.get(url, headers=headers)
html = r.text
soup = BeautifulSoup(html, 'html.parser')

lines = soup.select('body > div > main > section > div > div > ul > li > div > div > strong > a')

# 한글로만 가져올때
for i, tag in enumerate(lines, start=1):
    text = tag.get_text().strip().replace(',', '')
    matches = re.findall('[가-힣0-9]+', text)
    print(f'{i}. {" ".join(matches)}')
# Out:
# 1. 환경부 병무청 농촌진흥청 2023년 성과관리 자체평가 우수기관 선정
# 2. 이태원 참사 특조위원 시한 내 임명 결국 무산 여당 몫 추천 아직
# 3. 윤상현 대표 경선 출마선언 대통령에게 할 말 하는 사람
# 4. 해병 특검법 법안소위 통과 여 하루에 3명 전대 출사표
# 5. 윤상현 수도권 승리 견인차 총선 패배한 사람 자숙의 시간 가져야
# 6. 대구시 환경단체 사업 중단 요구에 무책임한 선동
# 7. 채상병특검 청문회 불출석 증인 무더기 고발 예고 신원식 김계환만 사유서 제출
# 8. 나경원 근본 깨는 이재명 대한민국 비명횡사 무조건 막아야 곧 결심
# 9. 박원석 원희룡 출마 용산 참전신호 김근식 결선투표 노린 듯
# 10. 나경원 당 대표는 대통령과의 갈등이 겉으로 드러나면 안 돼 차별화해 대권 가겠다는 건 미래 없어
# 11. 최진녕 변호사 서용주 전 더불어민주당 상근부대변인 원 구성 놓고 여야 입장 차 대치 정국 심화
# 12. 중산층까지 악영향 금투세 쟁점과 필요한 결정은
# 13. 위계충 권폭귀
# 14. 1년 전 나경원 막은 친윤 이번엔 한동훈 대항마로 키운다
# 15. 김경율 누가 데려왔나 한동훈 둘러싸고 뜬금없는 공방

# %%
from datetime import datetime
import os

query = input('검색 키워드를 입력하세요 : ')
query = query.replace(' ', '+')
print(query)

news_url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query={}'

# format(query) 메서드는 URL 템플릿의 {} 부분을 query로 대체
req = requests.get(news_url.format(query))

html = req.text
soup = BeautifulSoup(html, 'html.parser')
links = soup.select('.news_tit')

for link in links:
    title = link.text
    urls = link.attrs['href']
    print(title, '\n', urls)
# Out:
# 인공지능
# AI의 일자리 습격…"은행업 54% 자동화 전망"
#  https://view.asiae.co.kr/article/2024062004370354312
# 한컴-한전, 인공지능·데이터 분야 협력
#  https://www.newsis.com/view/NISX20240620_0002779950
# [그래픽] 생성형 인공지능(AI) 이용 조사 결과
#  https://www.yna.co.kr/view/GYH20240620000300044?input=1363m
# '인공지능과의 동행'…ETRI 컨퍼런스 2024 오는 26일 개막
#  https://www.news1.kr/articles/5453714
# 생성형 인공지능 이용 경험 10명 중 1명 꼴
#  https://www.hani.co.kr/arti/society/media/1145694.html
# [월드 핫피플] 인공지능(AI) 왕의 귀환 “안전한 초지능 만들겠다”
#  https://www.seoul.co.kr/news/plan/2024/06/20/20240620500110?wlog_tag3=naver
# 세계 통신사 인공지능 협력 본격화
#  https://www.naeil.com/news/read/514064?ref=naver
# 인공지능이 차량 높이 식별해 지하도로 끼임 사고 막는다
#  https://news.heraldcorp.com/view.php?ud=20240620050109
# KT&G, 인공지능 활용해 디자인한 '레종 데트르' 한정판 선봬
#  http://www.edaily.co.kr/news/newspath.asp?newsid=02296006638923688
# 인공지능 탑재된 냉장고
#  https://www.news1.kr/photos/view/?6715440

# %% [markdown]
# news_url.format(query): URL 문자열 내의 특정 부분을 query 변수의 값으로 대체
# - news_url 변수에는 포맷 문자열 'https://news.example.com/search?query={}'가 저장
# - news_url.format(query)는 포맷 문자열의 {} 부분을 query 변수의 값으로 대체
# - 결과적으로, 포맷팅된 URL은 'https://news.example.com/search?query=politics'가 된다.
