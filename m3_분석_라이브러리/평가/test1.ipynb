# %%
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, WebDriverException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
from time import sleep
import pandas as pd
import os

# %%
# 페이지 로드
url = 'https://app.catchtable.co.kr/'

numnumnum =0
id = '01076300106'
pw = '=Cherrycow910'


# name = item.select_one("h4.name").text.strip() if item.select_one("h4.name") else 'NA'
# category = item.select_one("span.tags").text.strip().split(' • ')[0] if item.select_one("span.tags") else 'NA'
# rating = item.select_one("span._1xnbt316._1ltqxco1d").text.strip() if item.select_one("span._1xnbt316._1ltqxco1d") else 'NA'
# review_num1 = item.select_one("span._1xnbt317._1ltqxco1g").text.strip().replace('(','').replace(')','').replace(',','') if item.select_one("span._1xnbt317._1ltqxco1g") else 'NA'
# description = item.select_one("p.excerpt").text.strip() if item.select_one("p.excerpt") else 'NA'
# price_range = item.select_one("span.price").text.strip() if item.select_one("span.price") else 'NA'
# review_num = int(review_num1)




driver = webdriver.Chrome()
driver.get(url)
time.sleep(5)

data = []

script = "document.querySelectorAll('#dock > div > nav > a:nth-child(5)').forEach(a => a.click())"
driver.execute_script(script)           
script = "document.querySelectorAll('._1qn1ik44._1ltqxco1e').forEach(a => a.click())"
driver.execute_script(script)
time.sleep(2)
script = "document.querySelectorAll('#main > section > div.__inner > div > div > div._1w07br45 > button:nth-child(3)').forEach(a => a.click())"
driver.execute_script(script)

# time.sleep(1)
# driver.execute_script("document.getElementById('login-id').value=\'" + id + "\'")
# time.sleep(1)
# driver.execute_script("document.getElementById('login-pw').value=\'" + pw + "\'")
# time.sleep(1)

time.sleep(8)
script = "document.querySelectorAll('.btn.btn-lg.btn-red.full-width').forEach(a => a.click())"
driver.execute_script(script)
time.sleep(5)

# 여기부터 다시 팝업 닫아야 됨
script = "document.querySelectorAll('._1qn1ik44._1ltqxco1e').forEach(a => a.click())"
driver.execute_script(script)
time.sleep(4)
#main > section:nth-child(6) > div > div.section-body > div > div > div > a.icon
# 내 주변 들어가기
script = "document.querySelectorAll('#main > section:nth-child(6) > div > div.section-body > div > div > div > a.icon').forEach(a => a.click())"
driver.execute_script(script)
time.sleep(3)

# 필터 클릭
script = "document.querySelectorAll('#main > div.search-header.__autohide > div:nth-child(2) > div > div.speb4g1 > button').forEach(a => a.click())"
driver.execute_script(script)
time.sleep(15)

# 필터 내 서울을 카테고리 클릭
# 서울에서 강남, 마포, 용산, 성동 클릭 후 밑에 결과 보기 클릭


# 서울 매장 수
m_num = driver.page_source
soup = BeautifulSoup(m_num, 'html.parser')
it = soup.select_one('#search-result-header > div._54rkq62 > strong').text
num = int(it.replace(',','').replace('개',''))
idx = 0
region_num = 0



while idx < num:
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    items = soup.select('.restaurant-info')

    for item in items:
        if item is not None:


            try:
                driver.find_element(By.CSS_SELECTOR, f'#virtual_{region_num} > div > div > div > div').click()
                time.sleep(3)

                # 광고창 뜨면 닫는 자바스크립트
                script = "document.querySelectorAll('._1ltqxco1b._10fm75h11').forEach(a => a.click())"
                driver.execute_script(script)

                # 다시 정보 확인
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')

                script = "document.querySelectorAll('##main > section.section.pt-30.pb-20 > div > div > a > strong').forEach(a => a.click())"
                # driver.find_element(By.CSS_SELECTOR, f'').click()
                # review_list = {}
                # review_infos = soup.find_all('div', class_='review_text')
                # if review_infos:
                #     for i, review_info in enumerate(review_infos):
                #         review_text = review_info.get_text(strip=True)
                #         review_list[i] = review_text
                #     review_descrip.append(review_list)
                # # items = soup.select_one('.section-body')
                # script = "document.querySelectorAll('._4qv338d.location').forEach(a => a.click())"
                # driver.execute_script(script)
                # time.sleep(1)
                # script = "document.querySelectorAll('.z8ddia').forEach(a => a.click())"
                # driver.execute_script(script)
                # html = driver.page_source
                # soup = BeautifulSoup(html, 'html.parser')
                # region = soup.select_one('.addr').text.replace('복사','')
                # time.sleep(3)
                # driver.back()
                # time.sleep(3)
                
                # 리뷰 들어가기
                # script = "document.querySelectorAll('._4qv338e').forEach(a => a.click())"
                # driver.execute_script(script)
                # time.sleep(2)
                

                # if numnumnum == 0:      # 1번만 실행하면 됨
                #     # 리뷰 카테고리 클릭
                #     script = "document.querySelectorAll('.btn-sort').forEach(a => a.click())"
                #     driver.execute_script(script)
                #     time.sleep(2)

                #     # 리뷰 최신순 클릭
                #     script = "document.querySelectorAll('._7cdeui0').forEach(a => a.click())"
                #     driver.execute_script(script)
                #     time.sleep(5)
                #     numnumnum +=1
                
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                time.sleep(5)
                
            #     for i in range(20):
            #         try :
            #             driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            #         except StaleElementReferenceException:
            #             print("요소를 다시 찾습니다.")
            #             driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            #         time.sleep(3)

            #         review = soup.select_one(f'#shopReviewListScroll_{i} > div > article > div.__body').text
            #         data.append([name, region, review,category, rating, review_num, description, price_range])

            #     driver.back()
            #     time.sleep(2)
            #     driver.back()
            #     time.sleep(2)
            # except Exception as e:
            #     print("요소를 클릭할 수 없습니다:", e)

            
            # print(review)
        else:
            data.append(['NA', 'NA', 'NA', 'NA', 'NA', 'NA','NA','NA'])

        region_num += 1
    
    # 모달 창 내부를 스크롤
    try:
        modal_scroll_element = driver.find_element(By.CSS_SELECTOR, '#root > div > div > div > div._53lcbm0._53lcbm1 > div')
        driver.execute_script('arguments[0].scrollTop += 100', modal_scroll_element)
    except StaleElementReferenceException:
        print("요소를 다시 찾습니다.")
        modal_scroll_element = driver.find_element(By.CSS_SELECTOR, '#root > div > div > div > div._53lcbm0._53lcbm1 > div')
        driver.execute_script('arguments[0].scrollTop += 100', modal_scroll_element)

    time.sleep(3)  # 페이지가 로드될 시간을 줍니다

    idx += len(items)

driver.quit()

# 데이터 출력
for entry in data:
    print(entry)
# Out:
# 요소를 클릭할 수 없습니다: 'NoneType' object has no attribute 'text'
# 남자친구와 1주년이라 다녀왔어요! 양갈비는 고기가 너무 부드럽고 까르보나라도 소스가 너무 맛있어서 싹싹 긁어먹었네요..ㅎㅎ 창가뷰로 예약했는데 선선하게 바람 불어서 기분 좋게 식사했네요ㅎㅎ    10MORE
# 요소를 클릭할 수 없습니다: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#virtual_1 > div > div > div > div"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6AB3EEEA2+31554]
# 	(No symbol) [0x00007FF6AB367ED9]
# 	(No symbol) [0x00007FF6AB22872A]
# 	(No symbol) [0x00007FF6AB278434]
# 	(No symbol) [0x00007FF6AB27853C]
# 	(No symbol) [0x00007FF6AB2BF6A7]
# 	(No symbol) [0x00007FF6AB29D06F]
# 	(No symbol) [0x00007FF6AB2BC977]
# 	(No symbol) [0x00007FF6AB29CDD3]
# 	(No symbol) [0x00007FF6AB26A33B]
# 	(No symbol) [0x00007FF6AB26AED1]
# 	GetHandleVerifier [0x00007FF6AB6F8B1D+3217341]
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup

# 초기 설정 및 URL 열기
url = 'https://app.catchtable.co.kr/'
id = '01076300106'
pw = '=Cherrycow910'

driver = webdriver.Chrome()
driver.get(url)
time.sleep(5)

# 팝업 정리
script = "document.querySelectorAll('#dock > div > nav > a:nth-child(5)').forEach(a => a.click())"
driver.execute_script(script)           
script = "document.querySelectorAll('._1qn1ik44._1ltqxco1e').forEach(a => a.click())"
driver.execute_script(script)
time.sleep(2)
script = "document.querySelectorAll('#main > section > div.__inner > div > div > div._1w07br45 > button:nth-child(3)').forEach(a => a.click())"
driver.execute_script(script)

# 로그인 절차
# ID와 PW 입력
driver.execute_script("document.getElementById('login-id')")
time.sleep(1)
driver.find_element(By.ID, 'login-id').send_keys(id)
time.sleep(2)
driver.execute_script("document.getElementById('login-pw')")
time.sleep(1)
driver.find_element(By.ID, 'login-pw').send_keys(pw)
time.sleep(2)

# 로그인 버튼 클릭
driver.find_element(By.CSS_SELECTOR, '#main > div > button').click()
time.sleep(2)

# 로그인 후 팝업 닫기
driver.find_element(By.CSS_SELECTOR, '._1qn1ik44._1ltqxco1e').click()
time.sleep(4)

# 내 주변 들어가기
driver.find_element(By.CSS_SELECTOR, '#main > section:nth-child(6) > div > div.section-body > div > div > div > a.icon').click()
time.sleep(3)

# 필터 클릭
driver.find_element(By.CSS_SELECTOR, '#main > div.search-header.__autohide > div:nth-child(2) > div > div.speb4g1 > button').click()
time.sleep(3)

# 서울에서 특정 지역 (예: 강남) 필터링
# 적절한 셀렉터는 페이지 구조에 따라 다를 수 있으므로 확인이 필요합니다.
# 예시: 서울 클릭 후 강남 클릭
# driver.find_element(By.CSS_SELECTOR, ".fldt7j1 #overlay > div.BottomSheet_bottomSheetContent__1tetrf80.BottomSheet_bottomSheetContent_hasMaxWidth_true__1tetrf81 > div > main > div:nth-child(1) > section > div.fldt7j0 > div.fldt7j1 > button.RoundButton_container__jgry590.app_typo_subtitle_sub3__jg3o1w1c.RoundButton_container_isFocused_true__jgry591").click()
# time.sleep(1)
# driver.find_element(By.CSS_SELECTOR, "#overlay > div.BottomSheet_bottomSheetContent__1tetrf80.BottomSheet_bottomSheetContent_hasMaxWidth_true__1tetrf81 > div > main > div:nth-child(1) > section > div.fldt7j0 > div.fldt7j2 > button:nth-child(2)").click()
# time.sleep(1)
driver.find_element(By.CSS_SELECTOR, '.fldt7j1 > button:nth-child(2)').click()
time.sleep(1)
driver.find_element(By.CSS_SELECTOR, '#overlay > div.BottomSheet_bottomSheetContent__1tetrf80.BottomSheet_bottomSheetContent_hasMaxWidth_true__1tetrf81 > div > main > div:nth-child(1) > section > div.fldt7j0 > div.fldt7j2 > button:nth-child(2)').click()
time.sleep(1)

# 결과 보기 클릭
driver.find_element(By.CSS_SELECTOR, '#overlay > div.BottomSheet_bottomSheetContent__1tetrf80.BottomSheet_bottomSheetContent_hasMaxWidth_true__1tetrf81 > div > footer > div.j4ixu30 > div > button').click()
time.sleep(5)

# 서울 매장 수 확인
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
it = soup.select_one('#search-result-header > div._54rkq62 > strong').text
num = int(it.replace(',', '').replace('개', ''))
idx = 0
region_num = 0

while idx < num:
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    items = soup.select('.restaurant-info')

    for item in items:
        if item is not None:
            try:
                driver.find_element(By.CSS_SELECTOR, f'#virtual_{region_num} > div > div > div > div').click()
                time.sleep(3)

                # 광고창 뜨면 닫는 자바스크립트
                script = "document.querySelectorAll('._1ltqxco1b._10fm75h11').forEach(a => a.click())"
                driver.execute_script(script)

                # 다시 정보 확인
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')

                # 전체리뷰 클릭 (적절한 셀렉터로 대체 필요)
                driver.find_element(By.CSS_SELECTOR, 'selector_for_all_reviews').click()
                time.sleep(5)
                
                # 이후의 추가 작업 수행...

            except Exception as e:
                print(f"Error: {e}")
                continue
        idx += 1

# 작업 완료 후 드라이버 닫기
driver.quit()
# Out:
# Error: Message: no such element: Unable to locate element: {"method":"css selector","selector":"selector_for_all_reviews"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6AB3EEEA2+31554]
# 	(No symbol) [0x00007FF6AB367ED9]
# 	(No symbol) [0x00007FF6AB22872A]
# 	(No symbol) [0x00007FF6AB278434]
# 	(No symbol) [0x00007FF6AB27853C]
# 	(No symbol) [0x00007FF6AB2BF6A7]
# 	(No symbol) [0x00007FF6AB29D06F]
# 	(No symbol) [0x00007FF6AB2BC977]
# 	(No symbol) [0x00007FF6AB29CDD3]
# 	(No symbol) [0x00007FF6AB26A33B]
# 	(No symbol) [0x00007FF6AB26AED1]
# 	GetHandleVerifier [0x00007FF6AB6F8B1D+3217341]
# 	GetHandleVerifier [0x00007FF6AB745AE3+3532675]
# 	GetHandleVerifier [0x00007FF6AB73B0E0+3489152]
# 	GetHandleVerifier [0x00007FF6AB49E776+750614]
# 	(No symbol) [0x00007FF6AB37375F]
# ...
