# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup

# 페이지 로드
url = 'https://app.catchtable.co.kr/ct/map/COMMON?showTabs=true&serviceType=DINING&isInitSearch=0&bottomSheetHeightType=FULL_LIST&isShowListLabelExpanded=1&zoomLevel=10&isNewSearchInMap=1&isShowMapSearchButton=0&centerBoundsLat=37.2155077987807&centerBoundsLng=126.98855338048534&location=CAT011_CAT011001_CAT011002_CAT011003_CAT011004_CAT011005_CAT011006_CAT011007_CAT011008_CAT011009_CAT011010_CAT011_CAT011001_CAT011002_CAT011003_CAT011004_CAT011005_CAT011006_CAT011007_CAT011008_CAT011009_CAT011010&isSearchedInMap=0&uniqueListId=1719297751495&sortMethod=price_level_asc'
driver = webdriver.Chrome()
driver.get(url)
time.sleep(5)

data = []

# 모달 창의 스크롤 가능한 영역을 선택
modal_scroll_element = driver.find_element(By.CSS_SELECTOR, '#root > div > div > div > div._53lcbm0._53lcbm1 > div')  # 모달 스크롤 영역의 클래스 이름을 지정합니다.

# 스크롤하여 모든 데이터를 가져오기
while True:
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    items = soup.select('.restaurant-info')

    if not items:
        break  # 더 이상 항목이 없으면 루프 종료

    for item in items:
        if item is not None:
            name = item.select_one("h4.name").text.strip() if item.select_one("h4.name") else 'NA'
            cat_loc = item.select_one("span.tags").text.strip() if item.select_one("span.tags") else 'NA'
            rating = item.select_one("span._1xnbt316._1ltqxco1d").text.strip() if item.select_one("span._1xnbt316._1ltqxco1d") else 'NA'
            review = item.select_one("span._1xnbt317._1ltqxco1g").text.strip() if item.select_one("span._1xnbt317._1ltqxco1g") else 'NA'
            description = item.select_one("p.excerpt").text.strip() if item.select_one("p.excerpt") else 'NA'
            price_range = item.select_one("span.price").text.strip() if item.select_one("span.price") else 'NA'
            data.append([name, cat_loc, rating, review, description, price_range])
            print(name, cat_loc, rating, review, description, price_range)
        else:
            data.append(['NA', 'NA', 'NA', 'NA', 'NA', 'NA'])

    # 모달 창 내부를 스크롤
    driver.execute_script('arguments[0].scrollTop = arguments[0].scrollHeight', modal_scroll_element)
    time.sleep(2)  # 페이지가 로드될 시간을 줍니다

driver.quit()

# 데이터 출력 (예시)
for entry in data:
    print(entry)
# Out:
# 옳음 OLH EUM 한식 • 청담 4.3 (617) 시즌별 테마로 구성되는 서호영 셰프의 모던 한식 다이닝 점심 가격변동 · 저녁 가격변동
# 바로크 칵테일,위스키 • 한남 4.9 (46) 하나뿐인 나만의 칵테일을 맛볼 수 있는 스피키지바 점심 영업안함 · 저녁 가격변동
# 권숙수 한식 • 청담 4.7 (920) 직접 담근 장, 김치, 식초, 장아찌로 전국에 진귀한 식재료를 이용하여 이 시대에 맞는 한국요리를 선보이는 권우중 셰프의 파인 다이닝 점심 가격변동 · 저녁 가격변동
# 퀴진 라끌레 프랑스음식 • 서촌 4.7 (399) 국내 최초 캐나다 퀘벡식 프렌치 레스토랑 점심 1 - 4만원 · 저녁 가격변동
# 이다 IDA 한식 • 종로 4.6 (1,530) 한식 재료를 이용한 창의적인 요리를 선보이는 컨템포러리 레스토랑 점심 가격변동 · 저녁 가격변동
# 육다시구 와인 • 신사 4.7 (178) 프라이빗 룸이 있는 신사역 분위기 좋은 와인바 점심 가격변동 · 저녁 가격변동
# 배수사 이자카야 • 익선 4.4 (141) 앤틱한 분위기가 돋보이는 익선동 이자카야 점심 가격변동 · 저녁 가격변동
# 신라스테이 광화문 Cafe 뷔페 • 광화문 4.3 (183) 합리적인 가격의 모던 & 캐주얼 뷔페 레스토랑 점심 2.9만원 · 저녁 가격변동
# 단정 다이닝바 • 마포 4.7 (226) 다양한 와인과 아늑한 분위기의 와인바 점심 가격변동 · 저녁 가격변동
# 두쓰멍 와인 • 용산 4.6 (251) 아늑한 분위기의 효창공원 프렌치 와인바 점심 영업안함 · 저녁 가격변동
# 양출서울 와인 • 논현 4.8 (160) 채소가 메인이 되는 곳, 맛있는 채소와 네츄럴 와인(비건X) 점심 영업안함 · 저녁 가격변동
# 레스토랑 우오보 파스타 • 도곡 4.6 (1,256) 다양한 생면 파스타와 요리, 와인을 즐기실 수 있는 레스토랑입니다. 5인이상 예약은 매장으로 연락 부탁드립니다. 점심 가격변동 · 저녁 가격변동
# 비아톨레도 파스타바 파스타 • 용산 4.8 (450) 나폴리를 담고 있는 파스타바 점심 영업안함 · 저녁 가격변동
# 와인소셜 와인 • 도산공원 4.7 (252) "Feel The Wine"잔과 잔 사이에 오가는 대화의 즐거움으로 일상에 녹아드는 와인 복합 문화 공간 점심 영업안함 · 저녁 가격변동
# 명동숙희 다이닝바 • 명동 4.8 (298) 을지로 숙희의 2호점, 근정전 컨셉의 한국형 클래식바 점심 영업안함 · 저녁 가격변동
# 화이트와인개러지 와인 • 청담 4.7 (228) 제철 식재료를 이용한 음식들이 매력적인 높은 층고의 청담동 와인바.예약이 마감 되었어도 당일 워크인방문은 매장으로 전화문의 가능합니다. 점심 영업안함 · 저녁 가격변동
# 리브나 RIVNA 코스요리 • 성수 4.9 (357) '리브나는 이탈리아에서 요리하던 추억과정갈한 재료의 가치를 담아냅니다.'성수 만족도 1위 코스 다이닝, 생일 기념일 이벤트, 가족모임, 대관행사, 브라이덜사워 점심 영업안함 · 저녁 가격변동
# 시미베 일식 • 신당 4.8 (427) 신당역 근처 이자카야 점심 영업안함 · 저녁 가격변동
# 앨리스 청담 칵테일,위스키 • 청담 4.7 (57) 바텐더들의 성지, 압구정로데오 스피크이지바 점심 영업안함 · 저녁 가격변동
# 라움아트센터 이탈리아음식 • 선릉 NA NA 유럽의 고성과 같은 이색적인 공간에서 즐기는 미식&공연 점심 가격변동 · 저녁 가격변동
# 사케츠바사 다이닝바 • 가로수길 4.8 (294) 제철 안주와 다양한 사케 및 에비스생맥을 즐길 수 있는 신사동 가로수길 자그마한 사케바 점심 영업안함 · 저녁 가격변동
# 퍼밋 청담 다이닝바 • 청담 NA NA 프라이빗한 공간에서 편하게 즐길 수 있는 몰트 바 점심 가격변동 · 저녁 가격변동
# 우노네 이탈리아음식 • 상암 4.7 (378) 클래식한 이탈리안요리를 추구하는 상암동 작은골목안에 숨어있는 모두를 위한, 이탈리안레스토랑 점심 가격변동 · 저녁 가격변동
# 바결 다이닝바 • 연남 5.0 (10) 위스키 칵테일 전통주 와인, 다양한 주류를 편안하게 즐기는 공간 점심 영업안함 · 저녁 가격변동
# 노퍼블릭 하우스 칵테일,위스키 • 가로수길 4.9 (27) 반복되는 일상 속 특별한 시간을 제공하는 NOPUBLIC 점심 영업안함 · 저녁 가격변동
# 한식술집 돌 전통주 • 성신여대 4.9 (219) 다양한 전통주를 즐길 수 있는 캐주얼 한식 다이닝바* 단품요리만  가능합니다 점심 영업안함 · 저녁 가격변동
# 몬드리안 럼퍼스 룸(Mondrian Rumpus Room) 다이닝바 • 이태원 4.3 (18) 엄선한 와인 리스트부터 독창적인 칵테일과 최고급 샴페인 라인업, 몬드리안 서울 이태원의 프리미엄 와인바 점심 영업안함 · 저녁 가격변동
# 더 플라자 세븐스퀘어 뷔페 • 시청 4.7 (251) 다채로운 라이브 코너를 선보이는 올데이 뷔페 다이닝 점심 가격변동 · 저녁 가격변동
# 오블리비언 Oblivion 다이닝바 • 왕십리 5.0 (95) 왕십리 어느 조용한 골목에 아늑한 공간 점심 가격변동 · 저녁 가격변동
# 용산피보 와인 • 삼각지 4.9 (116) 무신사에서도 촬영한 분위기 맛집. 2023트랜드 외식경영, GQ코리아, 무신사 등 다양한 매체에 소개된, 와인을 위한 와인바 점심 영업안함 · 저녁 가격변동
# 재료의 산책 코스요리 • 성신여대 4.9 (45) 제철 채소 요리를 경험할 수 있는 공간 점심 가격변동 · 저녁 가격변동
# 스크립트 와인 • 연남 5.0 (3) 나만 알고 싶은 연남동 와인바 점심 가격변동 · 저녁 가격변동
# 칠링 을지로 와인 • 을지로 4.9 (39) 먹고 싶은 음식을 가져와 후카/시샤와 와인,위스키 페어링을 즐기는 아지트 점심 영업안함 · 저녁 가격변동
# 무스타슈 코스요리 • 압구정 4.4 (15) 프랑스 음식을 하는 작은 식당 점심 영업안함 · 저녁 가격변동
# 바 참 Bar Cham 칵테일,위스키 • 서촌 4.9 (165) 2023 Asia's 50 Best Bars 13th Bar Cham 2023 World's 50 Best Bars 75th Bar Cham  ※공간이 협소하여 팀당 최대 4인까지만 이용하실 수 있는 점 양해 부탁 드립니다. 점심 영업안함 · 저녁 가격변동
# 78도 광화문 칵테일,위스키 • 광화문 4.8 (7) 몰트 위스키바 점심 영업안함 · 저녁 가격변동
# 게리슨 칵테일,위스키 • 압구정로데오 4.5 (4) 위스키,칵테일,와인,드래프트 비어를 즐길 수 있는 클래식바 점심 영업안함 · 저녁 가격변동
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[4], line 19
#      17 # 스크롤하여 모든 데이터를 가져오기
#      18 while True:
# ---> 19     html = driver.page_source
#      20     soup = BeautifulSoup(html, 'html.parser')
#      21     items = soup.select('.restaurant-info')
#
# File c:\Users\RYS\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:455, in WebDriver.page_source(self)
#     446 @property
#     447 def page_source(self) -> str:
#     448     """Gets the source of the current page.
#     449
#     450     :Usage:
#    (...)
#     453             driver.page_source
#     454     """
# --> 455     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# File c:\Users\RYS\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File c:\Users\RYS\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=126.0.6478.63)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF661D7EEA2+31554]
# 	(No symbol) [0x00007FF661CF7ED9]
# 	(No symbol) [0x00007FF661BB872A]
# 	(No symbol) [0x00007FF661B8D995]
# 	(No symbol) [0x00007FF661C344D7]
# 	(No symbol) [0x00007FF661C4C051]
# 	(No symbol) [0x00007FF661C2CDD3]
# 	(No symbol) [0x00007FF661BFA33B]
# 	(No symbol) [0x00007FF661BFAED1]
# 	GetHandleVerifier [0x00007FF662088B1D+3217341]
# 	GetHandleVerifier [0x00007FF6620D5AE3+3532675]
# 	GetHandleVerifier [0x00007FF6620CB0E0+3489152]
# 	GetHandleVerifier [0x00007FF661E2E776+750614]
# 	(No symbol) [0x00007FF661D0375F]
# 	(No symbol) [0x00007FF661CFEB14]
# 	(No symbol) [0x00007FF661CFECA2]
# 	(No symbol) [0x00007FF661CEE16F]
# 	BaseThreadInitThunk [0x00007FFEA3B4257D+29]
# 	RtlUserThreadStart [0x00007FFEA56EAF28+40]

# %%
import pandas as pd

df = pd.read_csv('catchtable.csv')
df
# Out:
#                 name       cat_loc  rating   review  \
# 0         옳음 OLH EUM       한식 • 청담     4.3    (617)
# 1                바로크  칵테일,위스키 • 한남     4.9     (46)
# 2                권숙수       한식 • 청담     4.7    (920)
# 3             퀴진 라끌레    프랑스음식 • 서촌     4.7    (398)
# 4             이다 IDA       한식 • 종로     4.6  (1,528)
# ...              ...           ...     ...      ...
# 5329          이종국104       한식 • 문정     4.7      (5)
# 5330         삼원가든 특실  한우오마카세 • 압구정     4.5     (10)
# 5331             라벤더     철판요리 • 청담     4.9    (284)
# 5332              산로       일식 • 청담     4.9    (126)
# 5333  호텔 크레센도 서울 라운지    코스요리 • 선정릉     NaN      NaN
#
#                                             description  \
# 0                        시즌별 테마로 구성되는 서호영 셰프의 모던 한식 다이닝
# 1                           하나뿐인 나만의 칵테일을 맛볼 수 있는 스피키지바
# 2     직접 담근 장, 김치, 식초, 장아찌로 전국에 진귀한 식재료를 이용하여 이 시대에 ...
# 3                                국내 최초 캐나다 퀘벡식 프렌치 레스토랑
# 4                   한식 재료를 이용한 창의적인 요리를 선보이는 컨템포러리 레스토랑
# ...                                                 ...
# 5329                      미슐랭 투스타 요리 연구가 이종국 선생님의 한식 공간
# 5330    삼원가든이 VVIP 고객님을 위해 준비한 특별한 공간, 단 하나의 독채로 운영됩니다.
# 5331                 엄선된 식재료를 가치 있고 조화롭게 펼쳐낸 코리안 데판 다이닝
# 5332                   교토 키쿠노이 본점 출신 유성엽 셰프가 풀어가는 일본 요리
# 5333                       엔틱한 분위기의 소규모 모임을 위한 프라이빗한 공간
#
#                     price_range
# 0             점심 가격변동 · 저녁 가격변동
# 1             점심 영업안함 · 저녁 가격변동
# 2             점심 가격변동 · 저녁 가격변동
# 3          점심 1 - 4만원 · 저녁 가격변동
# 4             점심 가격변동 · 저녁 가격변동
# ...                         ...
# 5329  점심 5 - 7만원 · 저녁 30 - 40만원
# 5330          점심 영업안함 · 저녁 35만원
# 5331        점심 17.5만원 · 저녁 35만원
# 5332         점심 6.8만원 · 저녁 35만원
# 5333                   최소 180만원
#
# [5334 rows x 6 columns]

# %%
df.drop_duplicates(['name'])
# Out:
#                 name       cat_loc  rating   review  \
# 0         옳음 OLH EUM       한식 • 청담     4.3    (617)
# 1                바로크  칵테일,위스키 • 한남     4.9     (46)
# 2                권숙수       한식 • 청담     4.7    (920)
# 3             퀴진 라끌레    프랑스음식 • 서촌     4.7    (398)
# 4             이다 IDA       한식 • 종로     4.6  (1,528)
# ...              ...           ...     ...      ...
# 3041          이종국104       한식 • 문정     4.7      (5)
# 3042         삼원가든 특실  한우오마카세 • 압구정     4.5     (10)
# 3043             라벤더     철판요리 • 청담     4.9    (284)
# 3044              산로       일식 • 청담     4.9    (126)
# 3045  호텔 크레센도 서울 라운지    코스요리 • 선정릉     NaN      NaN
#
#                                             description  \
# 0                        시즌별 테마로 구성되는 서호영 셰프의 모던 한식 다이닝
# 1                           하나뿐인 나만의 칵테일을 맛볼 수 있는 스피키지바
# 2     직접 담근 장, 김치, 식초, 장아찌로 전국에 진귀한 식재료를 이용하여 이 시대에 ...
# 3                                국내 최초 캐나다 퀘벡식 프렌치 레스토랑
# 4                   한식 재료를 이용한 창의적인 요리를 선보이는 컨템포러리 레스토랑
# ...                                                 ...
# 3041                      미슐랭 투스타 요리 연구가 이종국 선생님의 한식 공간
# 3042    삼원가든이 VVIP 고객님을 위해 준비한 특별한 공간, 단 하나의 독채로 운영됩니다.
# 3043                 엄선된 식재료를 가치 있고 조화롭게 펼쳐낸 코리안 데판 다이닝
# 3044                   교토 키쿠노이 본점 출신 유성엽 셰프가 풀어가는 일본 요리
# 3045                       엔틱한 분위기의 소규모 모임을 위한 프라이빗한 공간
#
#                     price_range
# 0             점심 가격변동 · 저녁 가격변동
# 1             점심 영업안함 · 저녁 가격변동
# 2             점심 가격변동 · 저녁 가격변동
# 3          점심 1 - 4만원 · 저녁 가격변동
# 4             점심 가격변동 · 저녁 가격변동
# ...                         ...
# 3041  점심 5 - 7만원 · 저녁 30 - 40만원
# 3042          점심 영업안함 · 저녁 35만원
# 3043        점심 17.5만원 · 저녁 35만원
# 3044         점심 6.8만원 · 저녁 35만원
# 3045                   최소 180만원
#
# [3046 rows x 6 columns]

# %%
from bs4 import BeautifulSoup
import requests as rq
import re
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import time
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException

# 데이터를 저장할 리스트
names = []
rates = []
sections = []
prices = []
addresses = []
# locations = []
descriptions = []
review_counts = []
review_descrip = []
processed_elements = set()

keyword = '서울'
url = f'https://www.siksinhot.com/search?keywords={keyword}'

# Chrome 드라이버 설정
driver = webdriver.Chrome()

# def close_popup():
#     try:
#         # 팝업 닫기 버튼을 찾고 클릭
#         close_button = driver.find_element(By.CSS_SELECTOR, '.popup_close')  # 예시: 팝업 닫기 버튼의 선택자
#         close_button.click()
#         time.sleep(2)
#     except NoSuchElementException:
#         # 팝업이 없으면 아무것도 하지 않음
#         pass

try:
    # 지정된 URL로 이동
    driver.get(url)
    time.sleep(8)

    while True:
        # 팝업 창이 뜰 경우 닫기
        # close_popup()

        # 현재 페이지의 식당 링크 요소들 찾기
        rest_elements = driver.find_elements(By.CSS_SELECTOR, 'a.textBox')

        # 링크가 없으면 루프 종료
        if not rest_elements:
            print("더 이상 식당 링크가 없습니다.")
            break

        # 자꾸 처음부터 돌아가니 전에꺼 있으면 그 다음부터 시작
        new_elements_found = False
        for rest_element in rest_elements:
            # 링크 확보 후 세트에 저장
            element_id = rest_element.get_attribute('href')
            if element_id in processed_elements:
                continue

            new_elements_found = True
            processed_elements.add(element_id)

            try:
                # 새 탭에서 링크 열기 (Ctrl + click)
                ActionChains(driver).key_down(Keys.CONTROL).click(rest_element).key_up(Keys.CONTROL).perform()
                time.sleep(2)

                # 새 탭으로 전환
                driver.switch_to.window(driver.window_handles[-1])
                time.sleep(2)

                # 상세 페이지에서 필요한 정보 추출
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')

                # 이름 추출
                name_item = soup.select_one('.name h1')
                # print(name_item)
                if name_item:
                    name_text = name_item.get_text(strip=True)
                    names.append(name_text)
                    print(f'Name: {name_text}')
                else:
                    names.append('NA')


                # 음식 종류
                section_item = soup.select('div.text02[data-reactid="348"]')
                # print(section_item)
                if section_item:
                    section_text = ', '.join([item.get_text(strip=True) for item in section_item])
                    sections.append(section_text)
                    print(f'Section: {section_text}')
                else:
                    sections.append('NA')


                # 평점
                rate_item = soup.select_one('span.score')
                # print(rate_item)
                if rate_item:
                    rate_text = rate_item.get_text(strip=True)
                    rates.append(rate_text)
                    print(f'Rate: {rate_text}')
                else:
                    rates.append('NA')


                # 음식점 내용
                description_item = soup.find('tr', class_='m_only table_row').find('td')
                # print(description_item)
                if description_item:
                    description_text = description_item.get_text(strip=True)
                    descriptions.append(description_text)
                    print(f'Description: {description_text}')
                else:
                    descriptions.append('NA')


                # 가격
                price_list = {}
                price_item = soup.find_all('span', class_='menu-price')
                # print(price_item)
                if price_item:
                    for i, price_elements in enumerate(price_item):
                        price_text = price_elements.get_text(strip=True)
                        # price_list.append(price_text)
                        price_list[i] = price_text
                        # print(f'Price: {price_text}')
                        prices.append(price_list)
                else:
                    price_list.append('NA')


                # 주소1
                address_item = soup.select_one('.clickable .text02')
                # print(address_item)
                if address_item:
                    address_text = address_item.get_text(strip=True)
                    addresses.append(address_text)
                    print(f'Address: {address_text}')
                else:
                    addresses.append('NA')

                # 주소2
                # location_item = soup.select_one('.text02 .link')
                # # print(address_item)
                # if location_item:
                #     location_text = location_item.get_text(strip=True)
                #     locations.append(location_text)
                #     print(f'Address: {location_text}')

                # 리뷰 개수
                review_item = soup.select_one('div.review_title span[data-reactid="75"]')
                if review_item:
                    review_count = review_item.get_text(strip=True).strip('()')
                    review_counts.append(review_count)
                    print(f'Count: {review_count}')
                else:
                    review_counts.append('NA')
                
                # 리뷰 내용

                while True:
                    try:
                        load_button = driver.find_element(By.XPATH, '//*[@id="storeView"]/div[2]/div[2]/a/span')
                        ActionChains(driver).click(load_button).perform()
                        driver.execute_script("window.scrollBy(0, 300);")
                        time.sleep(3)
                    except (NoSuchElementException, ElementClickInterceptedException):
                        print("더 이상 '더보기' 버튼이 없습니다.")
                        break

                # 리뷰 내용 추출
                review_list = {}
                review_infos = soup.find_all('div', class_='review_text')
                if review_infos:
                    for i, review_info in enumerate(review_infos):
                        review_text = review_info.get_text(strip=True)
                        review_list[i] = review_text
                        review_descrip.append(review_list)
                else:
                    review_descrip.append('NA')                
                           



                break
                # 현재 탭 닫기
                driver.close()
                time.sleep(2)

                # 원래 탭으로 전환
                driver.switch_to.window(driver.window_handles[0])
                time.sleep(2)

                

            except Exception as e:
                print(f"크롤링 이상 발생: {e}")

        # 새로운 요소가 없으면 더보기 버튼 클릭
        if not new_elements_found:
            try:
                load_more_button = driver.find_element(By.XPATH, '//*[@id="main_search"]/div/article/section/div[2]/div[1]/a')
                load_more_button.click()
                time.sleep(4)
            except (NoSuchElementException, ElementClickInterceptedException):
                print("더 이상 '더보기' 버튼이 없습니다.")
                break
        else:
            # 페이지를 약간 스크롤하여 새 요소를 로드
            driver.execute_script("window.scrollBy(0, 500);")
            time.sleep(2)

finally:
    driver.quit()
# Out:
# Name: 벽제갈비 방이본점
# Section: 한국음식>돼지갈비
# Rate: 4.3
# Description: 월스트리트지가 아시아 5대 음식점의 하나로 선정했고, 중국에서 브랜드 로열티를 받는 등 해외에도 잘 알려진 벽제갈비의 방이동 본점입니다. 1++ 축산 등급 확인서를 확인할 수 있을 만큼 최고급 한우만을 취급합니다.
# Address: 지번서울특별시 송파구 방이동 205-8
# Count: 91
# 더 이상 '더보기' 버튼이 없습니다.
# 더 이상 식당 링크가 없습니다.

# %%
df = pd.DataFrame({
    'Name': names,
    'Section': sections,
    # 'Price': prices,
    'Address': addresses,
    'Rate': rates,
    'Intro': descriptions,
    'Review_count': review_counts,
    # 'Review_info' : review_descrip
    
})

df
# Out:
#         Name    Section                Address Rate  \
# 0  벽제갈비 방이본점  한국음식>돼지갈비  지번서울특별시 송파구 방이동 205-8  4.3
#
#                                                Intro Review_count
# 0  월스트리트지가 아시아 5대 음식점의 하나로 선정했고, 중국에서 브랜드 로열티를 받는...           91

# %%
print(prices)
print(review_descrip)
# Out:
# [{0: '140,000원', 1: '160,000원', 2: '73,000원', 3: '73,000원'}, {0: '140,000원', 1: '160,000원', 2: '73,000원', 3: '73,000원'}, {0: '140,000원', 1: '160,000원', 2: '73,000원', 3: '73,000원'}, {0: '140,000원', 1: '160,000원', 2: '73,000원', 3: '73,000원'}]
# [{0: '맛잇엇어요 분위기도 서비스도 괜찬앗음', 1: '설화생갈비 최고급 잘먹엇어요', 2: '고기 좋으네요 맛잇어요', 3: '괜찮은집'}, {0: '맛잇엇어요 분위기도 서비스도 괜찬앗음', 1: '설화생갈비 최고급 잘먹엇어요', 2: '고기 좋으네요 맛잇어요', 3: '괜찮은집'}, {0: '맛잇엇어요 분위기도 서비스도 괜찬앗음', 1: '설화생갈비 최고급 잘먹엇어요', 2: '고기 좋으네요 맛잇어요', 3: '괜찮은집'}, {0: '맛잇엇어요 분위기도 서비스도 괜찬앗음', 1: '설화생갈비 최고급 잘먹엇어요', 2: '고기 좋으네요 맛잇어요', 3: '괜찮은집'}]

# %%
from bs4 import BeautifulSoup
import requests as rq
import re
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import time
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException

# 데이터를 저장할 리스트
names = []
rates = []
sections = []
prices = []
addresses = []
# locations = []
descriptions = []
review_counts = []
review_descrip = []
processed_elements = set()

keyword = '서울'
url = f'https://www.siksinhot.com/search?keywords={keyword}'

# Chrome 드라이버 설정
driver = webdriver.Chrome()

# def close_popup():
#     try:
#         # 팝업 닫기 버튼을 찾고 클릭
#         close_button = driver.find_element(By.CSS_SELECTOR, '.popup_close')  # 예시: 팝업 닫기 버튼의 선택자
#         close_button.click()
#         time.sleep(2)
#     except NoSuchElementException:
#         # 팝업이 없으면 아무것도 하지 않음
#         pass

try:
    # 지정된 URL로 이동
    driver.get(url)
    time.sleep(8)

    while True:
        # 팝업 창이 뜰 경우 닫기
        # close_popup()

        # 현재 페이지의 식당 링크 요소들 찾기
        rest_elements = driver.find_elements(By.CSS_SELECTOR, 'a.textBox')

        # 링크가 없으면 루프 종료
        if not rest_elements:
            print("더 이상 식당 링크가 없습니다.")
            break

        # 자꾸 처음부터 돌아가니 전에꺼 있으면 그 다음부터 시작
        new_elements_found = False
        for rest_element in rest_elements:
            # 링크 확보 후 세트에 저장
            element_id = rest_element.get_attribute('href')
            if element_id in processed_elements:
                continue

            new_elements_found = True
            processed_elements.add(element_id)

            try:
                # 새 탭에서 링크 열기 (Ctrl + click)
                ActionChains(driver).key_down(Keys.CONTROL).click(rest_element).key_up(Keys.CONTROL).perform()
                time.sleep(2)

                # 새 탭으로 전환
                driver.switch_to.window(driver.window_handles[-1])
                time.sleep(2)

                # 리뷰 내부의 더보기를 클릭하여 모든 리뷰 로드
                while True:
                    try:
                        load_button = driver.find_element(By.XPATH, '//*[@id="storeView"]/div[2]/div[2]/a/span')
                        ActionChains(driver).click(load_button).perform()
                        driver.execute_script("window.scrollBy(0, 300);")
                        time.sleep(3)
                    except (NoSuchElementException, ElementClickInterceptedException):
                        print("더 이상 '더보기' 버튼이 없습니다.")
                        break

                # 업데이트 된 페이지에서 필요한 정보 추출
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')

                # 가격
                price_list = {}
                price_item = soup.find_all('span', class_='menu-price')
                # print(price_item)
                if price_item:
                    for i, price_elements in enumerate(price_item):
                        price_text = price_elements.get_text(strip=True)
                        if price_text in price_list:
                            break
                        else:
                            price_list[i] = price_text
                        # print(f'Price: {price_text}')
                    prices.append(price_list)
                else:
                    price_list.append('NA')


                # 주소1
                address_item = soup.select_one('.clickable .text02')
                # print(address_item)
                if address_item:
                    address_text = address_item.get_text(strip=True)
                    addresses.append(address_text)
                    print(f'Address: {address_text}')
                else:
                    addresses.append('NA')

                # 리뷰 개수
                review_item = soup.select_one('div.review_title span[data-reactid="75"]')
                if review_item:
                    review_count = review_item.get_text(strip=True).strip('()')
                    review_counts.append(review_count)
                    print(f'Count: {review_count}')
                else:
                    review_counts.append('NA')
                
                # 리뷰 내용



                # 리뷰 내용 추출
                soup = BeautifulSoup
                review_list = {}
                review_infos = soup.find_all('div', class_='review_text')
                if review_infos:
                    for i, review_info in enumerate(review_infos):
                        review_text = review_info.get_text(strip=True)
                        review_list[i] = review_text
                    review_descrip.append(review_list)
                else:
                    review_descrip.append('NA')                
                           



                break
                # 현재 탭 닫기
                driver.close()
                time.sleep(2)

                # 원래 탭으로 전환
                driver.switch_to.window(driver.window_handles[0])
                time.sleep(2)

                

            except Exception as e:
                print(f"크롤링 이상 발생: {e}")

        # 새로운 요소가 없으면 더보기 버튼 클릭
        if not new_elements_found:
            try:
                load_more_button = driver.find_element(By.XPATH, '//*[@id="main_search"]/div/article/section/div[2]/div[1]/a')
                load_more_button.click()
                time.sleep(4)
            except (NoSuchElementException, ElementClickInterceptedException):
                print("더 이상 '더보기' 버튼이 없습니다.")
                break
        else:
            # 페이지를 약간 스크롤하여 새 요소를 로드
            driver.execute_script("window.scrollBy(0, 500);")
            time.sleep(2)

finally:
    driver.quit()
# Out:
# Address: 지번서울특별시 송파구 방이동 205-8
# Count: 91
# 더 이상 '더보기' 버튼이 없습니다.
# 더 이상 식당 링크가 없습니다.

# %%
print(review_descrip)
# Out:
# [{0: '맛잇엇어요 분위기도 서비스도 괜찬앗음', 1: '설화생갈비 최고급 잘먹엇어요', 2: '고기 좋으네요 맛잇어요', 3: '괜찮은집'}]

# %%
print(prices)
print(review_descrip)

df = pd.DataFrame({
    # 'Name': names,
    # 'Section': sections,
    'Price': prices,
    'Address': addresses,
    # 'Rate': rates,
    # 'Intro': descriptions,
    'Review_count': review_counts,
    'Review_info' : review_descrip
    
})

df
# Out:
# [{0: '140,000원', 1: '160,000원', 2: '73,000원', 3: '73,000원'}]
# [{0: '맛잇엇어요 분위기도 서비스도 괜찬앗음', 1: '설화생갈비 최고급 잘먹엇어요', 2: '고기 좋으네요 맛잇어요', 3: '괜찮은집'}]
#                                                Price                Address  \
# 0  {0: '140,000원', 1: '160,000원', 2: '73,000원', 3...  지번서울특별시 송파구 방이동 205-8
#
#   Review_count                                        Review_info
# 0           91  {0: '맛잇엇어요 분위기도 서비스도 괜찬앗음', 1: '설화생갈비 최고급 잘먹엇어...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException

# 데이터를 저장할 리스트
names = []
rates = []
sections = []
prices = []
addresses = []
descriptions = []
review_descrip = []
processed_elements = set()

keyword = '서울'
url = f'https://www.siksinhot.com/search?keywords={keyword}'

# Chrome 드라이버 설정
driver = webdriver.Chrome()

def close_popup():
    try:
        # 팝업 닫기 버튼을 찾고 클릭
        close_button = driver.find_element(By.CSS_SELECTOR, '.popup_close')  # 예시: 팝업 닫기 버튼의 선택자
        close_button.click()
        time.sleep(2)
    except NoSuchElementException:
        # 팝업이 없으면 아무것도 하지 않음
        pass

try:
    # 지정된 URL로 이동
    driver.get(url)
    time.sleep(8)

    while True:
        # 팝업 창이 뜰 경우 닫기
        close_popup()

        # 현재 페이지의 식당 링크 요소들 찾기
        rest_elements = driver.find_elements(By.CSS_SELECTOR, 'a.textBox')

        # 링크가 없으면 루프 종료
        if not rest_elements:
            print("더 이상 식당 링크가 없습니다.")
            break

        # 자꾸 처음부터 돌아가니 전에꺼 있으면 그 다음부터 시작
        new_elements_found = False
        for rest_element in rest_elements:
            # 링크 확보 후 세트에 저장
            element_id = rest_element.get_attribute('href')
            if element_id in processed_elements:
                continue

            new_elements_found = True
            processed_elements.add(element_id)

            try:
                # 새 탭에서 링크 열기 (Ctrl + click)
                ActionChains(driver).key_down(Keys.CONTROL).click(rest_element).key_up(Keys.CONTROL).perform()
                time.sleep(2)

                # 새 탭으로 전환
                driver.switch_to.window(driver.window_handles[-1])
                time.sleep(2)

                # "더보기" 버튼을 클릭하여 모든 리뷰 로드
                while True:
                    try:
                        load_button = driver.find_element(By.XPATH, '//*[@id="storeView"]/div[2]/div[2]/a/span')
                        ActionChains(driver).click(load_button).perform()
                        driver.execute_script("window.scrollBy(0, 300);")
                        time.sleep(3)
                    except (NoSuchElementException, ElementClickInterceptedException):
                        print("더 이상 '더보기' 버튼이 없습니다.")
                        break

                # 업데이트된 페이지 소스 가져오기
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')

                # 이름 추출
                name_item = soup.select_one('.name h1')
                if name_item:
                    name_text = name_item.get_text(strip=True)
                    names.append(name_text)
                    print(f'Name: {name_text}')
                else:
                    names.append(['NA'])

                # 음식 종류
                section_item = soup.select_one('.text02')
                if section_item:
                    section_text = section_item.get_text(strip=True)
                    sections.append(section_text)
                    print(f'Section: {section_text}')
                else:
                    sections.append(['NA'])

                # 평점
                rate_item = soup.select_one('span.score')
                if rate_item:
                    rate_text = rate_item.get_text(strip=True)
                    rates.append(rate_text)
                    print(f'Rate: {rate_text}')
                else:
                    rates.append(['NA'])

                # 음식점 내용
                description_item = soup.select_one('.m_only table_row td')
                if description_item:
                    description_text = description_item.get_text(strip=True)
                    descriptions.append(description_text)
                    print(f'Descrip: {description_text}')
                else:
                    descriptions.append(['NA'])

                # 가격
                prices_set = set()
                price_items = soup.find_all('span', class_='menu-price')
                if price_items:
                    for price_item in price_items:
                        price_text = price_item.get_text(strip=True)
                        prices_set.add(price_text)
                    prices.append(list(prices_set))
                    print(f'Prices: {prices_set}')
                else:
                    prices.append(['NA'])

                # 주소
                address_item = soup.select_one('.text01')
                if address_item:
                    address_text = address_item.get_text(strip=True)
                    addresses.append(address_text)
                    print(f'Address: {address_text}')
                else:
                    addresses.append(['NA'])

                # 리뷰 내용 추출
                review_list = {}
                review_infos = soup.find_all('div', class_='review_text')
                if review_infos:
                    for i, review_info in enumerate(review_infos):
                        review_text = review_info.get_text(strip=True)
                        review_list[i] = review_text
                    review_descrip.append(review_list)
                    print(f'Reviews: {review_list}')
                else:
                    review_descrip.append(['NA'])


                # 현재 탭 닫기
                driver.close()
                time.sleep(2)

                # 원래 탭으로 전환
                driver.switch_to.window(driver.window_handles[0])
                time.sleep(2)
                
            except Exception as e:
                print(f"크롤링 이상 발생: {e}")

        # 새로운 요소가 없으면 더보기 버튼 클릭
        if not new_elements_found:
            try:
                load_more_button = driver.find_element(By.XPATH, '//*[@id="main_search"]/div/article/section/div[2]/div[1]/a')
                load_more_button.click()
                time.sleep(4)
            except (NoSuchElementException, ElementClickInterceptedException):
                print("더 이상 '더보기' 버튼이 없습니다.")
                break
        else:
            # 페이지를 약간 스크롤하여 새 요소를 로드
            driver.execute_script("window.scrollBy(0, 500);")
            time.sleep(2)

finally:
    driver.quit()
# Out:
# 더 이상 '더보기' 버튼이 없습니다.
# Name: 벽제갈비 방이본점
# Section: 서울-강남>송파/방이
# Rate: 4.3
# Prices: {'160,000원', '73,000원', '140,000원'}
# Address: 서울특별시 송파구 양재대로71길 1-4
# Reviews: {0: '맛잇엇어요 분위기도 서비스도 괜찬앗음', 1: '설화생갈비 최고급 잘먹엇어요', 2: '고기 좋으네요 맛잇어요', 3: '괜찮은집', 4: '잠바에 운동화 신고 밥먹으러 갔다가.. 차별대우 받고... 쩝쩝\n김정숙대리님..담에는 좀 친절히 대해 주세요', 5: '만족스러웠습니다.', 6: '오늘의고기는 그날그날 들어오는거에따라 구성도가 살짝씩바뀌는데, 고기이름이 귀에 안들어옴ㅋㅋㅋㅋㅋ마블링보자마자 그냥 이성잃고 먹게됩니다. 고기맛은 확실히 보장함', 7: '벽제갈비는 가족외식장소로 추천드리고싶어요~ ㅎㅎㅎ 금액대비 두명이오기엔 음식양도 많은데다가 가격도있기에 ㅎㅎㅎ 이것저것 다양하게 뜯고즐기고싶다면 가족이서 방문추천합니다~', 8: '대낮부터 밥으로 고기를먹는게 내몸에게 미안하지만…. 방이동주민으로써 벽제갈비는 밥집이나 다름없는곳이기에… 뭐.. 맛있으면 된거아닌가? 아몰랑 걍먹어', 9: '점심가격으로도 착하진않은데 음식이맛있다보니 자꾸자꾸생각나요!반찬들도 다양하게 맛볼수있게 조금씩 골고루나와요~! 오히려 금액대비 실속있던맛집이라 생각해요!!^^', 10: '설화생갈비 지방이 너무 많아서인지 느끼하고.. 사실 서비스, 분위기, 밑반찬 그리고 고기질 모두 1인분 89천원 가치는 아님. 5~7만원정도가 적당할 듯.. 비싼집으로 인식되어 오히려 덕보는 집. (접대등의 이유?) 암튼 개인의 취향이겠지만 간혹 갈때마다 후회하는 곳.. 그나마 다른 부위, 식사류는 그래도 나은편.', 11: "벽제갈비 진짜 맛있어요'-' 생갈비 진짜맛있어요 ㅋㅋ값어치 하는 집입니다. 진짜", 12: '주차장이 만차라, 힘들게 들어갔어요. 기다린 만큼의 맛이 보장되네요!', 13: '첫 월급으로 부모님께 무슨 음식을 대접할까 고민하다가 선택했어요. 부모님이 너무 좋아하십니다.', 14: '역시 고기에는 냉면이다. 여기는 고기가 입에서 사르르 녹고, 냉면을 후루룩 빨려들어가고.. 끝맛도 깔끔', 15: '친구랑 가서 먹었눈데 가족외식으로 딱이더라구요!! 담에 부모님이랑 같이 갈 예정 ㅋㅋㅋㅋ 맛있어용~', 16: '냉면이 특이하게 백김치랑 나왔었는데 완전 기대 이상이라 놀랐어요. 고기도 너무 맛있고 냉면까지 대박이였어요 0_0', 17: '양념의 단 맛을 싫어했었는데, 지인의 추천으로다녀왔어요. 너무 달지 않고 적당한 갈비의 맛이 너무 만족스럽습니다.', 18: '갈비집이지만 갈비뿐아니라 순면의 맛또한 끝내줘요!! 국물이 끝내줘요!! ㅎㅎ', 19: '고기먹고 진짜 감동받아서 ㅜㅜ 송파사는 친구 꼬셔서 며칠뒤에 또 갔어요 ㅋㅋㅋㅋㅋ 완전 양념이 너무 맛있어용!!!!!!!!!!!', 20: '소문듣고 갔는데 역시 실망시키지 않았음요 ㅋㅋㅋㅋ 진짜 양 푸짐하고 배불러요 냉면 강추 ㅋㅋㅋ', 21: '매장이 크고 깔끔해서 좋았고 고기도 진짜 맛있었어요!!! 가족끼리 갈때 좋을듯', 22: '1++ 최고급 한우만 취급한다는 이곳!! 진짜 맛있었어요 완전 강추!!!!', 23: '양념이 약간 달지만 냉면이랑 먹으니 괜춘^^', 24: '비즈니스 모임하기에도 적당한곳이에요~~~', 25: '봉피양 냉면과 함께 미디엄레어로 구운 갈비의 육즙이 뚝뚝~ 식욕이 왕성 해졌어요.', 26: '맛집이란 저렴하면서 맛있고 친절해야한다. 여긴 비싸고 맛있고 친절함은 교육받은 정도. 마음이 느껴지지 않는다. 이 가격에 이 수준은 보통이라 생각한다', 27: '날씰과 씨실의 교차한 모양으로 촘촘한 칼집을 내 양념이 쏙쏙!! 먹기 전에 어찌나 군침이 돌든지..', 28: '금수저에 접시까지 뭔가 전통의 맛이 느껴질거 같은 느낌 아이들도 좋아하더라구요. 다음에 또 가족 식사 자리를 잡기에 좋을거 같아요.', 29: '고기 좋아하시는 분은 꼭 벽제갈비로 드시길', 30: '와 생갈비 빛깔이 예사롭지 않ㅇ던디~ 입에 넣으면 그냥 녹아버려', 31: '최상급의 한우 먹고싶은사람은 꼭 가보는것이 좋을듯 bb', 32: '반찬들이 푸짐하더라구요!! 맛도 깔끔하고!! 진짜 배부르게 먹고 왔네요. 담에 또 갈 의양있어요 +_+', 33: '고기는 냉면이랑 같이 먹어야해요,. 이거슨 진리', 34: '나름 식사시간보다 일찍 갔는데 사람들이 완전 바글바글 하더라구요. 딱 보면 맛집인지 알겠음ㅋㅋㅋㅋ 고기랑 냉면 같이 드셔야함', 35: '부드럽게 씹히는 육질이 아주 좋았습니다 .한점한점이행복했 ㅠㅠㅠㅠㅠ또 먹고 싶다 하…', 36: '벽제갈비 밑반찬으로 같이 나오는  김치랑 같은 먹어도 좋앙', 37: '밑반찬들도 정성스러워보이고 맛도 좋던데요. 특히 우엉조림괜찮아요 밑반찬 먹고있을때 나온 꽃등심은 왜 꽃등심꽃등심하는지 알겠더라고요. 고급짐', 38: '위치도 편하고 발렛 주차가 가능한 식당!! 아무래도 갈비다 보니 가격이 있겠거니 했지만, 밑반찬부터 만족만족! 잊을 수없는 육즙의 맛이예요 ㅎㅎ', 39: '평양 비빔냉면 기대하지 않고 먹었는데 맛있더라고요~ 원래 냉면 잘 안먹는 편인데 잘먹었어요', 40: '직원분들도 친절하시고 맛집인지 모르고 갔는데 나름 유명하더라구요. 담에 고기 땡길때 여기로 갈꺼에요 ㅋㅋㅋㅋㅋ', 41: '밑반찬부터 후식까지 뭐 하나 트집잡을 곳이 한 군데도 없는 완벽한 맛집이예요!!', 42: '부모님들도 좋아라 하실 만한 맛집', 43: '고기가 부들럽고 칼집이 숑숑 나있어 먹기 편합니다', 44: '술술 끊기는 100% 순면은 아니지만 메밀향이 풍부함이로다', 45: '특상한우 양념갈비도 맛있음 히히비싸서 많이는 못 주문했지만... 짧지만 행복했음 ㅠㅠㅠㅠ', 46: '평양냉면 처음으로 먹어봤는데 심심한 육수에 메밀가루로 만든 면이라서 일반 빙초산 냉면과는 맛이 다릅디다', 47: '여기 식객만화에서 본적있지아나요?ㅋㅋㅋ꼭 가보고싶었던곳이어느데 실제 가보니 고기가 진짜 부드러워어', 48: '우리나라 갈비집 중 손가락안에 단연 꼽히는 벽제갈비가 입 안에서 살살 녹으니 더 바랄 것이 없어요', 49: '갈비는 칼집이 나있어서 훨씬 더 먹음직 스러웠던', 50: '후식으로 과일과 오미자 차가 나오는데 깔끔하고 정갈한 서비스에 기분이 좋았어요 ㅎㅎ', 51: '여긴 무조건 고기먹고 냉면 시켜야함ㅋㅋㅋㅋㅋ 고기 남겨 놓고 냉면이랑 드셔보세요 대박', 52: '얼마전에 방문했던 봉피양이 옆에 보인다. 한 건물로 크게되어 있는 벽제 갈비에 정갈한 밑반찬에.. 삼삼하니 좋았다.  고기도 소스에 짝어서 먹으니까 맛있다.', 53: '갈비와 함께 냉면 먹으면 좋을듯(?) 물냉으로 먹었는데 깔끔했다', 54: '최고급 한우를 사용하였다는 글귀를 보니 가격이 이해가 되네요. 맛은 정말 보장합니다!', 55: '아이가 기운이 너무 없는 거같아 몸보신을 할겸 평소 좋아하던 갈비를 먹으러 갔어요. 너무 좋아하더라구요^^영양만점입니다', 56: '벽제갈비 만화 식객의 배경이 된 곳이라고 해서 정말 기대헀는데!!! 기대한만큼 맛있네요', 57: '아 진짜 고기 입에 넣자마자 스르륵 녹아요. 진심 양념 대박….. 굽자마자 순식간에 사라짐ㅋㅋㅋ 강추', 58: '가격이 저렴한 편은 아니지만 솔직히 가격값 하는거 같아요. 고기가 정말 싱싱하고 마블링이 좋더라구요!!! 입에서 살살', 59: '강추 강추!! ㅋㅋㅋㅋ 맛집 인정합니다 ㅋㅋㅋㅋ 친절하게 해주셔서 감사해용', 60: '질 좋은 참숯을 이용한답니다. 자고로 참숯에 구운 갈비가 짱임', 61: '음식점에 와인종류도 많고 서비스도 짱입니다. 반찬이 비면 알아서 채워주는 직원분들의 센스까지.', 62: '한우 전문점에서도 새가리르 보기 쉽지 않은데 가격이 그리 싼편은 아니지만 어디서든 맛볼수 있는게 아니기에…..', 63: '숯향도 나고 고기 한점이 보들보들하고 부드러워 내스타일인것 같음', 64: '비싸서 자주는 못 갈 것 같지만 중요한 손님이나 모실 때 제격인 곳 !!!', 65: '고기 푸짐히 먹고 싶을땐 벽제갈비로 고고ㅋㅋㅋㅋ 밤에 자꾸 생각남 ㅜㅜ 양념맛잇어요 ㅜㅜ', 66: '예나제나 맛에는 변함이 없는거같군요..', 67: '굽는데 침이 꼴깍꼴깍 ~ 부드럽게 씹히는 육질이 아주 좋았어요 ㅎㅎ', 68: '인테리어도 깔끔, 맛도 최고, 서비스도 최고, 별 4개정도 드리고 싶은 식당입니다.', 69: '이쁜접시에다가 깔 ...
# 크롤링 이상 발생: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=126.0.6478.63)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF661D7EEA2+31554]
# 	(No symbol) [0x00007FF661CF7ED9]
# 	(No symbol) [0x00007FF661BB872A]
# 	(No symbol) [0x00007FF661B8D995]
# 	(No symbol) [0x00007FF661C344D7]
# 	(No symbol) [0x00007FF661C4C051]
# 	(No symbol) [0x00007FF661C2CDD3]
# 	(No symbol) [0x00007FF661BFA33B]
# 	(No symbol) [0x00007FF661BFAED1]
# 	GetHandleVerifier [0x00007FF662088B1D+3217341]
# 	GetHandleVerifier [0x00007FF6620D5AE3+3532675]
# 	GetHandleVerifier [0x00007FF6620CB0E0+3489152]
# 	GetHandleVerifier [0x00007FF661E2E776+750614]
# 	(No symbol) [0x00007FF661D0375F]
# 	(No symbol) [0x00007FF661CFEB14]
# 	(No symbol) [0x00007FF661CFECA2]
# 	(No symbol) [0x00007FF661CEE16F]
# 	BaseThreadInitThunk [0x00007FFEA3B4257D+29]
# 	RtlUserThreadStart [0x00007FFEA56EAF28+40]
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[85], line 56
#      53 new_elements_found = False
#      54 for rest_element in rest_elements:
#      55     # 링크 확보 후 세트에 저장
# ---> 56     element_id = rest_element.get_attribute('href')
#      57     if element_id in processed_elements:
#      58         continue
#
# File c:\Users\RYS\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:178, in WebElement.get_attribute(self, name)
#     176 if getAttribute_js is None:
#     177     _load_js()
# --> 178 attribute_value = self.parent.execute_script(
#     179     f"/* getAttribute */return ({getAttribute_js}).apply(null, arguments);", self, name
#     180 )
#     181 return attribute_value
#
# File c:\Users\RYS\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:414, in WebDriver.execute_script(self, script, *args)
#     411 converted_args = list(args)
#     412 command = Command.W3C_EXECUTE_SCRIPT
# --> 414 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File c:\Users\RYS\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File c:\Users\RYS\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=126.0.6478.63)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF661D7EEA2+31554]
# 	(No symbol) [0x00007FF661CF7ED9]
# 	(No symbol) [0x00007FF661BB872A]
# 	(No symbol) [0x00007FF661B8D995]
# 	(No symbol) [0x00007FF661C344D7]
# 	(No symbol) [0x00007FF661C4C051]
# 	(No symbol) [0x00007FF661C2CDD3]
# 	(No symbol) [0x00007FF661BFA33B]
# 	(No symbol) [0x00007FF661BFAED1]
# 	GetHandleVerifier [0x00007FF662088B1D+3217341]
# 	GetHandleVerifier [0x00007FF6620D5AE3+3532675]
# 	GetHandleVerifier [0x00007FF6620CB0E0+3489152]
# 	GetHandleVerifier [0x00007FF661E2E776+750614]
# 	(No symbol) [0x00007FF661D0375F]
# 	(No symbol) [0x00007FF661CFEB14]
# 	(No symbol) [0x00007FF661CFECA2]
# 	(No symbol) [0x00007FF661CEE16F]
# 	BaseThreadInitThunk [0x00007FFEA3B4257D+29]
# 	RtlUserThreadStart [0x00007FFEA56EAF28+40]

# %%
df = pd.DataFrame({
    'Name': names,
    'Section': sections,
    'Price': prices,
    'Address': addresses,
    'Rate': rates,
    'Intro': descriptions,
    'Review_count': review_counts,
    'Review_info' : review_descrip
    
})

df
# Out:
#         Name      Section                          Price  \
# 0  벽제갈비 방이본점  서울-강남>송파/방이  [160,000원, 73,000원, 140,000원]
#
#                  Address Rate Intro Review_count  \
# 0  서울특별시 송파구 양재대로71길 1-4  4.3  [NA]           91
#
#                                          Review_info
# 0  {0: '맛잇엇어요 분위기도 서비스도 괜찬앗음', 1: '설화생갈비 최고급 잘먹엇어...

# %%
from bs4 import BeautifulSoup
import requests as rq
import re
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import time
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException

# 데이터를 저장할 리스트
names = []
rates = []
sections = []
prices = []
addresses = []
# locations = []
descriptions = []
review_counts = []
review_descrip = []
processed_elements = set()

keyword = '서울'
url = f'https://www.siksinhot.com/search?keywords={keyword}'

# Chrome 드라이버 설정
driver = webdriver.Chrome()

# def close_popup():
#     try:
#         # 팝업 닫기 버튼을 찾고 클릭
#         close_button = driver.find_element(By.CSS_SELECTOR, '.popup_close')  # 예시: 팝업 닫기 버튼의 선택자
#         close_button.click()
#         time.sleep(2)
#     except NoSuchElementException:
#         # 팝업이 없으면 아무것도 하지 않음
#         pass


# a = 1

try:
    # 지정된 URL로 이동
    driver.get(url)
    time.sleep(8)

    while True:
        # 팝업 창이 뜰 경우 닫기
        # close_popup()

        # 현재 페이지의 식당 링크 요소들 찾기
        rest_elements = driver.find_elements(By.CSS_SELECTOR, 'a.textBox')

        # 링크가 없으면 루프 종료
        if not rest_elements:
            print("더 이상 식당 링크가 없습니다.")
            break

        # 자꾸 처음부터 돌아가니 전에꺼 있으면 그 다음부터 시작
        new_elements_found = False
        for rest_element in rest_elements:
            # 링크 확보 후 세트에 저장
            element_id = rest_element.get_attribute('href')
            if element_id in processed_elements:
                continue

            new_elements_found = True
            processed_elements.add(element_id)

            try:
                # 새 탭에서 링크 열기 (Ctrl + click)
                ActionChains(driver).key_down(Keys.CONTROL).click(rest_element).key_up(Keys.CONTROL).perform()
                time.sleep(2)

                # 새 탭으로 전환
                driver.switch_to.window(driver.window_handles[-1])
                time.sleep(2)

                # # 내부 모든 리뷰 로드
                # while True:
                #     try:
                #         load_button = driver.find_element(By.XPATH, '//*[@id="storeView"]/div[2]/div[2]/a/span')
                #         ActionChains(driver).click(load_button).perform()
                #         driver.execute_script("window.scrollBy(0, 300);")
                #         time.sleep(3)
                #     except (NoSuchElementException, ElementClickInterceptedException):
                #         print("더 이상 '더보기' 버튼이 없습니다.")
                #         break


                # 업데이트 된 페이지에서 필요한 정보 추출
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')

                # 이름 추출
                name_item = soup.select_one('.name h1')
                # print(name_item)
                if name_item:
                    name_text = name_item.get_text(strip=True)
                    names.append(name_text)
                    print(f'Name: {name_text}')
                else:
                    names.append(['NA'])


                # 음식 종류
                section_item = soup.select('div.info_list .text02')
                # print(section_item)
                if section_item:
                    section_text = ', '.join([item.get_text(strip=True) for item in section_item])
                    sections.append(section_text)
                    print(f'Section: {section_text}')
                else:
                    sections.append(['NA'])


                # 평점
                rate_item = soup.select_one('span.score')
                # print(rate_item)
                if rate_item:
                    rate_text = rate_item.get_text(strip=True)
                    rates.append(rate_text)
                    print(f'Rate: {rate_text}')
                else:
                    rates.append(['NA'])


                # 음식점 내용
                description_item = soup.find('tr', class_='m_only table_row').find('td')
                # print(description_item)
                if description_item:
                    description_text = description_item.get_text(strip=True)
                    descriptions.append(description_text)
                    print(f'Description: {description_text}')
                else:
                    descriptions.append(['NA'])


                # 가격
                price_list = {}
                price_item = soup.find_all('span', class_='menu-price')
                # print(price_item)
                if price_item:
                    for i, price_elements in enumerate(price_item):
                        price_text = price_elements.get_text(strip=True)
                        # price_list.append(price_text)
                        price_list[i] = price_text
                        # print(f'Price: {price_text}')
                    prices.append(price_list)



                # 주소1
                address_item = soup.select_one('.clickable .text02')
                # print(address_item)
                if address_item:
                    address_text = address_item.get_text(strip=True)
                    addresses.append(address_text[2:])
                    print(f'Address: {address_text}')
                else:
                    addresses.append(['NA'])

                # 주소2
                # location_item = soup.select_one('.text02 .link')
                # # print(address_item)
                # if location_item:
                #     location_text = location_item.get_text(strip=True)
                #     locations.append(location_text)
                #     print(f'Address: {location_text}')

                # 리뷰 개수
                review_item = soup.select_one('div.review_title span[data-reactid="75"]')
                if review_item:
                    review_count = review_item.get_text(strip=True).strip('()')
                    review_counts.append(review_count)
                    print(f'Count: {review_count}')
                else:
                    review_counts.append(['NA'])
                
                
                # 리뷰 내용 추출
                review_list = {}
                review_infos = soup.find_all('div', class_='review_text')
                if review_infos:
                    for i, review_info in enumerate(review_infos):
                        review_text = review_info.get_text(strip=True)
                        review_list[i] = review_text
                    review_descrip.append(review_list)
            
                           
                # a += 1
                # if a == 5:
                #     break 

                # 현재 탭 닫기
                driver.close()
                time.sleep(2)

                # 원래 탭으로 전환
                driver.switch_to.window(driver.window_handles[0])
                time.sleep(2)

                

            except Exception as e:
                print(f"크롤링 이상 발생: {e}")

        # 새로운 요소가 없으면 더보기 버튼 클릭
        if not new_elements_found:
            try:
                load_more_button = driver.find_element(By.XPATH, '//*[@id="main_search"]/div/article/section/div[2]/div[1]/a')
                load_more_button.click()
                time.sleep(4)
            except (NoSuchElementException, ElementClickInterceptedException):
                print("더 이상 '더보기' 버튼이 없습니다.")
                break
        else:
            # 페이지를 약간 스크롤하여 새 요소를 로드
            driver.execute_script("window.scrollBy(0, 500);")
            time.sleep(2)

finally:
    driver.quit()
# Out:
# Name: 벽제갈비 방이본점
# Section: 서울-강남>송파/방이, 한국음식>돼지갈비, Take out주차장(있음), 맥주, 소주, 음료, http://www.bjgalbi.com/,https://www.facebook.com/bjgalbi,
# Rate: 4.3
# Description: 월스트리트지가 아시아 5대 음식점의 하나로 선정했고, 중국에서 브랜드 로열티를 받는 등 해외에도 잘 알려진 벽제갈비의 방이동 본점입니다. 1++ 축산 등급 확인서를 확인할 수 있을 만큼 최고급 한우만을 취급합니다.
# Address: 지번서울특별시 송파구 방이동 205-8
# Count: 91
# Name: 평양면옥
# Section: 경기>의정부시, 한국음식>냉면/막국수, 예약 가능주차장(있음), 맥주, 소주, 전통주, 음료,
# Rate: 4.1
# Description: 의정부동에 위치한 서울 대표 평양냉면집의 모태가 되는 '평양면옥'. 장충동 평양면옥, 필동면옥, 서북면옥의 원조격으로 메밀을 사용해 뽑아낸 면에 시원한 육수를 부어 고춧가루를 뿌려 내는 물냉면이 대표 메뉴입니다. 직접 빚은 커다란 손 만두와 돼지고기 수육에 매콤한 양념장을 곁들여 먹는 제육도 인기 메뉴로 냉면과 함께 주문하는 손님이 많습니다.
# Address: 지번경기도 의정부시 의정부동 385
# Count: 89
# Name: 자하손만두
# Section: 서울-강북>부암동/평창/구기, 한국음식>만두/만두전골, Take out예약 가능주차장(있음), 맥주, 소주, 전통주, 차, http://www.jahasonmandoo.com,
# Rate: 3.9
# Description: 이북식 손 만두 전문점 ‘자하손만두’입니다. 북악 스카이웨이 초입에 자리 잡은 이곳에서는 자연과 어우러진 고즈넉한 풍경 속에서 식사를 즐길 수 있습니다. 대표 메뉴는 직접 빚는 만두를 넣은 ‘만두국’입니다. 만둣국은 집 간장으로 간을 해 심심하면서도 부드러운 육수가 담백한 만두와 조화를 이루는 것이 특징입니다. 알록달록한 색감을 자랑하는 떡만둣국 속의 만두는 시금치, 당근, 비트로 색을 내어 다채로운 색감이 식욕을 자극합니다. 만둣국 이외에도 물만두, 찐만두, 편수, 김치만두 등 다양한 종류의 만두가 있습니다.
# Address: 지번서울특별시 종로구 부암동 245-2
# Count: 129
# Name: 명동교자 본점
# Section: 서울-강북>명동, 한국음식>칼국수/국수, Take out주차장(없음), http://www.mdkj.co.kr/,
# Rate: 4.1
# Description: 칼국수와 교자 전문점으로 여러 개의 분점을 가지고 있는 '명동교자'. 외국인들 손님들이 많고, 줄을 서서 기다릴 때가 많은 오래된 노포입니다. 이곳은 칼국수와 마늘김치, 만두의 변함없는 맛 때문에 재방문 하는 손님들이 아주 많습니다. 명동의 맛집으로 손꼽히는 이곳은 밥도 무한리필되어 칼국수와 함께 먹기도 합니다. 담백한 육즙이 나오는 '만두'와 진한 국물의 '칼국수'가 인기 메뉴입니다.
# Address: 지번서울특별시 중구 명동2가 25-2
# Count: 158
# Name: 안주마을
# Section: 서울-강북>서촌누하동/청운효자동, 나이트라이프>포장마차, 예약 가능, 맥주, 소주, 전통주, 음료,
# Rate: 3.5
# Description: 극악의 웨이팅을 자랑하지만 한번 방문하면 또 찾고 싶어지는 마성의 맛집입니다. 저녁 웨이팅을 피해 영업을 시작하는 낮 시간에 맞춰 방문하는 손님들로 오픈하자마자 금세 만석이 되기도 합니다. 전국 각지에서 공수한 신선한 해산물로 맛깔나는 안주들을 만들어냅니다. 퀄리티가 좋은 해산물과 주방장의 손맛이 만나니 어떤 메뉴를 시키던 만족하게 됩니다. 몸통은 식감 좋게 칼집을 내고 다리는 토치로 그을려 불맛과 쫄깃함을 더한 ‘한치회’가 유명하며, 멸치회 무침과 청어알젓과 두부를 오이와 곁들여 먹는 메뉴도 유명합니다. 여기에 탕과 밥 종류를 하나 곁들이면 박수를 받을 만한 메뉴 구색이니 참고하면 좋습니다. 기다려서라도 먹고 갈만한 가치가 있는 집입니다.
# Address: 지번서울특별시 종로구 내자동 1-2
# Count: 9
# Name: 솔밤
# Section: 서울-강남>압구정, 한국음식>한정식,
# Rate: 4.3
# Description: 미국 CIA 요리학교를 졸업하고 임프레션에서 경력을 쌓은 엄태준 셰프의 레스토랑입니다. 한식을 베이스로 한 컨템포러리 퀴진을 표방하는데 프렌치의 색채가 강합니다. 솔잎을 태워 한우 스테이크에 향을 입히고, 솔잎 가닥을 붓으로 활용해 소스를 바르는 등 기물과 요리 곳곳에 녹아든 솔밤의 아이덴티티를 발견하는 재미가 있습니다. 식사 전 마음을 담은 페이퍼부터 고심의 흔적이 담긴 요리, 그리고 식사 후 챙겨주는 젓가락과 선물까지 비단 요리뿐만이 아닌, 들어설 때부터 나설 때까지의 모든 과정이 이곳의 다이닝입니다.
# Address: 지번서울특별시 신사동 629-38   4층
# Count: 3
# Name: 테판 그랜드하얏트서울
# Section: 서울-강북>이태원-한남동/독서당로, 한국음식>덮밥/볶음밥, Take out예약 가능주차장(있음), https://seoul.grand.hyatt.com/ko/hotel/dining/teppan.html,
# Rate: 4.0
# Description: 그랜드 하얏트 호텔 내의 인터내셔널 철판 요리 레스토랑. 남산 중턱에 위치하고 있어 시원한 한강뷰와 화려한 강남 도심 뷰를 즐길 수 있습니다. 철판 스테이션은 2개로 운영되는데, 로맨틱한 분위기의 정원 쪽 스테이션과 이태원, 멀리 한강과 강남이 내려다보이는 한강뷰 스테이션이 있습니다. 좌석 수가 많지 않아 예약은 필수. 단, 한강뷰 스테이션은 낮에 이용 시 햇빛을 바로 받는다는 단점이 있습니다. 준비되는 코스의 구성은 가격대에 따라 차이가 있으며, 최근에는 기름종이에 싸서 구운 '메로 파필로트'의 인기가 좋은 편입니다. 세트뿐 아니라 단품도 준비되어 있습니다.
# Address: 지번서울특별시 용산구 한남동 747-7 그랜드하얏트서울
# Count: 5
# Name: 강민철레스토랑
# Section: 서울-강남>청담동, 세계음식>프렌치, 와인,
# Rate: 4.1
# Description: 피에르 가니에르, 알랭 뒤카스, 조엘로 부숑 세계적 명성의 프렌치 레스토랑에서 경력을 쌓은 강민철 셰프의 레스토랑입니다. 원형 테이블과 파티션, 벽면의 모양까지 유려한 곡선이 가득한 공간이 인상적입니다. 전통적이면서도 새롭다는 말이 어울리는 코스 구성과 요리들이 마음을 설레게 만듭니다. 메인 디시를 맛볼 때는 크리스토플 식기를 꺼내는 등 퍼포먼스적인 부분도 잊지 않았습니다. 예약이 어려운 것이 유일한 단점입니다.
# Address: 지번서울특별시 강남구 청담동 18-38  지하 1층
# Count: 3
# Name: 고성막국수
# Section: 서울-강남>김포공항/방화/마곡지구, 한국음식>칼국수/국수, 주차장(없음), 맥주, 소주, 전통주, 음료,
# Rate: 4.1
# Description: 1996년부터 지금까지 25년의 전통을 이어오고 있는 영동식 막국수 전문점 ‘고성막국수’. 주문과 동시에 손 반죽을 시작해 면을 뽑아 국수를 만드는 점이 특징입니다. 대표 메뉴 ‘동치미 막국수’는 첨가물 없이 순 메밀 100%로 선보이는 면발과 살얼음이 동동 띄워져 있는 동치미 육수가 함께 나옵니다. 메밀 껍질이 붙어 있어 거뭇거뭇한 자태를 뽐내는 면발은 툭툭 끊기는 식감과 씹을수록 입안 가득 퍼지는 구수한 풍미가 일품입니다. 자칫 쌉쌀하게 느껴질 수 있는 순 메밀 면발을 동치미 육수의 단맛이 잡아주며 조화롭게 어울립니다. 오랜 시간 삶아 야들야들한 식감을 뽐내는 ‘편육’도 인기입니다. 밑반찬으로 제공되는 회무침, 백김치를 곁들여 삼합 스타일로 즐기면 됩니다.
# Address: 지번서울특별시 강서구 방화동 323-6
# Count: 100
# Name: 7th Door
# Section: 서울-강남>청담동, 세계음식>유러피안, 예약 가능주차장(있음), 전통주, 와인, 칵테일, 음료, http://www.7thdoor.kr,http://www.instagram.com/7thdoor_official,
# Rate: 평가중
# Description: 김대천 셰프가 한식의 기반인 발효와 숙성에 초점을 맞춰 감각적인 요리를 제시하는 ‘7th Door’. 세븐스도어는 입구 쪽에 마련된 유리 케이스엔 매장에서 수제로 만든 장, 장아찌, 청이 가득 채워져 있습니다. 대표 메뉴 ‘디너 코스’는 그 날 가장한 신선한 재료를 사용하여 매일 구성이 변경되는 점이 특징입니다. 감 푸아그라, 육회 타르트, 발효 호박 무스 감태칩 등 4~5가지가 나오는 아뮤즈 부쉬가 등장하는 순간부터 셰프의 톡톡 튀는 개성을 느낄 수 있습니다. 대천김에 쌀밥과 캐비아를 듬뿍 올려 한입에 먹는 ‘김밥’도 인기입니다. 캐비아와 김이 어우러지며 입안 가득 짙은 감칠맛을 선사합니다.
# Address: 지번서울특별시 강남구 청담동 69-5  4층
# Count: 1
# Name: 밍글스
# Section: 서울-강남>청담동, 세계음식>퓨전, 예약 가능주차장(있음), 전통주, 와인, http://www.restaurant-mingles.com/,
# Rate: 4.4
# Description: 기존의 한식을 재해석하여 틀에 국한되지 않은 자유로운 조리법과 아이디어, 식재료의 조합을 구사하는 강민구 쉐프의 레스토랑입니다. 새로운 식문화의 지표를 만들어 나가고 있다는 호평이 줄을 이으며 2016년 아시아베스트 50 레스토랑에 선정되기도 했습니다.
# Address: 지번서울특별시 강남구 청담동 94-6 더채플앳 청담
# Count: 65
# Name: 어머니대성집
# Section: 서울-강북>고려대/성신여대/돈암동, 한국음식>해장국/국밥/육개장, Take out예약 가능주차장(있음), 맥주, 소주, 음료,
# Rate: 3.9
# Description: 1967년부터 3대째 대를 이어 운영중인 ‘어머니대성집’. 올해 1월, 3층 규모의 건물로 확장 이전하여, 보다 넓고 쾌적한 분위기 속에서 식사를 할 수 있습니다. 대표 메뉴 ‘해장국’은 직접 말린 우거지를 듬뿍 넣어 시원한 맛을 낸 국물에 콩나물, 양지고기, 선지를 푸짐하게 담아 제공합니다. 토렴 과정을 거친 해장국은 밥알 사이사이 국물이 스며들어 있어 간이 고루 배어있는 점이 특징입니다. 진득한 국물에 어우러진 부드러운 우거지와 탱글탱글한 선지의 조화가 일품이다. ‘모듬수육’, ‘육회’, ‘등골’ 등의 다양한 안주 메뉴도 준비되어 있어 애주가들의 많은 사랑을 받고 있습니다.
# Address: 지번서울특별시 동대문구 용두동 232-26
# Count: 68
# Name: 아루히
# Section: 서울-강남>여의도, 세계음식>일식, 예약 가능, 소주, 음료, https://www.instagram.com/aruhi_specialday/,
# Rate: 평가중
# Description: 매월 20일, 온라인으로만 한 달 치 예약을 한꺼번에 받는 ‘아루히’입니다. 냉동고를 따로 구비해 두지 않고 그때그때 신선한 생선들로 스시를 만듭니다. 대표 메뉴 ‘오마카세 디너’는 2~3가지의 츠마미, 스시, 튀김, 후토마키, 후식의 구성으로 이루어졌습니다. 샥스핀과 목이버섯으로 풍미를 살린 차완무시를 시작으로 잿방어, 참치, 참돔, 줄무늬 전갱이, 가리비 관자, 금태 등 15가지 종류의 스시가 본격적으로 등장합니다. 스시 중간중간 건네주는 굴 튀김, 가지 튀김, 네기도로마키, 후토마키로 등의 요리류로 코스의 완성도를 높였습니다. 디너 오마카세 이용 시 주류를 필수로 주문해야 하니 참고하세요.
# Address: 지번서울특별시 영등포구 여의도동 35-5
# Count: 2
# Name: 삼청동수제비
# Section: 서울-강북>삼청동/북촌한옥마을, 한국음식>칼국수/국수, , 전통주, http://www.삼청동수제비.kr,http://samcheongdongsujebi.cityfood.co.kr,
# Rate: 4.0
# Description: ‘삼청동수제비’는 1982년부터 운영 중인 수제비 전문점입니다. 대표 메뉴는 작은 항아리에 담겨 제공되는 ‘수제비’입니다. 멸치를 우려 만든 육수에 바지락을 넣어 시원한 국물 맛을 자랑합니다. 얇게 떼어낸 수제비 반죽은 쫄깃하면서도 부드러운 목 넘김이 특징입니다. 채 썬 호박과 당근, 부추를 넣어 다양한 식감을 느끼는 재미가 있습니다. 100% 생 감자만을 이용해 만든 ‘감자전’은 바삭하면서도 담백한 맛으로 인기라고 하니 참고 바랍니다.
# Address: 지번서울특별시 종로구 삼청동 102-2
# Count: 134
# Name: 라연 서울신라호텔
# Section: 서울-강북>동대문/장충/신당, 한국음식>한정식, 예약 가능주차장(있음), http://www.shilla.net/seoul/dining,
# Rate: 4.1
# Description: 전국에서 가장 훌륭한 식재료를 수급하여 정통 조리법을 바탕으로 현대적으로 재해석한 한식의 정수를 보여주는 라연입니다. 전통의 맛을 세심하고 세련되게 표현한 한식당입니다.
# Address: 지번서울특별시 중구 장충동2가 202 신라호텔
# Count: 17
# Name: 필동면옥
# Section: 서울-강북>충무로, 한국음식>냉면/막국수, 주차장(있음), 맥주, 소주, 전통주, 음료,
# Rate: 4.0
# Description: 평양냉면 전문점. 면발의 색이 투명하고, 가늘고 찰진 것이 특징입니다. 북한 사람들이 전통적으로 먹던 방법처럼 냉면에는 고춧가루가 뿌려져 나옵니다. 냉면을 먹기 전에 꼭 먹어줘야 하는 만두와 편육. 평양식 만두는 먹음직스러운 크기에 만두소가 꽉 차있어 육즙을 그대로 느낄 수 있고, 편육은 질 좋은 고기를 잘 삶아서 독특한 새우젓 양념에 살짝 찍어 먹는 것이 일품이랍니다.
# Address: 지번서울특별시 중구 필동3가 1-5
# Count: 146
# Name: 온지음
# Section: 서울-강북>서촌누하동/청운효자동, 한국음식>한정식, 예약 가능, 전통주, 차, 음료, http://www.instagram.com/onjium_restaurant,
# Rate: 4.1
# Description: 의(衣), 식(食), 주(住) 분야의 전문가들이 한 데 모여 전통문화를 계승하고 현대화에 힘쓰는 아름지기 재단의 음식 공방 ‘온지음’. 조선 왕조 궁중 음식 이수자 조은희 방장과 신라호텔 한식당 서라벌 출신의 박성배 선임 연구원이 필두가 되어 한국의 맛을 풀어냈습니다. 각 계절에 가장 맛이 오른 식재료를 사용하여 죽, 주전부리, 냉채, 생선찜, 전, 회, 식사, 후식 등 다채로운 요리를 탄생시킵니다. 화려한 연꽃 모양의 청자 그릇, 고급스러운 방짜 유기, 깔끔한 백자 그릇 등 음식을 담아내는 각양각색의 식기는 보는 재미를 더하며 식사의 즐거움을 한층 살려줍니다. 매달 바뀌는 메뉴 구성은 공식 SNS를 통해 확인할 수 있습니다.
# Address: 지번서울특별시 종로구 창성동 17-1
# Count: 8
# Name: 하동관 명동본점
# Section: 서울-강북>명동, 한국음식>설렁탕/곰탕/갈비탕, Take out예약 가능주차장(있음), http://www.hadongkwan.com/,
# Rate: 4.0
# Description: 대한민국 대표 곰탕집으로 창업 이후 80년 넘게 이어져 온 전통있는 곳입니다. 40년 넘게 하동관의 국솥을 지켜 한결같은 맛을 유지하고 있으며, 한우만을 사용하여 담백하면서 깊은 맛의 곰탕과 상큼한 단맛의 깍두기는 북촌 반갓집의 기품과 격식 그대로 느낄 수 있습니다. 곰탕은 보통과 특이 준비되어 있는데 기호에 따라 날계란을 추가한 '통닭', 깍두기 국물을 부은 '깍국', 고기의 양을 늘린 '열두공' 부터 '스무공'까지 다양하게 즐길 수 있습니다.
# Address: 지번서울특별시 중구 명동1가 10-4
# Count: 166
# Name: 서촌계단집
# Section: 서울-강북>서촌누하동/청운효자동, 한국음식>해물탕/해물요리, 맥주, 소주, 전통주, 음료,
# Rate: 4.0
# Description: 서울에서 제철 해산물 하면 이 집을 빼놓을 수없습니다. 노랑가오리가 제철인 시즌에는 이 진미를 서울에서 맛볼 수 있어 더욱 좋은 곳입니다. 늘 손님이 많아 회전율이 좋은 만큼 해산물의 신선함은 말할 것이 없습니다. 황가오리는 회로 제공되는데 큼직큼직하게 썰어 입안 꽉 차는 식감을 느낄 수 있습니다. 여기에 가오리애의 버터리한 맛이 소주 안주로 활약합니다. 달큰한 맛이 좋은 ‘참소라’나 녹진한 내장맛이 일품인 ‘오징어통찜’도 인기가 많은 메뉴 중 하나입니다. 또 거의 모든 테이블이 꼭 주문하는 ‘바다라면’은 자극적이지 않고 깔끔한 국물맛으로 해장을 하기에도 일품입니다.
# Address: 지번서울특별시 종로구 내자동 11-1
# Count: 90
# Name: 계향각
# Section: 서울-강북>대학로, 세계음식>중식, https://www.instagram.com/shinkyesook,
# Rate: 평가중
# Description: 수원식단이란 중국 청대 문인 원매 선생이 지은 조리서로서 계향각은 이를 기초로 30년 이상 중식 요리를 연구한 신계숙 교수의 본토 중국요리집입니다. 중국에서 흔히 먹는 가정식 요리부터 고급요리까지 다양합니다.
# Address: 지번서울특별시 종로구 동숭동 31-37  1층
# Count: 2
# Name: 약수순대
# Section: 서울-강북>약수/옥수/금호, 한국음식>순댓국/순대, 소주,
# Rate: 4.1
# Description: 약수동 일대에서는 유명한 오래된 순댓국집입니다. 당면과 선지가 들어간 스타일의 순대로 30여 년의 전통을 가지고 있는 오래된 곳입니다. 식사 시간 대에는 사람이 많아 줄을 서야 할 때가 많으므로 평일에 가볼 것을 추천합니다.
# Address: 지번서울특별시 중구 신당동 857 약수역 더시티
# Count: 13
# Name: 에빗
# Section: 서울-강남>역삼역, 세계음식>퓨전, 예약 가능주차장(있음), 전통주, 와인, http://www.restaurantevett.com,http://www.instagram.com/restaurantevett,http://www.facebook.com/restaurantevett,
# Rate: 4.2
# Description: 미국의 ‘프렌치 런드리’, 영국의 ‘레드버리’ 등 전 세계 유명 레스토랑에서 경력을 쌓은 호주 출신의 조셉 리저우드 셰프의 레스토랑입니다. 역삼동 골목에서 도산공원 인근으로 자리를 이전하면서 더욱 심혈을 기울인 키친 설계를 통해 실험과 준비 과정을 거친 한국의 식재료를 고객에게 선보이고 있습니다. 어느 한국 셰프들보다도 한국의 식재료와 장에 열정을 가지고 탐구하는 셰프인만큼, 다양한 식재료를 사용하면서도 틀에 박히지 않은 요리들을 선보입니다. 한국적인 미를 담은 밝고 뉴트럴한 컬러톤에 푸른 컬러를 포인트로 사용하여 편안하면서도 고급스러운 매장의 분위기도 즐거운 다이닝 경험에 일조를 하는 곳입니다.
# Address: 지번서울특별시 강남구 신사동 650-13 LS빌딩  1층
# Count: 3
# Name: 키이로
# Section: 서울-강남>신사-가로수길, 세계음식>일식, http://instagram.com/tempura_kiro,
# Rate: 평가중
# Description: 한우, 스시오마카세에 비해 합리적인 가격으로 만날 수 있는 일본식 튀김 오마카세 전문점입니다. 10차례 넘게 이어지는 코스요리로 매일매일 가장 신선한 재료로 만들어지는 튀김요리를 맛볼 수 있습니다. 가게 내부는 작은 편이며 미리 예약하는 것이 필수입니다.
# Address: 지번서울특별시 강남구 신사동 504-11 SINSA SQUARE 2층 2층
# Count: 1
# Name: 호수집
# Section: 서울-강북>서대문/충정로, 한국음식>닭볶음탕/닭갈비/닭발, 맥주, 소주, 전통주,
# Rate: 4.1
# Description: 연탄불 직화로 갓 구워낸 닭꼬치는 고추장 양념과 불맛이 배어 있으며 뼈째 먹는 식감이 예술입니다. 이외에도 식사하기 좋은 닭도리탕과 오삼불고기도 있어 취향에 맞게 주문하여 드시는 걸 추천합니다.
# Address: 지번서울특별시 중구 중림동 61-4
# Count: 104
# Name: 알라프리마
# Section: 서울-강남>논현/학동, 세계음식>퓨전, 예약 가능주차장(있음)노키즈존, 와인, 음료, http://allaprima.co.kr,
# Rate: 3.5
# Description: 일본에서 요리를 공부한 김진혁쉐프가 오너세프로 있는 일본스타일의 퓨전 이탈리안 레스토랑입니다. 테이블자리도 있지만 오픈키친앞의 카운터 자리가 더 인기가 많습니다. 합리적인 가격으로 아주 긴 코스를 자랑하는 코스요리가 이채롭습니다. 30여가지 이상의 야채와 허브를 사용하고 신선한 식재료를 사용하여 다양한 메뉴를 선사합니다. 특히 청어나 금태 같은 생선을 이용한 요리들이 독특하기까지 합니다. 이탈리안 레스토랑이지만 전혀 이탈리안 스럽지 않고 오히려 스시야에 온듯한 느낌을 받는 음식들도 많습니다. 비교적 좋은 가격에 만족할만한 긴 코스가 매력적입니다. 음식맛도 훌륭합니다.
# Address: 지번서울특별시 강남구 논현동 42-6
# Count: 11
# Name: 서울신라호텔팔선
# Section: 서울-강북>동대문/장충/신당, 세계음식>중식, 예약 가능주차장(있음), 맥주, 와인, 백주, 차, 탄산수, 음료, http://www.shilla.net/seoul/dining,
# Rate: 4.3
# Description: 동대입구역 5번 출구 인근에 있는, 신라호텔 2층에 위치한 중식당 ‘팔선’. 광둥과 북경 지방 출신의 조리사들이 선보이는 중국 본토의 맛을 경험할 수 있습니다. 식사류로 인기가 많은 볶음밥은 파인애플부터 킹크랩, 새우, 닭고기, 바비큐 등 약 8가지 메뉴가 준비되어 있어 선택의 폭이 넓습니다. 대표 메뉴 ‘팔진 볶음밥’은 질 좋은 한우와 통통하게 살이 오른 새우를 주재료로 기름지지 않게 볶아 낸 점이 특징입니다. 전체적으로 깔끔한 맛이 돋보이는 볶음밥은 중간중간 씹히는 소고기와 새우가 식감을 살려주는 것과 동시에 감칠맛을 더하며 조화롭게 어우러집니다.
# Address: 지번서울특별시 중구 장충동2가 202 신라호텔 2층
# Count: 71
# Name: 콘피에르
# Section: 서울-강북>서울역/남대문, 세계음식>퓨전, 예약 가능주차장(있음), 와인, 음료, http://www.instagram.com/confier.seoul,https://app.catchtable.co.kr/ct/shop/confier,
# Rate: 평가중
# Description: ‘콘피에르’는 한국에서 나고 자란 제철 식자재를 활용해 프렌치 스타일의 코스요리로 풀어내는 파인 다이닝입니다. 생소한 식재료를 사용하며 이해를 강요하는 것이 아닌, 누구나 접근하고 비평할 수 있는 재미를 선사합니다. '기승전결'을 갖추고 있는 콘피에르의 코스요리를 통해 다양한 식재료들이 하나의 예술 작품으로써 완성되는 과정을 감상해보세요.
# Address: 지번서울특별시 중구 남대문로5가 831 그랜드센트럴(GRAND CENTRAL)  지하 2층
# Count: 2
# Name: 을밀대 평양냉면
# Section: 서울-강북>마포/공덕, 한국음식>냉면/막국수, Take out예약 가능주차장(있음), 맥주, 소주, 전통주,
# Rate: 4.0
# Description: 이곳은 40년 이상의 전통을 가지고 있는 냉면 전문점입니다. 한우 육수로 국물을 내고, 직접 면을 뽑아낸다고 합니다. 또한 이곳은 모두 룸식으로 되어 있어 개인적인 자리가 가능하다고 합니다. 보통 한 방에 두 개의 테이블이 배치되어 있고 한 개의 테이블만 있는 곳도 있습니다. 메뉴는 정말 간단하며, 그중에서도 물냉면이 가장 인기입니다. 평양냉면 특유의 독특한 맛을 볼 수 있는 곳입니다.
# Address: 지번서울특별시 마포구 염리동 147-6
# Count: 175
# Name: 무오키 MUOKI
# Section: 서울-강남>청담동, 세계음식>유러피안, 예약 가능주차장(있음), 와인, http://www.muoki.kr,http://www.instagram.com/muoki.seoul,
# Rate: 3.9
# Description: 박무현 셰프가 미국을 시작으로 영국, 호주, 남아공까지 해외 경험을 통해 쌓은 노하우를 바탕으로 독창적인 요리를 선보이는 ‘MUOKI’. 오픈 주방이 매장 중앙에 위치하고 있어 활기찬 분위기 속에서 식사를 즐길 수 있습니다. 대표 메뉴는 셰프의 개성이 녹아든 요리를 차례로 맛볼 수 있는 ‘런치/디너 코스’. 코스 초반에 제공되는 ‘Tomato #4’는 토마토를 피클, 젤리, 튀일, 드레싱 등 여섯 가지 조리 방식으로 만든 시그니처 메뉴입니다. 토마토라는 주제 하나로 다채로운 맛과 식감을 표현한 점이 인상적입니다. 음식에 곁들여 마시기 좋은 주류는 스파클링 와인부터 레드/화이트/디저트 와인, 샴페인까지 다양하게 준비되어 있습니다.
# Address: 지번서울특별시 강남구 청담동 38-4
# Count: 5
# Name: 진미식당
# Section: 서울-강북>마포/공덕, 한국음식>꽃게/랍스터/새우, 예약 가능주차장(있음), 맥주, 소주, 음료, http://thejinmi.modoo.at/,
# Rate: 4.2
# Description: 간장게장 전문점 ‘진미식당’입니다. 정치인, 연예인, 대기업 간부들의 단골집으로도 소문난 곳입니다. 간장게장과 정갈한 밑반찬, 게국지, 계란찜이 함께 나오는 ‘간장게장정식’이 대표 메뉴이자 단일 메뉴입니다. 직거래를 통해 대천, 서산을 비롯한 서해에서 건져 올린 싱싱한 꽃게만 사용합니다. 숙성과정을 거친 간장 양념은 자극적이지 않아, 꽃게 본연의 맛을 느낄 수 있습니다. 밥에 양념과 꽃게살을 넣고 버무린 후 감태에 싸서 한입에 먹으면, 입안 가득 퍼지는 깊은 감칠맛이 일품입니다. 식사를 마쳐갈 즈음 제공되는 구수한 숭늉은 입가심으로 마무리하기 좋습니다.
# Address: 지번서울특별시 마포구 공덕동 105-127 선화의원
# Count: 121
# Name: 스시조
# Section: 서울-강북>시청, 세계음식>일식, Take out예약 가능주차장(있음), https://www.josunhotel.com/hotel/westinSeoul.do,
# Rate: 4.0
# Description: 스시 명가인 서울 웨스틴조선호텔 일식당 스시조(鮨朝)는 ‘보고 음미하는 요리’인 일식에 현대적인 감각을 불어넣은 신화식으로 세계적인 레스토랑 가이드북 ‘자갓(ZAGAT)’한국판에서 맛 부분으로 최고의 레스토랑으로 인정 받는 등 그 명성을 확인 받고 있습니다. 스식코스와 오마카세 코스가 인기가 많습니다. 도쿄의 유명 스시집 큐베 출신의 일본인 수석셰프가 요리를 담당하며, 스시, 조림, 튀김을 따로 주문할 수 있고, 코스요리도 준비되어 있습니다. 원래 지하에 자리잡고 있다가, 2009년 20층으로 위치를 옮기고 메뉴를 강화했습니다.
# Address: 지번서울특별시 중구 소공동 87-1 서울웨스틴조선호텔
# Count: 57
# Name: 몽탄
# Section: 서울-강북>용산/삼각지, 한국음식>돼지구이, 예약 가능주차장(없음), 맥주, 소주, 음료,
# Rate: 4.1
# Description: 삼각지역 8번 출구 인근에 위치한 '몽탄'은100년이 넘은 적산가옥을 개조하여 짚불 구이 전문점으로 재탄생했습니다. 대표 메뉴 '우대 갈비'는 소갈비 부위 중 가장 맛있다고 소문 난 진갈비를 달짝지근한 간장 양념장에 재운 후 초벌구이하여 제공됩니다. 숯불로 짚을 태우는 초벌구이 과정을 거쳐 갈비 전체적으로 배어 있는 은은한 불 향이 일품입니다. 밑반찬으로 나오는 살짝 얼어 있는 무생채는 갈비의 감칠맛을 한층 살려주고 차가운 온도가 뒷맛을 깔끔하게 마무리해줍니다. 냉이가 듬뿍 들어가 구수하면서도 향긋한 국물을 자랑하는 '된장찌개'는 식사 메뉴로 즐겨 찾습니다. 재료 소진으로 조기 마감되는 경우가 많아 전화 확인 후 방문하는 것을 추천합니다.
# Address: 지번서울특별시 용산구 한강로1가 251-1
# Count: 6
# Name: 새벽집 청담동점
# Section: 서울-강남>청담동, 한국음식>육회/육사시미, 예약 가능주차장(있음), 맥주, 소주, 전통주, 백주, 음료, https://saebyukjip.modoo.at/,
# Rate: 4.0
# Description: 소고기 전문점 ‘새벽집’은 유명 연예인들의 단골집으로도 유명합니다. 매장 내부는 테이블마다 분리되어 있어 편안한 분위기에서 식사할 수 있습니다. 대표 메뉴 ‘육회비빔밥’을 주문하면 얼큰한 선지 해장국이 서비스로 제공됩니다. 비빔밥은 애호박, 당근, 콩나물, 김가루 등 기본 나물 위에 붉은 육회가 푸짐하게 얹어 나옵니다. 고추장 양념을 넣고 비벼낸 비빔밥을 마른 김에 싸서 먹는 것도 별미입니다. 전라도 함평과 화순에서 매일 공급받은 한우 암소를 이용한 ‘꽃등심’도 인기 메뉴입니다. 24시간 영업을 하므로 부담 없이 방문하기 좋습니다.
# Address: 지번서울특별시 강남구 청담동 129-10
# Count: 174
# Name: 대성갈비
# Section: 서울-강북>성수/서울숲/뚝섬, 한국음식>돼지갈비, 맥주, 소주,
# Rate: 3.5
# Description: 효율적인 공간 활용으로 주변 직장인들의 회식 장소로 유명한 성수의 ‘대성갈비’입니다. 맛있는 갈비를 상추, 깻잎을 비롯해 배추, 당귀 등 다양한 쌈채소와 함께 즐길 수 있습니다. 대표 메뉴는 선홍빛 갈빗살을 달달한 양념에 재운 후, 숯불에 구워 먹는 ‘돼지갈비’로 참숯에 구워 내어 숯향이 가득하고 한 층 깊어진 감칠맛이 납니다. 고기를 주문하면 함께 나오는 김치찌개와 봉긋하게 솟아오른 계란찜에 넉넉한 인심을 느낄 수 있는 곳입니다. 김치찌개 속 푸짐한 돼지고기에 든든한 식사도 할 수 있습니다.
# Address: 지번서울특별시 성동구 성수동1가 656-591 서울숲A타워  101호~103호
# Count: 18
# Name: 진주집
# Section: 서울-강남>여의도, 한국음식>칼국수/국수, Take out예약 가능주차장(있음), 맥주, 소주, 음료,
# Rate: 4.0
# Description: 여의도 백화점 지하 1층에 위치한 ‘진주집’입니다. 점심시간에는 직장인들로 늘 북적이는 곳입니다. 대표 메뉴는 국내산 콩으로만 국물을 만들어 깊은 풍미를 자랑하는 ‘냉콩국수’입니다. 소금을 넣어 비릿함을 없애 콩국수를 처음 먹어보는 사람도 쉽게 즐길 수 있습니다. 뜨끈한 국물에 부추 무침, 닭고기, 만두를 고명으로 풍성하게 올린 ‘닭칼국수’도 인기 메뉴입니다. 밑반찬으로 제공되는 달큰한 보쌈김치와 곁들여 한입에 먹으면 더욱 맛있게 즐길 수 있습니다. 여유로운 식사를 즐기고 싶다면 평일 점심 시간대를 피해 방문하는 것을 추천합니다.
# Address: 지번서울특별시 영등포구 여의도동 36-2
# Count: 141
# Name: 성수족발
# Section: 서울-강북>성수/서울숲/뚝섬, 한국음식>족발/보쌈, Take out, 맥주, 소주, 전통주, 음료, http://blog.naver.com/ssjb1983,http://ssjb1983.modoo.at/,
# Rate: 4.0
# Description: 30년 전통의 족발 맛집 '성수족발'은 서울 3대 족발집으로 알려진 유명한 곳입니다. 이 곳 족발의 특징은 잡내가 전혀 없고, 따로 소스를 찍어 먹지 않아도 될 정도로 껍질과 속살까지 양념이 잘 베어 있다는 것입니다. 또한, 특유의 단맛 덕분에 계속 먹어도 느끼하거나 물리지 않는다고 합니다. 밑반찬으로 제공되는 부추무침이나 김치, 무생채와 곁들여 먹으면 더욱 맛있게 즐길 수 있습니다.
# Address: 지번서울특별시 성동구 성수동2가 289-273 동진빌딩
# Count: 128
# Name: 봉피양 방이점
# Section: 서울-강남>송파/방이, 한국음식>소구이/불고기, Take out예약 가능주차장(있음), 맥주, 소주, 음료, http://www.bjgalbi.com,http://bonpiyang.modoo.at,
# Rate: 4.0
# Description: 매일 직송하는 벽제 갈비에서 운영하는 평양냉면과 한우 꽃등심 설화등심 갈비가 유명한 곳입니다. 냉면은 고기 육수와 동치미 국물이 어우러져 깔끔하고, 70% 이상 메밀로 만든 면을 사용합니다. 돼지갈비는 국내산 돈육에 담백한 양념, 고급 숯 백탄을 사용하여 구워내는 것이 특징이며, 한우 설렁탕과 양곰탕도 인기 메뉴입니다. 예약은 8인 이상 단체만 가능하니 참고 바랍니다.
# Address: 지번서울특별시 송파구 방이동 205-8
# Count: 78
# Name: STAY 시그니엘서울
# Section: 서울-강남>잠실-롯데월드/롯데타워, 세계음식>프렌치, Take out불가예약 가능주차장(있음), 와인, 양주, 커피, 차, 주스, 음료, http://www.lottehotel.com/signielseoul/,
# Rate: 3.7
# Description: 시그니엘서울 81층에 자리 잡은 프렌치 모던 다이닝, ‘스테이’입니다. 아름다운 전망과 함께 창의적인 프랑스 요리를 즐길 수 있습니다. 다양한 옵션으로 준비된 코스 중 대표 인기 메뉴는 ‘한우 안심구이와 매쉬드 감자’입니다. 전 세계 스테이 지점에서 스테디셀러로 꼽히는 메뉴로 쫄깃한 한우 안심과 흑후추 향의 조화로운 맛을 느낄 수 있습니다. 메쉬드 포테이토는 버터 풍미 가득한 부드러운 맛으로 곁들여 먹기 좋습니다. 레스토랑 내 즉석 페이스트리 시연 코너에서는 다양한 디저트를 무제한으로 맛볼 수 있습니다. 전문 파티세의 퍼포먼스까지 진행된다고 합니다.
# Address: 지번서울특별시 송파구 신천동 29 롯데월드타워 81층
# Count: 10
# Name: 토속촌
# Section: 서울-강북>서촌누하동/청운효자동, 한국음식>삼계탕/백숙/찜닭, Take out주차장(있음), 맥주, 소주, 전통주, http://www.tosokchon.co.kr/,https://www.facebook.com/Tosokchon,http://www.instagram.com/Tosokchon_Samgyetang,
# Rate: 4.0
# Description: 한옥을 개조하여 만든 건물로, 외국인 관광객들도 많이 찾는다는 삼계탕집입니다. 견과류 들어간 영계삼계탕 맛집으로 소개되어 더욱 인기 있는 곳입니다. 4년생 인삼, 국내산 대추, 호박씨, 은행, 검은깨 등 각종 한약재와 견과류를 갈아넣어 국물이 고소하고 진한 것이 특징이라고 합니다. 다양하고 신선한 식재료들만을 사용해서 보양식이 따로 없는 훌륭한 요리입니다.
# Address: 지번서울특별시 종로구 체부동 85-1
# Count: 173
# Name: 부자피자 1호점
# Section: 서울-강북>이태원-한남동/독서당로, 세계음식>피자, Take out예약 가능주차장(없음), 맥주, 와인, 칵테일, http://www.buzzapizza.com/,
# Rate: 4.1
# Description: 최고의 식재료를 사용하여 이탈리아 정통의 피자 방식을 고수하면서 새로운 식문화 전달에 앞장서는 피자 전문점으로 줄이 길게 늘어서서 기다릴 정도로 인기가 아주 높은 집입니다. 쫀득하면서 담백한 도우가 매력적인 진정한 이탈리아 화덕피자를 맛 볼 수 있습니다.
# Address: 지번서울특별시 용산구 한남동 743-33 1층
# Count: 129
# Name: 목포집
# Section: 서울-강남>신사역, 한국음식>닭볶음탕/닭갈비/닭발, Take out예약 가능주차장(있음), 맥주, 소주, 와인, 음료,
# Rate: 4.1
# Description: 신사역 부근 골목길에 위치한 닭볶음탕 전문점, ‘목포집’입니다. 대표 메뉴는 강렬한 붉은 색 양념의 ‘닭볶음탕’입니다. 닭 속까지 베여 있는 매콤한 양념은 짭조름하면서도 달큰한 맛이 매력적입니다. 자작하면서 진득한 국물은 흰쌀밥에 안성맞춤. 남은 양념에 김가루와 깨를 듬뿍 넣은 ‘볶음밥’도 별미입니다. ‘닭볶음탕’을 주문하면 함께 제공되는 다양한 반찬은 정감가는 전라도의 손맛을 고스란히 느끼도록 해줍니다. 시원하고 칼칼한 맛의 ‘생태찌개’도 인기 메뉴입니다.
# Address: 지번서울특별시 강남구 신사동 514-3
# Count: 127
# Name: 금돼지식당
# Section: 서울-강북>약수/옥수/금호, 한국음식>돼지구이, 예약 불가, 맥주, 소주, 전통주, 음료, https://www.instagram.com/gold_pig1982,http://goldpig1982.blog.me,
# Rate: 4.1
# Description: 돼지고기 전문점인 ‘금돼지식당’은 방탄소년단, 엑소 등 유명 연예인들이 즐겨 찾는 곳으로 소문난 곳입니다. 1층은 일반 식당, 2층은 바, 3층은 테라스 좌석으로 층별로 다른 분위기를 느낄 수 있습니다. 이 집의 모든 고기는 풍부한 육즙의 살코기와 진한 지방의 풍미를 자랑하는 버크셔, 요크셔, 듀록 돼지의 교배종인 YBD만을 사용합니다. 갈빗대가 붙어 있는 삼겹살 부위인 ‘본삼겹’이 대표 메뉴입니다. 삼겹살과 갈빗살 두 가지 부위를 맛볼 수 있으며 쫀득하면서 탱글탱글한 식감이 일품입니다. 알맞게 익은 고기는 먼저 고기 본연의 맛을 느낄 수 있는 소금에 살짝 찍어 먹고, 이후에는 갈치 속젓 또는 간장 소스를 곁들여 먹는 방법이 팁입니다.
# Address: 지번서울특별시 중구 신당동 370-69
# Count: 10
# Name: 소이연남
# Section: 서울-강북>연남동, 세계음식>태국, Take out주차장(없음), 맥주, https://www.instagram.com/soi_yeonnam/,
# Rate: 4.4
# Description: 툭툭누들타이의 2번째 브랜드이며 테이스티 로드에 방영된 곳. 소이는 태국어로 길이라는 뜻. 태국식 소고기 쌀국수가 주 메뉴이며 그 밖에 파파야 샐러드인 쏨땀, 소고기국밥, 소이뽀삐아, 수육 등이 있으며 세트메뉴가 준비되어 있다. 소고기 국수는 면발의 굵기를 보통면, 얇은면 선택 가능하다. 매장 내부는 태국의 길거리 식당에 들른 듯한 느낌을 주는 곳.
# Address: 지번서울특별시 마포구 연남동 229-67
# Count: 25
# Name: 레스토랑 알렌
# Section: 서울-강남>역삼역, 세계음식>프렌치, https://app.catchtable.co.kr/ct/shop/allen,
# Rate: 평가중
# Description: 조선팰리스가 위치한 센터필드 E5쪽으로 올라오면 바로 보이는 곳입니다. 차분한 내부 인테리어와 함께 웰컴티부터 디저트까지 환상적이고 정교한 프랑스 파인다이닝을 즐길 수 있습니다. 예약금 10만원이 있으며 식사 후 돌려주는 방식입니다.
# Address: 지번서울특별시 강남구 역삼동 676 2층 E205호
# Count: 1
# Name: 진미평양냉면
# Section: 서울-강남>논현/학동, 한국음식>냉면/막국수, Take out예약 가능주차장(있음), 맥주, 소주, 음료, http://jinmipy.modoo.at,
# Rate: 4.4
# Description: ‘진미평양냉면’에서는 평양냉면과 다양한 이북식 음식을 맛볼 수 있습니다. 대표 메뉴는 그릇의 바닥이 보일 정도로 투명한 육수에 푸짐한 면사리를 더한 ‘냉면’입니다. 진한 육향이 느껴지는 육수는 담백하면서도 깔끔한 맛이 특징입니다.제육, 편육, 만두 등 냉면에 곁들여 먹기 좋은 사이드 메뉴도 합리적인 가격에 만나볼 수 있습니다.
# Address: 지번서울특별시강남구 논현동 115-10
# Count: 16
# Name: 아리아께
# Section: 서울-강북>동대문/장충/신당, 세계음식>일식, 주차장(있음), http://www.shilla.net/seoul/dining,
# Rate: 4.0
# Description: 섬세하고 우아한 전통미와 세련된 현대미가 조화를 이룬 인테리어와 일본과 한국을 조화시킨 감각적인 푸드 스타일링을 선보입니다. 국내의 엄선된 완도의 청정수산물과 일본의 자연산 최고급 식재료를 직접 운송해서 가장 신선한 상태로 준비합니다. 스시코스와 오마카세가 인기가 많습니다.
# Address: 지번서울특별시중구 장충동2가 202신라호텔
# Count: 22
# Name: 소문난성수감자탕
# Section: 서울-강북>성수/서울숲/뚝섬, 한국음식>감자탕, Take out주차장(있음), 맥주, 소주, 전통주, 음료,
# Rate: 3.5
# Description: 성수 수제화 거리에 위치한 곳으로 인기가 많아 늘 웨이팅이 있는 맛집으로도 유명합니다. 메뉴는 여럿이서 먹기 좋은 감자탕과 뚝배기에 나오는 뼈해장국인 ‘감자국 식사 종류뿐입니다. 부드러운 우거지가 참 맛있기 때문에 기본 해장국보다는 우거지가 들어간 ‘우거지 감자국’이나 ‘우거지 곱빼기’를 추천합니다. 곱빼기를 주문하면 진한 국물에 돼지뼈와 함께 우거지를 산처럼 쌓아주는데, 이곳의 국물은 해장국 좀 먹으러 다닌 사람이라면 모두 인정할 만한 FM 같은 맛입니다. 함께 나오는 수제 소스가 아주 별미라 이곳을 자꾸 찾게 만드는 매력적인 조연이 됩니다.
# Address: 지번서울특별시 성동구 성수동2가 315-54
# Count: 18
# Name: 스시코우지
# Section: 서울-강남>논현/학동, 세계음식>일식, 주차장(있음)룸 있음, 맥주, 소주, 전통주, 음료, http://www.sushikoji.co.kr/,
# Rate: 3.8
# Description: 적지 않은 가격만큼 휼륭한 맛과 서비스를 보이는 곳입니다. 고급스러운 분위기에서 최고급 스시를 맛볼 수 있습니다. 신선한 맛이 특히 일품인 이곳은 특별한 날이나 중요한 모임을 하기에도 제격입니다.
# Address: 지번서울특별시 강남구 논현동 92
# Count: 15
# Name: 이문설렁탕
# Section: 서울-강북>인사동, 한국음식>설렁탕/곰탕/갈비탕, Take out예약 가능주차장(없음), 맥주, 소주, 전통주, 음료, https://imun.modoo.at,
# Rate: 4.1
# Description: 100년 전통의 '이문설농탕'. 종로의 역사를 함께한 공로를 인정받아 서울 미래 유산으로 지정된 곳이기도 합니다. 대표 메뉴는 토렴된 밥과 소면이 담겨 나오는 형식의 '설렁탕'. 뽀얀 국물과 맑은 국물의 중간쯤 되는 설렁탕은 슴슴하면서도 구수한 맛이 일품입니다. 고기 국물임에도 불구하고 기름기가 덜해 담백한 것이 특징이며, 기본 간이 되어있지 않아 개인의 취향에 맞춰 소금, 후추, 대파 등을 첨가해 먹을 수 있습니다. '특설렁탕'을 주문 시 비장이나 소 혀, 머릿고기 등 소의 다양한 부위를 맛볼 수 있습니다. 설렁탕과 김치 모두 조미료를 사용하지 않아 자극적이지 않고 깔끔한 맛이 이 곳의 특징입니다.
# Address: 지번서울특별시 종로구 견지동 88
# Count: 112
# Name: 정식당
# Section: 서울-강남>청담동, 한국음식>한정식, 예약 가능주차장(있음)룸 있음, 맥주, 와인, 음료, https://www.jungsik.kr/hello/,
# Rate: 4.1
# Description: 매달 바뀌는 코스요리만 제공되는 퓨전 한식당으로 서울과 뉴욕에서 운영되고 있습니다. 뉴 코리안 요리를 보여주려는 임정식 오너셰프의 창작요리를 만날 수 있습니다.
# Address: 지번서울특별시 강남구 청담동 83-24
# Count: 57
# Name: 원조호수삼계탕
# Section: 서울-강남>영등포/신도림/신길, 한국음식>삼계탕/백숙/찜닭, Take out주차장(있음), 맥주, 소주, 전통주, 음료, www.hosufood.com/,
# Rate: 4.0
# Description: 신길동에 위치한 들깨삼계탕으로 유명한 호수삼계탕입니다. 삼계탕의 느끼한 맛을 싫어하시는 분들이 짠맛이나 기름기 없이 담백하고 구수하게 즐길 수 있는 독특한 국물의 삼계탕집입니다. 닭머리, 닭발 등을 푹고아낸 물에 들깨, 찹쌀, 참깨가루 등을 풀어 국물이 스프처럼 걸쭉한 것이 특징입니다. 닭고기, 쌀, 깍두기 등을 국내산으로만 사용하며 1시간 반동안 삶은 영계를 넣어 부드러운 육질의 닭을 드실수 있습니다.
# Address: 지번서울특별시 영등포구 신길동 342-108
# Count: 107
# Name: 물랑
# Section: 서울-강북>서촌누하동/청운효자동, 세계음식>프렌치, 예약 가능, 와인, 커피, 차, 주스, 음료, https://www.instagram.com/moulin_official/,
# Rate: 4.3
# Description: 예약제로 운영되는 ‘물랑’은 정통 프렌치 파인 다이닝을 즐길 수 있는 곳입니다. 직접 수집한 원목 오브제로 꾸민 인테리어와 블랙톤의 조화로 차분하면서도 우아한 분위기를 자랑합니다. 메뉴는 단일 코스로만 제공되며 계절별로 바뀌어 준비됩니다. ‘여름 코스’ 중 가장 인기 있는 메뉴는 메인 메뉴로 제공되는 ‘송아지 안심 쌈’입니다. 배춧잎에 감싼 송아지 안심 요리로, 부드러운 송아지 스테이크의 육질과 아삭하게 씹히는 배춧잎의 조화로운 맛을 느낄 수 있습니다. 디저트 코스인 ‘금귤 마말레이드를 곁들인 프로마주’는 와인에 곁들이기 좋은 메뉴로 세프님이 직접 공수한 치즈를 다양하게 맛볼 수 있어 인기가 좋습니다.
# Address: 지번서울특별시 종로구 창성동 87-1
# Count: 11
# Name: 우래옥
# Section: 서울-강북>을지로, 한국음식>냉면/막국수, Take out예약 가능주차장(있음), 맥주, 소주, 전통주, 와인, 음료,
# Rate: 4.0
# Description: 상가와 공장들이 오밀조밀하게 붙어 있는 을지로4가 좁은 골목길을 지나면 만날 수 있는 ‘우래옥’. 1946년 평양 출신의 창업주가 첫 문을 열고 지금까지 명맥을 이어오고 있는 유서 깊은 식당입니다. 평양냉면 맛집으로 널리 알려졌지만, 마니아층 사이에선 ‘김치말이 냉면’이 별미로 꼽힙니다. 김치말이 냉면은 밥 위로 메밀 면사리를 올린 뒤 고기 육수를 넉넉하게 붓고 김치, 배, 양지를 얹어 제공합니다. 짙은 육향이 감도는 육수에 배추김치와 나박김치의 맛이 어우러지며 한층 고급스러운 맛을 냅니다. 감칠맛 가득한 육수에 더해지는 메밀 면의 구수함이 일품입니다. 주문 시 기호에 맞게 면이나 밥을 뺄 수 있으니 참고 바랍니다.
# Address: 지번서울특별시 중구 주교동 118-1
# Count: 163
# Name: 임프레션
# Section: 서울-강남>압구정-도산공원/로데오, 세계음식>유러피안, 예약 가능주차장(있음), 와인, http://www.limpression.co.kr,https://www.instagram.com/limpression_seoul/,
# Rate: 평가중
# Description: 임프레션은 이 땅에서 자란 식자재를 활용하여, 숙성과 발효에 대한 깊은 이해와 한국 본연의 요리법을 접목한 컨템포러리 프렌치 퀴진을 선보입니다. 임프레션의 철학과 영감, 그리고 열정이 녹아 든 최고의 식사를 통해 기억에 남을 특별한 순간을 경험하시기 바랍니다.
# Address: 지번서울특별시 강남구 신사동 649-7
# Count: 2
# Name: 제로컴플렉스
# Section: 서울-강북>남산/후암동, 세계음식>프렌치, 예약 가능주차장(있음), 와인, http://instagram.com/zerocomplex_seoul,https://catchtable.co.kr/zerocomplex,
# Rate: 4.1
# Description: 서빙고역 인근에 위치한 프렌치 레스토랑인 ‘제로 컴플렉스’는 복합 문화 공간입니다. 런치와 디너로 나뉘어 코스 형태로만 제공되며 런치코스는 6가지 메뉴, 디너코스는 8가지 메뉴로 구성되어 있습니다. 코스 중 인기 메뉴는 직접 기른 허브를 사용해 화려한 플레이팅을 자랑하는 ‘생선 스테이크’입니다. 제철 생선으로 요리하기 때문에 생선 종류가 달라질 수 있으니 참고 바랍니다. 이외에도 해산물과 허브를 창의적으로 배합한 다양한 음식을 선보이고 있습니다.
# Address: 지번서울특별시 용산구 서빙고동 205-2
# Count: 62
# Name: 진진
# Section: 서울-강북>망원/성산, 세계음식>중식, Take out예약 가능, http://jinjinseoul.modoo.at/,
# Rate: 3.9
# Description: 40여 년 경력의 중식계 대부 왕육성 셰프가 오픈한 중식당으로 3만 원의 가입비를 내고 회원으로 등록 시 평생 20% 할인된 가격으로 음식을 즐길 수 있다고 합니다. 진진의 대표 인기 메뉴는 단연 ‘멘보샤’입니다. 낮은 온도에서부터 튀겨내기 시작해 겉은 바삭하고, 속은 촉촉하게 유지한 것이 포인트입니다. 바삭한 식빵 튀김 속에는 통통하고 탱글탱글한 새우 살을 넣어 식감을 살렸습니다. 고소한 맛과 함께 새우의 단맛이 입안 가득 전하는 풍미가 일품입니다. 가지와 함께 각종 야채, 다진 돼지고기를 넣고 볶아낸 '어향가지'와 대게살, 죽순, 양파 등을 함께 볶아낸  ‘대게살 볶음’ 역시 인기 메뉴 중 하나이니 참고 바랍니다.
# Address: 지번서울특별시 마포구 서교동 469-67
# Count: 17
# Name: 원강
# Section: 서울-강남>신논현/영동시장, 한국음식>소구이/불고기, 예약 가능주차장(있음), 맥주, 소주, 음료,
# Rate: 4.1
# Description: 주인이 직접 골라 당일날 막 잡은 한우를 전남 함평에서 매일매일 직송받아 사용하는 한우생고기전문점 원강입니다. 초원에서 좋은 흙냄새를 맡고 자란 한우암소 1등급만을 사용하는 자부심이 있는 가게로 저렴한 가격은 아니지만 어떤 다른 가게보다도 질 좋은 한우를 제공합니다. 간받이 꽃등심 안창살 갈비살 등이 인기가 많으며 밥을 지어서 바로 내오는 무밥도 인기가 많습니다.
# Address: 지번서울특별시 강남구 논현동 122-19
# Count: 87
# Name: 스와니예
# Section: 서울-강남>신사역, 세계음식>퓨전, Take out불가야외 좌석(없음)예약 가능주차장(있음)룸 없음, 와인, https://www.instagram.com/soigneseoul/,
# Rate: 4.3
# Description: 팝업 레스토랑으로 유명세를 가진 이준 쉐프의 레스토랑으로 트렌디하게 음식을 풀어나가는 다이닝 공간입니다. 다국적 음식의 집합지라고 할 수 있으며 메뉴는 런치, 디너 세트로 구성되어 있습니다. 최근 스와니예 수쉐프인 김호윤 쉐프도 방송에 출연하면서 인기를 더하고 있습니다. 스와니예는 프랑스어로 정성을 다한다는 의미를 갖고 있는데, 이준 쉐프의 유학시절 닉네임이자 요리의 모토이기도 합니다. 프랑스에서 유학한 이준 쉐프가 정통 프랑스 요리에 한국식 요리 기법을 접목시켜 독창적이고 새로운 컨템포러리 요리를 선보입니다. 코스요리만을 하고 있으며 동서양이 접목된 독특한 취향의 풍미가 일품입니다.
# Address: 지번서울특별시 강남구 신사동 504-11 SINSA SQUARE  2층  2층
# Count: 94
# Name: 피에르가니에르서울 롯데호텔서울
# Section: 서울-강북>시청, 세계음식>프렌치, 예약 가능주차장(있음), 맥주, 와인, 양주, 칵테일, 음료, https://www.lottehotel.com/seoul-hotel/ko/dining/restaurant-pierre-gagnaire-a-seoul.html,
# Rate: 4.2
# Description: 세계 최고의 세프로 선정되기도 한 ‘피에르 가니에르’의 한국 매장. 창의적이고 예술적인 감각이 돋보이는 프랑스 요리를 선보입니다. 식사를 하려면 100% 사전 예약제이며, 대표 코스는 가장 긴 코스로 제공되는 '오마쥬 아 서울(Hommage a Seoul)'입니다. 아뮤즈 부쉬 5가지, 제주 달고기구이, 랍스터 요리, 메추라기 요리, 한우 알등심 구이, 디저트가 차례로 제공됩니다. 코스나 메뉴 구성이 달라질 수 있으니 방문 전 미리 확인하는 것을 추천.
# Address: 지번서울특별시 중구 소공동 1 롯데백화점본점
# Count: 49
# Name: 스시인
# Section: 서울-강남>압구정-도산공원/로데오, 세계음식>일식, 예약 가능, 맥주, 와인,
# Rate: 4.0
# Description: 웨스틴 조선호텔의 일식당 ‘스시조’ 출신의 이진욱 셰프의 요리를 맛볼 수 있는 ‘스시인’. 3월 말까지 예약이 마감되었을 정도로 뜨거운 인기를 누리고 있습니다. 수요일과 토요일은 런치만, 휴일을 제외한 나머지 요일은 디너만 운영하고 있습니다. 대표 메뉴 ‘런치 오마카세’는 제철 해산물을 활용한 다양한 구성의 츠마미가 인상적입니다. 그 중, 유부 안에 다진 참치와 성게소를 섞어 채워 넣은 ‘이나리도로마키’의 진한 감칠맛이 식사의 기대감을 한껏 올려줍니다. 스시는 샤리 위로 바훈우니를 듬뿍 얹고 김으로 겉면을 감싼 ‘바훈우니 군함 스시’가 가장 인기를 끌고 있습니다. 혀를 진득하게 감싸며 입안 가득 퍼지는 녹진한 맛과 바다의 풍미가 일품입니다.
# Address: 지번서울특별시강남구 신사동 645-28
# Count: 10
# Name: 무교동북어국집
# Section: 서울-강북>시청, 한국음식>전골, 주차장(없음), 맥주, 소주,
# Rate: 3.9
# Description: ‘무교동북어국집’은 1968년부터 지금까지 북엇국 하나로 승부해오고 있는 곳입니다. 식사 시간마다 기나긴 대기 행렬이 이어질 정도로 많은 인기를 자랑합니다. 대표 메뉴는 한우 사골 육수에 북어 대가리와 뼈를 우린 육수를 섞어 깊고 담백한 맛을 완성한 ‘북어 해장국’. 북어와 두부, 달걀이 어우러진 뽀얀 국물은 간이 자극적이지 않아 속을 부드럽게 달래줍니다. 북어 해장국은 처음에 삼삼한 국물을 맛본 후, 입맛에 따라 새우젓을 넣어 간을 맞춰 먹으면 됩니다. 북엇국은 리필이 가능한데 건더기만, 국물만, 건더기와 국물 같이 등과 같이 주문을 할 수 있으니 참고 바랍니다.
# Address: 지번서울특별시 중구 다동 173
# Count: 88
# Name: 원조순희네빈대떡
# Section: 서울-강북>종로, 한국음식>전/빈대떡, Take out주차장(없음), 맥주, 소주, 전통주, 음료, http://빈대떡.com,
# Rate: 4.1
# Description: 광장시장 내에 위치한 명물 '순희네빈대떡'. 줄이 길게 늘어선 곳으로 가면 빈대떡집을 발견할 수 있는데, 녹두빈대떡, 고기완자 두 가지의 메뉴만으로 승부를 보고 있는 곳입니. 녹두로 만든 고소한 빈대떡과 고기가 들어간 완자를 함께 먹을 수 있는 모듬 메뉴도 준비되어 있습니다. 빈대떡뿐만 아니라 반죽도 구매 가능하므로 참고하면 좋습니다.
# Address: 지번서울특별시 종로구 종로5가 138-9
# Count: 119
# Name: 을지면옥
# Section: 서울-강북>종로-익선동, 한국음식>냉면/막국수, 예약 가능주차장(없음), 맥주, 소주,
# Rate: 4.2
# Description: 서울의 대표적인 평양냉면 맛집이자 3대 평양냉면으로 꼽히던 을지면옥이 낙원동에 다시 자리를 잡았습니다. 이전하는 동안 영업을 중지해서 평양냉면 매니아들을 아쉽게 만들었던 곳으로 재개장 하자마자 웨이팅하는 손님으로 북적이고 있습니다. 한모금 들이키자마자 깊은 맛에 감탄하게 되는 육수맛이 일품으로 향긋한 메밀향과 쫄깃한 면발의 식감까지 더해져 완벽한 맛을 자랑합니다. 재개장 후 서비스와 맛이 모두 개선되었다는 평이 많습니다. 총 3층의 매장으로 대기가 많아도 회전이 빨라 생각보다 오래 기다리지 않고 그 맛을 즐길 수 있습니다.
# Address: 지번서울특별시 종로구 낙원동 55-1
# Count: 72
# Name: 연희동칼국수 본점
# Section: 서울-강북>연희동, 한국음식>칼국수/국수, 예약 가능주차장(있음),
# Rate: 4.1
# Description: ‘연희동칼국수’는 3층 단독 주택을 개조하여 넓은 규모를 자랑한다. 대표 메뉴는 12시간 동안 우려낸 진한 사골과 국수에서 나온 전분이 더해져 걸쭉한 국물이 특징인 ‘칼국수’. 면 사이사이에 배어든 진득한 국물이 입안에서 기분 좋게 어우러진다. 달큰한 겉절이를 올려 한입에 먹으면 더욱 맛있게 즐길 수 있다. 담백한 국물을 그 자체로 즐겨도 좋고 취향에 따라 후추, 파 양념장을 넣어 먹어도 된다. 특허를 받은 새콤한 백김치는 뒷맛을 깔끔하게 해줘 곁들여 먹기 좋다. 장시간 삶아 부드러운 식감이 매력적인 ‘수육’도 인기메뉴. 넓은 주차공간이 마련되어 있어 차를 이용해 방문하기에도 좋다.
# Address: 지번서울특별시서대문구 연희동 132-29 2층
# Count: 107
# Name: 이도곰탕 본점
# Section: 서울-강남>역삼역, 한국음식>설렁탕/곰탕/갈비탕, Take out예약 가능주차장(있음), 맥주, 소주, 전통주, 음료,
# Rate: 3.8
# Description: 역삼역 근처의 한우곰탕 전문점으로 세종대왕 18대손인 한의사가 만든 비법으로 3대째 이어지고 있는 한식당입니다. 시원하고 깔끔하면서도 깊이 있는 육수의 곰탕이 인기 메뉴입니다. 싱싱한 부추 아래에 1등급 한우의 우설, 눈두덩, 볼살이 들어있는 수육과 수육 후에 추가로 먹을 수 있는 장국수, 장죽도 별미입니다.
# Address: 지번서울특별시 강남구 역삼동 671-17
# Count: 46
# Name: 페스타 바이 민구
# Section: 서울-강북>남산/후암동, 세계음식>퓨전, 예약 가능주차장(있음), http://banyantreeclub.com/kr/dining/festa-dining.asp,http://www.instagram.com/festa_dining,http://www.facebook.com/FestaDining,
# Rate: 3.9
# Description: ‘페스타 바이 민구'는 내추럴하고 트렌디한 '어번 그린 다이닝(Urban Green Dining)'을 선보입니다. 밍글스(Mingles)의 오너 셰프이자 페스타 총괄 셰프인 강민구 셰프의 터치로 완성되는 자유분방하면서도 정성이 담긴 유러피안 캐주얼 푸드를 경험해보세요. 대표 메뉴는 강민구 총괄 셰프가 전국 각지를 돌아다니며 엄선한 제철 식재료로 준비한 메인 요리, 식사, 후식의 구성으로 이루어져 있습니다.
# Address: 지번서울특별시 중구 장충동2가 201
# Count: 28
# Name: 모퉁이우 사랑방
# Section: 서울-강남>삼성동, 한국음식>소구이/불고기, 예약 가능주차장(있음), http://www.instagram.com/__sarangbang__,
# Rate: 평가중
# Description: ‘모퉁이우 사랑방’은 모퉁이우에서 RIPE, WX에 이어 3번째로 런칭한 브랜드입니다. 기존 모퉁이우 브랜드보다 부담 없는 가격으로 수준급 한우 오마카세를 경험할 수 있습니다. 2부제로 나눠 한 타임에 4팀 이하로 운영하는 카운터 석과 하루에 한 팀만 받는 룸 공간은 고객에게 집중하겠다는 셰프의 철학을 엿볼 수 있습니다. ‘한우 오마카세’는 트러플의 은은한 풍미가 담긴 소고기 육수와 라이스 페이퍼로 제철 채소를 감싼 요리로 식사를 시작을 알립니다. 이어 짚불로 훈연한 설깃살, 우설과 양깃머리 구이, 특수 부위 구이, 물회, 채끝살 구이, 떡갈비, 등심, 식사, 후식 등 고기 위주로 구성한 메뉴 구성이 돋보입니다. 예약은 공식 인스타그램을 통해 가능합니다.
# Address: 지번서울특별시 강남구 삼성동 59-11
# Count: 1
# Name: 부여집
# Section: 서울-강남>당산역, 한국음식>설렁탕/곰탕/갈비탕, Take out예약 가능주차장(있음), 맥주, 소주, 음료,
# Rate: 4.0
# Description: 70년의 전통을 가진 특수부위 탕 전문점으로 꼬리곰탕, 도가니탕 등 다양한 탕 메뉴를 선보입니다. 수입산을 사용한 메뉴와 한우를 사용한 메뉴가 따로 나누어져 있는 것이 특징입니다. 탕 외에도 찜, 수육 메뉴가 준비되어 있습니다. 대표 메뉴인 ‘꼬리곰탕’은 오직 꼬리만으로 끓여내 국물이 맑고 진합니다. 한우 특유의 고소함과 감칠맛을 느끼고 싶은 이들은 ‘한우 꼬리곰탕’을 주문하는 것을 추천합니다. 도가니 특유의 점성이 느껴지는 진한 국물의 ‘도가니탕’과 소 꼬리를 푹 찐 후에 간장 양념을 올려내는 ‘꼬리찜’도 별미 메뉴입니다.
# Address: 지번서울특별시 영등포구 당산동2가 162-13
# Count: 44
# Name: 당산원조곱창
# Section: 서울-강남>당산역, 한국음식>곱창/대창, Take out예약 가능주차장(없음), 맥주, 소주, 전통주, 음료,
# Rate: 3.8
# Description: 비교적 저렴한 가격에 제공되는 곱창 전문점입니다. 곱을 유지하기 위해 다 익을 때까 자르지 않고 통째로 굽고, 초벌구이를 해서 돌판 위에 구워 내는 것이 특징입니다. 곱창과 대창, 염통 등을 모두 즐길 수 있는 곱창 모둠과 미니가마솥에 볶아주는 김치 볶음밥이 인기 메뉴입니다. 곁들여 나오는 달래 부추 무침과 미역오이 냉국이 곱창의 느끼함을 덜어줍니다.
# Address: 지번서울특별시 영등포구 당산동5가 36
# Count: 29
# Name: 익스퀴진
# Section: 서울-강남>청담동, 세계음식>유러피안, 예약 가능룸 없음, 맥주, 와인, 음료, http://www.instagram.com/exquisine_seoul,
# Rate: 3.5
# Description: 호주, 캐나다, 미국 등 다양한 나라에서 경력을 쌓은 장경원 오너 셰프가 운영하는 ‘익스퀴진’. 레스토랑에서 직접 재배한 허브와 산지 직거래로 공수한 재료들로 독창적인 요리를 선보입니다. 고객과의 소통을 위해 서버를 따로 두지 않고, 셰프가 직접 음식 서빙과 함께 설명을 해줘 더욱 깊이 있는 식사를 즐길 수 있습니다. 대표 메뉴 ‘디너 코스’는 입맛 살려주는 5가지 스낵을 시작으로 제철 과일, 시금치, 감자, 보리를 이용한 요리와 스테이크, 후식의 순서대로 제공됩니다. 알알이 흩어지는 보리의 식감이 매력적인 리조또와 촉촉한 육즙을 자랑하는 스테이크가 코스 요리 중 가장 많은 사랑을 받고 있습니다.
# Address: 지번서울특별시 강남구 청담동 63-11 라파빌딩
# Count: 7
# Name: 네기다이닝라운지
# Section: 서울-강남>신사-가로수길, 세계음식>일식, Take out예약 가능주차장(있음), 맥주, 소주, 음료,
# Rate: 4.0
# Description: 갓포요리로 유명한 네기에서 2호점 성격으로 만든 프리미엄 일식 코스요리를 전문으로 하는 네기 다이닝 라운지입니다. 유명 일식집인 갓포네기'의 요릴 한층 더 업그레이드 시켜  일식 프리미엄 요리의 진수를 만나 볼 수 있습니다. 공간이 훨씬 쾌적하고 넓은 곳에서 최고의 맛과 멋을 느낄 수 있습니다.
# Address: 지번서울특별시 강남구 신사동 540 4층
# Count: 5
# Name: 고운님
# Section: 서울-강남>선릉역/선정릉역, 한국음식>한정식, 예약 가능룸 있음, 맥주, 소주, 전통주, 음료,
# Rate: 3.9
# Description: 포스코사거리 포스코 안쪽 먹자골목에 위치한 남도식 사계절 제철 음식을 내는 한식집입니다. 민어, 생굴 등 제철 전라도 남도 요리를 즐길 수 있습니다. 탱글탱글한 갑오징어 숙회가 인기메뉴이며 반찬 모두 남도 음식답게 정갈하고 맛있어서 인기가 많습니다.
# Address: 지번서울특별시 강남구 대치동 894-5 대치동우편취급소 2층
# Count: 17
# Name: 오장동흥남집 본점
# Section: 서울-강북>충무로, 한국음식>냉면/막국수, 예약 가능주차장(있음), 맥주, 소주, 전통주, 음료, http://www.오장동흥남집.com,
# Rate: 4.0
# Description: 을지로4가역 인근에 위치한 함흥냉면 전문점, ‘오장동 흥남집’입니다. 함흥냉면 골목의 원조로 불리며 온종일 만석 대기 행렬을 이루는 곳입니다. 대표 메뉴는 편육과 간재미 회무침을 모두 올려 제공하는 ‘섞임 냉면’입니다. 고기의 육향과 간재미 회무침의 쫀득한 식감 모두를 즐길 수 있습니다. 비빔 냉면이지만 갈색빛 육수가 자작하게 부어서 제공되는 것이 특징입니다. 매콤한 감칠맛의 양념장과 고루 섞어지며 개운한 맛이 일품입니다. 냉면과 함께 먹기 좋은 곁들임 메뉴로는 촉촉하게 삶아낸 부드러운 맛의 ‘수육’이 인기라고 하니 참고 바랍니다.
# Address: 지번서울특별시 중구 오장동 101-7
# Count: 67
# Name: 코지마
# Section: 서울-강남>청담동, 세계음식>일식, 예약 가능주차장(있음), 맥주, 전통주, 음료, http://kojima.modoo.at/,
# Rate: 4.0
# Description: 호텔신라 일식당 출신인 박경재 쉐프가 이끄는 강남 최고의 스시 맛집입니다. 정통 에도마에식 스시의 참맛을 느낄 수 있는 곳으로 스시조, 아리아께, 모모야마의 맛이 난다고 정평이 나있습니다.
# Address: 지번서울특별시 강남구 청담동 89 분더샵(A)
# Count: 14
# Name: 볼피노
# Section: 서울-강남>압구정-도산공원/로데오, 세계음식>이탈리안, Take out예약 가능주차장(있음), 와인, 음료, https://www.instagram.com/cucciologroup/,
# Rate: 4.0
# Description: 해방촌 ‘쿠촐로’와 이태원 ‘마렘마’에 이어 김지운 셰프가 개업한 이탈리안 레스토랑입니다. 인기 메뉴는 쫀득한 펜네의 식감이 매력적인 ‘새우 소시지 오징어 먹물 펜네 파스타’와 소 골수를 넣어 감칠맛을 더한 ‘라구 볼로네즈 탈리아텔레 파스타’입니다. 자극적이지 않은 특제 라구 소스와 포동포동한 생면이 어루어져 가정에서 맛보는 따뜻함을 선사합니다. 기본으로 제공되는 프로슈토와 그라씨니는 와인과 곁들이기 좋습니다.
# Address: 지번서울특별시 강남구 신사동 650-12 신사동 K빌딩
# Count: 10
# Name: 함경도찹쌀순대
# Section: 서울-강남>문정/가락/거여, 한국음식>순댓국/순대, Take out주차장(있음), 맥주, 소주, 전통주, 음료,
# Rate: 4.2
# Description: 한옥을 개조하여 운영 중인 ‘함경도찹쌀순대’는 할머니 집에 온 듯한 정겨운 느낌을 줍니다. 대표 메뉴 ‘순대 국밥’은 뜨끈한 국물에 머리 고기, 내장, 순대를 넉넉하게 담아냅니다. 돼지 뼈와 양파, 마늘, 파 등 갖은 재료를 넣어 오랜 시간 끓여낸 육수는 묵직하게 느껴지는 구수한 맛이 일품입니다. 24시간 운영하고 있어 부담 없이 방문하기 좋습니다.
# Address: 지번서울특별시 송파구 가락동 79-7
# Count: 97
# Name: 백년옥
# Section: 서울-강남>교대/서초/남부터미널, 한국음식>전골, Take out예약 가능주차장(있음), 맥주, 소주, 전통주, 음료, http://baengnyeonok.modoo.at,
# Rate: 4.1
# Description: 직접 만든 순두부를 맛볼 수 있는 두부 요리 전문점입니다. TV 맛집 프로그램에도 여러 번 소개되었으며, 별관을 두고 있을 정도로 찾는 손님이 많다고 합니다. 매일 직접 만든 순두부와 두부, 콩비지를 사용하여 요리하는데, 인기메뉴는 맑은 국물의 순두부에 간장으로만 간을 하여 먹는 자연순두부와 얼큰한 뚝배기 순두부입니다. 묵은지를 넣고 끓여 낸 콩비지백반도 인기입니다. 10인 이상 예약가능합니다.
# Address: 지번서울특별시 서초구 서초동 1450-6
# Count: 138
# Name: 류니끄
# Section: 서울-강남>압구정-도산공원/로데오, 세계음식>퓨전, 주차장(있음), http://www.ryunique.co.kr/,
# Rate: 4.1
# Description: 프렌치 퓨전 레스토랑입니다. 2011년 10월 셰프 류태환이 오픈한 곳으로 2015 아시아 최고 레스토랑 50 시상식에서 27위에 선정된 곳입니다. 한국적인 식재료에 분자요리를 가미한 프랑스식 요리를 선보입니다. 산지를 이용한 계절 요리를 바탕으로한 런치세트와 디너 테이스팅메뉴가 제공됩니다. 런치는 3시까지이며 디너는 6시에 시작합니다.
# Address: 지번서울특별시강남구 신사동 651-3
# Count: 47
# Name: 파올로데마리아
# Section: 서울-강북>부암동/평창/구기, 세계음식>이탈리안, Take out예약 가능주차장(있음), 와인, https://blog.naver.com/paolodemaria3,
# Rate: 3.9
# Description: 이태리 북부 스타일의 파스타를 맛볼 수 있는 이탈리안 레스토랑입니다. 유명 레스토랑인 압구정동 <보나세라>와 홍대 <디비노>에서 일했던 파올로 데 마리아 셰프가 키친을 맡고 있습니다.
# Address: 지번서울특별시 서대문구 연희동 79-4
# Count: 20
# Name: 스시 렌
# Section: 서울-강남>청담동, 세계음식>일식,
# Rate: 평가중
# Description: 셰프님의 설명이 친절한 스시 오마카세입니다. 하이엔드 스시야에서만 만나볼 수 있는 이곳만의 특별함이 있는 곳으로 서비스까지 좋아 흠잡을 곳 없는 곳입니다. 하이엔드 스시야에 대한 궁금증이 있었던 분이라면 이곳에서 친절하게 시작해보세요.
# Address: 지번서울특별시 강남구 청담동 20-3 2F
# Count: 0
# Name: 일미간장게장
# Section: 서울-강북>왕십리/마장/답십리, 한국음식>꽃게/랍스터/새우, Take out예약 가능주차장(있음), 맥주, 소주, http://www.ilmicrab.co.kr/index.asp,
# Rate: 3.8
# Description: ‘한춘상일미간장게장’은 장안동 먹자골목에서 40년의 전통을 자랑하는 곳입니다. 일본 방송 프로그램에 방영되어 일본인 관광객들도 즐겨 찾습니다. 대표 메뉴 ‘간장게장’은 12가지 한방 약재를 넣고 달인 특제 간장으로 게장을 담가 손님상에 올립니다. 날치알과 김가루가 들어있는 ‘알밥’을 추가하여 통통한 꽃게의 살을 넣어 비빔밥으로도 즐길 수 있다. 아무런 양념 없이 꽃게를 쪄내 진한 풍미가 고스란히 느껴지는 ‘꽃게찜’도 인기 메뉴입니다. 24시간 운영을 하고 있어 시간에 상관없이 부담 없이 방문하기 좋으니 참고 바랍니다.
# Address: 지번서울특별시 동대문구 장안동 367-3
# Count: 63
# Name: 부원면옥
# Section: 서울-강북>서울역/남대문, 한국음식>냉면/막국수, 예약 가능, 맥주, 소주, 전통주,
# Rate: 4.1
# Description: 40년 넘게 3대째 이어온 평양냉면과 100% 녹두로 빚은 녹두전이 인기메뉴인 냉면집입니다. 면발은 메밀과 고구마 전분으로 뽑아내며, 돼지고기 편육이 고명으로 얹혀 나옵니다. 삶은 닭을 가늘게 찢어 채소와 함께 버무린 닭무침도 인기입니다.
# Address: 지번서울특별시 중구 남창동 47-10 2층
# Count: 107
# Name: 주
# Section: 서울-강남>방배, 세계음식>중식, 주차장(없음), 맥주, 소주, 전통주, 백주, 음료,
# Rate: 3.9
# Description: 조선호텔 중식당의 창립 멤버인 주덕성 셰프의 중식당입니다. 대표 인기 메뉴는 소스를 부어놓은 상태에서도 바삭함을 유지하는 ‘탕수육’입니다. 다른 곳에 비해 도톰한 두께와 크기를 자랑하는 고기 덕분에 육즙과 함께 씹는 식감도 즐길 수 있습니다. 식사 메뉴로는 간장소스를 베이스로 두툼한 새우, 닭고기, 소고기를 넣어 진하게 끓여낸 ‘팔진탕면’이 인기입니다.
# Address: 지번서울특별시 서초구 방배동 795-5 복합빌딩
# Count: 102
# Name: 라미띠에
# Section: 서울-강남>청담동, 세계음식>프렌치, 예약 가능주차장(있음), 와인, 커피, 차, https://app.catchtable.co.kr/ct/shop/l'amitie,
# Rate: 3.9
# Description: 국내에 최초로 부띠끄 프렌치 레스토랑의 개념을 도입한 곳으로 굉장히 아담한 규모입니다. 코스의 구성은 주기적으로 바뀌며 요리사가 직접 메뉴에 대해서 설명해줍니다. 예약 방문은 필수입니다.
# Address: 지번서울특별시 강남구 청담동 81-7 2층
# Count: 58
# Name: 체부동잔치집
# Section: 서울-강북>서촌누하동/청운효자동, 한국음식>칼국수/국수, 주차장(없음), 맥주, 소주, 전통주, 음료,
# Rate: 3.8
# Description: 세종마을 음식문화거리에 위치한 '체부동잔치집'. 인기 있는 면 요리 전문점으로 잔치국수, 칼국수, 모빌 등 다양하면서도 가격이 저렴한 칼국수 전문점입니다. 저렴한 가격으로 즐기려는 손님들로 항상 북적이는 노포입니다. 간단한 끼니를 때울 수 있을 뿐만 아니라 술 한잔 하기도 좋습니다. 다양한 안주류도 있으며 특히 파전과 골뱅이무침이 인기가 많습니다.
# Address: 지번서울특별시종로구 체부동 190
# Count: 30
# Name: 마이클 바이 해비치
# Section: 서울-강북>인사동, 세계음식>유러피안, Take out예약 가능주차장(있음), http://www.michaelsbyhaevichi.com/,
# Rate: 평가중
# Description: 뉴 아메리칸 퀴진과 공간이 주는 분위기, 친근하지만 사려 깊은 서비스로 일상 속 잠깐의 여행을 떠나온 듯한 즐거움을 선사하는 다이닝 공간입니다. 특급 호텔을 운영하며 축적해 온 메뉴 개발 노하우를 바탕으로 다채로운 콘셉트의 요리를 선보입니다. 층고가 높고 고급스러운 우드소재의 인테리어가 기분까지 상쾌하게 만들어 줍니다.
# Address: 지번서울특별시종로구 공평동 5-1
# Count: 1
# Name: 대성정육식당
# Section: 서울-강북>이태원-보광동, 한국음식>소구이/불고기, 예약 가능, 맥주, 소주, 전통주, 음료,
# Rate: 4.0
# Description: 고기를 근 단위(600g)로만 판매하는 구이 전문점 ‘대성정육식당’. 오후부터 다음날 오전까지 영업하기 때문에 늦은 시간에도 찾기 좋은 곳 입니다. 대표 메뉴는 ‘삶아 먹어도 돼지’라는 이름의 돼지고기 수육. 주문과 동시에 삶아 내는 수육은 20분 정도의 시간이 소요됩니다. 잘 익은 수육은 덩어리째로 도마와 함께 제공됩니다. 먹고 싶은 크기로 직접 숭덩숭덩 잘라먹는 재미가 있으며, 담백한 살결은 촉촉하게 즐길 수 있습니다. 반찬으로 준비되는 김치는 침이 절로 고일 정도의 신 감칠맛이 매력적입니다. 돌판에 김치와 함께 구워 먹는 ‘한우 차돌박이’도 인기메뉴 입니다.
# Address: 지번서울특별시 용산구 보광동 63-2 통일여관
# Count: 20
# Name: 마포진짜원조 최대포본점
# Section: 서울-강북>마포/공덕, 한국음식>돼지갈비, 주차장(있음), 맥주, 소주,
# Rate: 4.2
# Description: 마장동 도축장에서 일했던 1대 창업자 최할아버지가 1955년 공덕동의 작은 대포집으로 시작한 돼지갈비집입니다. 돼지갈비는 물론 소금구이, 껍데기, 염통, 곱창 등의 다양한 돼지고기의 부위를 즐길 수 있습니다.
# Address: 지번서울특별시 마포구 공덕동 255-6
# Count: 65
# Name: 원조제일 어버이순대
# Section: 서울-강북>숙대/남영/효창, 한국음식>순댓국/순대, Take out주차장(없음), 맥주, 소주,
# Rate: 4.2
# Description: 매일 직접 만든 순대를 맛볼 수 있는 순대 요리 전문점 ‘제일어버이순대’입니다. 매일 새벽 밀가루를 이용해 돼지 소창을 깨끗이 씻어내는 것으로 하루의 영업을 시작하는 곳입니다. 야채와 고기, 찹쌀 등의 재료를 넣어 직접 만든 순대는 고소하면서도 담백해 슴슴하게 즐길 수 있는 것이 장점입니다. 이 집의 순댓국은 순대의 찹쌀 사이사이에 육수가 배어들어 탱글탱글한 순대의 식감과 육수의 진한 맛을 모두 살려낸 것이 특징입니다. 순댓국, 머리고기를 곁들인 순대 한 접시가 함께 준비되는 ‘순대정식’도 인기입니다. 모든 메뉴는 포장이 가능하며 당일 준비된 순대가 소진되면 영업이 종료되니 참고 바랍니다.
# Address: 지번서울특별시용산구 갈월동 98-52
# Count: 98
# Name: 희락갈치
# Section: 서울-강북>서울역/남대문, 한국음식>해물탕/해물요리, Take out예약 가능주차장(없음), 맥주, 소주,
# Rate: 3.9
# Description: 남대문 갈치조림 골목에서 가장 오래된 가게입니다. 직접 섬에서 공수해 오는 생갈치를 양은 냄비에 매콤한 양념을 올려 조려냅니다. 갈치 양념 국물에 푹 익은 무를 넣고 밥과 함께 비벼 먹는 것이 일품입니다. 남대문 방문하시는 분들 사이에서 입소문이 자자 한 갈치조림 맛집입니다.
# Address: 지번서울특별시중구 남창동 34-34
# Count: 69
# Name: 필경재
# Section: 서울-강남>개포/수서, 한국음식>한정식, 주차장(있음), 맥주, 전통주, 와인, 음료, http://www.philkyungjae.co.kr/rain/index.php,
# Rate: 4.0
# Description: 유서깊은 전통 한옥에서 궁중요리를 맛볼 수 있는 곳입니다. 세종대왕의 5남인 광평대군의 증손 이천수가 건립한 전통 한옥으로, 1987년 전통건조물 제1호로 지정되어 특히 외국인들에게 호평을 받고 있습니다. 메뉴는 다양한 정식 메뉴가 준비되어 있는데, 탕평채, 떡갈비, 굴비구이, 두텁떡 등으로 구성되어 있습니다. 코스에 따라, 장어구이, 자연송이볶음, 은대구 구이 등의 요리들이 추가됩니다. 한국을 대표하는 고급 프리미엄 한정식 레스토랑입니다.
# Address: 지번서울특별시 강남구 수서동 739-1
# Count: 70
# Name: 기가스
# Section: 서울-강남>압구정-도산공원/로데오, 세계음식>유러피안,
# Rate: 평가중
# Description: 지속가능한 미식을 추구하는 도산공원의 레스토랑입니다. 셰프가 소유하고 있는 농장에서 직접 공수하는 채소와 허브를 활용하는 팜투테이블(farm to table)을 몸소 실천하고 있습니다. 그리스를 떠오르게 하는 파란색 돔형 외관 장식에서부터 해산물 요리가 훌륭할 것임을 예감할 수 있는데, 메인 요리인 스테이크를 제외하고는 해산물을 중심으로 코스를 꾸려 기대에 부응하는 곳입다. 요리에 다양한 허브를 사용해 다른 곳에서는 맛보지 못한 재미있는 맛을 만드는 스타일이 특징입니다. 전문 소믈리에가 추천하는 완벽한 와인 페어링을 제공하는 것도 장점입니다.
# Address: 지번서울특별시 중구 남창동 194 피크닉  ３층
# Count: 2
# Name: 일미집
# Section: 서울-강북>남산/후암동, 한국음식>감자탕, Take out주차장(없음), 맥주, 소주, 전통주, 음료, https://m.shopping.naver.com/fresh/localfood/stores/100754990/products/4931260768?NaPm=ct%3Dklt82492%7Cci%3Dshoppingwindow%7Ctr%3Dmyz%7Chk%3Dc83efaf1ee49112feb939543d40da38f8f39150e%7Ctrx%3D,
# Rate: 3.7
# Description: 용산 후암동에서 많은 청춘들과 직장인들의 한 끼를 책임져온 노포 중의 노포입니다. 벽에 붙은 연예인의 싸인 행렬만으로도 맛을 짐작하게 합니다. 이곳의 뼈해장국은 우거지나 시래기 없이 오로지 돼지 등뼈와 목뼈, 감자, 파와 마늘을 우린 국물에 최소한의 양념만 가미합니다. 그렇기 때문에 맵지 않은 맛의 국물은 육향이 오롯이 느껴지면서 뒷맛이 깔끔하게 떨어집니다. 사용하는 돼지 뼈는 국내산 냉장 뼈를 공수해 끓이기 때문에 뼈에 붙은 살코기가 잡내없이 찰진 식감을 자랑합니다. 뚝배기를 가득 채운 국물과 뼈, 감자 한 알이 전부인 심플한 모양새지만, 맑은 국물에 한 번 빠지게 되면 참새가 방앗간 들리듯이 찾게 되는 곳입니다.
# Address: 지번서울특별시 용산구 후암동 194-3
# Count: 15
# Name: 홍보각
# Section: 서울-강남>역삼역, 세계음식>중식,
# Rate: 평가중
# Description: 신논현역에 위치한 여경래 셰프가 운영하는 프리미엄 중식 레스토랑 홍보각입니다. 세계 중국요리협회 부회장, 한국 중식연맹회장을 겸하고 있는 여경래셰프의 중식 파인다이닝으로 특정지역요리에 국한되지 않고 북경, 광동, 사천 등의 여러 지역을 아우르는 중국 정통요리를 선보이는곳입니다. 음식이 깊이있는 요리와 섬세하고 유려한 서비스로 격식있는 자리부터 가족모임까지 어떠한 모임에도 적합한 곳이니 특별한날에 방문하여 좋은 시간보내시기에 바랍니다.
# Address: 지번서울특별시 강남구 역삼동 603  LL층 LL층
# Count: 1
# Name: 어울더울 과천본점
# Section: 경기>과천/서울대공원, 한국음식>소구이/불고기, Take out예약 가능주차장(있음), 맥주, 소주,
# Rate: 4.1
# Description: 경기 및 전국에 분점이 운영되고 있는 한우 숯불구이 전문 정육식당입니다. 고기를 구매한 후 사람 수에 따라 야채와 숯불의 비용을 별도로 내고 비닐하우스로 지은 실내에서 구매한 고기를 구워먹는 시스템입니다. 남은 고기는 포장도 가능합니다. 꽃등심과 등심이 인기가 많습니다.
# Address: 지번경기도 과천시 갈현동 175-2
# Count: 57
# Name: 대두소곱창
# Section: 서울-강북>마포/공덕, 한국음식>곱창/대창, Take out예약 가능주차장(없음), 소주,
# Rate: 3.5
# Description: 당일 도축된 소의 부속만을 사용하는 한우곱창 전문점입니다. 신선한 내장을 제공하기 위해 주말엔 간 서비스를 하고 있지 않습니다. 이곳은 국내산 양깃머리를 취급하는데, 선도 좋은 빛깔의 양을 잘 구워 기름장을 살짝 찍어 즐기면 쫄깃쫄깃한 식감과 맛이 좋습니다. 또한 곱창은 남다른 두툼함을 자랑하는 통통한 사이즈로, 한 점으로도 입안 가득차는 곱의 풍미를 맛볼 수 있습니다. 별미로 맛볼 수 있는 ‘홍창’은 소의 네번째 위로 부드러우면서도 쫄깃한 식감의 고소한 풍미가 살아있습니다. 곱창이 들어가 고소한 맛이 도드라지는 ‘곱창라면’도 빼놓을 수 없습니다.
# Address: 지번서울특별시마포구도화동 4-47 1층
# Count: 7
# Name: 은주정
# Section: 서울-강북>을지로, 한국음식>돼지구이, Take out예약 가능주차장(없음), 맥주, 소주, 전통주, 음료, http://m.smartstore.naver.com/ssamkimchi,
# Rate: 4.1
# Description: ‘은주정’은 점심시간엔 김치찌개, 저녁 시간에는 삼겹살+김치찌개의 단일 메뉴만 판매하는 곳 입니다. 대표 메뉴는 묵은지와 국내산 돼지고기를 넣고 푹 끓여낸 김치찌개에 밥에 비벼 쌈을 싸 먹는 ‘쌈싸먹는김치찌개’. 음료수와 사리 메뉴는 매장 한 편의 자판기에서 셀프로 이용할 수 있습니다.
#
# 생방송투데이 빅데이터 랭킹 맛집!  서울 김치찌개TOP5
# Address: 지번서울특별시 중구 주교동 43-23
# Count: 120
# Name: 만포막국수
# Section: 서울-강북>약수/옥수/금호, 한국음식>칼국수/국수, Take out예약 가능주차장(있음), 맥주, 소주, 전통주, 음료,
# Rate: 4.2
# Description: 실향민 출신 1대 사장님의 고향 만포에서 이름을 따온 ‘만포 막국수’. 지금은 창업주의 조카분이 2대째 대를 이어오며 한결같은 맛을 선사하고 있습니다. 대표 메뉴 ‘물 막국수’는 투명한 육수가 어우러진 면발 위로 양념장과 오이, 고기, 달걀 고명을 올려 제공합니다. 단단하기 똬리를 튼 면 사리는 성인 남성도 한 그릇만으로도 배가 충분히 부를 만큼 푸짐한 양을 자랑합니다. 이북식 스타일로 맑은 육수에 쪄낸 하얀 닭 위로 데친 쪽파를 수북하게 올려 나오는 ‘찜닭’도 인기 메뉴. 쪄내는 과정에서 기름기가 쪽 빠져 담백한 맛과 부드럽게 씹히는 살점이 일품입니다.
# Address: 지번서울특별시 중구 신당동 425-18
# Count: 107
# Name: 소금집델리 망원
# Section: 서울-강북>망원/성산, 세계음식>유러피안, Take out, 맥주, 와인, 양주, 칵테일, 커피, 차, 음료, http://www.salthousekorea.com,
# Rate: 평가중
# Description: ‘소금집델리 망원’은 훈제 베이컨을 만들던 작은 작업실에서 시작하여 지금은 수제 가공육을 제조하는 전문점으로 자리 잡았습니다. 유명 매스컴에 방영되며 샤퀴테리에 대한 큰 관심과 대중화를 불러 일으킨 곳이기도 합니다. 대표 메뉴는 이즈니 버터를 듬뿍 바른 바게트 사이로 수제 잠봉을 푸짐하게 채워 넣은 ‘잠봉 뵈르’. 돼지 뒷다릿살을 소금과 설탕으로 3주간 숙성시켜 은은한 감칠맛이 살아있는 잠봉과 버터의 향긋함이 어우러지며 고급스러운 풍미를 즐길 수 있습니다. 바삭한 식감과 고소한 맛을 지닌 바게트에 잠봉 특유의 짭조름한 맛이 더해지며 적절한 훌륭한 밸런스를 이룹니다.
# Address: 지번서울특별시 마포구 망원동 57-38
# Count: 2
# Name: 사리원 본점
# Section: 대전>서구-둔산/탄방, 한국음식>냉면/막국수, Take out예약 가능주차장(있음), 맥주, 소주, 와인, 음료, 사리원면옥.com,http://www.instagram.com/sariwon__,
# Rate: 4.0
# Description: 4대에 걸쳐 60년 이상 영업해 온 냉면 전문점 '사리원'의 본점입니다. 현재 대전과 서울, 세종 등지에서 분점이 운영되고 있습니다. 대표 메뉴인 '물냉면'은 얼음 동동 띄운 사골 육수에 삶은 메밀 면을 넣고 채소와 편육, 삶은 계란을 얹어 내어줍니다. 매콤달콤한 '비빔냉면'과 직접 빚은 '왕손만두' 등 다양한 메뉴가 준비되어 있습니다.
# Address: 지번대전광역시 서구 둔산동 968
# Count: 41
# Name: 진미
# Section: 서울-강북>연희동, 세계음식>중식, Take out예약 가능주차장(있음),
# Rate: 평가중
# Description: 연희동 내공 가득한 중국요리집으로 신라호텔 팔선 등 여러 유명 중식당 경력의 유신재 셰프가 직접 운영하는 곳이다.
# Address: 지번서울특별시 서대문구 연희동 137-4
# Count: 1
# Name: 리북집
# Section: 서울-강남>신논현/영동시장, 한국음식>족발/보쌈, Take out예약 가능주차장(없음), 맥주, 소주, 전통주, 음료, http://reebuk.co.kr/,
# Rate: 4.1
# Description: 논현동 영동 시장 근처에 위치한 족발전문점 '리북집'은 순수 국내산 돼지의 앞발만을 사용하여 전통가마솥에 직접 조리해 더욱 쫄깃하고 맛있는 족발을 즐길 수 있는 곳입니다. 갖가지 한방재료를 첨가하여 전통가마솥에서 삶아낸 담백한 족발이 대표메뉴이며, 얇게 저민 족발에 오이와 해파리를 넣고, 겨자 소스로 새콤하게 맛을 낸 냉채 족발도 별미입니다. 족발과 환상적인 궁합을 자랑하는 쟁반국수도 인기메뉴라고 하니 참고하면 좋겠습니다.
# Address: 지번서울특별시 강남구 논현동 163-3
# Count: 105
# Name: 갓포아키 도산공원점
# Section: 서울-강남>압구정-도산공원/로데오, 세계음식>일식, Take out예약 가능, 맥주, 소주, 음료, https://instagram.com/kappo_akii?igshid=mahyywysqynq,
# Rate: 4.1
# Description: 품격있는 갓포 요리 전문점 아키입니다. 제철 재료를 살려 그날 그날 싱싱한 메뉴를 제공합니다. 매일 메뉴가 변동되기 때문에 방문하는 재미가 있습니다. 수준 높은 갓포 요리를 맛보고 싶다면 추천합니다.
# Address: 지번서울특별시 강남구 신사동 651-5 쿠키빌딩
# Count: 43
# Name: 한아람
# Section: 서울-강남>송파/방이, 한국음식>소구이/불고기, 예약 가능주차장(있음), 맥주, 소주, 음료, http://www.한아람.kr/,
# Rate: 3.8
# Description: 정육점 겸 한우구이 전문점입니다. 20일간 숙성시킨 한우구이를 선보이고 있습니다. 안심과 등심 뿐 아니라 토시살, 제비추리, 양대창 등 소의 다양한 부위를 취급합니다. 갈비에 녹용과 대추 등과 누릉지를 넣어 걸쭉하게 끓여낸 보양 전골도 인기 메뉴입니다. 홀이 넓고, 돼지 고기도 판매하고 있어 회식 및 단체 모임을 하는 손님이 많습니다.
# Address: 지번서울특별시 송파구 방이동 180-7 지산빌딩
# Count: 28
# Name: 보보식당
# Section: 서울-강남>압구정-도산공원/로데오, 세계음식>중식,
# Rate: 평가중
# Description: 화교3세 장보원 셰프와 ‘네기’의 황규연 셰프가 합작하여 오픈한 레스토랑입니다. 원래 광주시에서 인기를 끌던 중식당이었는데 압구정으로 자리를 옮겨 새로운 이야기를 써내려가고 있습니다. 일반 테이블과 함께 디귿자 모양 바테이블이 있어 취향에 맞게 골라 앉을 수 있습니다. 크게 전채요리와 돼지, 소, 가금류, 해산물, 식사류로 나누어져 있고 각 카테고리 별로 이곳만의 매력을 고스란히 느낄 수 있는 음식들로 구성이 되어 있습니다. 대표 메뉴인 동파육은 부들부들한 번에 동파육과 파채, 오이를 싸먹는 요리로 단짠단짠한 고기맛을 채소가 깔끔하게 잡아주는 밸런스가 좋습니다. 탕수육 위에 버터 한조각이 올라간 ‘버터탕수육’과 닭고기 냉채인 ‘산동 샤오찌’등이 인기가 좋습니다.
# Address: 지번서울특별시 강남구 신사동 640-2 로빈명품관 1층 103호 1층 103호
# Count: 2
# Name: 리치몬드과자점 성산본점
# Section: 서울-강북>망원/성산, 세계음식>베이커리/제과점, Take out예약 가능주차장(있음), 커피, 차, 주스, 음료, http://www.richemont.co.kr,https://www.instagram.com/richemont_bakery/,
# Rate: 4.5
# Description: 리치몬드과자점 성산본점'은 1979년부터 시작해서 대를 이어 계속 운영되어 온 제과명가입니다. 80년대 당시에는 최신 트렌드의 빵들을 선보인 곳으로 추억 속 빵들을 만나볼 수 있습니다. 대한민국명장으로도 지정된 이 곳은 특히 오랜 역사가 느껴지는 듯한 앤틱한 인테리어가 인상적이며 매장 내부는 넓은 편입니다. 다양한 음료메뉴도 함께 판매하는 베이커리 겸 카페로 운영되기 때문에 앉아서 먹고 갈 수 있는 좌석이 많이 마련되어 있습니다. 이 곳의 시그니처 메뉴는 크림이 가득 들어 있는 '슈크림'과 고소한 맛의 '밤식빵', 그리고 상큼함이 가득 느껴지는 '레몬케이크'입니다.
# Address: 지번서울특별시 마포구 성산동 114-5
# Count: 16
# Name: 우텐더
# Section: 서울-강남>압구정-도산공원/로데오, 한국음식>소구이/불고기, Take out예약 가능주차장유료5,000원룸 있음, 맥주, 소주, 전통주, 음료, https://wootender.modoo.at,https://www.instagram.com/wootender/,
# Rate: 3.9
# Description: 우텐더는 압구정 로데오 인근에 위치한 한우 숯불구이 전문 레스토랑으로 마장동의 본 앤 브레드의 프리미엄 한우 고기를 합리적인 가격으로 만나 볼 수 있습니다. 다른 프리미엄 고깃집과 다르게 반찬들도 정성스럽게 나오고 규가츠, 고추장찌개 등 식사류도 정갈합니다. 룸은 5인 이상 예약 가능하고 홀은 2인일 경우 개런티가 발생할 수 있습니다. 콜키지는 만원이라는 합리적인 가격으로 이용 가능하며, 가게 옆 유료주차장에 5천원에 이용 가능합니다.
# Address: 지번서울특별시 강남구 신사동 643-20
# Count: 5
# Name: 신성각
# Section: 서울-강북>마포/공덕, 세계음식>중식, 음료,
# Rate: 4.1
# Description: 효창공원 앞에 위치한 ‘신성각’은 1981년 문을 열어 36년째 운영 중인 중국집입니다. 주문과 동시에 손으로 직접 뽑아낸 쫄깃한 면발에 돼지고기, 양배추, 양파 등을 춘장에 볶아 만든 ‘간짜장’이 대표 메뉴입니다. 오로지 물과 밀가루로만 부드러운 면을 만들어 내는 덕분에 면만 따로 먹어도 고소한 맛을 느낄 수 있습니다. 소스에는 부추, 오이, 양파, 양배추 등이 가득 들어가 있어 아삭한 식감을 더해줍니다. 탕수육은 양파 대신 소스에 파를 넣어 향을 더하고, 큼직한 고기와 함께 도톰한 감자튀김을 넣어 색다르게 즐길 수 있습니다.
# Address: 지번서울특별시 마포구 신공덕동 2-463
# Count: 72
# Name: 원대구탕
# Section: 서울-강북>용산/삼각지, 한국음식>해물탕/해물요리, 예약 가능주차장(없음), 맥주, 소주,
# Rate: 4.0
# Description: 1979년 오픈하여 2대에 걸쳐 실속있는 대구탕으로 인기를 얻고 있는 곳입니다. 2명이상 가면 대구탕과 대구내장탕을 섞어서 시키는데 대구살과 함께 고니, 애 등의 내장이 미나리 등의 야채와 함께 넉넉히 준비됩니다. 직접 김치 공장에서 주문 제작하는 아가미 젓갈 김치에 들기름을 넣고 함께 볶는 볶음밥도 좋은 평가를 받고 있습니다. 예약은 10인이상 가능합니다.
# Address: 지번서울특별시 용산구 한강로1가 142-4
# Count: 66
# Name: 일미락
# Section: 서울-강남>목동, 한국음식>돼지구이, 예약 가능주차장(없음), 맥주, 소주, 음료,
# Rate: 4.1
# Description: 숙성 삼겹살과 전라도식 파김치의 조화를 맛볼 수 있는 곳입니다. 맛집블로거 출신 주인장이 수년동안 수천곳의 맛집들을 돌아다니며 고기와 어울리는 찬으로 구성한 생고기 전문점입니다. 고기 주문시 목포에서 올린 통갈치젓을 직접 믹서에 갈아 담근 파김치, 한달이상 숙성한 짱아지, 1년된 해남묵은지를 물에 씻은 씻은지, 갈치속젓, 멸치로 직접 육수를 우린 시원한 경상도식 김치국 갱시기 등으로 상이 차려집니다. 일요일은 10시까지 영업합니다.
# Address: 지번서울특별시 양천구 목동 406-126
# Count: 17
# Name: 목란
# Section: 서울-강북>연희동, 세계음식>중식, Take out예약 가능주차장(있음), 맥주, 소주, 백주, 음료,
# Rate: 4.0
# Description: ‘이연복 세프’가 운영하는 식당으로 알려진 중식 레스토랑, ‘목란’. 방문 한 달 전부터 예약을 서둘러야 하는 맛집이다. ‘동파육’, ‘멘보샤’, ‘군만두’ 등 요리메뉴는 예약 시 미리 주문해야 하고, 식사 메뉴는 바로 주문이 가능하다. 대표 식사 메뉴는 중식코스의 깔끔한 마무리를 도와주는 ‘짬뽕’이다. 각종 해산물과 채소 등 큼지막한 재료와 함께 얼큰하고 개운한 맛이 살아있다. 또 다른 인기 식사메뉴는 잘게 썰어낸 청경채와 함께 구운 캐슈넛과 땅콩이 건더기로 들어가는 ‘탄탄면’이다. 고소한 맛의 진득한 국물 뒤에 느껴지는 얼얼한 맛이 매력적이다.
# Address: 지번서울특별시 서대문구 연희동 132-28
# Count: 68
# Name: 비채나
# Section: 서울-강남>잠실-롯데월드/롯데타워, 한국음식>한정식, Take out예약 가능주차장(있음), 와인, http://www.bicena.com/,https://www.instagram.com/bicena_seoul/,
# Rate: 3.7
# Description: (주)광주요그룹에서 오픈한 모던 한식집입니다. 이태원에서 잠실 롯데월드타워로 4월에 이전 오픈 예정입니다. 한식을 현대에 맞게 응용하면서도 전통의 맛을 잘 살려 이색적인 맛을 볼 수 있습니다. 시래기홍합돌솥밥, 농어면 등이 독특한 메뉴들이 가득합니다.
# Address: 지번서울특별시 송파구 신천동 29 롯데월드타워 81층
# Count: 20
# Name: 장미식당
# Section: 경남>거제시, 한국음식>해물탕/해물요리, 주차장(없음), 소주,
# Rate: 3.9
# Description: 대구뽈찜이 맛있는 거제도 현지인들에게 사랑 받는 숨은 맛집입니다. 대구뽈찜과 아귀찜, 낙지볶음 등이 인기가 많습니다. 거제도 특유의 감칠맛 나는 요리기법으로 매콤하고 깔끔하게 양념된 대구뽈찜은 서울에서는 맛볼 수 없는 탁월한 맛입니다.
# Address: 지번경상남도 거제시 고현동 961-80
# Count: 9
# Name: 쥬에
# Section: 서울-강북>이태원-한남동/독서당로, 세계음식>중식, 예약 가능주차장(있음), 와인, 백주, 커피, 차, 탄산수, 음료, http://www.instagram.com/jue_seoul,
# Rate: 평가중
# Description: ‘쥬에’는 광동식 요리를 선보이는 중식 파인 다이닝 레스토랑입니다. 화이트 톤으로 꾸며진 인테리어 속 도자기와 예술 작품들이 곳곳에 놓여 있어 고급스러운 분위기를 자아냅니다. 오독오독한 식감이 매력적인 목이버섯 무침과 바삭한 튀김이 아뮤즈 부쉬로 제공되어 본격적인 식사 전 입맛을 돋아줍니다. 대표 메뉴는 전채 요리인 돼지고기 바비큐를 시작으로 홍콩식 딤섬 4종, 아보카도 해산물 수프, 생선튀김, 탄탄면, 후식의 구성을 합리적인 가격으로 맛볼 수 있는 ‘런치 남작 코스’입니다. 그중에서도 달짝지근한 바비큐 소스를 발라 껍질은 바삭, 살점은 촉촉하게 구워낸 ‘돼지고기 바비큐’가 가장 인기입니다. 2인석부터 단체석, 프라이빗 룸까지 다양한 공간이 준비되어 모임을 하기에도 좋습니다.
# Address: 지번서울특별시 용산구 한남동 3-1
# Count: 2
# Name: 쮸즈
# Section: 서울-강남>신사-가로수길, 세계음식>중식, 주차장(없음), 맥주, 소주, 음료, https://www.facebook.com/jooos.dimsum,
# Rate: 4.5
# Description: 정통 광동식 딤섬과 홍콩식 면류를 한국에서 캐쥬얼하게 만나실 수 있는 레스토랑 입니다. 고소한 육수가 가득 담겨있는 소룡포 만두가 대표 메뉴입니다. 그 외에도 쇼마이, 딴딴면 등 다양한 현지의 맛을 제공합니다.
# Address: 지번서울특별시 강남구 신사동 540-4
# Count: 15
# Name: 수린
# Section: 서울-강남>압구정-도산공원/로데오, 한국음식>소구이/불고기, 예약 가능주차장(있음)룸 있음,
# Rate: 3.9
# Description: 도산공원의 울창한 숲이 보이는 전망좋은 곳에 위치한 100% 예약제로만 운영되는 고품격 한우 구이 전문레스토랑입니다. 4,6,8인실로 구성된 룸 3개만 운영하고 있으며 본앤브레드의 한우암소 1++ 고기만을 취급합니다. 룸마다 별도의 고기 굽는 시설이 되어 있고 레스팅 과정을 가쳐서 최상의 맛을 선사 합니다. 메뉴는 코스요리로만 제공되고 있으며 콜키지 프리이고 다양한 와인잔을 구비하여 술 종류에 맞게 서브해줍니다.
# Address: 지번서울특별시 강남구 신사동 649-7 아크로스 빌딩
# Count: 5
# Name: 웨스틴조선호텔 홍연
# Section: 서울-강북>시청, 세계음식>중식, 예약 가능주차장(있음)룸 있음, 맥주, 와인, 백주, 탄산수, 음료, https://www.josunhotel.com/hotel/westinSeoul.do,
# Rate: 3.9
# Description: ‘홍연’은 서울 시청 근처 웨스틴 조선호텔 로비에 있는 광둥식 요리 전문점입니다. 재료의 신선도를 강조하며 재료 본연의 향과 맛을 살려낸 음식을 선보입니다. 음식을 주문하면 목이버섯 무침, 오이지, 자차이가 밑반찬으로 제공됩니다. 홍식초로 버무린 목이버섯 무침의 새콤한 맛은 식사 전 입맛을 한껏 돋우어 줍니다. 대표 메뉴는 ‘자금성 코스’인데 성게알 두부 수프를 시작으로, 해삼 전복, 간장소스 메로 찜, 아스파라거스 소고기, 식사, 후식의 구성으로 이루어져 있습니다. 특히, 전복과 해삼이 통통하게 살이 올라 쫀득한 식감이 살아 있는 ‘해삼 전복’이 가장 인기. 코스 요리는 2인 이상 주문 가능하니 참고 바랍니다.
# Address: 지번서울특별시 중구 소공동 87-1 서울 웨스틴조선호텔 저층 로비
# Count: 12
# Name: 진남포면옥
# Section: 서울-강북>약수/옥수/금호, 한국음식>삼계탕/백숙/찜닭, 주차장(있음), 맥주, 소주, 전통주, 음료,
# Rate: 3.7
# ...
# Address: 지번서울특별시 용산구 한남동 32-25
# Count: 3
# Name: 스시고니
# Section: 서울-강남>압구정-도산공원/로데오, 세계음식>일식,
# Rate: 평가중
# Description: 스시조 출신의 조병곤 셰프가 진두지휘 하는 압구정의 하이엔드 오마카세입니다. 전체적인 구성이나 밥에 적초를 넣어 맛과 향을 내는 것 등에서 스시조의 향기를 어렴풋 느낄 수 있습니다. 원물의 손질 속도가 빨라 구경하는 재미가 있습니다. 많은 이들이 베스트로 꼽는 것은 바로 ‘전갱이’인데 시소와 실파를 다져 올린 고명이 셰프의 킥인 듯 황홀한 맛이 특징입니다. 좋은 와사비를 공수하여 매운맛이 세지 않으면서 와사비 특유의 향이 넘치도록 풍부한 것이 매력적인 곳입니다. 흠잡을 곳 없는 스시야입니다.
# Address: 지번서울특별시 강남구 신사동 635-7 스페이스데코
# Count: 1
# Name: 육회자매집
# Section: 서울-강북>종로, 한국음식>육회/육사시미, Take out예약 가능, 맥주, 소주, 전통주, 음료, https://www.instagram.com/uke.zamezip/,
# Rate: 4.0
# Description: 자매집(since1974)은 육회를 1,000원에 시작.광장시장을 육회의 성지로 만든 역사와 전통이 있는 육회집입니다.광장시장 오시면 꼭한번 드셔보세요.チャメチッはユッケひと皿1,000ウォンで販売し始めクァンジャンシジャンがユッケの聖地として作った歴史と伝統のあるユッケチッです。
# Address: 지번서울특별시 종로구 종로4가 177 제우빌딩
# Count: 67
# Name: 경상도식당
# Section: 서울-강북>을지로, 한국음식>돼지갈비, 주차장(없음), 맥주, 소주, 음료,
# Rate: 3.5
# Description: 특별한 간판 없이 펄럭거리는 천막에 큼직한 글씨로 상호가 적힌 ‘경상도식당’. 매장 앞, 새파란 플라스틱 테이블과 의자가 길게 놓인 풍경이 제대로 찾아왔음을 알립니다. ‘국내산 돼지갈비’ 메뉴 하나로 대를 이어오며 50년이 넘는 전통을 지켜오고 있습니다. 대표 메뉴 국내산 돼지갈비는 초벌구이해 놓은 돼지갈비를 손님상에 나가기 직전 연탄불에 한 번 더 구워 화끈한 불맛을 더합니다. 두툼하게 썰어 씹는 맛을 살린 돼지갈비는 씹을수록 입안 가득 짙게 맴도는 불 향이 매력적입니다. 달짝지근한 양념이 배어있는 갈비에 새콤한 초장을 곁들이면 중독적인 단짠의 맛을 경험할 수 있습니다. 갈비는 첫 주문과 추가 주문 상관없이 2인분 이상 주문이 가능합니다.
# Address: 지번서울특별시 중구 을지로6가 1-1
# Count: 17
# Name: 평래옥
# Section: 서울-강북>을지로, 한국음식>전골, 주차장(없음), 맥주, 소주, 전통주, 백주,
# Rate: 4.0
# Description: 1950년부터 시작한 이북음식 전문점입니다. 시원한 육수에 차갑게 식힌 닭고기와 메밀면 사리를 넣고 그 위에 얼갈이배추, 양배추, 마른 대추, 무 등의 야채를 올린 초계탕과 녹두 지짐이가 인기 메뉴입니다. 삶은 닭을 찢어 오이와 새콤하게 무친 닭무침은 기본찬으로도 제공됩니다. 평래옥은 서울미래유산 선정되었습니다. 평래옥의 문화유산은 서울시민의 기억과  감성이 담긴 가치 있는 근현대 문화유산으로서, 서울특별시 미래유산보존위원회가 서울 미래유산으로 선정하였습니다. 오전 11:00 ~ 14:30분 까지 매장앞 도로변 주차가능, 오후 18:00 ~ 20:00 까지 매장 앞 도로변 주차가능
# Address: 지번서울특별시 중구 저동2가 18-1
# Count: 76
# Name: 박서방순대국밥 삼성본점
# Section: 서울-강남>삼성동, 한국음식>순댓국/순대, Take out야외 좌석(없음)예약 불가룸 없음, 맥주, 소주, 음료,
# Rate: 3.7
# Description: ‘박서방순대국밥 삼성본점’은 매 식사 시간이면 순댓국을 찾는 사람들로 대기행렬을 이루는 곳입니다. 이 집의 순댓국은 국물이 보이지 않을 정도로 순대와 내장이 수북하게 들어가 있으며 그 위에 파, 깻잎, 들깻가루, 양념장을 얹어냅니다. 순댓국은 토렴해 제공되기 때문에 밥알과 육수가 조화롭게 어우러져 깊은 맛을 느낄 수 있습니다. 순대는 선지를 넣지 않고 갖은 채소와 당면으로만 채워 넣어 담백하게 즐길 수 있습니다. 공깃밥, 국, 머리 고기와 순대를 담은 한 접시가 제공되는 ‘순대정식’은 2인 이상 주문이 가능합니다. 롯데월드몰에 직영점도 운영 중이니 참고하면 좋겠습니다.
# 생방송투데이 빅데이터 랭킹 맛집!서울순댓국TOP5
# Address: 지번서울특별시강남구 삼성동 156-5
# Count: 15
# Name: 통일집
# Section: 서울-강북>을지로, 한국음식>소구이/불고기, 주차장(없음), 맥주, 소주, 전통주,
# Rate: 4.0
# Description: 드럼통 한우안심구이로 유명한 을지로 3가의 고깃집입니다. 아담하고 허름한 매장이 나름의 분위기를 냅니다. 겉절이와 무생채가 밑반찬으로 나오고 드럼통에 숯불을 사용하여 고기를 구워 먹습니다. 된장찌개도 인기가 좋습니다.
# Address: 지번서울특별시 중구 을지로3가 202
# Count: 66
# Name: 이조보쌈
# Section: 서울-강남>당산역, 한국음식>족발/보쌈, Take out주차장(있음),
# Rate: 3.8
# Description: 하얀 바탕에 투박하게 글씨체로 쓰인 간판에서 노포 포스가 느껴지는 ‘이조보쌈’ 입니다. 대표 메뉴 ‘오징어 보쌈’은 부드럽게 삶아낸 보쌈에 쫄깃쫄깃한 오징어, 달큰한 보쌈김치와 무김치를 한 접시에 담아냈습니다. 다양한 식감과 맛을 지닌 재료들을 입맛에 맞게 조합해 먹는 재미가 있습니다. 쿰쿰한 향을 풍기는 청국장이 서비스로 나와 푸짐함을 더합니다.
# Address: 지번서울특별시 영등포구 당산동6가 295
# Count: 57
# Name: 스시 시미즈
# Section: 서울-강남>압구정-도산공원/로데오, 세계음식>일식, , 와인,
# Rate: 4.0
# Description: 일본 분위기가 색다른 키노이 출신 김다운셰프와 마츠모토 출신 이광열셰프가 함께 오픈한 스시야로 깔끔하고 정제된 맛이 일본 느낌을 느끼기에 풍족합니다. 전체적으로 코스요리가 양도 많고 맛도 좋은 편입니다.
# Address: 지번서울특별시 강남구 신사동 631-18 지하 1층
# Count: 6
# Name: 창성옥
# Section: 서울-강북>숙대/남영/효창, 한국음식>해장국/국밥/육개장, Take out예약 가능, 맥주, 소주, 전통주,
# Rate: 3.5
# Description: 용문시장이 개장한 1948년부터, 시장 내 한 자리를 지켜오고 있는 ‘창성옥’. 서울미래유산으로 지정될 만큼 오랜 역사를 이어오고 있는 이곳은 용문동 해장국의 뿌리로 불립니다. 대표 메뉴 ‘해장국’은 가마솥에서 소뼈를 여러 번 삶아낸 육수에 된장으로 간을 맞춘 후 배추 속대, 선지, 소뼈가 어우러져 농후한 맛이 느껴집니다. 해장국 위에 올려진 파 양념장은 매콤하면서도 달짝지근한 맛을 더하며 맛을 한층 풍부하게 해줍니다. 얼큰한 국물에 고기와 선지를 더욱 푸짐하게 넣고 끓여낸 ‘뼈 전골’도 즐겨 찾습니다. 밥에 달걀 프라이를 추가하여 전골 국물을 얹어 비벼 먹는 방법도 많은 인기를 끌고 있습니다.
# Address: 지번서울특별시 용산구 용문동 25-16
# Count: 19
# Name: 페리지
# Section: 서울-강남>선릉역/선정릉역, 세계음식>이탈리안,
# Rate: 평가중
# Description: 미국의 요리학교 ‘CIA’를 거쳐 뉴욕, 샌프란시스코 등의 레스토랑의 경력을 가진 젊은 부부 셰프가 운영하는 ‘페리지’입니다. 상호 ‘PERIGEE’는 달이 지구에 가장 가까워지는 ‘근지점’이라는 뜻으로 한곳에 모여 음식과 와인으로 가까워지기를 바라는 의미를 담고 있습니다. 대표 메뉴 ‘Andarions with Lobster’는 밀가루에 사프란을 넣어 만든 반죽을 나선 형태로 꼬아 만든 안다리노스 생면에 비스크 소스를 넣고 볶은 뒤 랍스터를 얹어 마무리했습니다. 토마토와 성게를 넣은 비스크 소스는 생면 사이사이 배어들어 짙은 바다의 풍미를 느낄 수 있습니다. 쫄깃한 식감이 돋보이는 안다리노스 생면에 녹진한 비스크 소스와 랍스터의 숯 향이 만나 풍성한 맛과 식감을 살려줍니다.
# Address: 지번서울특별시 강남구 삼성동 114-40
# Count: 1
# Name: 서관면옥
# Section: 서울-강남>교대/서초/남부터미널, 한국음식>냉면/막국수, Take out예약 가능주차장(있음), 맥주, 소주, 전통주, http://www.instagram.com/seogwanmyeonog,http://seogwanmyeonog.kr,
# Rate: 4.2
# Description: ‘선주후면’의 대표 음식답게, 평양냉면에 고기가 듬뿍 들어간 안주 냉면인 ‘맛박이 냉면’을 내며 애주가들의 사랑을 받고 있는 곳입니다. 평양냉면은 국내산 한우 암소의 양지, 사태를 삶은 베이스에 지리산 흑돼지, 제주 토종닭을 삶은 육수를 혼합하여 육향이 진한 육수를 내는 것이 특징입니다. 면은 국내산 메밀로 매장에서 직접 자가제면합니다. 메밀면에 들기름을 비벼 먹는 ‘골동냉면’도 별미입니다. 들깨가루로 무친 버섯, 무나물 등의 재료를 함께 비며 입안에서 폭발하듯 터지는 고소한 풍미가 일품입니다.
# Address: 지번서울특별시 서초구 서초동 1675-5
# Count: 6
# Name: 스시산원
# Section: 서울-강남>선릉역/선정릉역, 세계음식>일식, 주차장(있음), 맥주,
# Rate: 4.1
# Description: 장성태 셰프가 오픈했던 곳으로 최근 리츠칼튼, 임페리얼팰리스 호텔 스시야에 있던 조규상 쉐프로 헤드셰프가 변경된 곳입니다. 메뉴는 셰프 특선인 런치, 디너 오마카세 메뉴 뿐이며 100% 예약제로 운영됩니다. 스시에 어울리는 다양한 사케도 준비되어 있습니다. 매장은 8~9명이 이용할 수 있는 기다란 스시카운터 테이블과 4명이 앉을 수 있는 룸으로 구성되어 있습니다.
# Address: 지번서울특별시 강남구 삼성동 142-7 LG선릉에클라트 A동 1층 1호
# Count: 9
# Name: 중앙해장
# Section: 서울-강남>삼성동, 한국음식>해장국/국밥/육개장, Take out야외 좌석(없음)예약 가능주차장(있음)룸 없음, 맥주, 소주, 전통주, 음료,
# Rate: 4.3
# Description: 강남구 삼성역 근처에 위치한 해장국 전문점 '중앙해장'입니다. 마장동에서 한우 부산물을 유통하는 중앙축산에서 문을 연 곳으로 매장도 넓고 푸짐한 양의 내장이 들어간 탕을 먹을 수 있는 곳입니다. 내포가 어마어마하게 들어 있는 해장국이 단연 인기 메뉴입니다. 해장은 물론이고, 간단한 식사나 모임에도 안성맞춤인 식당입니다.
# Address: 지번서울특별시 강남구 대치동 996-16 육인빌딩
# Count: 13
# Name: 윌로뜨
# Section: 서울-강남>청담동, 세계음식>프렌치, 예약 가능주차장(있음), 와인, https://www.instagram.com/hulotte_seoul/,
# Rate: 4.0
# Description: 이승준 셰프가 운영하는 곳으로 입맛을 돋우는 다양한 프렌치 요리가 준비되어 있습니다. 부르고 뉴스타일로 요리한 백골뱅이와 바삭한 파슬리 스펀지 케이크, 육즙을 한껏 머금은 한우 채끝살 구이, 쫀득한 식감과 탱글함이 일품인 생대구 구이, 고운 색감의 디저트 등으로 구성된 코스요리가 일품입니다.
# Address: 지번서울특별시 강남구 청담동 19-17
# Count: 5
# Name: 미쉬매쉬
# Section: 서울-강북>삼청동/북촌한옥마을, 세계음식>퓨전, 예약 가능주차장(있음), 맥주, 와인, 음료, http://www.mishmashkorea.com/,https://www.instagram.com/mishmashkorea,
# Rate: 3.8
# Description: ‘Mishmash’ 미쉬매쉬는 덴마크계 한국인 김민지가 셰프가 오너 셰프로 운영하는 곳 입니다. 유럽 식문화에 대한 이해를 바탕으로 모던 한식을 선보이며 2018빕 구르망에 선정되었습니다. 대표 메뉴 ‘포키포크’는 덴마크식 스타일로 조리한 보쌈으로 겉면은 바삭하면서도 속은 촉촉한 식감을 자랑합니다. 보쌈과 함께 마늘장아찌, 된장 리코타 치즈, 김치 마말레이드가 찬으로 준비되어 취향에 맞게 곁들여 먹으면 됩니다. 꽈리고추 장아찌에 튀김 반죽을 얇게 입혀 바삭하게 튀겨낸 ‘피클 튀김’도 인기 메뉴. 장아찌 특유의 새콤함과 튀김의 고소함이 모두 기분 좋게 어우러집니다.
# Address: 지번서울특별시 종로구 원서동 134-1
# Count: 6
# Name: 평양면옥
# Section: 서울-강남>논현/학동, 한국음식>냉면/막국수, Take out예약 가능주차장(있음), 맥주, 소주, 음료,
# Rate: 4.0
# Description: 3대를 걸쳐 내려온 이북식 평양냉면 전문점입니다. 메밀로 만든 면과 양지살로 낸 맑은 국물의 육수가 특징입니다. 자극적이지 않고 산뜻한 특유의 맛으로 많은 이들에게 사랑 받고 있습니다. 평양식 만두와 제육 등 냉면 외 다양한 메뉴도 준비되어 있습니다.
# Address: 지번서울특별시 강남구 논현동 66-2
# Count: 132
# Name: 삼거리먼지막 순대국
# Section: 서울-강남>구로/대림/가산/금천구, 한국음식>순댓국/순대, Take out예약 가능주차장(있음), 맥주, 소주, 음료, http://itvplus.co.kr/home6/sam/,
# Rate: 4.2
# Description: 150환의 가격으로 시작해 현재까지 5,000원의 가격을 유지하고 있는 이곳은 서울에서 가장 오래된 순댓국집입니다. 대표 메뉴 ‘순대국’은 빈속을 채워줄 뜨끈한 국물에 순대와 내장이 푸짐하게 담겨 나옵니다. 전통 방식으로 가마솥에서 뼈와 고기를 함께 온종일 우려낸 진한 육수는 구수하면서도 깊은 맛을 자랑합니다. 기호에 따라 다진 마늘을 국물에 넣어 먹으면 감칠맛을 함께 느낄 수 있습니다. 고기, 순대, 막창, 오소리감투 등 다양한 내장 종류를 한 번에 맛볼 수 있는 ‘안주’도 인기 메뉴입니다. 기본 국밥은 토렴 방식으로 제공되며, 밥이 따로 나오는 따로국밥 메뉴도 준비되어 있습니다.
# 생방송투데이 빅데이터 랭킹 맛집!  서울 순댓국TOP5
# Address: 지번서울특별시 영등포구 대림동 963-9
# Count: 86
# Name: 알척
# Section: 서울-강북>연남동, 세계음식>이탈리안, Take out예약 가능, 맥주, 와인, 탄산수, 음료, http://www.alchoc.kr,http://www.instagram.com/al.choc,http://www.facebook.com/AlChocSeoul,http://blog.naver.com/alchoc0925,
# Rate: 4.6
# Description: 이탈리아 베네치아 출신의 마르코 셰프가 이탈리아 여러 지역의 전통 요리를 바탕으로 음식을 만드는 ‘Al Choc’. 본토의 맛을 최대한 구현하기 위해, 치즈, 올리브 오일, 발사믹 식초, 파스타 등 대부분의 식재료들을 이탈리아에서 직접 공수해옵니다. 대표 메뉴 ‘카포나타 부라타’는 푸릇한 새싹 채소 위로, 불그스름한 채소 볶음, 하얀 부라타 치즈를 순서대로 올려 알록달록한 색감이 시선을 끕니다. 발사믹 식초가 뿌려진 바게트 위로 채소와 부라타 치즈를 올려 한입에 먹으면 채소의 은은한 단맛과 담백하면서도 고소한 치즈의 맛이 조화롭게 어울립니다. 이탈리아 와인부터 스페인 와인, 칠레 와인 등 음식에 곁들이기 좋은 주류도 다양하게 준비되어 있습니다.
# Address: 지번서울특별시 마포구 연남동 257-8
# Count: 17
# Name: 무수옥
# Section: 서울-강북>도봉/수락, 한국음식>육회/육사시미, Take out예약 가능주차장(있음),
# Rate: 4.1
# Description: 설랑탕과 내장탕, 육회비빔밥 등 다양한 메뉴를 판매하는 무수옥입니다. 별다른 양념 없이 무생채와 육회, 새싹 밥을 비벼먹는 육회비빔밥이 독특한 맛을 냅니다. 전용 주차장이 준비되어 있으니 참고 바랍니다.
# Address: 지번서울특별시도봉구 도봉동 600-4
# Count: 15
# Name: 유원설렁탕
# Section: 서울-강남>잠실/석촌호수, 한국음식>설렁탕/곰탕/갈비탕, 주차장(있음), 맥주, 소주, 전통주, 음료,
# Rate: 4.7
# Description: 30년 전통의 설렁탕 전문점입니다. 설렁탕은 고기가 푸짐하고 다른 곳보다 맑은 국물로 유명합니다. 넣어먹을 수 있는 깍두기 국물도 준비되어 있습니다. 재료 소진 시 영업을 조기 마감합니다.
# Address: 지번서울특별시 송파구 삼전동 3-3 금화빌딩
# Count: 11
# Name: 도우룸
# Section: 서울-강남>서래마을, 세계음식>이탈리안, Take out예약 가능주차장(있음), 와인,
# Rate: 3.7
# Description: 스와니예의 이준 셰프님이 방배동에 새롭게 오픈한 캐주얼 이탈리안 레스토랑으로, 손으로 직접 만드는 Artisan Pasta를 중심의 캐주얼 컨셉으로 운영됩니다. 모든 메뉴들이 단품으로 주문 가능하기에 부담없이 찾아갈 수 있다는 것도 하나의 장점입니다.
# Address: 지번서울특별시 서초구 방배동 797-20
# Count: 15
# Name: 목멱산방
# Section: 서울-강북>남산/후암동, 한국음식>비빔밥/돌솥밥/쌈밥, 예약 불가, 커피, 차, https://mmmroom.co.kr,https://mmmroom.co.kr/,
# Rate: 4.0
# Description: ‘목멱산방’은 남산의 운치를 바라보며 식사와 음료를 동시에 즐길 수 있는 카페 겸 식당입니다. 패스트푸드점을 표방한 전통 한식집으로 주문부터 정리까지 셀프로 이용됩니다. 대표 메뉴 ‘산방비빔밥’은 지리산 언저리에서 직접 채취한 나물과 매실청을 넣은 고추장이 함께 제공됩니다. 놋그릇에 밥을 담고 고명은 따로 나와 입맛에 맞게 비벼 먹을 수 있습니다. 순도 99.9%의 진한 들기름으로 버무린 나물에서 진한 고소함을 느낄 수 있습니다. 전통차와 한과 등 후식 메뉴도 준비되어 있으며, 식사 후 주문하면 할인을 받을 수 있으니 참고 바랍니다.
# Address: 지번서울특별시 중구 남산동2가 25-4 한남빌딩
# Count: 84
# Name: 보건옥
# Section: 서울-강북>을지로, 한국음식>소구이/불고기, Take out예약 가능주차장(없음), 맥주, 소주, 음료,
# Rate: 3.7
# Description: 방산시장 인근 골목길에 자리 잡은 ‘보건옥’. 매장 1층에 마련된 정육점에서 질 좋은 고기를 직접 썰어 손님상에 올립니다. 붉은빛 색감과 고소한 참기름 향이 눈과 코를 자극하는 ‘불고기’가 대표 메뉴로, 사골 육수에 버섯, 양파, 대파, 당근 등 여러 채소와 한우 전지 부위를 넣고 끓여냅니다. 은은한 단맛이 감도는 고기는 쌈 채소나 밑반찬으로 제공되는 파김치를 곁들여 먹기를 추천합니다. 자칫 느낄 할 수 있는 고기의 맛을 깔끔하게 잡아줍니다. 남은 국물에 소면을 넣거나 볶음밥으로 즐기는 것도 별미. 큼지막하게 썬 등심 부위를 감칠맛 가득한 특제 양념장에 버무린 ‘등심주물럭’도 인기 메뉴입니다.
# Address: 지번서울특별시 중구 주교동 89-1
# Count: 13
# Name: 마포원조떡볶이
# Section: 서울-강북>마포/공덕, 한국음식>떡볶이/라면/분식,
# Rate: 4.1
# Description: 마포에서 가장 오래된 떡볶이 원조 식당입니다. 긴 밀가루떡을 직접 가위로 잘라 먹는게 특징이며 달달하면서도 매운맛이 좋은 집입니다. 떡볶이 외 인기메뉴로는, 순대와 김밥이 있는데 속은 가득 차 있지만 단순한 맛의 김밥은 매콤달달한 국물에 듬뿍 적셔 먹으면 맛이 좋습니다.
# Address: 지번서울특별시 마포구 도화동 345-4
# Count: 15
# Name: Just Steak
# Section: 서울-강남>압구정-도산공원/로데오, 세계음식>스테이크, 예약 가능주차장(있음), 맥주, 와인, 커피, 차, 주스, 탄산수, 음료,
# Rate: 4.0
# Description: 이탈리아 요리 기관 ICIF 출신 셰프가 운영하는 스테이크 전문점 'Just Steak'입니다. 가게 내부는 모노톤으로 칠해져 있고 각기 다른 모양의 앤티크 가구로 차분하게 꾸며져 있습니다. 온도, 습도 등 조건을 맞춰 3주간 숙성시킨 드라이 에이징 방식으로 만든 티본스테이크가 대표 메뉴입니다. 이 외에도 오늘의 파스타, 애피타이저 등이 준비되어 있습니다.
# Address: 지번서울특별시 강남구 신사동 631-16
# Count: 59
# Name: 송화산시도삭면
# Section: 서울-강북>건대/자양/화양, 세계음식>중식, Take out예약 가능, 맥주, 소주, 백주, 음료, https://www.instagram.com/explore/locations/144822052872398/,
# Rate: 4.0
# Description: ‘송화산시도삭면’은 건대 차이나타운에 위치한 산시성 요리 전문점입니다. 하얼빈 출신의 사장님이 고향에서 먹던 맛을 고스란히 재현한 음식을 만나볼 수 있습니다. 대표 메뉴는 숙성 과정을 거친 두툼한 반죽을 즉석에서 칼로 썰어 만드는 ‘도삭면’. 칼로 비스듬히 썰어낸 면발은 바깥쪽과 안쪽의 두께가 달라 부드러우면서도 탄력적인 식감을 동시에 경험할 수 있습니다. 화자오와 산초, 팔각, 정향 등 다양한 향신료로 맛을 낸 국물은 이국적인 풍미와 탁 치고 올라오는 매콤함이 묘한 중독성을 자랑합니다. 쇼마이, 쇼룽포오 등 촉촉한 육즙이 매력적인 딤섬도 도삭면과 함께 즐겨 찾습니다.
# Address: 지번서울특별시 광진구 자양동 851-20
# Count: 5
# Name: 한성돈까스
# Section: 서울-강남>신사역, 세계음식>경양식/돈가스, Take out예약 가능주차장(있음), 음료, http://www.hansungdongas.com/,https://www.instagram.com/hansungdonkatsu/,
# Rate: 4.0
# Description: 신사역 사무실이 즐비한 골목 근처에 위치한 돈까스 맛집 '한성돈까스'입니다. 전통 일본식 돈까스에 한국적 요소를 더한 돈까스 전문점으로 30여년의 역사를 이어오고 있는 곳입니다. 이 곳의 돈까스는 양질의 돈육에 생 빵가루와 순식물성 기름을 고집해서 바삭하고 담백한 것이 특징이며, 조미료는 일체 사용하지 않습니다. 국내산 생등심을 저온숙성하여 만든 '돈까스'와 등심부위를 일정기간 wet aging 숙성하여 소고기 특유의 진한 맛과 뛰어난 육질이 일품인 '비후까스'가 인기 메뉴입니다. 특제 소스에 함께 나오는 겨자를 살짝 섞어 찍어 먹으면 더욱 특별한 매력을 느낄 수 있으므로 참고하면 좋겠습니다.
# Address: 지번서울특별시 서초구 잠원동 25-12 2층
# Count: 79
# Name: 땅코참숯구이 본점
# Section: 서울-강북>왕십리/마장/답십리, 한국음식>돼지갈비, 예약 가능주차장(없음), 맥주, 소주, 전통주, 음료,
# Rate: 3.6
# Description: 왕십리 행당시장 내에 위치하고 있는 '땅코 참숯 구이'입니다. 참숯 직화 조리 방식으로 고기를 무쇠판에 자주 뒤집어가며 빠르게 익혀 내는 것이 특징입니다. 불의 세기와 온도, 불판의 특성, 불판에 고기를 올리고 뒤집는 타이밍 그리고 커팅까지 모두 적절하게 이루어져 고기의 육즙이 잘 살아있습니다. 대표 인기 메뉴는 '생 삼겹살'와 '생 목살'. 숙련된 기술의 직원분이 직접 고기를 구워주는데, 고기 안에 육즙이 가득해 씹을 때마다 고소함과 함께 쫀득한 고기의 결을 느낄 수 있습니다. 신 김치와 목살을 썰어 넣고 매콤하게 끓여낸 서비스 비지찌개도 별미입니다. 대기 손님이 많아 식사 시간은 2시간으로 제한하고 있으니 참고 바랍니다.
# Address: 지번서울특별시 성동구 행당동 292-34
# Count: 15
# Name: 신미식당
# Section: 서울-강남>압구정, 한국음식>감자탕, 예약 가능주차장(있음), 맥주, 소주, 음료,
# Rate: 3.8
# Description: 압구정에서 20년 이상 한자리를 지켜온 노포로 ‘생 삼겹살’과 ‘감자탕’이 대표 인기 메뉴입니다. 깻잎과 파를 듬뿍 올려낸 감자탕은 묵직한 국물에 자극적인 맛이 특징입니다. 야들야들한 살코기는 진한 국물의 간이 잘 배어들어 흰쌀밥에 올려 매콤하게 무쳐낸 마늘장아찌와 곁들여 먹으면 그 맛이 일품입니다. 신미식당의 또 다른 인기 메뉴 ‘생 삼겹살’은 도톰한 두께에 살코기와 비계가 적절히 섞여 있어 솥뚜껑에 구워 먹으면 고소한 맛이 일품입니다. 함께 내어주는 잘 익은 김치와 무 절임, 마늘장아찌도 별미입니다. 삼겹살을 주문하면 뚝배기에 담긴 얼큰한 감자탕이 서비스로 제공됩니다.
# Address: 지번서울특별시 강남구 신사동 615 현대종합상가빌딩 1층
# Count: 64
# Name: 경동함흥냉면
# Section: 서울-강북>경희대/청량리/외대, 한국음식>냉면/막국수,
# Rate: 평가중
# Description: 경동시장의 25년 전통의 함흥냉면집으로 직접 반죽하여 만든 면을 즉석에서 뽑아 바로 쌂아 식혀서 그릇에 올리고 각종 고명과 시원한 육수를 넣어 내오는 집이다. 비빔냉면은 홍어무침을 사용하는데 아삭한 식감이 아주 좋다. 사이드메뉴로 홍어 무침을 내어 준다.
# Address: 지번서울특별시 동대문구 제기동 989-4
# Count: 1
# Name: 황평집닭곰탕
# Section: 서울-강북>충무로, 한국음식>삼계탕/백숙/찜닭, Take out불가예약 가능주차장(없음), 맥주, 소주, 전통주, 음료,
# Rate: 3.6
# Description: 닭찜, 닭전골, 닭내장탕 등 다양한 닭 요리를 맛볼 수 있는 ‘황평집’. 대표 메뉴 ‘닭곰탕’은 기름기 없이 맑고 담백한 국물을 자랑합니다. 닭 뼈에 통마늘을 넣고 오랜 시간 우려낸 육수는 닭 본연의 고소한 풍미를 온전히 느낄 수 있습니다. 쫄깃한 닭고기와 닭 껍질을 매콤새콤한 양념에 버무려 주는 ‘닭무침’은 주당들의 사랑을 받는 인기 안주 메뉴입니다.
# Address: 지번서울특별시 중구 인현동2가 135-13
# Count: 15
# Name: 팔레드신
# Section: 서울-강북>시청, 세계음식>중식, 예약 가능주차장(있음), 맥주, 백주, 차, 탄산수, 음료, http://www.lescapehotel.com/,
# Rate: 3.5
# 크롤링 이상 발생: 'NoneType' object has no attribute 'find'
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[104], line 64
#      61 new_elements_found = False
#      62 for rest_element in rest_elements:
#      63     # 링크 확보 후 세트에 저장
# ---> 64     element_id = rest_element.get_attribute('href')
#      65     if element_id in processed_elements:
#      66         continue
#
# File c:\Users\RYS\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:178, in WebElement.get_attribute(self, name)
#     176 if getAttribute_js is None:
#     177     _load_js()
# --> 178 attribute_value = self.parent.execute_script(
#     179     f"/* getAttribute */return ({getAttribute_js}).apply(null, arguments);", self, name
#     180 )
#     181 return attribute_value
#
# File c:\Users\RYS\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:414, in WebDriver.execute_script(self, script, *args)
#     411 converted_args = list(args)
#     412 command = Command.W3C_EXECUTE_SCRIPT
# --> 414 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File c:\Users\RYS\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File c:\Users\RYS\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: element not found
#   (Session info: chrome=126.0.6478.63); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF661D7EEA2+31554]
# 	(No symbol) [0x00007FF661CF7ED9]
# 	(No symbol) [0x00007FF661BB872A]
# 	(No symbol) [0x00007FF661BCADBD]
# 	(No symbol) [0x00007FF661BCB84A]
# 	(No symbol) [0x00007FF661BBF5BB]
# 	(No symbol) [0x00007FF661BCB888]
# 	(No symbol) [0x00007FF661BBF5BB]
# 	(No symbol) [0x00007FF661BBD326]
# 	(No symbol) [0x00007FF661BC11D8]
# 	(No symbol) [0x00007FF661C4D69B]
# 	(No symbol) [0x00007FF661C2D02A]
# 	(No symbol) [0x00007FF661C4C977]
# 	(No symbol) [0x00007FF661C2CDD3]
# 	(No symbol) [0x00007FF661BFA33B]
# 	(No symbol) [0x00007FF661BFAED1]
# 	GetHandleVerifier [0x00007FF662088B1D+3217341]
# 	GetHandleVerifier [0x00007FF6620D5AE3+3532675]
# 	GetHandleVerifier [0x00007FF6620CB0E0+3489152]
# 	GetHandleVerifier [0x00007FF661E2E776+750614]
# 	(No symbol) [0x00007FF661D0375F]
# 	(No symbol) [0x00007FF661CFEB14]
# 	(No symbol) [0x00007FF661CFECA2]
# 	(No symbol) [0x00007FF661CEE16F]
# 	BaseThreadInitThunk [0x00007FFEA3B4257D+29]
# 	RtlUserThreadStart [0x00007FFEA56EAF28+40]

# %%
df = pd.DataFrame({
    'Name': names,
    'Section': sections,
    'Price': prices,
    'Address': addresses,
    'Rate': rates,
    'Intro': descriptions,
    'Review_count': review_counts,
    'Review_info' : review_descrip
    
})

df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 df = pd.DataFrame({
#       2     'Name': names,
#       3     'Section': sections,
#       4     'Price': prices,
#       5     'Address': addresses,
#       6     'Rate': rates,
#       7     'Intro': descriptions,
#       8     'Review_count': review_counts,
#       9     'Review_info' : review_descrip
#      10
#      11 })
#      13 df
#
# File c:\Users\RYS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File c:\Users\RYS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\RYS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File c:\Users\RYS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
print(review_descrip)
# Out:
# [{0: '맛잇엇어요 분위기도 서비스도 괜찬앗음', 1: '설화생갈비 최고급 잘먹엇어요', 2: '고기 좋으네요 맛잇어요', 3: '괜찮은집', 4: '잠바에 운동화 신고 밥먹으러 갔다가.. 차별대우 받고... 쩝쩝\n김정숙대리님..담에는 좀 친절히 대해 주세요', 5: '만족스러웠습니다.', 6: '오늘의고기는 그날그날 들어오는거에따라 구성도가 살짝씩바뀌는데, 고기이름이 귀에 안들어옴ㅋㅋㅋㅋㅋ마블링보자마자 그냥 이성잃고 먹게됩니다. 고기맛은 확실히 보장함', 7: '벽제갈비는 가족외식장소로 추천드리고싶어요~ ㅎㅎㅎ 금액대비 두명이오기엔 음식양도 많은데다가 가격도있기에 ㅎㅎㅎ 이것저것 다양하게 뜯고즐기고싶다면 가족이서 방문추천합니다~', 8: '대낮부터 밥으로 고기를먹는게 내몸에게 미안하지만…. 방이동주민으로써 벽제갈비는 밥집이나 다름없는곳이기에… 뭐.. 맛있으면 된거아닌가? 아몰랑 걍먹어', 9: '점심가격으로도 착하진않은데 음식이맛있다보니 자꾸자꾸생각나요!반찬들도 다양하게 맛볼수있게 조금씩 골고루나와요~! 오히려 금액대비 실속있던맛집이라 생각해요!!^^', 10: '설화생갈비 지방이 너무 많아서인지 느끼하고.. 사실 서비스, 분위기, 밑반찬 그리고 고기질 모두 1인분 89천원 가치는 아님. 5~7만원정도가 적당할 듯.. 비싼집으로 인식되어 오히려 덕보는 집. (접대등의 이유?) 암튼 개인의 취향이겠지만 간혹 갈때마다 후회하는 곳.. 그나마 다른 부위, 식사류는 그래도 나은편.', 11: "벽제갈비 진짜 맛있어요'-' 생갈비 진짜맛있어요 ㅋㅋ값어치 하는 집입니다. 진짜", 12: '주차장이 만차라, 힘들게 들어갔어요. 기다린 만큼의 맛이 보장되네요!', 13: '첫 월급으로 부모님께 무슨 음식을 대접할까 고민하다가 선택했어요. 부모님이 너무 좋아하십니다.', 14: '역시 고기에는 냉면이다. 여기는 고기가 입에서 사르르 녹고, 냉면을 후루룩 빨려들어가고.. 끝맛도 깔끔', 15: '친구랑 가서 먹었눈데 가족외식으로 딱이더라구요!! 담에 부모님이랑 같이 갈 예정 ㅋㅋㅋㅋ 맛있어용~', 16: '냉면이 특이하게 백김치랑 나왔었는데 완전 기대 이상이라 놀랐어요. 고기도 너무 맛있고 냉면까지 대박이였어요 0_0', 17: '양념의 단 맛을 싫어했었는데, 지인의 추천으로다녀왔어요. 너무 달지 않고 적당한 갈비의 맛이 너무 만족스럽습니다.', 18: '갈비집이지만 갈비뿐아니라 순면의 맛또한 끝내줘요!! 국물이 끝내줘요!! ㅎㅎ', 19: '고기먹고 진짜 감동받아서 ㅜㅜ 송파사는 친구 꼬셔서 며칠뒤에 또 갔어요 ㅋㅋㅋㅋㅋ 완전 양념이 너무 맛있어용!!!!!!!!!!!', 20: '소문듣고 갔는데 역시 실망시키지 않았음요 ㅋㅋㅋㅋ 진짜 양 푸짐하고 배불러요 냉면 강추 ㅋㅋㅋ', 21: '매장이 크고 깔끔해서 좋았고 고기도 진짜 맛있었어요!!! 가족끼리 갈때 좋을듯', 22: '1++ 최고급 한우만 취급한다는 이곳!! 진짜 맛있었어요 완전 강추!!!!', 23: '양념이 약간 달지만 냉면이랑 먹으니 괜춘^^', 24: '비즈니스 모임하기에도 적당한곳이에요~~~', 25: '봉피양 냉면과 함께 미디엄레어로 구운 갈비의 육즙이 뚝뚝~ 식욕이 왕성 해졌어요.', 26: '맛집이란 저렴하면서 맛있고 친절해야한다. 여긴 비싸고 맛있고 친절함은 교육받은 정도. 마음이 느껴지지 않는다. 이 가격에 이 수준은 보통이라 생각한다', 27: '날씰과 씨실의 교차한 모양으로 촘촘한 칼집을 내 양념이 쏙쏙!! 먹기 전에 어찌나 군침이 돌든지..', 28: '금수저에 접시까지 뭔가 전통의 맛이 느껴질거 같은 느낌 아이들도 좋아하더라구요. 다음에 또 가족 식사 자리를 잡기에 좋을거 같아요.', 29: '고기 좋아하시는 분은 꼭 벽제갈비로 드시길', 30: '와 생갈비 빛깔이 예사롭지 않ㅇ던디~ 입에 넣으면 그냥 녹아버려', 31: '최상급의 한우 먹고싶은사람은 꼭 가보는것이 좋을듯 bb', 32: '반찬들이 푸짐하더라구요!! 맛도 깔끔하고!! 진짜 배부르게 먹고 왔네요. 담에 또 갈 의양있어요 +_+', 33: '고기는 냉면이랑 같이 먹어야해요,. 이거슨 진리', 34: '나름 식사시간보다 일찍 갔는데 사람들이 완전 바글바글 하더라구요. 딱 보면 맛집인지 알겠음ㅋㅋㅋㅋ 고기랑 냉면 같이 드셔야함', 35: '부드럽게 씹히는 육질이 아주 좋았습니다 .한점한점이행복했 ㅠㅠㅠㅠㅠ또 먹고 싶다 하…', 36: '벽제갈비 밑반찬으로 같이 나오는  김치랑 같은 먹어도 좋앙', 37: '밑반찬들도 정성스러워보이고 맛도 좋던데요. 특히 우엉조림괜찮아요 밑반찬 먹고있을때 나온 꽃등심은 왜 꽃등심꽃등심하는지 알겠더라고요. 고급짐', 38: '위치도 편하고 발렛 주차가 가능한 식당!! 아무래도 갈비다 보니 가격이 있겠거니 했지만, 밑반찬부터 만족만족! 잊을 수없는 육즙의 맛이예요 ㅎㅎ', 39: '평양 비빔냉면 기대하지 않고 먹었는데 맛있더라고요~ 원래 냉면 잘 안먹는 편인데 잘먹었어요', 40: '직원분들도 친절하시고 맛집인지 모르고 갔는데 나름 유명하더라구요. 담에 고기 땡길때 여기로 갈꺼에요 ㅋㅋㅋㅋㅋ', 41: '밑반찬부터 후식까지 뭐 하나 트집잡을 곳이 한 군데도 없는 완벽한 맛집이예요!!', 42: '부모님들도 좋아라 하실 만한 맛집', 43: '고기가 부들럽고 칼집이 숑숑 나있어 먹기 편합니다', 44: '술술 끊기는 100% 순면은 아니지만 메밀향이 풍부함이로다', 45: '특상한우 양념갈비도 맛있음 히히비싸서 많이는 못 주문했지만... 짧지만 행복했음 ㅠㅠㅠㅠ', 46: '평양냉면 처음으로 먹어봤는데 심심한 육수에 메밀가루로 만든 면이라서 일반 빙초산 냉면과는 맛이 다릅디다', 47: '여기 식객만화에서 본적있지아나요?ㅋㅋㅋ꼭 가보고싶었던곳이어느데 실제 가보니 고기가 진짜 부드러워어', 48: '우리나라 갈비집 중 손가락안에 단연 꼽히는 벽제갈비가 입 안에서 살살 녹으니 더 바랄 것이 없어요', 49: '갈비는 칼집이 나있어서 훨씬 더 먹음직 스러웠던', 50: '후식으로 과일과 오미자 차가 나오는데 깔끔하고 정갈한 서비스에 기분이 좋았어요 ㅎㅎ', 51: '여긴 무조건 고기먹고 냉면 시켜야함ㅋㅋㅋㅋㅋ 고기 남겨 놓고 냉면이랑 드셔보세요 대박', 52: '얼마전에 방문했던 봉피양이 옆에 보인다. 한 건물로 크게되어 있는 벽제 갈비에 정갈한 밑반찬에.. 삼삼하니 좋았다.  고기도 소스에 짝어서 먹으니까 맛있다.', 53: '갈비와 함께 냉면 먹으면 좋을듯(?) 물냉으로 먹었는데 깔끔했다', 54: '최고급 한우를 사용하였다는 글귀를 보니 가격이 이해가 되네요. 맛은 정말 보장합니다!', 55: '아이가 기운이 너무 없는 거같아 몸보신을 할겸 평소 좋아하던 갈비를 먹으러 갔어요. 너무 좋아하더라구요^^영양만점입니다', 56: '벽제갈비 만화 식객의 배경이 된 곳이라고 해서 정말 기대헀는데!!! 기대한만큼 맛있네요', 57: '아 진짜 고기 입에 넣자마자 스르륵 녹아요. 진심 양념 대박….. 굽자마자 순식간에 사라짐ㅋㅋㅋ 강추', 58: '가격이 저렴한 편은 아니지만 솔직히 가격값 하는거 같아요. 고기가 정말 싱싱하고 마블링이 좋더라구요!!! 입에서 살살', 59: '강추 강추!! ㅋㅋㅋㅋ 맛집 인정합니다 ㅋㅋㅋㅋ 친절하게 해주셔서 감사해용', 60: '질 좋은 참숯을 이용한답니다. 자고로 참숯에 구운 갈비가 짱임', 61: '음식점에 와인종류도 많고 서비스도 짱입니다. 반찬이 비면 알아서 채워주는 직원분들의 센스까지.', 62: '한우 전문점에서도 새가리르 보기 쉽지 않은데 가격이 그리 싼편은 아니지만 어디서든 맛볼수 있는게 아니기에…..', 63: '숯향도 나고 고기 한점이 보들보들하고 부드러워 내스타일인것 같음', 64: '비싸서 자주는 못 갈 것 같지만 중요한 손님이나 모실 때 제격인 곳 !!!', 65: '고기 푸짐히 먹고 싶을땐 벽제갈비로 고고ㅋㅋㅋㅋ 밤에 자꾸 생각남 ㅜㅜ 양념맛잇어요 ㅜㅜ', 66: '예나제나 맛에는 변함이 없는거같군요..', 67: '굽는데 침이 꼴깍꼴깍 ~ 부드럽게 씹히는 육질이 아주 좋았어요 ㅎㅎ', 68: '인테리어도 깔끔, 맛도 최고, 서비스도 최고, 별 4개정도 드리고 싶은 식당입니다.', 69: '이쁜접시에다가 깔끔한 인테리어가 ...
