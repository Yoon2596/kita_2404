# %% [markdown]
# <a href="https://colab.research.google.com/github/Yoon2596/kita_2404/blob/main/m3_%EB%B6%84%EC%84%9D_%EB%9D%BC%EC%9D%B4%EB%B8%8C%EB%9F%AC%EB%A6%AC/%EA%B3%BC%EC%A0%9C/%EA%B3%BC%EC%A0%9C_0604.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task4. 2023년 1월 1일부터 2023년 12월 31일까지의 날짜 범위를 생성하고, 이 날짜 범위에서 매월 첫 번째 날만 포함하는 데이터프레임을 작성하세요.

# %%
import numpy as np
import pandas as pd

t1 = pd.date_range(start='2023/01/01', end='2023/12/31', freq='MS')
print(t1)
t1df = pd.DataFrame(t1, columns=['firstday_of_Month'])
print(t1df)
# Out:
# DatetimeIndex(['2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01',
#                '2023-09-01', '2023-10-01', '2023-11-01', '2023-12-01'],
#               dtype='datetime64[ns]', freq='MS')
#    firstday_of_Month
# 0         2023-01-01
# 1         2023-02-01
# 2         2023-03-01
# 3         2023-04-01
# 4         2023-05-01
# 5         2023-06-01
# 6         2023-07-01
# 7         2023-08-01
# 8         2023-09-01
# 9         2023-10-01
# 10        2023-11-01
# 11        2023-12-01

# %% [markdown]
# Task5. 2020년부터 2025년까지의 분기별 기간 범위를 생성하고, 각 분기의 시작과 끝 날짜를 포함하는 데이터프레임을 작성하세요.

# %%
t2 = pd.period_range('2020Q1','2025Q4', freq='Q', )
print(t2, '\n')

# t2 = pd.date_range('2020Q1','2025-12', freq='Q')
# print(t2)
dft2 = pd.DataFrame({
    'quarter' : t2,
    'start_date' : t2.start_time.date,
    'end_date' : t2.end_time.date
})
print(dft2)
# Out:
# PeriodIndex(['2020Q1', '2020Q2', '2020Q3', '2020Q4', '2021Q1', '2021Q2',
#              '2021Q3', '2021Q4', '2022Q1', '2022Q2', '2022Q3', '2022Q4',
#              '2023Q1', '2023Q2', '2023Q3', '2023Q4', '2024Q1', '2024Q2',
#              '2024Q3', '2024Q4', '2025Q1', '2025Q2', '2025Q3', '2025Q4'],
#             dtype='period[Q-DEC]')
#
#    quarter  start_date    end_date
# 0   2020Q1  2020-01-01  2020-03-31
# 1   2020Q2  2020-04-01  2020-06-30
# 2   2020Q3  2020-07-01  2020-09-30
# 3   2020Q4  2020-10-01  2020-12-31
# 4   2021Q1  2021-01-01  2021-03-31
# 5   2021Q2  2021-04-01  2021-06-30
# 6   2021Q3  2021-07-01  2021-09-30
# 7   2021Q4  2021-10-01  2021-12-31
# 8   2022Q1  2022-01-01  2022-03-31
# 9   2022Q2  2022-04-01  2022-06-30
# 10  2022Q3  2022-07-01  2022-09-30
# 11  2022Q4  2022-10-01  2022-12-31
# 12  2023Q1  2023-01-01  2023-03-31
# 13  2023Q2  2023-04-01  2023-06-30
# 14  2023Q3  2023-07-01  2023-09-30
# 15  2023Q4  2023-10-01  2023-12-31
# 16  2024Q1  2024-01-01  2024-03-31
# 17  2024Q2  2024-04-01  2024-06-30
# 18  2024Q3  2024-07-01  2024-09-30
# 19  2024Q4  2024-10-01  2024-12-31
# 20  2025Q1  2025-01-01  2025-03-31
# 21  2025Q2  2025-04-01  2025-06-30
# 22  2025Q3  2025-07-01  2025-09-30
# 23  2025Q4  2025-10-01  2025-12-31

# %% [markdown]
# Task6. 0일부터 10일까지의 시간 범위를 12시간 간격으로 생성하고, 각 간격에 대해 누적 시간을 계산하여 데이터프레임을 작성하세요.

# %%
# t3 = pd.date_range('2024-01-01', '2024-01-10', freq= '12h')
# print(t3)
# df_t3 = pd.DataFrame(np.arange(19), index=t3, columns=['value'])
# df_t3


# 시간 범위 생성 (0일 부터 10일까지 12시간 간격)
# start_date = pd.to_datetime('2024-01-01')
# end_date = pd.to_datetime('2024-01-11')
# date_range = pd.date_range(start=start_date, end=end_date, freq='12H')

# # 시간 차이 계산 (timedelta)
# timedelta_range = date_range - start_date
# import pandas as pd

# 시간 범위 생성 (0일 부터 10일까지 12시간 간격)
timedelta_range = pd.timedelta_range(start=0, end='10D', freq='12H')

# 데이터 생성
df = pd.DataFrame({
    'timedelta' : timedelta_range,
    'cumulative_time' : [timedelta.total_seconds() / 3600 for timedelta in timedelta_range]  # 누적시간을 시간 단위로 계산
})
print(df)
# Out:
#           timedelta  cumulative_time
# 0   0 days 00:00:00              0.0
# 1   0 days 12:00:00             12.0
# 2   1 days 00:00:00             24.0
# 3   1 days 12:00:00             36.0
# 4   2 days 00:00:00             48.0
# 5   2 days 12:00:00             60.0
# 6   3 days 00:00:00             72.0
# 7   3 days 12:00:00             84.0
# 8   4 days 00:00:00             96.0
# 9   4 days 12:00:00            108.0
# 10  5 days 00:00:00            120.0
# 11  5 days 12:00:00            132.0
# 12  6 days 00:00:00            144.0
# 13  6 days 12:00:00            156.0
# 14  7 days 00:00:00            168.0
# 15  7 days 12:00:00            180.0
# 16  8 days 00:00:00            192.0
# 17  8 days 12:00:00            204.0
# 18  9 days 00:00:00            216.0
# 19  9 days 12:00:00            228.0
# 20 10 days 00:00:00            240.0

# %% [markdown]
# Task7. 주어진 df 에서 특정 날짜 이후의 데이터를 필터링하세요.

# %%
import pandas as pd

# 데이터프레임 생성
df = pd.DataFrame({
    'date': ['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04', '2022-01-05'],
    'value': [1, 2, 3, 4, 5]
})
df['date'] = pd.to_datetime(df['date'])
df
# Out:
#         date  value
# 0 2022-01-01      1
# 1 2022-01-02      2
# 2 2022-01-03      3
# 3 2022-01-04      4
# 4 2022-01-05      5

# %%
print(df[::2], '\n')
print(df[:2], '\n')
print(df[1:4], '\n')

filtered_df = df[df['date'] > '2022-01-02']
print(filtered_df)
# Out:
#         date  value
# 0 2022-01-01      1
# 2 2022-01-03      3
# 4 2022-01-05      5
#
#         date  value
# 0 2022-01-01      1
# 1 2022-01-02      2
#
#         date  value
# 1 2022-01-02      2
# 2 2022-01-03      3
# 3 2022-01-04      4
#
#         date  value
# 2 2022-01-03      3
# 3 2022-01-04      4
# 4 2022-01-05      5

# %% [markdown]
# Task8. 주어진 df에서 월별로 데이터의 합계를 계산하세요.

# %%
import pandas as pd

# 데이터프레임 생성
df = pd.DataFrame({
    'date': ['2022-01-01', '2022-01-15', '2022-02-01', '2022-02-15', '2022-03-01'],
    'value': [1, 2, 3, 4, 5]
})

df['date'] = pd.to_datetime(df['date'])
df
# Out:
#         date  value
# 0 2022-01-01      1
# 1 2022-01-15      2
# 2 2022-02-01      3
# 3 2022-02-15      4
# 4 2022-03-01      5

# %%
# 월별 데이터 집계
df['month'] = df['date'].dt.to_period('M')
df
# Out:
#         date  value    month
# 0 2022-01-01      1  2022-01
# 1 2022-01-15      2  2022-01
# 2 2022-02-01      3  2022-02
# 3 2022-02-15      4  2022-02
# 4 2022-03-01      5  2022-03

# %%
monthly_sum = df.groupby('month')['value'].sum().reset_index()
print(monthly_sum)
# Out:
#      month  value
# 0  2022-01      3
# 1  2022-02      7
# 2  2022-03      5

# %% [markdown]
# Task9. 주어진 데이터프레임에서 주말(토요일과 일요일) 데이터를 필터링하세요.

# %%
import pandas as pd

# 데이터프레임 생성
df = pd.DataFrame({
    'date': ['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-08', '2022-01-09'],
    'value': [1, 2, 3, 4, 5]
})
df['date'] = pd.to_datetime(df['date'])
df
# Out:
#         date  value
# 0 2022-01-01      1
# 1 2022-01-02      2
# 2 2022-01-03      3
# 3 2022-01-08      4
# 4 2022-01-09      5

# %%
# 주말 데이터 필터링
df['day_of_week'] = df['date'].dt.dayofweek
df
# Out:
#         date  value    month  day_of_week
# 0 2022-01-01      1  2022-01            5
# 1 2022-01-15      2  2022-01            5
# 2 2022-02-01      3  2022-02            1
# 3 2022-02-15      4  2022-02            1
# 4 2022-03-01      5  2022-03            1

# %%
weekend_df = df[df['day_of_week'] >= 5]
print(weekend_df)
# Out:
#         date  value    month  day_of_week
# 0 2022-01-01      1  2022-01            5
# 1 2022-01-15      2  2022-01            5

# %% [markdown]
# Task10. 주어진 df에서 분기별 데이터의 평균을 계산하세요.

# %%
import pandas as pd

# 데이터프레임 생성
df = pd.DataFrame({
    'date': ['2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01'],
    'value': [1, 2, 3, 4, 5]
})
df['date'] = pd.to_datetime(df['date'])

df
# Out:
#         date  value
# 0 2022-01-01      1
# 1 2022-02-01      2
# 2 2022-03-01      3
# 3 2022-04-01      4
# 4 2022-05-01      5

# %%
# 분기별 데이터 평균 계산
df['quarter'] = df['date'].dt.to_period('Q')
df
# Out:
#         date  value quarter
# 0 2022-01-01      1  2022Q1
# 1 2022-02-01      2  2022Q1
# 2 2022-03-01      3  2022Q1
# 3 2022-04-01      4  2022Q2
# 4 2022-05-01      5  2022Q2

# %%
quarterly_mean = df.groupby('quarter')['value'].mean().reset_index()
print(quarterly_mean)
# Out:
#   quarter  value
# 0  2022Q1    2.0
# 1  2022Q2    4.5

# %% [markdown]
# Task11. 주어진 df에서 작업 일자(월요일부터 금요일)만 남기고 필터링하세요.

# %%
import pandas as pd

# 데이터프레임 생성
df = pd.DataFrame({
    'date': ['2022-01-01', '2022-01-03', '2022-01-04', '2022-01-05', '2022-01-08', '2022-01-09'],
    'value': [1, 2, 3, 4, 5, 6]
})
df['date'] = pd.to_datetime(df['date'])
df
# Out:
#         date  value
# 0 2022-01-01      1
# 1 2022-01-03      2
# 2 2022-01-04      3
# 3 2022-01-05      4
# 4 2022-01-08      5
# 5 2022-01-09      6

# %%
# 작업 일지(월요일부터 금요일) 필터링
df['day_of_week'] = df['date'].dt.dayofweek
df
# Out:
#         date  value  day_of_week
# 0 2022-01-01      1            5
# 1 2022-01-03      2            0
# 2 2022-01-04      3            1
# 3 2022-01-05      4            2
# 4 2022-01-08      5            5
# 5 2022-01-09      6            6

# %%
workdays_df = df[df['day_of_week'] < 5]
print(workdays_df)
# Out:
#         date  value  day_of_week
# 1 2022-01-03      2            0
# 2 2022-01-04      3            1
# 3 2022-01-05      4            2
